# %% [markdown]
# ## 1. Environment Setup and Imports

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# Torch & GNN
import torch
from torch_geometric.nn import SAGEConv

# Custom modules
from load_elliptic_data import load_and_preprocess_elliptic_data
from data_utils_randomsplit import random_split
from model_sage import GraphSAGENet
from train_utils import set_seed, train_full, save_feature_experiment
from config import SEEDS

# Feature pipeline
from features.feature_config import FEATURE_CONFIGS
from features.feature_runner import apply_engineered_features
from features.feature_utils import prepare_graph_and_timestamps
from normalization import normalize_base_features_only

print("✓ All modules imported successfully.")
# Out:
# ✓ All modules imported successfully.

# %% [markdown]
# ## 2. Load and Preprocess the Elliptic Dataset + Graph for Features + Time Stamps
# This loads the PyG-formatted graph and base features. We also construct a NetworkX transaction graph for topology-based features. Per-node timestamp sequences is extracted for temporal burst analysis

# %%
from normalization import normalize_base_features_only
from features.feature_pipeline import generate_all_features
import os
import torch

# 1. Load graph
data = load_and_preprocess_elliptic_data("../elliptic_bitcoin_dataset", normalize=False)
print(f"✓ PyG Data object loaded: {data}")

# 2. Prepare NetworkX and timestamps
G_nx, node_timestamps = prepare_graph_and_timestamps(
    edgelist_path="../elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv",
    features_path="../elliptic_bitcoin_dataset/elliptic_txs_features.csv",
    num_nodes=data.num_nodes
)

# 3. Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ABLATORS = {
    k: v for k, v in FEATURE_CONFIGS.items()
}
FEATURED_DATA = {}

# 4. Loop through ablations and seeds
for ablation_name, feature_flags in ABLATORS.items():
    print(f"\n== Config: {ablation_name} ==")
    for seed in SEEDS:
        print(f"→ Seed {seed}")
        set_seed(seed)
        train_idx, val_idx = random_split(data, random_state=seed)

        # Clone and extract features
        data_exp = data.clone()
        X, feature_names = generate_all_features(data_exp, G_nx, node_timestamps, **feature_flags)
        data_exp.x = torch.tensor(X, dtype=torch.float)

        # Optional monitoring of temporal features
        temporal_names = {"temporal_lag", "component_size"}
        temporal_indices = [i for i, name in enumerate(feature_names) if name in temporal_names]

        if temporal_indices:
            print("→ Temporal features (raw)")
            print("  Means:", data_exp.x[:, temporal_indices].mean(0))
            print("  Stds :", data_exp.x[:, temporal_indices].std(0))

        # Normalize base features only
        data_exp.x = normalize_base_features_only(data_exp.x, feature_names)

        # Move to device
        data_exp = data_exp.to(device)

        # Store in memory
        FEATURED_DATA[(ablation_name, seed)] = {
            "data": data_exp,
            "train_idx": train_idx,
            "val_idx": val_idx,
            "feature_flags": feature_flags,
        }

        # Save to disk
        save_dir = f"../data/SAGE_randomsplit/{ablation_name}/seed_{seed}"
        os.makedirs(save_dir, exist_ok=True)
        torch.save(data_exp, os.path.join(save_dir, "data_exp.pt"))
        torch.save(train_idx, os.path.join(save_dir, "train_idx.pt"))
        torch.save(val_idx, os.path.join(save_dir, "val_idx.pt"))
        print(f"✓ Saved: {save_dir}")
        print(f"✓ Final shape: {data_exp.x.shape}")
# Out:
# ✓ PyG Data object loaded: Data(x=[203769, 166], edge_index=[2, 234355], y=[203769])
# Loaded directed graph with 203769 nodes and 234355 edges.
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Features DataFrame shape: (203769, 167)
# Number of features (excluding txId and time_step): 165
# Timestamps found for 203769 out of 203769 nodes.
# ✓ Time step range: 1.0 to 49.0
#
# == Config: base ==
# → Seed 42
# ✓ Saved: ../data/SAGE_randomsplit/base/seed_42
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 123
# ✓ Saved: ../data/SAGE_randomsplit/base/seed_123
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 777
# ✓ Saved: ../data/SAGE_randomsplit/base/seed_777
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 2023
# ✓ Saved: ../data/SAGE_randomsplit/base/seed_2023
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 31415
# ✓ Saved: ../data/SAGE_randomsplit/base/seed_31415
# ✓ Final shape: torch.Size([203769, 166])
#
# == Config: base+structural ==
# → Seed 42
# ✓ Saved: ../data/SAGE_randomsplit/base+structural/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# ✓ Saved: ../data/SAGE_randomsplit/base+structural/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# ✓ Saved: ../data/SAGE_randomsplit/base+structural/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# ✓ Saved: ../data/SAGE_randomsplit/base+structural/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# ✓ Saved: ../data/SAGE_randomsplit/base+structural/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: base+typology ==
# → Seed 42
# ✓ Saved: ../data/SAGE_randomsplit/base+typology/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# ✓ Saved: ../data/SAGE_randomsplit/base+typology/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# ✓ Saved: ../data/SAGE_randomsplit/base+typology/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# ✓ Saved: ../data/SAGE_randomsplit/base+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# ✓ Saved: ../data/SAGE_randomsplit/base+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+structural+typology ==
# → Seed 42
# ✓ Saved: ../data/SAGE_randomsplit/base+structural+typology/seed_42
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 123
# ✓ Saved: ../data/SAGE_randomsplit/base+structural+typology/seed_123
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 777
# ✓ Saved: ../data/SAGE_randomsplit/base+structural+typology/seed_777
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 2023
# ✓ Saved: ../data/SAGE_randomsplit/base+structural+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 31415
# ✓ Saved: ../data/SAGE_randomsplit/base+structural+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 172])
#
# == Config: base+basic_temporal ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 547250.57it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 449802.66it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 573170.68it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 526443.96it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 506381.47it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+basic_temporal+typology ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 488895.00it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal+typology/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 483401.12it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal+typology/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 514593.40it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal+typology/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 503444.56it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 505423.51it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/base+basic_temporal+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: all ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 521261.13it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/all/seed_42
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 580468.56it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/all/seed_123
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 571972.36it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/all/seed_777
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 555756.93it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/all/seed_2023
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 515449.34it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/SAGE_randomsplit/all/seed_31415
# ✓ Final shape: torch.Size([203769, 174])

# %%
import torch
import os

ROOT_DIR = "../data/SAGE_randomsplit"
BASE_DIM = 166
SEEDS = [42, 123, 777, 2023, 31415]

print("\n📊 ENGINEERED FEATURE INSPECTION (from disk)")

# Loop over ablation folders
for ablation_name in sorted(os.listdir(ROOT_DIR)):
    ablation_path = os.path.join(ROOT_DIR, ablation_name)
    if not os.path.isdir(ablation_path):
        continue

    for seed in SEEDS:
        seed_dir = f"seed_{seed}"
        data_path = os.path.join(ablation_path, seed_dir, "data_exp.pt")
        if not os.path.exists(data_path):
            print(f"⛔ Missing file: {data_path}")
            continue

        data = torch.load(data_path, map_location="cpu", weights_only=False)
        x = data.x

        if x.shape[1] <= BASE_DIM:
            print(f"\n {ablation_name} | Seed: {seed}")
            print(" No engineered features found.")
            continue

        engineered = x[:, BASE_DIM:]
        print(f"\n {ablation_name} | Seed: {seed}")
        print(f" Engineered feature count: {engineered.shape[1]}")

        means = engineered.mean(dim=0)
        stds = engineered.std(dim=0)

        for i in range(engineered.shape[1]):
            m = means[i].item()
            s = stds[i].item()
            sample_vals = engineered[:5, i].numpy()
            print(f"Feature {BASE_DIM + i:>3} | Mean: {m:8.4f} | Std: {s:8.4f} | Sample: {sample_vals}")
# Out:
# 📊 ENGINEERED FEATURE INSPECTION (from disk)
#
#  all | Seed: 42
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 123
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 777
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 2023
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 31415
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base | Seed: 42
#  No engineered features found.
#
#  base | Seed: 123
#  No engineered features found.
#
#  base | Seed: 777
#  No engineered features found.
#
#  base | Seed: 2023
#  No engineered features found.
#
#  base | Seed: 31415
#  No engineered features found.
#
#  base+basic_temporal | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+structural | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural+typology | Seed: 42
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 123
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 777
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 2023
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 31415
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]

# %% [markdown]
# ## 3. Initialize the GraphSAGE Model and Training
# Set hyperparameters and move model/data to GPU/CPU if available.

# %%
from model_sage import GraphSAGENet
from train_utils import train_full, save_feature_experiment
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SKIP_CONFIGS = {}

for (ablation_name, seed), bundle in FEATURED_DATA.items():
    if ablation_name in SKIP_CONFIGS:
        print(f"Skipping config: {ablation_name}")
        continue
    print(f"\n=== Training GraphSAGE (Random, No Class Weights): {ablation_name} | Seed: {seed} ===")

    data_exp = bundle["data"]
    train_idx = bundle["train_idx"]
    val_idx = bundle["val_idx"]
    feature_flags = bundle["feature_flags"]

    # 1. Model
    model = GraphSAGENet(
        in_channels=data_exp.x.shape[1],
        hidden_channels=64,
        out_channels=2,
        dropout=0.1
    ).to(device)

    # 2. Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # 3. Train
    model, *results = train_full(
        model=model,
        data=data_exp,
        train_idx=train_idx,
        val_idx=val_idx,
        optimizer=optimizer,
        num_epochs=300,
        patience=30
    )

    # 4. Save
    output_dir = f"../model_features/randomsplit/SAGE_ablation/{ablation_name}/seed_{seed}"
    os.makedirs(output_dir, exist_ok=True)

    save_feature_experiment(
        output_dir=output_dir,
        model=model,
        results=results,
        seed=seed,
        config={
            "model": "SAGE",
            "ablation_name": ablation_name,
            "feature_flags": feature_flags,
            "feature_dim": data_exp.x.shape[1],
            "dropout": 0.1,
            "num_epochs": 300,
            "patience": 30,
            "lr": 0.001,
            "weight_decay": 5e-4,
            "class_weights": None
        },
        val_idx=val_idx
    )
# Out:
# === Training GraphSAGE (Random, No Class Weights): base | Seed: 42 ===
# Epoch 001 | Loss: 0.6729 | Val Acc: 0.7946 | Val F1: 0.5936 | F1 Illicit: 0.8794
# Epoch 002 | Loss: 0.5554 | Val Acc: 0.8488 | Val F1: 0.6366 | F1 Illicit: 0.9143
# Epoch 003 | Loss: 0.4819 | Val Acc: 0.8753 | Val F1: 0.6590 | F1 Illicit: 0.9306
# Epoch 004 | Loss: 0.4300 | Val Acc: 0.8897 | Val F1: 0.6664 | F1 Illicit: 0.9393
# Epoch 005 | Loss: 0.3905 | Val Acc: 0.8971 | Val F1: 0.6667 | F1 Illicit: 0.9438
# Epoch 006 | Loss: 0.3617 | Val Acc: 0.9008 | Val F1: 0.6603 | F1 Illicit: 0.9461
# Epoch 085 | Loss: 0.1236 | Val Acc: 0.9655 | Val F1: 0.8920 | F1 Illicit: 0.9811
# Epoch 086 | Loss: 0.1233 | Val Acc: 0.9656 | Val F1: 0.8925 | F1 Illicit: 0.9812
# Epoch 087 | Loss: 0.1227 | Val Acc: 0.9659 | Val F1: 0.8933 | F1 Illicit: 0.9813
# Epoch 088 | Loss: 0.1225 | Val Acc: 0.9662 | Val F1: 0.8944 | F1 Illicit: 0.9815
# Epoch 089 | Loss: 0.1215 | Val Acc: 0.9662 | Val F1: 0.8944 | F1 Illicit: 0.9815
# Epoch 090 | Loss: 0.1205 | Val Acc: 0.9663 | Val F1: 0.8946 | F1 Illicit: 0.9815
# Epoch 091 | Loss: 0.1197 | Val Acc: 0.9666 | Val F1: 0.8956 | F1 Illicit: 0.9817
# Epoch 092 | Loss: 0.1189 | Val Acc: 0.9667 | Val F1: 0.8962 | F1 Illicit: 0.9818
# Epoch 093 | Loss: 0.1189 | Val Acc: 0.9666 | Val F1: 0.8958 | F1 Illicit: 0.9817
# Epoch 094 | Loss: 0.1183 | Val Acc: 0.9669 | Val F1: 0.8968 | F1 Illicit: 0.9818
# Epoch 095 | Loss: 0.1183 | Val Acc: 0.9670 | Val F1: 0.8972 | F1 Illicit: 0.9819
# Epoch 096 | Loss: 0.1175 | Val Acc: 0.9671 | Val F1: 0.8977 | F1 Illicit: 0.9820
# Epoch 097 | Loss: 0.1162 | Val Acc: 0.9673 | Val F1: 0.8982 | F1 Illicit: 0.9821
# Epoch 098 | Loss: 0.1163 | Val Acc: 0.9674 | Val F1: 0.8986 | F1 Illicit: 0.9821
# Epoch 099 | Loss: 0.1157 | Val Acc: 0.9675 | Val F1: 0.8990 | F1 Illicit: 0.9822
# Epoch 100 | Loss: 0.1145 | Val Acc: 0.9676 | Val F1: 0.8993 | F1 Illicit: 0.9822
# Epoch 101 | Loss: 0.1144 | Val Acc: 0.9679 | Val F1: 0.9003 | F1 Illicit: 0.9824
# Epoch 102 | Loss: 0.1138 | Val Acc: 0.9679 | Val F1: 0.9007 | F1 Illicit: 0.9824
# Epoch 103 | Loss: 0.1132 | Val Acc: 0.9681 | Val F1: 0.9012 | F1 Illicit: 0.9825
# Epoch 104 | Loss: 0.1128 | Val Acc: 0.9683 | Val F1: 0.9020 | F1 Illicit: 0.9826
# Epoch 105 | Loss: 0.1124 | Val Acc: 0.9686 | Val F1: 0.9030 | F1 Illicit: 0.9828
# Epoch 106 | Loss: 0.1115 | Val Acc: 0.9686 | Val F1: 0.9034 | F1 Illicit: 0.9828
# Epoch 107 | Loss: 0.1110 | Val Acc: 0.9691 | Val F1: 0.9052 | F1 Illicit: 0.9831
# Epoch 108 | Loss: 0.1111 | Val Acc: 0.9692 | Val F1: 0.9054 | F1 Illicit: 0.9831
# Epoch 109 | Loss: 0.1100 | Val Acc: 0.9696 | Val F1: 0.9067 | F1 Illicit: 0.9833
# Epoch 110 | Loss: 0.1102 | Val Acc: 0.9697 | Val F1: 0.9072 | F1 Illicit: 0.9834
# Epoch 105 | Loss: 0.1089 | Val Acc: 0.9644 | Val F1: 0.8913 | F1 Illicit: 0.9805
# Epoch 106 | Loss: 0.1081 | Val Acc: 0.9647 | Val F1: 0.8924 | F1 Illicit: 0.9806
# Epoch 107 | Loss: 0.1068 | Val Acc: 0.9649 | Val F1: 0.8932 | F1 Illicit: 0.9807
# Epoch 108 | Loss: 0.1073 | Val Acc: 0.9652 | Val F1: 0.8939 | F1 Illicit: 0.9809
# Epoch 109 | Loss: 0.1066 | Val Acc: 0.9657 | Val F1: 0.8954 | F1 Illicit: 0.9812
# Epoch 110 | Loss: 0.1067 | Val Acc: 0.9655 | Val F1: 0.8945 | F1 Illicit: 0.9810
# Epoch 111 | Loss: 0.1062 | Val Acc: 0.9655 | Val F1: 0.8945 | F1 Illicit: 0.9810
# Epoch 112 | Loss: 0.1047 | Val Acc: 0.9661 | Val F1: 0.8967 | F1 Illicit: 0.9814
# Epoch 113 | Loss: 0.1051 | Val Acc: 0.9671 | Val F1: 0.8999 | F1 Illicit: 0.9819
# Epoch 114 | Loss: 0.1045 | Val Acc: 0.9674 | Val F1: 0.9012 | F1 Illicit: 0.9821
# Epoch 115 | Loss: 0.1038 | Val Acc: 0.9675 | Val F1: 0.9015 | F1 Illicit: 0.9821
# Epoch 116 | Loss: 0.1035 | Val Acc: 0.9676 | Val F1: 0.9017 | F1 Illicit: 0.9822
# Epoch 117 | Loss: 0.1025 | Val Acc: 0.9675 | Val F1: 0.9012 | F1 Illicit: 0.9821
# Epoch 118 | Loss: 0.1018 | Val Acc: 0.9676 | Val F1: 0.9011 | F1 Illicit: 0.9822
# Epoch 119 | Loss: 0.1017 | Val Acc: 0.9677 | Val F1: 0.9017 | F1 Illicit: 0.9823
# Epoch 120 | Loss: 0.1010 | Val Acc: 0.9679 | Val F1: 0.9025 | F1 Illicit: 0.9824
# Epoch 121 | Loss: 0.1003 | Val Acc: 0.9684 | Val F1: 0.9041 | F1 Illicit: 0.9826
# Epoch 122 | Loss: 0.0995 | Val Acc: 0.9686 | Val F1: 0.9052 | F1 Illicit: 0.9828
# Epoch 123 | Loss: 0.0985 | Val Acc: 0.9684 | Val F1: 0.9042 | F1 Illicit: 0.9826
# Epoch 124 | Loss: 0.0996 | Val Acc: 0.9684 | Val F1: 0.9039 | F1 Illicit: 0.9826
# Epoch 125 | Loss: 0.0988 | Val Acc: 0.9684 | Val F1: 0.9041 | F1 Illicit: 0.9826
# Epoch 126 | Loss: 0.0980 | Val Acc: 0.9687 | Val F1: 0.9053 | F1 Illicit: 0.9828
# Epoch 127 | Loss: 0.0972 | Val Acc: 0.9691 | Val F1: 0.9069 | F1 Illicit: 0.9830
# Epoch 128 | Loss: 0.0976 | Val Acc: 0.9694 | Val F1: 0.9078 | F1 Illicit: 0.9831
# Epoch 129 | Loss: 0.0965 | Val Acc: 0.9694 | Val F1: 0.9077 | F1 Illicit: 0.9831
# Epoch 130 | Loss: 0.0961 | Val Acc: 0.9691 | Val F1: 0.9069 | F1 Illicit: 0.9830
# Epoch 287 | Loss: 0.0591 | Val Acc: 0.9766 | Val F1: 0.9307 | F1 Illicit: 0.9871
# Epoch 288 | Loss: 0.0594 | Val Acc: 0.9772 | Val F1: 0.9321 | F1 Illicit: 0.9874
# Epoch 289 | Loss: 0.0587 | Val Acc: 0.9774 | Val F1: 0.9328 | F1 Illicit: 0.9875
# Epoch 290 | Loss: 0.0580 | Val Acc: 0.9772 | Val F1: 0.9322 | F1 Illicit: 0.9874
# Epoch 291 | Loss: 0.0593 | Val Acc: 0.9770 | Val F1: 0.9320 | F1 Illicit: 0.9873
# Epoch 292 | Loss: 0.0582 | Val Acc: 0.9775 | Val F1: 0.9333 | F1 Illicit: 0.9876
# Epoch 293 | Loss: 0.0581 | Val Acc: 0.9776 | Val F1: 0.9334 | F1 Illicit: 0.9877
# Epoch 294 | Loss: 0.0581 | Val Acc: 0.9776 | Val F1: 0.9335 | F1 Illicit: 0.9877
# Epoch 295 | Loss: 0.0579 | Val Acc: 0.9772 | Val F1: 0.9326 | F1 Illicit: 0.9874
# Epoch 296 | Loss: 0.0582 | Val Acc: 0.9772 | Val F1: 0.9324 | F1 Illicit: 0.9874
# Epoch 297 | Loss: 0.0574 | Val Acc: 0.9773 | Val F1: 0.9326 | F1 Illicit: 0.9875
# Epoch 298 | Loss: 0.0585 | Val Acc: 0.9772 | Val F1: 0.9323 | F1 Illicit: 0.9875
# Epoch 299 | Loss: 0.0574 | Val Acc: 0.9772 | Val F1: 0.9325 | F1 Illicit: 0.9875
# Epoch 300 | Loss: 0.0568 | Val Acc: 0.9772 | Val F1: 0.9323 | F1 Illicit: 0.9874

# %% [markdown]
# ## 4. EValuation

# %%
import torch, os

base_dir = "../model_features/randomsplit/SAGE_ablation"  # adjust as needed

for ablation in sorted(os.listdir(base_dir)):
    for seed in [42, 123, 777, 2023, 31415]:
        path = os.path.join(base_dir, ablation, f"seed_{seed}", "model.pth")
        if not os.path.exists(path): continue
        state_dict = torch.load(path, map_location="cpu")
        in_dim = state_dict["conv1.lin_l.weight"].shape[1]
        print(f"{ablation}/seed_{seed} → expects in_channels: {in_dim}")
# Out:
# all/seed_42 → expects in_channels: 174
# all/seed_123 → expects in_channels: 174
# all/seed_777 → expects in_channels: 174
# all/seed_2023 → expects in_channels: 174
# all/seed_31415 → expects in_channels: 174
# base/seed_42 → expects in_channels: 166
# base/seed_123 → expects in_channels: 166
# base/seed_777 → expects in_channels: 166
# base/seed_2023 → expects in_channels: 166
# base/seed_31415 → expects in_channels: 166
# base+basic_temporal/seed_42 → expects in_channels: 168
# base+basic_temporal/seed_123 → expects in_channels: 168
# base+basic_temporal/seed_777 → expects in_channels: 168
# base+basic_temporal/seed_2023 → expects in_channels: 168
# base+basic_temporal/seed_31415 → expects in_channels: 168
# base+basic_temporal+typology/seed_42 → expects in_channels: 170
# base+basic_temporal+typology/seed_123 → expects in_channels: 170
# base+basic_temporal+typology/seed_777 → expects in_channels: 170
# base+basic_temporal+typology/seed_2023 → expects in_channels: 170
# base+basic_temporal+typology/seed_31415 → expects in_channels: 170
# base+structural/seed_42 → expects in_channels: 170
# base+structural/seed_123 → expects in_channels: 170
# base+structural/seed_777 → expects in_channels: 170
# base+structural/seed_2023 → expects in_channels: 170
# base+structural/seed_31415 → expects in_channels: 170
# base+structural+typology/seed_42 → expects in_channels: 172
# base+structural+typology/seed_123 → expects in_channels: 172
# base+structural+typology/seed_777 → expects in_channels: 172
# base+structural+typology/seed_2023 → expects in_channels: 172
# base+structural+typology/seed_31415 → expects in_channels: 172
# base+typology/seed_42 → expects in_channels: 168
# base+typology/seed_123 → expects in_channels: 168
# base+typology/seed_777 → expects in_channels: 168
# base+typology/seed_2023 → expects in_channels: 168
# base+typology/seed_31415 → expects in_channels: 168

# %%
import os
import json
import torch

base_dir = "../model_features/randomsplit/SAGE_ablation"
data_dir = "../data/SAGE_randomsplit"
seeds = [42, 123, 777, 2023, 31415]

for ablation in sorted(os.listdir(base_dir)):
    ablation_model_path = os.path.join(base_dir, ablation)
    ablation_data_path = os.path.join(data_dir, ablation)

    if not os.path.isdir(ablation_model_path):
        continue

    print(f"\n→ Processing ablation: {ablation}")
    for seed in seeds:
        seed_dir = f"seed_{seed}"
        config_path = os.path.join(ablation_model_path, seed_dir, "config.json")
        model_path = os.path.join(ablation_model_path, seed_dir, "model.pth")
        data_path = os.path.join(ablation_data_path, seed_dir, "data_exp.pt")

        if not all(os.path.exists(p) for p in [config_path, model_path, data_path]):
            continue

        with open(config_path, "r") as f:
            config = json.load(f)

        updated = False
        data = torch.load(data_path, map_location="cpu", weights_only=False)
        feature_dim = data.x.shape[1]
        if config.get("feature_dim") != feature_dim:
            config["feature_dim"] = feature_dim
            updated = True

        if config.get("model") == "SAGE":
            if config.get("hidden_channels") != 64:
                config["hidden_channels"] = 64
                updated = True
            if config.get("out_channels") != 2:
                config["out_channels"] = 2
                updated = True
            if config.get("dropout") != 0.1:
                config["dropout"] = 0.1
                updated = True

        if updated:
            with open(config_path, "w") as f:
                json.dump(config, f, indent=4)
            print(f"✓ Patched config for {ablation} / seed {seed}")
        else:
            print(f"✓ Already complete: {ablation} / seed {seed}")
# Out:
# → Processing ablation: all
# ✓ Already complete: all / seed 42
# ✓ Already complete: all / seed 123
# ✓ Already complete: all / seed 777
# ✓ Already complete: all / seed 2023
# ✓ Already complete: all / seed 31415
#
# → Processing ablation: base
# ✓ Already complete: base / seed 42
# ✓ Already complete: base / seed 123
# ✓ Already complete: base / seed 777
# ✓ Already complete: base / seed 2023
# ✓ Already complete: base / seed 31415
#
# → Processing ablation: base+basic_temporal
# ✓ Already complete: base+basic_temporal / seed 42
# ✓ Already complete: base+basic_temporal / seed 123
# ✓ Already complete: base+basic_temporal / seed 777
# ✓ Already complete: base+basic_temporal / seed 2023
# ✓ Already complete: base+basic_temporal / seed 31415
#
# → Processing ablation: base+basic_temporal+typology
# ✓ Already complete: base+basic_temporal+typology / seed 42
# ✓ Already complete: base+basic_temporal+typology / seed 123
# ✓ Already complete: base+basic_temporal+typology / seed 777
# ✓ Already complete: base+basic_temporal+typology / seed 2023
# ✓ Already complete: base+basic_temporal+typology / seed 31415
#
# → Processing ablation: base+structural
# ✓ Already complete: base+structural / seed 42
# ✓ Already complete: base+structural / seed 123
# ✓ Already complete: base+structural / seed 777
# ✓ Already complete: base+structural / seed 2023
# ✓ Already complete: base+structural / seed 31415
#
# → Processing ablation: base+structural+typology
# ✓ Already complete: base+structural+typology / seed 42
# ✓ Already complete: base+structural+typology / seed 123
# ✓ Already complete: base+structural+typology / seed 777
# ✓ Already complete: base+structural+typology / seed 2023
# ✓ Already complete: base+structural+typology / seed 31415
#
# → Processing ablation: base+typology
# ✓ Already complete: base+typology / seed 42
# ✓ Already complete: base+typology / seed 123
# ✓ Already complete: base+typology / seed 777
# ✓ Already complete: base+typology / seed 2023
# ✓ Already complete: base+typology / seed 31415

# %%
import os
from features.evaluate_ablation_model import evaluate_ablation_model
from evaluation_pipeline import run_inference_all_seeds
from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
from features.feature_utils import make_model_class_from_config

# === Config ===
seeds = [42, 123, 777, 2023, 31415]
base_dir = "../model_features/randomsplit/SAGE_ablation"
data_exp_root = "../data/SAGE_randomsplit"
node_id_csv_path = "../elliptic_bitcoin_dataset/elliptic_txs_features.csv"

model_tag = "SAGE-Random"
split = "randomsplit"

# === Evaluate all ablations ===
for ablation in sorted(os.listdir(base_dir)):
    model_dir = os.path.join(base_dir, ablation)
    if not os.path.isdir(model_dir):
        continue

    print(f"\n→ Evaluating ablation: {ablation}")
    model_name = f"{model_tag}: {ablation}"
    ablation_data_dir = os.path.join(data_exp_root, ablation)
    config_path = os.path.join(model_dir, "seed_42", "config.json")
    model_class = make_model_class_from_config(config_path)

    # Run full evaluation
    evaluate_ablation_model(
        model_dir=model_dir,
        model_class=model_class,
        model_name=model_name,
        seeds=seeds,
        node_id_csv_path=node_id_csv_path,
        data_dir=ablation_data_dir
    )

    # Run inference (for logging CSV)
    y_true_all, y_pred_all, y_proba_all, seed_metrics = run_inference_all_seeds(
        model_dir=model_dir,
        model_class=model_class,
        data_dir=ablation_data_dir,
        seeds=seeds
    )
    val_acc_list = load_metrics_across_seeds(model_dir, ["val_acc"])["val_acc"]

    # Save to CSV
    log_metrics_to_csv(
        model_name=model_tag,
        split_name=split,
        ablation=ablation,
        seeds=seeds,
        val_acc_list=val_acc_list,
        seed_metrics=seed_metrics,
        is_feature=True  # append _feature to filename
    )
# Out:
# → Evaluating ablation: all
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 26
#      24 ablation_data_dir = os.path.join(data_exp_root, ablation)
#      25 config_path = os.path.join(model_dir, "seed_42", "config.json")
# ---> 26 model_class = make_model_class_from_config(config_path)
#      28 # Run full evaluation
#      29 evaluate_ablation_model(
#      30     model_dir=model_dir,
#      31     model_class=model_class,
#    (...)     35     data_dir=ablation_data_dir
#      36 )
#
# File c:\Users\ruoho\Documents\BSP\src\features\feature_utils.py:93, in make_model_class_from_config(config_path)
#      91 model_name = config["model"]
#      92 feature_dim = config["feature_dim"]
# ---> 93 hidden_channels = config["hidden_channels"]
#      94 heads = config.get("heads", 8)
#      95 out_channels = config.get("out_channels", 2)
#
# KeyError: 'hidden_channels'
