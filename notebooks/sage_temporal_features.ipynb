# %% [markdown]
# ## 1. Import and Setup

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# Torch & GNN
import torch
from torch_geometric.nn import SAGEConv

# Custom modules
from data_utils_temporal import load_and_preprocess_elliptic_temporal
from train_temporal import temporal_split
from model_sage import GraphSAGENet
from train_utils import set_seed, train_full, save_feature_experiment
from config import SEEDS

# Feature engineering control
from features.feature_config import FEATURE_CONFIGS
from features.feature_runner import apply_engineered_features

print("✓ All modules imported successfully.")
# Out:
# ✓ All modules imported successfully.

# %% [markdown]
# ## 2. Load and Preprocess the Elliptic Dataset
# This loads the data, maps transaction IDs to node indices, filters isolated nodes, and normalizes node features. Uses temporal splitting.

# %%
from normalization import normalize_base_features_only
from features.feature_pipeline import generate_all_features
from features.feature_utils import prepare_graph_and_timestamps
from data_utils_temporal import load_and_preprocess_elliptic_temporal
from train_temporal import temporal_split
from features.feature_config import FEATURE_CONFIGS
from train_utils import set_seed
from config import SEEDS
import torch
import os

# 1. Load PyG temporal data (with node_times)
data, node_times = load_and_preprocess_elliptic_temporal("../elliptic_bitcoin_dataset", normalize=False)
print(f"✓ Temporal PyG Data object loaded: {data}")

# 2. Prepare NetworkX graph + timestamps
G_nx, node_timestamps = prepare_graph_and_timestamps(
    edgelist_path="../elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv",
    features_path="../elliptic_bitcoin_dataset/elliptic_txs_features.csv",
    num_nodes=data.num_nodes
)

print(f"✓ NetworkX Graph: {G_nx.number_of_nodes()} nodes, {G_nx.number_of_edges()} edges")
print(f"✓ Timestamps found for {sum(len(ts) > 0 for ts in node_timestamps)} nodes")

# 3. Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ABLATORS = {
    k: v for k, v in FEATURE_CONFIGS.items()
}
FEATURED_DATA = {}

# 4. Loop through ablations + seeds
for ablation_name, feature_flags in ABLATORS.items():
    print(f"\n== Config: {ablation_name} ==")
    for seed in SEEDS:
        print(f"→ Seed {seed}")
        set_seed(seed)

        # 4.1 Temporal split (train up to time step 35)
        train_idx, val_idx = temporal_split(data, node_times=node_times, train_until=35)

        # 4.2 Feature engineering
        data_exp = data.clone()
        X, feature_names = generate_all_features(data_exp, G_nx, node_timestamps, **feature_flags)
        data_exp.x = torch.tensor(X, dtype=torch.float)

        # Optional: monitor temporal feature stats
        temporal_names = {"temporal_lag", "component_size"}
        temporal_indices = [i for i, name in enumerate(feature_names) if name in temporal_names]
        if temporal_indices:
            print("→ Temporal features (raw)")
            print("  Means:", data_exp.x[:, temporal_indices].mean(0))
            print("  Stds :", data_exp.x[:, temporal_indices].std(0))

        # 4.3 Normalize base features only
        data_exp.x = normalize_base_features_only(data_exp.x, feature_names)

        # 4.4 Finalize
        data_exp = data_exp.to(device)
        FEATURED_DATA[(ablation_name, seed)] = {
            "data": data_exp,
            "train_idx": train_idx,
            "val_idx": val_idx,
            "feature_flags": feature_flags,
        }

        # 4.5 Save to disk
        save_dir = f"../data/SAGE_temporal/{ablation_name}/seed_{seed}"
        os.makedirs(save_dir, exist_ok=True)
        torch.save(data_exp, os.path.join(save_dir, "data_exp.pt"))
        torch.save(train_idx, os.path.join(save_dir, "train_idx.pt"))
        torch.save(val_idx, os.path.join(save_dir, "val_idx.pt"))
        print(f"✓ Saved to {save_dir}")
        print(f"✓ Final shape: {data_exp.x.shape}")
# Out:
# ✓ Temporal PyG Data object loaded: Data(x=[203769, 166], edge_index=[2, 234355], y=[203769])
# Loaded directed graph with 203769 nodes and 234355 edges.
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Features DataFrame shape: (203769, 167)
# Number of features (excluding txId and time_step): 165
# Timestamps found for 203769 out of 203769 nodes.
# ✓ Time step range: 1.0 to 49.0
# ✓ NetworkX Graph: 203769 nodes, 234355 edges
# ✓ Timestamps found for 203769 nodes
#
# == Config: base ==
# → Seed 42
# ✓ Saved to ../data/SAGE_temporal/base/seed_42
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 123
# ✓ Saved to ../data/SAGE_temporal/base/seed_123
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 777
# ✓ Saved to ../data/SAGE_temporal/base/seed_777
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 2023
# ✓ Saved to ../data/SAGE_temporal/base/seed_2023
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 31415
# ✓ Saved to ../data/SAGE_temporal/base/seed_31415
# ✓ Final shape: torch.Size([203769, 166])
#
# == Config: base+structural ==
# → Seed 42
# ✓ Saved to ../data/SAGE_temporal/base+structural/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# ✓ Saved to ../data/SAGE_temporal/base+structural/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# ✓ Saved to ../data/SAGE_temporal/base+structural/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# ✓ Saved to ../data/SAGE_temporal/base+structural/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# ✓ Saved to ../data/SAGE_temporal/base+structural/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: base+typology ==
# → Seed 42
# ✓ Saved to ../data/SAGE_temporal/base+typology/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# ✓ Saved to ../data/SAGE_temporal/base+typology/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# ✓ Saved to ../data/SAGE_temporal/base+typology/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# ✓ Saved to ../data/SAGE_temporal/base+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# ✓ Saved to ../data/SAGE_temporal/base+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+structural+typology ==
# → Seed 42
# ✓ Saved to ../data/SAGE_temporal/base+structural+typology/seed_42
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 123
# ✓ Saved to ../data/SAGE_temporal/base+structural+typology/seed_123
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 777
# ✓ Saved to ../data/SAGE_temporal/base+structural+typology/seed_777
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 2023
# ✓ Saved to ../data/SAGE_temporal/base+structural+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 31415
# ✓ Saved to ../data/SAGE_temporal/base+structural+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 172])
#
# == Config: base+basic_temporal ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 407350.75it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 271939.50it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 232821.70it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 357435.39it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 316850.29it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+basic_temporal+typology ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 556535.36it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal+typology/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 361131.87it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal+typology/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 288168.30it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal+typology/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 341305.73it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 210136.31it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/base+basic_temporal+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: all ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 486592.81it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/all/seed_42
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 570928.89it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/all/seed_123
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 551132.41it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/all/seed_777
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 555331.18it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/all/seed_2023
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 550570.03it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/SAGE_temporal/all/seed_31415
# ✓ Final shape: torch.Size([203769, 174])

# %%
import torch
import os

ROOT_DIR = "../data/SAGE_temporal"
BASE_DIM = 166
SEEDS = [42, 123, 777, 2023, 31415]

print("\n📊 ENGINEERED FEATURE INSPECTION (from disk)")

# Loop over ablation folders
for ablation_name in sorted(os.listdir(ROOT_DIR)):
    ablation_path = os.path.join(ROOT_DIR, ablation_name)
    if not os.path.isdir(ablation_path):
        continue

    for seed in SEEDS:
        seed_dir = f"seed_{seed}"
        data_path = os.path.join(ablation_path, seed_dir, "data_exp.pt")
        if not os.path.exists(data_path):
            print(f"⛔ Missing file: {data_path}")
            continue

        data = torch.load(data_path, map_location="cpu", weights_only=False)
        x = data.x

        if x.shape[1] <= BASE_DIM:
            print(f"\n {ablation_name} | Seed: {seed}")
            print(" No engineered features found.")
            continue

        engineered = x[:, BASE_DIM:]
        print(f"\n {ablation_name} | Seed: {seed}")
        print(f" Engineered feature count: {engineered.shape[1]}")

        means = engineered.mean(dim=0)
        stds = engineered.std(dim=0)

        for i in range(engineered.shape[1]):
            m = means[i].item()
            s = stds[i].item()
            sample_vals = engineered[:5, i].numpy()
            print(f"Feature {BASE_DIM + i:>3} | Mean: {m:8.4f} | Std: {s:8.4f} | Sample: {sample_vals}")
# Out:
# 📊 ENGINEERED FEATURE INSPECTION (from disk)
#
#  all | Seed: 42
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 123
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 777
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 2023
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 31415
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base | Seed: 42
#  No engineered features found.
#
#  base | Seed: 123
#  No engineered features found.
#
#  base | Seed: 777
#  No engineered features found.
#
#  base | Seed: 2023
#  No engineered features found.
#
#  base | Seed: 31415
#  No engineered features found.
#
#  base+basic_temporal | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+structural | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural+typology | Seed: 42
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 123
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 777
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 2023
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 31415
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]

# %% [markdown]
# ## 3. Training Multiseed Models and Ablation

# %%
from model_sage import GraphSAGENet
from train_utils import train_full, save_feature_experiment
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


for (ablation_name, seed), bundle in FEATURED_DATA.items():
    print(f"\n=== Training GraphSAGE (Temporal Split): {ablation_name} | Seed: {seed} ===")

    data_exp = bundle["data"]
    train_idx = bundle["train_idx"]
    val_idx = bundle["val_idx"]
    feature_flags = bundle["feature_flags"]

    # 1. Initialize model
    model = GraphSAGENet(
        in_channels=data_exp.x.shape[1],
        hidden_channels=64,
        out_channels=2,
        dropout=0.1
    ).to(device)

    # 2. Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # 3. Train the model (use default CrossEntropyLoss)
    model, *results = train_full(
        model=model,
        data=data_exp,
        train_idx=train_idx,
        val_idx=val_idx,
        optimizer=optimizer,
        num_epochs=300,
        patience=30
    )

    # 4. Save model + logs
    output_dir = f"../model_features/temporal/SAGE_ablation/{ablation_name}/seed_{seed}"
    os.makedirs(output_dir, exist_ok=True)

    save_feature_experiment(
        output_dir=output_dir,
        model=model,
        results=results,
        seed=seed,
        config={
            "model": "SAGE",
            "ablation_name": ablation_name,
            "feature_flags": feature_flags,
            "feature_dim": data_exp.x.shape[1],
            "dropout": 0.1,
            "num_epochs": 300,
            "patience": 30,
            "lr": 0.001,
            "weight_decay": 5e-4,
            "class_weights": None  # explicitly noting unweighted
        },
        val_idx=val_idx
    )
# Out:
# === Training GraphSAGE (Temporal Split): base | Seed: 42 ===
# Epoch 001 | Loss: 0.6544 | Val Acc: 0.7222 | Val F1: 0.5062 | F1 Illicit: 0.8328
# Epoch 002 | Loss: 0.5410 | Val Acc: 0.7699 | Val F1: 0.5436 | F1 Illicit: 0.8650
# Epoch 003 | Loss: 0.4701 | Val Acc: 0.7900 | Val F1: 0.5611 | F1 Illicit: 0.8781
# Epoch 004 | Loss: 0.4188 | Val Acc: 0.8054 | Val F1: 0.5761 | F1 Illicit: 0.8879
# Epoch 005 | Loss: 0.3808 | Val Acc: 0.8158 | Val F1: 0.5866 | F1 Illicit: 0.8944
# Epoch 006 | Loss: 0.3536 | Val Acc: 0.8237 | Val F1: 0.5931 | F1 Illicit: 0.8994
# Epoch 007 | Loss: 0.3322 | Val Acc: 0.8331 | Val F1: 0.5996 | F1 Illicit: 0.9054
# Epoch 008 | Loss: 0.3141 | Val Acc: 0.8406 | Val F1: 0.6057 | F1 Illicit: 0.9100
# Epoch 009 | Loss: 0.3000 | Val Acc: 0.8465 | Val F1: 0.6103 | F1 Illicit: 0.9137
# Epoch 010 | Loss: 0.2873 | Val Acc: 0.8532 | Val F1: 0.6150 | F1 Illicit: 0.9178
# Epoch 011 | Loss: 0.2773 | Val Acc: 0.8594 | Val F1: 0.6202 | F1 Illicit: 0.9216
# Epoch 012 | Loss: 0.2683 | Val Acc: 0.8644 | Val F1: 0.6253 | F1 Illicit: 0.9246
# Epoch 013 | Loss: 0.2606 | Val Acc: 0.8693 | Val F1: 0.6300 | F1 Illicit: 0.9275
# Epoch 014 | Loss: 0.2539 | Val Acc: 0.8726 | Val F1: 0.6332 | F1 Illicit: 0.9295
# Epoch 015 | Loss: 0.2481 | Val Acc: 0.8749 | Val F1: 0.6346 | F1 Illicit: 0.9309
# Epoch 016 | Loss: 0.2427 | Val Acc: 0.8777 | Val F1: 0.6362 | F1 Illicit: 0.9326
# Epoch 017 | Loss: 0.2381 | Val Acc: 0.8793 | Val F1: 0.6353 | F1 Illicit: 0.9336
# Epoch 018 | Loss: 0.2338 | Val Acc: 0.8805 | Val F1: 0.6350 | F1 Illicit: 0.9343
# Epoch 019 | Loss: 0.2290 | Val Acc: 0.8832 | Val F1: 0.6381 | F1 Illicit: 0.9359
# Epoch 020 | Loss: 0.2250 | Val Acc: 0.8860 | Val F1: 0.6417 | F1 Illicit: 0.9375
# Epoch 021 | Loss: 0.2214 | Val Acc: 0.8870 | Val F1: 0.6430 | F1 Illicit: 0.9381
# Epoch 022 | Loss: 0.2180 | Val Acc: 0.8890 | Val F1: 0.6459 | F1 Illicit: 0.9393
# Epoch 023 | Loss: 0.2144 | Val Acc: 0.8898 | Val F1: 0.6477 | F1 Illicit: 0.9398
# Epoch 024 | Loss: 0.2115 | Val Acc: 0.8902 | Val F1: 0.6477 | F1 Illicit: 0.9400
# Epoch 025 | Loss: 0.2078 | Val Acc: 0.8909 | Val F1: 0.6487 | F1 Illicit: 0.9404
# Epoch 026 | Loss: 0.2041 | Val Acc: 0.8917 | Val F1: 0.6495 | F1 Illicit: 0.9409
# Epoch 027 | Loss: 0.2015 | Val Acc: 0.8929 | Val F1: 0.6519 | F1 Illicit: 0.9416
# Epoch 028 | Loss: 0.1982 | Val Acc: 0.8944 | Val F1: 0.6556 | F1 Illicit: 0.9424
# Epoch 029 | Loss: 0.1955 | Val Acc: 0.8954 | Val F1: 0.6578 | F1 Illicit: 0.9430
# Epoch 030 | Loss: 0.1927 | Val Acc: 0.8962 | Val F1: 0.6599 | F1 Illicit: 0.9434
# Epoch 031 | Loss: 0.1897 | Val Acc: 0.8980 | Val F1: 0.6636 | F1 Illicit: 0.9444
# Epoch 032 | Loss: 0.1870 | Val Acc: 0.8985 | Val F1: 0.6648 | F1 Illicit: 0.9447
# Epoch 033 | Loss: 0.1846 | Val Acc: 0.8995 | Val F1: 0.6666 | F1 Illicit: 0.9453
# Epoch 034 | Loss: 0.1824 | Val Acc: 0.9001 | Val F1: 0.6678 | F1 Illicit: 0.9456
# Epoch 035 | Loss: 0.1798 | Val Acc: 0.9010 | Val F1: 0.6692 | F1 Illicit: 0.9461
# Epoch 036 | Loss: 0.1777 | Val Acc: 0.9024 | Val F1: 0.6728 | F1 Illicit: 0.9469
# Epoch 037 | Loss: 0.1759 | Val Acc: 0.9031 | Val F1: 0.6744 | F1 Illicit: 0.9473
# Epoch 038 | Loss: 0.1741 | Val Acc: 0.9038 | Val F1: 0.6759 | F1 Illicit: 0.9477
# Epoch 039 | Loss: 0.1719 | Val Acc: 0.9049 | Val F1: 0.6785 | F1 Illicit: 0.9483
# Epoch 040 | Loss: 0.1696 | Val Acc: 0.9061 | Val F1: 0.6802 | F1 Illicit: 0.9490
# Epoch 041 | Loss: 0.1680 | Val Acc: 0.9073 | Val F1: 0.6828 | F1 Illicit: 0.9497
# Epoch 042 | Loss: 0.1656 | Val Acc: 0.9084 | Val F1: 0.6843 | F1 Illicit: 0.9503
# Epoch 043 | Loss: 0.1643 | Val Acc: 0.9096 | Val F1: 0.6861 | F1 Illicit: 0.9510
# Epoch 044 | Loss: 0.1623 | Val Acc: 0.9110 | Val F1: 0.6888 | F1 Illicit: 0.9518
# Epoch 045 | Loss: 0.1600 | Val Acc: 0.9126 | Val F1: 0.6919 | F1 Illicit: 0.9527
# Epoch 046 | Loss: 0.1589 | Val Acc: 0.9143 | Val F1: 0.6947 | F1 Illicit: 0.9537
# Epoch 047 | Loss: 0.1571 | Val Acc: 0.9165 | Val F1: 0.6999 | F1 Illicit: 0.9549
# Epoch 048 | Loss: 0.1561 | Val Acc: 0.9183 | Val F1: 0.7040 | F1 Illicit: 0.9558
# Epoch 049 | Loss: 0.1540 | Val Acc: 0.9200 | Val F1: 0.7072 | F1 Illicit: 0.9568
# Epoch 050 | Loss: 0.1533 | Val Acc: 0.9213 | Val F1: 0.7099 | F1 Illicit: 0.9575
# Epoch 051 | Loss: 0.1512 | Val Acc: 0.9230 | Val F1: 0.7131 | F1 Illicit: 0.9585
# Epoch 052 | Loss: 0.1498 | Val Acc: 0.9246 | Val F1: 0.7162 | F1 Illicit: 0.9594
# Epoch 053 | Loss: 0.1482 | Val Acc: 0.9262 | Val F1: 0.7197 | F1 Illicit: 0.9603
# Epoch 054 | Loss: 0.1470 | Val Acc: 0.9277 | Val F1: 0.7228 | F1 Illicit: 0.9611
# Epoch 055 | Loss: 0.1459 | Val Acc: 0.9289 | Val F1: 0.7255 | F1 Illicit: 0.9618
# Epoch 056 | Loss: 0.1443 | Val Acc: 0.9300 | Val F1: 0.7275 | F1 Illicit: 0.9624
# Epoch 057 | Loss: 0.1427 | Val Acc: 0.9314 | Val F1: 0.7299 | F1 Illicit: 0.9632
# Epoch 058 | Loss: 0.1418 | Val Acc: 0.9321 | Val F1: 0.7305 | F1 Illicit: 0.9636
# Epoch 059 | Loss: 0.1408 | Val Acc: 0.9333 | Val F1: 0.7331 | F1 Illicit: 0.9643
# Epoch 060 | Loss: 0.1390 | Val Acc: 0.9340 | Val F1: 0.7343 | F1 Illicit: 0.9646
# Epoch 061 | Loss: 0.1384 | Val Acc: 0.9345 | Val F1: 0.7347 | F1 Illicit: 0.9649
# Epoch 062 | Loss: 0.1372 | Val Acc: 0.9355 | Val F1: 0.7376 | F1 Illicit: 0.9655
# Epoch 063 | Loss: 0.1363 | Val Acc: 0.9363 | Val F1: 0.7392 | F1 Illicit: 0.9659
# Epoch 064 | Loss: 0.1348 | Val Acc: 0.9374 | Val F1: 0.7416 | F1 Illicit: 0.9665
# Epoch 065 | Loss: 0.1338 | Val Acc: 0.9381 | Val F1: 0.7434 | F1 Illicit: 0.9669
# Epoch 066 | Loss: 0.1332 | Val Acc: 0.9389 | Val F1: 0.7450 | F1 Illicit: 0.9673
# Epoch 067 | Loss: 0.1320 | Val Acc: 0.9395 | Val F1: 0.7468 | F1 Illicit: 0.9677
# Epoch 068 | Loss: 0.1308 | Val Acc: 0.9407 | Val F1: 0.7500 | F1 Illicit: 0.9683
# Epoch 069 | Loss: 0.1297 | Val Acc: 0.9417 | Val F1: 0.7528 | F1 Illicit: 0.9689
# Epoch 070 | Loss: 0.1288 | Val Acc: 0.9421 | Val F1: 0.7533 | F1 Illicit: 0.9691
# Epoch 071 | Loss: 0.1277 | Val Acc: 0.9426 | Val F1: 0.7548 | F1 Illicit: 0.9694
# Epoch 072 | Loss: 0.1274 | Val Acc: 0.9431 | Val F1: 0.7561 | F1 Illicit: 0.9697
# Epoch 073 | Loss: 0.1261 | Val Acc: 0.9432 | Val F1: 0.7562 | F1 Illicit: 0.9697
# Epoch 074 | Loss: 0.1256 | Val Acc: 0.9434 | Val F1: 0.7566 | F1 Illicit: 0.9699
# Epoch 075 | Loss: 0.1242 | Val Acc: 0.9440 | Val F1: 0.7579 | F1 Illicit: 0.9701
# Epoch 076 | Loss: 0.1235 | Val Acc: 0.9445 | Val F1: 0.7592 | F1 Illicit: 0.9704
# Epoch 077 | Loss: 0.1229 | Val Acc: 0.9449 | Val F1: 0.7604 | F1 Illicit: 0.9707
# Epoch 078 | Loss: 0.1216 | Val Acc: 0.9457 | Val F1: 0.7626 | F1 Illicit: 0.9711
# Epoch 079 | Loss: 0.1219 | Val Acc: 0.9461 | Val F1: 0.7639 | F1 Illicit: 0.9713
# Epoch 080 | Loss: 0.1205 | Val Acc: 0.9464 | Val F1: 0.7647 | F1 Illicit: 0.9715
# Epoch 081 | Loss: 0.1200 | Val Acc: 0.9470 | Val F1: 0.7660 | F1 Illicit: 0.9718
# Epoch 082 | Loss: 0.1193 | Val Acc: 0.9473 | Val F1: 0.7671 | F1 Illicit: 0.9720
# Epoch 083 | Loss: 0.1182 | Val Acc: 0.9476 | Val F1: 0.7677 | F1 Illicit: 0.9721
# Epoch 084 | Loss: 0.1174 | Val Acc: 0.9483 | Val F1: 0.7697 | F1 Illicit: 0.9725
# Epoch 085 | Loss: 0.1166 | Val Acc: 0.9487 | Val F1: 0.7707 | F1 Illicit: 0.9727
# Epoch 086 | Loss: 0.1164 | Val Acc: 0.9492 | Val F1: 0.7721 | F1 Illicit: 0.9730
# Epoch 087 | Loss: 0.1158 | Val Acc: 0.9497 | Val F1: 0.7735 | F1 Illicit: 0.9733
# Epoch 088 | Loss: 0.1151 | Val Acc: 0.9505 | Val F1: 0.7754 | F1 Illicit: 0.9737
# Epoch 089 | Loss: 0.1146 | Val Acc: 0.9515 | Val F1: 0.7786 | F1 Illicit: 0.9742
# Epoch 090 | Loss: 0.1134 | Val Acc: 0.9521 | Val F1: 0.7802 | F1 Illicit: 0.9746
# Epoch 091 | Loss: 0.1127 | Val Acc: 0.9524 | Val F1: 0.7809 | F1 Illicit: 0.9747
# Epoch 092 | Loss: 0.1117 | Val Acc: 0.9530 | Val F1: 0.7826 | F1 Illicit: 0.9751
# Epoch 093 | Loss: 0.1117 | Val Acc: 0.9536 | Val F1: 0.7843 | F1 Illicit: 0.9754
# Epoch 094 | Loss: 0.1110 | Val Acc: 0.9542 | Val F1: 0.7861 | F1 Illicit: 0.9757
# Epoch 095 | Loss: 0.1105 | Val Acc: 0.9545 | Val F1: 0.7871 | F1 Illicit: 0.9759
# Epoch 096 | Loss: 0.1092 | Val Acc: 0.9549 | Val F1: 0.7880 | F1 Illicit: 0.9761
# Epoch 097 | Loss: 0.1089 | Val Acc: 0.9552 | Val F1: 0.7890 | F1 Illicit: 0.9763
# Epoch 098 | Loss: 0.1079 | Val Acc: 0.9555 | Val F1: 0.7897 | F1 Illicit: 0.9764
# Epoch 099 | Loss: 0.1078 | Val Acc: 0.9560 | Val F1: 0.7915 | F1 Illicit: 0.9767
# Epoch 100 | Loss: 0.1072 | Val Acc: 0.9564 | Val F1: 0.7925 | F1 Illicit: 0.9769
# Epoch 101 | Loss: 0.1064 | Val Acc: 0.9566 | Val F1: 0.7933 | F1 Illicit: 0.9770
# Epoch 102 | Loss: 0.1066 | Val Acc: 0.9570 | Val F1: 0.7945 | F1 Illicit: 0.9772
# Epoch 103 | Loss: 0.1052 | Val Acc: 0.9572 | Val F1: 0.7953 | F1 Illicit: 0.9773
# Epoch 104 | Loss: 0.1047 | Val Acc: 0.9574 | Val F1: 0.7961 | F1 Illicit: 0.9775
# Epoch 105 | Loss: 0.1045 | Val Acc: 0.9576 | Val F1: 0.7965 | F1 Illicit: 0.9776
# Epoch 106 | Loss: 0.1036 | Val Acc: 0.9579 | Val F1: 0.7973 | F1 Illicit: 0.9777
# Epoch 107 | Loss: 0.1033 | Val Acc: 0.9581 | Val F1: 0.7976 | F1 Illicit: 0.9778
# Epoch 108 | Loss: 0.1029 | Val Acc: 0.9583 | Val F1: 0.7985 | F1 Illicit: 0.9780
# Epoch 109 | Loss: 0.1024 | Val Acc: 0.9586 | Val F1: 0.7995 | F1 Illicit: 0.9781
# Epoch 110 | Loss: 0.1020 | Val Acc: 0.9588 | Val F1: 0.8001 | F1 Illicit: 0.9782
# Epoch 111 | Loss: 0.1022 | Val Acc: 0.9591 | Val F1: 0.8011 | F1 Illicit: 0.9784
# Epoch 112 | Loss: 0.1007 | Val Acc: 0.9596 | Val F1: 0.8026 | F1 Illicit: 0.9786
# Epoch 113 | Loss: 0.1012 | Val Acc: 0.9599 | Val F1: 0.8043 | F1 Illicit: 0.9788
# Epoch 114 | Loss: 0.1000 | Val Acc: 0.9602 | Val F1: 0.8051 | F1 Illicit: 0.9790
# Epoch 115 | Loss: 0.0998 | Val Acc: 0.9603 | Val F1: 0.8055 | F1 Illicit: 0.9790
# Epoch 116 | Loss: 0.0993 | Val Acc: 0.9606 | Val F1: 0.8061 | F1 Illicit: 0.9792
# Epoch 117 | Loss: 0.0984 | Val Acc: 0.9608 | Val F1: 0.8067 | F1 Illicit: 0.9793
# Epoch 118 | Loss: 0.0986 | Val Acc: 0.9610 | Val F1: 0.8074 | F1 Illicit: 0.9794
# Epoch 119 | Loss: 0.0978 | Val Acc: 0.9611 | Val F1: 0.8076 | F1 Illicit: 0.9794
# Epoch 120 | Loss: 0.0972 | Val Acc: 0.9611 | Val F1: 0.8076 | F1 Illicit: 0.9795
# Epoch 121 | Loss: 0.0967 | Val Acc: 0.9612 | Val F1: 0.8080 | F1 Illicit: 0.9795
# Epoch 122 | Loss: 0.0965 | Val Acc: 0.9613 | Val F1: 0.8082 | F1 Illicit: 0.9796
# Epoch 123 | Loss: 0.0967 | Val Acc: 0.9615 | Val F1: 0.8089 | F1 Illicit: 0.9797
# Epoch 124 | Loss: 0.0963 | Val Acc: 0.9616 | Val F1: 0.8091 | F1 Illicit: 0.9797
# Epoch 125 | Loss: 0.0950 | Val Acc: 0.9617 | Val F1: 0.8095 | F1 Illicit: 0.9798
# Epoch 126 | Loss: 0.0951 | Val Acc: 0.9618 | Val F1: 0.8099 | F1 Illicit: 0.9799
# Epoch 127 | Loss: 0.0949 | Val Acc: 0.9618 | Val F1: 0.8099 | F1 Illicit: 0.9799
# Epoch 128 | Loss: 0.0944 | Val Acc: 0.9619 | Val F1: 0.8101 | F1 Illicit: 0.9799
# Epoch 129 | Loss: 0.0936 | Val Acc: 0.9622 | Val F1: 0.8112 | F1 Illicit: 0.9801
# Epoch 130 | Loss: 0.0932 | Val Acc: 0.9625 | Val F1: 0.8121 | F1 Illicit: 0.9802
# Epoch 131 | Loss: 0.0924 | Val Acc: 0.9626 | Val F1: 0.8125 | F1 Illicit: 0.9803
# Epoch 132 | Loss: 0.0927 | Val Acc: 0.9628 | Val F1: 0.8132 | F1 Illicit: 0.9804
# Epoch 133 | Loss: 0.0925 | Val Acc: 0.9629 | Val F1: 0.8134 | F1 Illicit: 0.9804
# Epoch 134 | Loss: 0.0912 | Val Acc: 0.9632 | Val F1: 0.8145 | F1 Illicit: 0.9806
# Epoch 135 | Loss: 0.0914 | Val Acc: 0.9631 | Val F1: 0.8140 | F1 Illicit: 0.9806
# Epoch 136 | Loss: 0.0908 | Val Acc: 0.9633 | Val F1: 0.8147 | F1 Illicit: 0.9807
# Epoch 137 | Loss: 0.0914 | Val Acc: 0.9635 | Val F1: 0.8151 | F1 Illicit: 0.9807
# Epoch 138 | Loss: 0.0909 | Val Acc: 0.9634 | Val F1: 0.8149 | F1 Illicit: 0.9807
# Epoch 139 | Loss: 0.0899 | Val Acc: 0.9634 | Val F1: 0.8147 | F1 Illicit: 0.9807
# Epoch 140 | Loss: 0.0902 | Val Acc: 0.9635 | Val F1: 0.8151 | F1 Illicit: 0.9808
# Epoch 141 | Loss: 0.0895 | Val Acc: 0.9637 | Val F1: 0.8156 | F1 Illicit: 0.9808
# Epoch 142 | Loss: 0.0890 | Val Acc: 0.9638 | Val F1: 0.8163 | F1 Illicit: 0.9809
# Epoch 143 | Loss: 0.0889 | Val Acc: 0.9637 | Val F1: 0.8156 | F1 Illicit: 0.9808
# Epoch 144 | Loss: 0.0877 | Val Acc: 0.9639 | Val F1: 0.8165 | F1 Illicit: 0.9809
# Epoch 145 | Loss: 0.0873 | Val Acc: 0.9639 | Val F1: 0.8165 | F1 Illicit: 0.9809
# Epoch 146 | Loss: 0.0879 | Val Acc: 0.9639 | Val F1: 0.8165 | F1 Illicit: 0.9809
# Epoch 147 | Loss: 0.0870 | Val Acc: 0.9641 | Val F1: 0.8171 | F1 Illicit: 0.9810
# Epoch 148 | Loss: 0.0865 | Val Acc: 0.9640 | Val F1: 0.8167 | F1 Illicit: 0.9810
# Epoch 149 | Loss: 0.0866 | Val Acc: 0.9641 | Val F1: 0.8169 | F1 Illicit: 0.9810
# Epoch 150 | Loss: 0.0861 | Val Acc: 0.9641 | Val F1: 0.8169 | F1 Illicit: 0.9810
# Epoch 151 | Loss: 0.0860 | Val Acc: 0.9641 | Val F1: 0.8169 | F1 Illicit: 0.9810
# Epoch 152 | Loss: 0.0861 | Val Acc: 0.9642 | Val F1: 0.8174 | F1 Illicit: 0.9811
# Epoch 153 | Loss: 0.0853 | Val Acc: 0.9644 | Val F1: 0.8180 | F1 Illicit: 0.9812
# Epoch 154 | Loss: 0.0847 | Val Acc: 0.9646 | Val F1: 0.8187 | F1 Illicit: 0.9813
# Epoch 155 | Loss: 0.0851 | Val Acc: 0.9645 | Val F1: 0.8183 | F1 Illicit: 0.9813
# Epoch 156 | Loss: 0.0846 | Val Acc: 0.9647 | Val F1: 0.8192 | F1 Illicit: 0.9814
# Epoch 157 | Loss: 0.0842 | Val Acc: 0.9648 | Val F1: 0.8194 | F1 Illicit: 0.9814
# Epoch 158 | Loss: 0.0838 | Val Acc: 0.9649 | Val F1: 0.8198 | F1 Illicit: 0.9815
# Epoch 159 | Loss: 0.0836 | Val Acc: 0.9649 | Val F1: 0.8201 | F1 Illicit: 0.9815
# Epoch 160 | Loss: 0.0825 | Val Acc: 0.9649 | Val F1: 0.8201 | F1 Illicit: 0.9815
# Epoch 161 | Loss: 0.0829 | Val Acc: 0.9650 | Val F1: 0.8203 | F1 Illicit: 0.9815
# Epoch 162 | Loss: 0.0826 | Val Acc: 0.9650 | Val F1: 0.8203 | F1 Illicit: 0.9815
# Epoch 163 | Loss: 0.0824 | Val Acc: 0.9650 | Val F1: 0.8205 | F1 Illicit: 0.9816
# Epoch 164 | Loss: 0.0824 | Val Acc: 0.9650 | Val F1: 0.8199 | F1 Illicit: 0.9815
# Epoch 165 | Loss: 0.0811 | Val Acc: 0.9650 | Val F1: 0.8196 | F1 Illicit: 0.9815
# Epoch 166 | Loss: 0.0816 | Val Acc: 0.9650 | Val F1: 0.8199 | F1 Illicit: 0.9815
# Epoch 167 | Loss: 0.0814 | Val Acc: 0.9651 | Val F1: 0.8203 | F1 Illicit: 0.9816
# Epoch 168 | Loss: 0.0809 | Val Acc: 0.9652 | Val F1: 0.8208 | F1 Illicit: 0.9817
# Epoch 169 | Loss: 0.0798 | Val Acc: 0.9652 | Val F1: 0.8208 | F1 Illicit: 0.9817
# Epoch 170 | Loss: 0.0808 | Val Acc: 0.9652 | Val F1: 0.8208 | F1 Illicit: 0.9817
# Epoch 171 | Loss: 0.0801 | Val Acc: 0.9654 | Val F1: 0.8212 | F1 Illicit: 0.9817
# Epoch 172 | Loss: 0.0798 | Val Acc: 0.9653 | Val F1: 0.8210 | F1 Illicit: 0.9817
# Epoch 173 | Loss: 0.0801 | Val Acc: 0.9652 | Val F1: 0.8208 | F1 Illicit: 0.9817
# Epoch 174 | Loss: 0.0790 | Val Acc: 0.9653 | Val F1: 0.8212 | F1 Illicit: 0.9817
# Epoch 175 | Loss: 0.0794 | Val Acc: 0.9654 | Val F1: 0.8214 | F1 Illicit: 0.9817
# Epoch 176 | Loss: 0.0791 | Val Acc: 0.9656 | Val F1: 0.8221 | F1 Illicit: 0.9819
# Epoch 177 | Loss: 0.0786 | Val Acc: 0.9657 | Val F1: 0.8224 | F1 Illicit: 0.9819
# Epoch 178 | Loss: 0.0784 | Val Acc: 0.9657 | Val F1: 0.8224 | F1 Illicit: 0.9819
# Epoch 179 | Loss: 0.0782 | Val Acc: 0.9658 | Val F1: 0.8226 | F1 Illicit: 0.9820
# Epoch 180 | Loss: 0.0779 | Val Acc: 0.9660 | Val F1: 0.8235 | F1 Illicit: 0.9821
# Epoch 181 | Loss: 0.0770 | Val Acc: 0.9662 | Val F1: 0.8242 | F1 Illicit: 0.9822
# Epoch 182 | Loss: 0.0770 | Val Acc: 0.9665 | Val F1: 0.8252 | F1 Illicit: 0.9823
# Epoch 183 | Loss: 0.0777 | Val Acc: 0.9665 | Val F1: 0.8252 | F1 Illicit: 0.9824
# Epoch 184 | Loss: 0.0766 | Val Acc: 0.9665 | Val F1: 0.8252 | F1 Illicit: 0.9824
# Epoch 185 | Loss: 0.0761 | Val Acc: 0.9666 | Val F1: 0.8254 | F1 Illicit: 0.9824
# Epoch 186 | Loss: 0.0765 | Val Acc: 0.9667 | Val F1: 0.8256 | F1 Illicit: 0.9824
# Epoch 187 | Loss: 0.0764 | Val Acc: 0.9667 | Val F1: 0.8259 | F1 Illicit: 0.9825
# Epoch 188 | Loss: 0.0757 | Val Acc: 0.9667 | Val F1: 0.8261 | F1 Illicit: 0.9825
# Epoch 189 | Loss: 0.0753 | Val Acc: 0.9668 | Val F1: 0.8263 | F1 Illicit: 0.9825
# Epoch 190 | Loss: 0.0756 | Val Acc: 0.9668 | Val F1: 0.8263 | F1 Illicit: 0.9825
# Epoch 191 | Loss: 0.0756 | Val Acc: 0.9667 | Val F1: 0.8259 | F1 Illicit: 0.9825
# Epoch 192 | Loss: 0.0751 | Val Acc: 0.9669 | Val F1: 0.8266 | F1 Illicit: 0.9826
# Epoch 193 | Loss: 0.0735 | Val Acc: 0.9669 | Val F1: 0.8266 | F1 Illicit: 0.9826
# Epoch 194 | Loss: 0.0741 | Val Acc: 0.9669 | Val F1: 0.8264 | F1 Illicit: 0.9826
# Epoch 195 | Loss: 0.0742 | Val Acc: 0.9669 | Val F1: 0.8259 | F1 Illicit: 0.9826
# Epoch 196 | Loss: 0.0740 | Val Acc: 0.9669 | Val F1: 0.8259 | F1 Illicit: 0.9826
# Epoch 197 | Loss: 0.0742 | Val Acc: 0.9668 | Val F1: 0.8255 | F1 Illicit: 0.9825
# Epoch 198 | Loss: 0.0738 | Val Acc: 0.9668 | Val F1: 0.8255 | F1 Illicit: 0.9825
# Epoch 199 | Loss: 0.0734 | Val Acc: 0.9669 | Val F1: 0.8259 | F1 Illicit: 0.9826
# Epoch 200 | Loss: 0.0729 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 201 | Loss: 0.0725 | Val Acc: 0.9668 | Val F1: 0.8255 | F1 Illicit: 0.9825
# Epoch 202 | Loss: 0.0731 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 203 | Loss: 0.0726 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 204 | Loss: 0.0722 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 205 | Loss: 0.0725 | Val Acc: 0.9670 | Val F1: 0.8264 | F1 Illicit: 0.9826
# Epoch 206 | Loss: 0.0724 | Val Acc: 0.9671 | Val F1: 0.8268 | F1 Illicit: 0.9827
# Epoch 207 | Loss: 0.0721 | Val Acc: 0.9671 | Val F1: 0.8268 | F1 Illicit: 0.9827
# Epoch 208 | Loss: 0.0714 | Val Acc: 0.9671 | Val F1: 0.8268 | F1 Illicit: 0.9827
# Epoch 209 | Loss: 0.0721 | Val Acc: 0.9671 | Val F1: 0.8266 | F1 Illicit: 0.9827
# Epoch 210 | Loss: 0.0709 | Val Acc: 0.9670 | Val F1: 0.8262 | F1 Illicit: 0.9826
# Epoch 211 | Loss: 0.0718 | Val Acc: 0.9670 | Val F1: 0.8260 | F1 Illicit: 0.9826
# Epoch 212 | Loss: 0.0707 | Val Acc: 0.9671 | Val F1: 0.8266 | F1 Illicit: 0.9827
# Epoch 213 | Loss: 0.0703 | Val Acc: 0.9673 | Val F1: 0.8274 | F1 Illicit: 0.9828
# Epoch 214 | Loss: 0.0707 | Val Acc: 0.9674 | Val F1: 0.8278 | F1 Illicit: 0.9829
# Epoch 215 | Loss: 0.0703 | Val Acc: 0.9675 | Val F1: 0.8281 | F1 Illicit: 0.9829
# Epoch 216 | Loss: 0.0703 | Val Acc: 0.9675 | Val F1: 0.8281 | F1 Illicit: 0.9829
# Epoch 217 | Loss: 0.0701 | Val Acc: 0.9675 | Val F1: 0.8279 | F1 Illicit: 0.9829
# Epoch 218 | Loss: 0.0702 | Val Acc: 0.9676 | Val F1: 0.8288 | F1 Illicit: 0.9830
# Epoch 219 | Loss: 0.0688 | Val Acc: 0.9676 | Val F1: 0.8290 | F1 Illicit: 0.9830
# Epoch 220 | Loss: 0.0696 | Val Acc: 0.9676 | Val F1: 0.8290 | F1 Illicit: 0.9830
# Epoch 221 | Loss: 0.0692 | Val Acc: 0.9676 | Val F1: 0.8290 | F1 Illicit: 0.9830
# Epoch 222 | Loss: 0.0690 | Val Acc: 0.9677 | Val F1: 0.8292 | F1 Illicit: 0.9830
# Epoch 223 | Loss: 0.0692 | Val Acc: 0.9677 | Val F1: 0.8292 | F1 Illicit: 0.9830
# Epoch 224 | Loss: 0.0691 | Val Acc: 0.9678 | Val F1: 0.8294 | F1 Illicit: 0.9830
# Epoch 225 | Loss: 0.0687 | Val Acc: 0.9678 | Val F1: 0.8297 | F1 Illicit: 0.9831
# Epoch 226 | Loss: 0.0682 | Val Acc: 0.9679 | Val F1: 0.8299 | F1 Illicit: 0.9831
# Epoch 227 | Loss: 0.0680 | Val Acc: 0.9680 | Val F1: 0.8302 | F1 Illicit: 0.9831
# Epoch 228 | Loss: 0.0678 | Val Acc: 0.9680 | Val F1: 0.8302 | F1 Illicit: 0.9831
# Epoch 229 | Loss: 0.0674 | Val Acc: 0.9679 | Val F1: 0.8297 | F1 Illicit: 0.9831
# Epoch 230 | Loss: 0.0673 | Val Acc: 0.9679 | Val F1: 0.8297 | F1 Illicit: 0.9831
# Epoch 231 | Loss: 0.0679 | Val Acc: 0.9680 | Val F1: 0.8300 | F1 Illicit: 0.9831
# Epoch 232 | Loss: 0.0666 | Val Acc: 0.9680 | Val F1: 0.8300 | F1 Illicit: 0.9832
# Epoch 233 | Loss: 0.0669 | Val Acc: 0.9680 | Val F1: 0.8298 | F1 Illicit: 0.9832
# Epoch 234 | Loss: 0.0675 | Val Acc: 0.9680 | Val F1: 0.8296 | F1 Illicit: 0.9832
# Epoch 235 | Loss: 0.0671 | Val Acc: 0.9681 | Val F1: 0.8298 | F1 Illicit: 0.9832
# Epoch 236 | Loss: 0.0667 | Val Acc: 0.9680 | Val F1: 0.8293 | F1 Illicit: 0.9832
# Epoch 237 | Loss: 0.0668 | Val Acc: 0.9680 | Val F1: 0.8300 | F1 Illicit: 0.9832
# Epoch 238 | Loss: 0.0665 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 239 | Loss: 0.0666 | Val Acc: 0.9678 | Val F1: 0.8288 | F1 Illicit: 0.9831
# Epoch 240 | Loss: 0.0667 | Val Acc: 0.9678 | Val F1: 0.8288 | F1 Illicit: 0.9831
# Epoch 241 | Loss: 0.0658 | Val Acc: 0.9678 | Val F1: 0.8288 | F1 Illicit: 0.9831
# Epoch 242 | Loss: 0.0662 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 243 | Loss: 0.0660 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 244 | Loss: 0.0663 | Val Acc: 0.9680 | Val F1: 0.8300 | F1 Illicit: 0.9832
# Epoch 245 | Loss: 0.0659 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 246 | Loss: 0.0660 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 247 | Loss: 0.0652 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 248 | Loss: 0.0653 | Val Acc: 0.9680 | Val F1: 0.8295 | F1 Illicit: 0.9832
# Epoch 249 | Loss: 0.0655 | Val Acc: 0.9678 | Val F1: 0.8286 | F1 Illicit: 0.9831
# Epoch 250 | Loss: 0.0647 | Val Acc: 0.9679 | Val F1: 0.8291 | F1 Illicit: 0.9831
# Epoch 251 | Loss: 0.0641 | Val Acc: 0.9679 | Val F1: 0.8289 | F1 Illicit: 0.9831
# Epoch 252 | Loss: 0.0646 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 253 | Loss: 0.0649 | Val Acc: 0.9681 | Val F1: 0.8294 | F1 Illicit: 0.9832
# Epoch 254 | Loss: 0.0642 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 255 | Loss: 0.0642 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 256 | Loss: 0.0640 | Val Acc: 0.9682 | Val F1: 0.8294 | F1 Illicit: 0.9833
# Epoch 257 | Loss: 0.0634 | Val Acc: 0.9681 | Val F1: 0.8292 | F1 Illicit: 0.9832
# Epoch 258 | Loss: 0.0630 | Val Acc: 0.9681 | Val F1: 0.8292 | F1 Illicit: 0.9832
# Epoch 259 | Loss: 0.0635 | Val Acc: 0.9682 | Val F1: 0.8294 | F1 Illicit: 0.9833
# Epoch 260 | Loss: 0.0634 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 261 | Loss: 0.0636 | Val Acc: 0.9680 | Val F1: 0.8287 | F1 Illicit: 0.9832
# Epoch 262 | Loss: 0.0630 | Val Acc: 0.9680 | Val F1: 0.8287 | F1 Illicit: 0.9832
# Epoch 263 | Loss: 0.0638 | Val Acc: 0.9680 | Val F1: 0.8287 | F1 Illicit: 0.9832
# Epoch 264 | Loss: 0.0627 | Val Acc: 0.9680 | Val F1: 0.8291 | F1 Illicit: 0.9832
# Epoch 265 | Loss: 0.0621 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 266 | Loss: 0.0634 | Val Acc: 0.9680 | Val F1: 0.8293 | F1 Illicit: 0.9832
# Epoch 267 | Loss: 0.0624 | Val Acc: 0.9680 | Val F1: 0.8293 | F1 Illicit: 0.9832
# Epoch 268 | Loss: 0.0624 | Val Acc: 0.9682 | Val F1: 0.8300 | F1 Illicit: 0.9833
# Epoch 269 | Loss: 0.0623 | Val Acc: 0.9682 | Val F1: 0.8303 | F1 Illicit: 0.9833
# Epoch 270 | Loss: 0.0627 | Val Acc: 0.9682 | Val F1: 0.8303 | F1 Illicit: 0.9833
# Epoch 271 | Loss: 0.0616 | Val Acc: 0.9682 | Val F1: 0.8298 | F1 Illicit: 0.9833
# Epoch 272 | Loss: 0.0615 | Val Acc: 0.9682 | Val F1: 0.8299 | F1 Illicit: 0.9833
# Epoch 273 | Loss: 0.0618 | Val Acc: 0.9682 | Val F1: 0.8299 | F1 Illicit: 0.9833
# Epoch 274 | Loss: 0.0615 | Val Acc: 0.9682 | Val F1: 0.8296 | F1 Illicit: 0.9833
# Epoch 275 | Loss: 0.0615 | Val Acc: 0.9682 | Val F1: 0.8299 | F1 Illicit: 0.9833
# Epoch 276 | Loss: 0.0609 | Val Acc: 0.9684 | Val F1: 0.8306 | F1 Illicit: 0.9834
# Epoch 277 | Loss: 0.0612 | Val Acc: 0.9684 | Val F1: 0.8310 | F1 Illicit: 0.9834
# Epoch 278 | Loss: 0.0607 | Val Acc: 0.9684 | Val F1: 0.8308 | F1 Illicit: 0.9834
# Epoch 279 | Loss: 0.0614 | Val Acc: 0.9684 | Val F1: 0.8308 | F1 Illicit: 0.9834
# Epoch 280 | Loss: 0.0607 | Val Acc: 0.9684 | Val F1: 0.8310 | F1 Illicit: 0.9834
# Epoch 281 | Loss: 0.0606 | Val Acc: 0.9684 | Val F1: 0.8308 | F1 Illicit: 0.9834
# Epoch 282 | Loss: 0.0609 | Val Acc: 0.9684 | Val F1: 0.8308 | F1 Illicit: 0.9834
# Epoch 283 | Loss: 0.0606 | Val Acc: 0.9684 | Val F1: 0.8308 | F1 Illicit: 0.9834
# Epoch 284 | Loss: 0.0605 | Val Acc: 0.9682 | Val F1: 0.8301 | F1 Illicit: 0.9833
# Epoch 285 | Loss: 0.0602 | Val Acc: 0.9680 | Val F1: 0.8289 | F1 Illicit: 0.9832
# Epoch 286 | Loss: 0.0603 | Val Acc: 0.9681 | Val F1: 0.8292 | F1 Illicit: 0.9832
# Epoch 287 | Loss: 0.0603 | Val Acc: 0.9682 | Val F1: 0.8294 | F1 Illicit: 0.9833
# Epoch 288 | Loss: 0.0598 | Val Acc: 0.9682 | Val F1: 0.8296 | F1 Illicit: 0.9833
# Epoch 289 | Loss: 0.0598 | Val Acc: 0.9682 | Val F1: 0.8296 | F1 Illicit: 0.9833
# Epoch 290 | Loss: 0.0605 | Val Acc: 0.9682 | Val F1: 0.8296 | F1 Illicit: 0.9833
# Epoch 291 | Loss: 0.0599 | Val Acc: 0.9683 | Val F1: 0.8299 | F1 Illicit: 0.9833
# Epoch 292 | Loss: 0.0596 | Val Acc: 0.9684 | Val F1: 0.8301 | F1 Illicit: 0.9834
# Epoch 293 | Loss: 0.0599 | Val Acc: 0.9686 | Val F1: 0.8317 | F1 Illicit: 0.9835
# Epoch 294 | Loss: 0.0596 | Val Acc: 0.9686 | Val F1: 0.8322 | F1 Illicit: 0.9835
# Epoch 295 | Loss: 0.0598 | Val Acc: 0.9686 | Val F1: 0.8319 | F1 Illicit: 0.9835
# Epoch 296 | Loss: 0.0592 | Val Acc: 0.9686 | Val F1: 0.8319 | F1 Illicit: 0.9835
# Epoch 297 | Loss: 0.0593 | Val Acc: 0.9686 | Val F1: 0.8319 | F1 Illicit: 0.9835
# Epoch 298 | Loss: 0.0592 | Val Acc: 0.9684 | Val F1: 0.8304 | F1 Illicit: 0.9834
# Epoch 299 | Loss: 0.0593 | Val Acc: 0.9684 | Val F1: 0.8304 | F1 Illicit: 0.9834
# Epoch 300 | Loss: 0.0589 | Val Acc: 0.9684 | Val F1: 0.8304 | F1 Illicit: 0.9834
#
# === Training GraphSAGE (Temporal Split): base | Seed: 123 ===
# Epoch 001 | Loss: 0.7151 | Val Acc: 0.5216 | Val F1: 0.4137 | F1 Illicit: 0.6653
# Epoch 002 | Loss: 0.6091 | Val Acc: 0.5893 | Val F1: 0.4558 | F1 Illicit: 0.7253
# Epoch 003 | Loss: 0.5439 | Val Acc: 0.6329 | Val F1: 0.4819 | F1 Illicit: 0.7616
# Epoch 004 | Loss: 0.4857 | Val Acc: 0.6600 | Val F1: 0.4977 | F1 Illicit: 0.7832
# Epoch 005 | Loss: 0.4445 | Val Acc: 0.6839 | Val F1: 0.5082 | F1 Illicit: 0.8022
# Epoch 006 | Loss: 0.4119 | Val Acc: 0.7056 | Val F1: 0.5195 | F1 Illicit: 0.8185
# Epoch 007 | Loss: 0.3844 | Val Acc: 0.7253 | Val F1: 0.5294 | F1 Illicit: 0.8330
# Epoch 008 | Loss: 0.3623 | Val Acc: 0.7460 | Val F1: 0.5403 | F1 Illicit: 0.8478
# Epoch 009 | Loss: 0.3432 | Val Acc: 0.7601 | Val F1: 0.5458 | F1 Illicit: 0.8578
# Epoch 010 | Loss: 0.3271 | Val Acc: 0.7758 | Val F1: 0.5552 | F1 Illicit: 0.8685
# Epoch 011 | Loss: 0.3138 | Val Acc: 0.7891 | Val F1: 0.5628 | F1 Illicit: 0.8773
# Epoch 012 | Loss: 0.3021 | Val Acc: 0.8005 | Val F1: 0.5681 | F1 Illicit: 0.8849
# Epoch 013 | Loss: 0.2922 | Val Acc: 0.8120 | Val F1: 0.5748 | F1 Illicit: 0.8924
# Epoch 014 | Loss: 0.2836 | Val Acc: 0.8217 | Val F1: 0.5803 | F1 Illicit: 0.8986
# Epoch 015 | Loss: 0.2759 | Val Acc: 0.8299 | Val F1: 0.5846 | F1 Illicit: 0.9038
# Epoch 016 | Loss: 0.2689 | Val Acc: 0.8368 | Val F1: 0.5883 | F1 Illicit: 0.9082
# Epoch 017 | Loss: 0.2629 | Val Acc: 0.8414 | Val F1: 0.5895 | F1 Illicit: 0.9111
# Epoch 018 | Loss: 0.2571 | Val Acc: 0.8477 | Val F1: 0.5950 | F1 Illicit: 0.9149
# Epoch 019 | Loss: 0.2523 | Val Acc: 0.8508 | Val F1: 0.5958 | F1 Illicit: 0.9169
# Epoch 020 | Loss: 0.2483 | Val Acc: 0.8550 | Val F1: 0.5985 | F1 Illicit: 0.9194
# Epoch 021 | Loss: 0.2434 | Val Acc: 0.8579 | Val F1: 0.6002 | F1 Illicit: 0.9212
# Epoch 022 | Loss: 0.2392 | Val Acc: 0.8618 | Val F1: 0.6046 | F1 Illicit: 0.9235
# Epoch 023 | Loss: 0.2352 | Val Acc: 0.8664 | Val F1: 0.6098 | F1 Illicit: 0.9262
# Epoch 024 | Loss: 0.2317 | Val Acc: 0.8697 | Val F1: 0.6131 | F1 Illicit: 0.9282
# Epoch 025 | Loss: 0.2284 | Val Acc: 0.8724 | Val F1: 0.6159 | F1 Illicit: 0.9298
# Epoch 026 | Loss: 0.2247 | Val Acc: 0.8747 | Val F1: 0.6187 | F1 Illicit: 0.9311
# Epoch 027 | Loss: 0.2206 | Val Acc: 0.8772 | Val F1: 0.6213 | F1 Illicit: 0.9326
# Epoch 028 | Loss: 0.2170 | Val Acc: 0.8804 | Val F1: 0.6256 | F1 Illicit: 0.9344
# Epoch 029 | Loss: 0.2137 | Val Acc: 0.8820 | Val F1: 0.6280 | F1 Illicit: 0.9354
# Epoch 030 | Loss: 0.2115 | Val Acc: 0.8847 | Val F1: 0.6311 | F1 Illicit: 0.9370
# Epoch 031 | Loss: 0.2078 | Val Acc: 0.8869 | Val F1: 0.6341 | F1 Illicit: 0.9382
# Epoch 032 | Loss: 0.2047 | Val Acc: 0.8887 | Val F1: 0.6372 | F1 Illicit: 0.9393
# Epoch 033 | Loss: 0.2018 | Val Acc: 0.8918 | Val F1: 0.6439 | F1 Illicit: 0.9410
# Epoch 034 | Loss: 0.1992 | Val Acc: 0.8939 | Val F1: 0.6471 | F1 Illicit: 0.9422
# Epoch 035 | Loss: 0.1968 | Val Acc: 0.8957 | Val F1: 0.6499 | F1 Illicit: 0.9432
# Epoch 036 | Loss: 0.1942 | Val Acc: 0.8982 | Val F1: 0.6549 | F1 Illicit: 0.9446
# Epoch 037 | Loss: 0.1916 | Val Acc: 0.9001 | Val F1: 0.6582 | F1 Illicit: 0.9458
# Epoch 038 | Loss: 0.1889 | Val Acc: 0.9020 | Val F1: 0.6626 | F1 Illicit: 0.9468
# Epoch 039 | Loss: 0.1871 | Val Acc: 0.9033 | Val F1: 0.6640 | F1 Illicit: 0.9476
# Epoch 040 | Loss: 0.1847 | Val Acc: 0.9055 | Val F1: 0.6691 | F1 Illicit: 0.9488
# Epoch 041 | Loss: 0.1817 | Val Acc: 0.9068 | Val F1: 0.6706 | F1 Illicit: 0.9495
# Epoch 042 | Loss: 0.1805 | Val Acc: 0.9078 | Val F1: 0.6727 | F1 Illicit: 0.9501
# Epoch 043 | Loss: 0.1776 | Val Acc: 0.9093 | Val F1: 0.6763 | F1 Illicit: 0.9509
# Epoch 044 | Loss: 0.1761 | Val Acc: 0.9105 | Val F1: 0.6791 | F1 Illicit: 0.9516
# Epoch 045 | Loss: 0.1742 | Val Acc: 0.9121 | Val F1: 0.6820 | F1 Illicit: 0.9525
# Epoch 046 | Loss: 0.1727 | Val Acc: 0.9138 | Val F1: 0.6859 | F1 Illicit: 0.9535
# Epoch 047 | Loss: 0.1704 | Val Acc: 0.9152 | Val F1: 0.6880 | F1 Illicit: 0.9542
# Epoch 048 | Loss: 0.1689 | Val Acc: 0.9166 | Val F1: 0.6907 | F1 Illicit: 0.9550
# Epoch 049 | Loss: 0.1669 | Val Acc: 0.9189 | Val F1: 0.6953 | F1 Illicit: 0.9563
# Epoch 050 | Loss: 0.1657 | Val Acc: 0.9200 | Val F1: 0.6972 | F1 Illicit: 0.9569
# Epoch 051 | Loss: 0.1634 | Val Acc: 0.9213 | Val F1: 0.6999 | F1 Illicit: 0.9577
# Epoch 052 | Loss: 0.1624 | Val Acc: 0.9230 | Val F1: 0.7036 | F1 Illicit: 0.9586
# Epoch 053 | Loss: 0.1611 | Val Acc: 0.9237 | Val F1: 0.7047 | F1 Illicit: 0.9590
# Epoch 054 | Loss: 0.1595 | Val Acc: 0.9252 | Val F1: 0.7079 | F1 Illicit: 0.9599
# Epoch 055 | Loss: 0.1576 | Val Acc: 0.9264 | Val F1: 0.7101 | F1 Illicit: 0.9605
# Epoch 056 | Loss: 0.1560 | Val Acc: 0.9273 | Val F1: 0.7117 | F1 Illicit: 0.9610
# Epoch 057 | Loss: 0.1546 | Val Acc: 0.9287 | Val F1: 0.7144 | F1 Illicit: 0.9618
# Epoch 058 | Loss: 0.1533 | Val Acc: 0.9294 | Val F1: 0.7156 | F1 Illicit: 0.9622
# Epoch 059 | Loss: 0.1524 | Val Acc: 0.9306 | Val F1: 0.7186 | F1 Illicit: 0.9628
# Epoch 060 | Loss: 0.1504 | Val Acc: 0.9318 | Val F1: 0.7212 | F1 Illicit: 0.9635
# Epoch 061 | Loss: 0.1495 | Val Acc: 0.9326 | Val F1: 0.7228 | F1 Illicit: 0.9640
# Epoch 062 | Loss: 0.1480 | Val Acc: 0.9337 | Val F1: 0.7252 | F1 Illicit: 0.9646
# Epoch 063 | Loss: 0.1469 | Val Acc: 0.9346 | Val F1: 0.7274 | F1 Illicit: 0.9651
# Epoch 064 | Loss: 0.1460 | Val Acc: 0.9354 | Val F1: 0.7290 | F1 Illicit: 0.9655
# Epoch 065 | Loss: 0.1453 | Val Acc: 0.9363 | Val F1: 0.7313 | F1 Illicit: 0.9660
# Epoch 066 | Loss: 0.1436 | Val Acc: 0.9369 | Val F1: 0.7324 | F1 Illicit: 0.9663
# Epoch 067 | Loss: 0.1421 | Val Acc: 0.9374 | Val F1: 0.7336 | F1 Illicit: 0.9666
# Epoch 068 | Loss: 0.1418 | Val Acc: 0.9379 | Val F1: 0.7347 | F1 Illicit: 0.9669
# Epoch 069 | Loss: 0.1404 | Val Acc: 0.9391 | Val F1: 0.7384 | F1 Illicit: 0.9676
# Epoch 070 | Loss: 0.1397 | Val Acc: 0.9395 | Val F1: 0.7393 | F1 Illicit: 0.9678
# Epoch 071 | Loss: 0.1381 | Val Acc: 0.9400 | Val F1: 0.7406 | F1 Illicit: 0.9680
# Epoch 072 | Loss: 0.1376 | Val Acc: 0.9408 | Val F1: 0.7427 | F1 Illicit: 0.9684
# Epoch 073 | Loss: 0.1365 | Val Acc: 0.9412 | Val F1: 0.7437 | F1 Illicit: 0.9687
# Epoch 074 | Loss: 0.1351 | Val Acc: 0.9416 | Val F1: 0.7450 | F1 Illicit: 0.9689
# Epoch 075 | Loss: 0.1339 | Val Acc: 0.9417 | Val F1: 0.7449 | F1 Illicit: 0.9689
# Epoch 076 | Loss: 0.1337 | Val Acc: 0.9419 | Val F1: 0.7459 | F1 Illicit: 0.9691
# Epoch 077 | Loss: 0.1331 | Val Acc: 0.9423 | Val F1: 0.7473 | F1 Illicit: 0.9693
# Epoch 078 | Loss: 0.1315 | Val Acc: 0.9430 | Val F1: 0.7490 | F1 Illicit: 0.9697
# Epoch 079 | Loss: 0.1309 | Val Acc: 0.9435 | Val F1: 0.7507 | F1 Illicit: 0.9699
# Epoch 080 | Loss: 0.1296 | Val Acc: 0.9440 | Val F1: 0.7521 | F1 Illicit: 0.9702
# Epoch 081 | Loss: 0.1295 | Val Acc: 0.9444 | Val F1: 0.7537 | F1 Illicit: 0.9704
# Epoch 082 | Loss: 0.1286 | Val Acc: 0.9449 | Val F1: 0.7548 | F1 Illicit: 0.9707
# Epoch 083 | Loss: 0.1278 | Val Acc: 0.9453 | Val F1: 0.7556 | F1 Illicit: 0.9709
# Epoch 084 | Loss: 0.1271 | Val Acc: 0.9457 | Val F1: 0.7568 | F1 Illicit: 0.9711
# Epoch 085 | Loss: 0.1258 | Val Acc: 0.9465 | Val F1: 0.7595 | F1 Illicit: 0.9716
# Epoch 086 | Loss: 0.1253 | Val Acc: 0.9470 | Val F1: 0.7614 | F1 Illicit: 0.9718
# Epoch 087 | Loss: 0.1245 | Val Acc: 0.9471 | Val F1: 0.7620 | F1 Illicit: 0.9719
# Epoch 088 | Loss: 0.1240 | Val Acc: 0.9474 | Val F1: 0.7631 | F1 Illicit: 0.9721
# Epoch 089 | Loss: 0.1231 | Val Acc: 0.9479 | Val F1: 0.7646 | F1 Illicit: 0.9723
# Epoch 090 | Loss: 0.1220 | Val Acc: 0.9483 | Val F1: 0.7659 | F1 Illicit: 0.9725
# Epoch 091 | Loss: 0.1218 | Val Acc: 0.9489 | Val F1: 0.7688 | F1 Illicit: 0.9729
# Epoch 092 | Loss: 0.1205 | Val Acc: 0.9496 | Val F1: 0.7710 | F1 Illicit: 0.9733
# Epoch 093 | Loss: 0.1200 | Val Acc: 0.9502 | Val F1: 0.7726 | F1 Illicit: 0.9736
# Epoch 094 | Loss: 0.1194 | Val Acc: 0.9504 | Val F1: 0.7729 | F1 Illicit: 0.9737
# Epoch 095 | Loss: 0.1184 | Val Acc: 0.9506 | Val F1: 0.7732 | F1 Illicit: 0.9738
# Epoch 096 | Loss: 0.1181 | Val Acc: 0.9509 | Val F1: 0.7739 | F1 Illicit: 0.9739
# Epoch 097 | Loss: 0.1177 | Val Acc: 0.9513 | Val F1: 0.7750 | F1 Illicit: 0.9741
# Epoch 098 | Loss: 0.1170 | Val Acc: 0.9516 | Val F1: 0.7759 | F1 Illicit: 0.9743
# Epoch 099 | Loss: 0.1165 | Val Acc: 0.9522 | Val F1: 0.7778 | F1 Illicit: 0.9746
# Epoch 100 | Loss: 0.1153 | Val Acc: 0.9527 | Val F1: 0.7793 | F1 Illicit: 0.9749
# Epoch 101 | Loss: 0.1153 | Val Acc: 0.9534 | Val F1: 0.7811 | F1 Illicit: 0.9753
# Epoch 102 | Loss: 0.1139 | Val Acc: 0.9539 | Val F1: 0.7826 | F1 Illicit: 0.9756
# Epoch 103 | Loss: 0.1133 | Val Acc: 0.9541 | Val F1: 0.7834 | F1 Illicit: 0.9757
# Epoch 104 | Loss: 0.1129 | Val Acc: 0.9546 | Val F1: 0.7849 | F1 Illicit: 0.9760
# Epoch 105 | Loss: 0.1128 | Val Acc: 0.9552 | Val F1: 0.7867 | F1 Illicit: 0.9763
# Epoch 106 | Loss: 0.1122 | Val Acc: 0.9553 | Val F1: 0.7871 | F1 Illicit: 0.9763
# Epoch 107 | Loss: 0.1115 | Val Acc: 0.9555 | Val F1: 0.7876 | F1 Illicit: 0.9764
# Epoch 108 | Loss: 0.1108 | Val Acc: 0.9558 | Val F1: 0.7884 | F1 Illicit: 0.9766
# Epoch 109 | Loss: 0.1105 | Val Acc: 0.9559 | Val F1: 0.7888 | F1 Illicit: 0.9767
# Epoch 110 | Loss: 0.1099 | Val Acc: 0.9565 | Val F1: 0.7908 | F1 Illicit: 0.9770
# Epoch 111 | Loss: 0.1094 | Val Acc: 0.9567 | Val F1: 0.7921 | F1 Illicit: 0.9771
# Epoch 112 | Loss: 0.1088 | Val Acc: 0.9570 | Val F1: 0.7928 | F1 Illicit: 0.9773
# Epoch 113 | Loss: 0.1088 | Val Acc: 0.9573 | Val F1: 0.7938 | F1 Illicit: 0.9774
# Epoch 114 | Loss: 0.1080 | Val Acc: 0.9575 | Val F1: 0.7944 | F1 Illicit: 0.9775
# Epoch 115 | Loss: 0.1073 | Val Acc: 0.9577 | Val F1: 0.7955 | F1 Illicit: 0.9776
# Epoch 116 | Loss: 0.1067 | Val Acc: 0.9581 | Val F1: 0.7967 | F1 Illicit: 0.9779
# Epoch 117 | Loss: 0.1066 | Val Acc: 0.9583 | Val F1: 0.7973 | F1 Illicit: 0.9780
# Epoch 118 | Loss: 0.1055 | Val Acc: 0.9588 | Val F1: 0.7990 | F1 Illicit: 0.9782
# Epoch 119 | Loss: 0.1052 | Val Acc: 0.9593 | Val F1: 0.8011 | F1 Illicit: 0.9785
# Epoch 120 | Loss: 0.1049 | Val Acc: 0.9595 | Val F1: 0.8017 | F1 Illicit: 0.9786
# Epoch 121 | Loss: 0.1042 | Val Acc: 0.9594 | Val F1: 0.8015 | F1 Illicit: 0.9786
# Epoch 122 | Loss: 0.1044 | Val Acc: 0.9596 | Val F1: 0.8019 | F1 Illicit: 0.9786
# Epoch 123 | Loss: 0.1034 | Val Acc: 0.9597 | Val F1: 0.8025 | F1 Illicit: 0.9787
# Epoch 124 | Loss: 0.1037 | Val Acc: 0.9599 | Val F1: 0.8031 | F1 Illicit: 0.9788
# Epoch 125 | Loss: 0.1027 | Val Acc: 0.9599 | Val F1: 0.8031 | F1 Illicit: 0.9788
# Epoch 126 | Loss: 0.1019 | Val Acc: 0.9599 | Val F1: 0.8025 | F1 Illicit: 0.9788
# Epoch 127 | Loss: 0.1018 | Val Acc: 0.9600 | Val F1: 0.8029 | F1 Illicit: 0.9789
# Epoch 128 | Loss: 0.1015 | Val Acc: 0.9601 | Val F1: 0.8033 | F1 Illicit: 0.9789
# Epoch 129 | Loss: 0.1006 | Val Acc: 0.9605 | Val F1: 0.8044 | F1 Illicit: 0.9791
# Epoch 130 | Loss: 0.1001 | Val Acc: 0.9605 | Val F1: 0.8046 | F1 Illicit: 0.9792
# Epoch 131 | Loss: 0.0998 | Val Acc: 0.9608 | Val F1: 0.8054 | F1 Illicit: 0.9793
# Epoch 132 | Loss: 0.1001 | Val Acc: 0.9609 | Val F1: 0.8058 | F1 Illicit: 0.9794
# Epoch 133 | Loss: 0.0987 | Val Acc: 0.9610 | Val F1: 0.8060 | F1 Illicit: 0.9794
# Epoch 134 | Loss: 0.0986 | Val Acc: 0.9609 | Val F1: 0.8058 | F1 Illicit: 0.9794
# Epoch 135 | Loss: 0.0986 | Val Acc: 0.9611 | Val F1: 0.8065 | F1 Illicit: 0.9794
# Epoch 136 | Loss: 0.0976 | Val Acc: 0.9613 | Val F1: 0.8075 | F1 Illicit: 0.9796
# Epoch 137 | Loss: 0.0981 | Val Acc: 0.9614 | Val F1: 0.8080 | F1 Illicit: 0.9796
# Epoch 138 | Loss: 0.0975 | Val Acc: 0.9616 | Val F1: 0.8084 | F1 Illicit: 0.9797
# Epoch 139 | Loss: 0.0970 | Val Acc: 0.9618 | Val F1: 0.8097 | F1 Illicit: 0.9799
# Epoch 140 | Loss: 0.0960 | Val Acc: 0.9620 | Val F1: 0.8101 | F1 Illicit: 0.9800
# Epoch 141 | Loss: 0.0963 | Val Acc: 0.9623 | Val F1: 0.8110 | F1 Illicit: 0.9801
# Epoch 142 | Loss: 0.0955 | Val Acc: 0.9624 | Val F1: 0.8112 | F1 Illicit: 0.9801
# Epoch 143 | Loss: 0.0955 | Val Acc: 0.9625 | Val F1: 0.8116 | F1 Illicit: 0.9802
# Epoch 144 | Loss: 0.0947 | Val Acc: 0.9626 | Val F1: 0.8121 | F1 Illicit: 0.9803
# Epoch 145 | Loss: 0.0948 | Val Acc: 0.9626 | Val F1: 0.8121 | F1 Illicit: 0.9803
# Epoch 146 | Loss: 0.0941 | Val Acc: 0.9628 | Val F1: 0.8127 | F1 Illicit: 0.9804
# Epoch 147 | Loss: 0.0938 | Val Acc: 0.9629 | Val F1: 0.8129 | F1 Illicit: 0.9804
# Epoch 148 | Loss: 0.0939 | Val Acc: 0.9630 | Val F1: 0.8134 | F1 Illicit: 0.9805
# Epoch 149 | Loss: 0.0932 | Val Acc: 0.9630 | Val F1: 0.8134 | F1 Illicit: 0.9805
# Epoch 150 | Loss: 0.0924 | Val Acc: 0.9630 | Val F1: 0.8134 | F1 Illicit: 0.9805
# Epoch 151 | Loss: 0.0926 | Val Acc: 0.9630 | Val F1: 0.8134 | F1 Illicit: 0.9805
# Epoch 152 | Loss: 0.0919 | Val Acc: 0.9629 | Val F1: 0.8132 | F1 Illicit: 0.9805
# Epoch 153 | Loss: 0.0921 | Val Acc: 0.9629 | Val F1: 0.8132 | F1 Illicit: 0.9805
# Epoch 154 | Loss: 0.0912 | Val Acc: 0.9630 | Val F1: 0.8134 | F1 Illicit: 0.9805
# Epoch 155 | Loss: 0.0906 | Val Acc: 0.9629 | Val F1: 0.8129 | F1 Illicit: 0.9805
# Epoch 156 | Loss: 0.0905 | Val Acc: 0.9631 | Val F1: 0.8132 | F1 Illicit: 0.9805
# Epoch 157 | Loss: 0.0903 | Val Acc: 0.9631 | Val F1: 0.8132 | F1 Illicit: 0.9805
# Epoch 158 | Loss: 0.0906 | Val Acc: 0.9631 | Val F1: 0.8132 | F1 Illicit: 0.9805
# Epoch 159 | Loss: 0.0898 | Val Acc: 0.9630 | Val F1: 0.8127 | F1 Illicit: 0.9805
# Epoch 160 | Loss: 0.0898 | Val Acc: 0.9631 | Val F1: 0.8134 | F1 Illicit: 0.9806
# Epoch 161 | Loss: 0.0892 | Val Acc: 0.9633 | Val F1: 0.8138 | F1 Illicit: 0.9806
# Epoch 162 | Loss: 0.0888 | Val Acc: 0.9634 | Val F1: 0.8143 | F1 Illicit: 0.9807
# Epoch 163 | Loss: 0.0886 | Val Acc: 0.9635 | Val F1: 0.8145 | F1 Illicit: 0.9807
# Epoch 164 | Loss: 0.0884 | Val Acc: 0.9635 | Val F1: 0.8147 | F1 Illicit: 0.9808
# Epoch 165 | Loss: 0.0882 | Val Acc: 0.9636 | Val F1: 0.8149 | F1 Illicit: 0.9808
# Epoch 166 | Loss: 0.0879 | Val Acc: 0.9636 | Val F1: 0.8149 | F1 Illicit: 0.9808
# Epoch 167 | Loss: 0.0875 | Val Acc: 0.9637 | Val F1: 0.8154 | F1 Illicit: 0.9809
# Epoch 168 | Loss: 0.0872 | Val Acc: 0.9638 | Val F1: 0.8156 | F1 Illicit: 0.9809
# Epoch 169 | Loss: 0.0868 | Val Acc: 0.9640 | Val F1: 0.8163 | F1 Illicit: 0.9810
# Epoch 170 | Loss: 0.0869 | Val Acc: 0.9641 | Val F1: 0.8165 | F1 Illicit: 0.9810
# Epoch 171 | Loss: 0.0865 | Val Acc: 0.9642 | Val F1: 0.8169 | F1 Illicit: 0.9811
# Epoch 172 | Loss: 0.0863 | Val Acc: 0.9642 | Val F1: 0.8169 | F1 Illicit: 0.9811
# Epoch 173 | Loss: 0.0857 | Val Acc: 0.9641 | Val F1: 0.8165 | F1 Illicit: 0.9811
# Epoch 174 | Loss: 0.0856 | Val Acc: 0.9643 | Val F1: 0.8172 | F1 Illicit: 0.9812
# Epoch 175 | Loss: 0.0855 | Val Acc: 0.9642 | Val F1: 0.8169 | F1 Illicit: 0.9811
# Epoch 176 | Loss: 0.0849 | Val Acc: 0.9643 | Val F1: 0.8174 | F1 Illicit: 0.9812
# Epoch 177 | Loss: 0.0850 | Val Acc: 0.9644 | Val F1: 0.8178 | F1 Illicit: 0.9813
# Epoch 178 | Loss: 0.0839 | Val Acc: 0.9647 | Val F1: 0.8187 | F1 Illicit: 0.9814
# Epoch 179 | Loss: 0.0843 | Val Acc: 0.9646 | Val F1: 0.8183 | F1 Illicit: 0.9814
# Epoch 180 | Loss: 0.0846 | Val Acc: 0.9646 | Val F1: 0.8181 | F1 Illicit: 0.9813
# Epoch 181 | Loss: 0.0836 | Val Acc: 0.9646 | Val F1: 0.8181 | F1 Illicit: 0.9813
# Epoch 182 | Loss: 0.0832 | Val Acc: 0.9646 | Val F1: 0.8181 | F1 Illicit: 0.9813
# Epoch 183 | Loss: 0.0835 | Val Acc: 0.9646 | Val F1: 0.8178 | F1 Illicit: 0.9813
# Epoch 184 | Loss: 0.0828 | Val Acc: 0.9646 | Val F1: 0.8178 | F1 Illicit: 0.9813
# Epoch 185 | Loss: 0.0825 | Val Acc: 0.9646 | Val F1: 0.8178 | F1 Illicit: 0.9813
# Epoch 186 | Loss: 0.0822 | Val Acc: 0.9646 | Val F1: 0.8176 | F1 Illicit: 0.9813
# Epoch 187 | Loss: 0.0826 | Val Acc: 0.9646 | Val F1: 0.8176 | F1 Illicit: 0.9813
# Epoch 188 | Loss: 0.0818 | Val Acc: 0.9646 | Val F1: 0.8179 | F1 Illicit: 0.9814
# Epoch 189 | Loss: 0.0827 | Val Acc: 0.9646 | Val F1: 0.8179 | F1 Illicit: 0.9814
# Epoch 190 | Loss: 0.0819 | Val Acc: 0.9648 | Val F1: 0.8183 | F1 Illicit: 0.9814
# Epoch 191 | Loss: 0.0814 | Val Acc: 0.9649 | Val F1: 0.8190 | F1 Illicit: 0.9815
# Epoch 192 | Loss: 0.0814 | Val Acc: 0.9650 | Val F1: 0.8194 | F1 Illicit: 0.9816
# Epoch 193 | Loss: 0.0809 | Val Acc: 0.9650 | Val F1: 0.8194 | F1 Illicit: 0.9816
# Epoch 194 | Loss: 0.0804 | Val Acc: 0.9650 | Val F1: 0.8194 | F1 Illicit: 0.9816
# Epoch 195 | Loss: 0.0808 | Val Acc: 0.9650 | Val F1: 0.8194 | F1 Illicit: 0.9816
# Epoch 196 | Loss: 0.0794 | Val Acc: 0.9650 | Val F1: 0.8192 | F1 Illicit: 0.9816
# Epoch 197 | Loss: 0.0801 | Val Acc: 0.9651 | Val F1: 0.8194 | F1 Illicit: 0.9816
# Epoch 198 | Loss: 0.0801 | Val Acc: 0.9652 | Val F1: 0.8197 | F1 Illicit: 0.9816
# Epoch 199 | Loss: 0.0793 | Val Acc: 0.9652 | Val F1: 0.8199 | F1 Illicit: 0.9817
# Epoch 200 | Loss: 0.0790 | Val Acc: 0.9653 | Val F1: 0.8201 | F1 Illicit: 0.9817
# Epoch 201 | Loss: 0.0790 | Val Acc: 0.9653 | Val F1: 0.8199 | F1 Illicit: 0.9817
# Epoch 202 | Loss: 0.0791 | Val Acc: 0.9653 | Val F1: 0.8199 | F1 Illicit: 0.9817
# Epoch 203 | Loss: 0.0789 | Val Acc: 0.9654 | Val F1: 0.8204 | F1 Illicit: 0.9818
# Epoch 204 | Loss: 0.0785 | Val Acc: 0.9654 | Val F1: 0.8201 | F1 Illicit: 0.9818
# Epoch 205 | Loss: 0.0780 | Val Acc: 0.9654 | Val F1: 0.8201 | F1 Illicit: 0.9818
# Epoch 206 | Loss: 0.0779 | Val Acc: 0.9654 | Val F1: 0.8206 | F1 Illicit: 0.9818
# Epoch 207 | Loss: 0.0779 | Val Acc: 0.9654 | Val F1: 0.8206 | F1 Illicit: 0.9818
# Epoch 208 | Loss: 0.0780 | Val Acc: 0.9654 | Val F1: 0.8206 | F1 Illicit: 0.9818
# Epoch 209 | Loss: 0.0779 | Val Acc: 0.9655 | Val F1: 0.8210 | F1 Illicit: 0.9818
# Epoch 210 | Loss: 0.0771 | Val Acc: 0.9656 | Val F1: 0.8215 | F1 Illicit: 0.9819
# Epoch 211 | Loss: 0.0772 | Val Acc: 0.9655 | Val F1: 0.8213 | F1 Illicit: 0.9818
# Epoch 212 | Loss: 0.0770 | Val Acc: 0.9655 | Val F1: 0.8213 | F1 Illicit: 0.9818
# Epoch 213 | Loss: 0.0767 | Val Acc: 0.9656 | Val F1: 0.8215 | F1 Illicit: 0.9819
# Epoch 214 | Loss: 0.0758 | Val Acc: 0.9655 | Val F1: 0.8213 | F1 Illicit: 0.9818
# Epoch 215 | Loss: 0.0760 | Val Acc: 0.9656 | Val F1: 0.8217 | F1 Illicit: 0.9819
# Epoch 216 | Loss: 0.0752 | Val Acc: 0.9657 | Val F1: 0.8219 | F1 Illicit: 0.9819
# Epoch 217 | Loss: 0.0763 | Val Acc: 0.9656 | Val F1: 0.8215 | F1 Illicit: 0.9819
# Epoch 218 | Loss: 0.0751 | Val Acc: 0.9656 | Val F1: 0.8210 | F1 Illicit: 0.9819
# Epoch 219 | Loss: 0.0751 | Val Acc: 0.9657 | Val F1: 0.8217 | F1 Illicit: 0.9819
# Epoch 220 | Loss: 0.0751 | Val Acc: 0.9657 | Val F1: 0.8217 | F1 Illicit: 0.9819
# Epoch 221 | Loss: 0.0743 | Val Acc: 0.9658 | Val F1: 0.8220 | F1 Illicit: 0.9820
# Epoch 222 | Loss: 0.0744 | Val Acc: 0.9658 | Val F1: 0.8222 | F1 Illicit: 0.9820
# Epoch 223 | Loss: 0.0749 | Val Acc: 0.9658 | Val F1: 0.8222 | F1 Illicit: 0.9820
# Epoch 224 | Loss: 0.0743 | Val Acc: 0.9659 | Val F1: 0.8224 | F1 Illicit: 0.9820
# Epoch 225 | Loss: 0.0746 | Val Acc: 0.9659 | Val F1: 0.8229 | F1 Illicit: 0.9821
# Epoch 226 | Loss: 0.0740 | Val Acc: 0.9659 | Val F1: 0.8229 | F1 Illicit: 0.9821
# Epoch 227 | Loss: 0.0742 | Val Acc: 0.9661 | Val F1: 0.8233 | F1 Illicit: 0.9821
# Epoch 228 | Loss: 0.0736 | Val Acc: 0.9659 | Val F1: 0.8226 | F1 Illicit: 0.9821
# Epoch 229 | Loss: 0.0735 | Val Acc: 0.9659 | Val F1: 0.8222 | F1 Illicit: 0.9820
# Epoch 230 | Loss: 0.0737 | Val Acc: 0.9659 | Val F1: 0.8222 | F1 Illicit: 0.9820
# Epoch 231 | Loss: 0.0729 | Val Acc: 0.9659 | Val F1: 0.8224 | F1 Illicit: 0.9821
# Epoch 232 | Loss: 0.0733 | Val Acc: 0.9659 | Val F1: 0.8224 | F1 Illicit: 0.9821
# Epoch 233 | Loss: 0.0727 | Val Acc: 0.9659 | Val F1: 0.8224 | F1 Illicit: 0.9821
# Epoch 234 | Loss: 0.0723 | Val Acc: 0.9661 | Val F1: 0.8231 | F1 Illicit: 0.9822
# Epoch 235 | Loss: 0.0730 | Val Acc: 0.9661 | Val F1: 0.8231 | F1 Illicit: 0.9822
# Epoch 236 | Loss: 0.0727 | Val Acc: 0.9661 | Val F1: 0.8225 | F1 Illicit: 0.9821
# Epoch 237 | Loss: 0.0715 | Val Acc: 0.9661 | Val F1: 0.8225 | F1 Illicit: 0.9821
# Epoch 238 | Loss: 0.0714 | Val Acc: 0.9660 | Val F1: 0.8222 | F1 Illicit: 0.9821
# Epoch 239 | Loss: 0.0717 | Val Acc: 0.9660 | Val F1: 0.8222 | F1 Illicit: 0.9821
# Epoch 240 | Loss: 0.0718 | Val Acc: 0.9659 | Val F1: 0.8220 | F1 Illicit: 0.9821
# Epoch 241 | Loss: 0.0715 | Val Acc: 0.9659 | Val F1: 0.8220 | F1 Illicit: 0.9821
# Epoch 242 | Loss: 0.0714 | Val Acc: 0.9661 | Val F1: 0.8229 | F1 Illicit: 0.9822
# Epoch 243 | Loss: 0.0710 | Val Acc: 0.9663 | Val F1: 0.8234 | F1 Illicit: 0.9822
# Epoch 244 | Loss: 0.0708 | Val Acc: 0.9663 | Val F1: 0.8234 | F1 Illicit: 0.9822
# Epoch 245 | Loss: 0.0707 | Val Acc: 0.9665 | Val F1: 0.8241 | F1 Illicit: 0.9823
# Epoch 246 | Loss: 0.0706 | Val Acc: 0.9665 | Val F1: 0.8241 | F1 Illicit: 0.9823
# Epoch 247 | Loss: 0.0705 | Val Acc: 0.9665 | Val F1: 0.8245 | F1 Illicit: 0.9824
# Epoch 248 | Loss: 0.0707 | Val Acc: 0.9665 | Val F1: 0.8245 | F1 Illicit: 0.9824
# Epoch 249 | Loss: 0.0706 | Val Acc: 0.9666 | Val F1: 0.8248 | F1 Illicit: 0.9824
# Epoch 250 | Loss: 0.0698 | Val Acc: 0.9666 | Val F1: 0.8248 | F1 Illicit: 0.9824
# Epoch 251 | Loss: 0.0704 | Val Acc: 0.9667 | Val F1: 0.8250 | F1 Illicit: 0.9825
# Epoch 252 | Loss: 0.0697 | Val Acc: 0.9667 | Val F1: 0.8250 | F1 Illicit: 0.9825
# Epoch 253 | Loss: 0.0694 | Val Acc: 0.9667 | Val F1: 0.8254 | F1 Illicit: 0.9825
# Epoch 254 | Loss: 0.0696 | Val Acc: 0.9667 | Val F1: 0.8252 | F1 Illicit: 0.9825
# Epoch 255 | Loss: 0.0690 | Val Acc: 0.9668 | Val F1: 0.8255 | F1 Illicit: 0.9825
# Epoch 256 | Loss: 0.0697 | Val Acc: 0.9668 | Val F1: 0.8255 | F1 Illicit: 0.9825
# Epoch 257 | Loss: 0.0685 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 258 | Loss: 0.0688 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 259 | Loss: 0.0685 | Val Acc: 0.9670 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 260 | Loss: 0.0686 | Val Acc: 0.9669 | Val F1: 0.8255 | F1 Illicit: 0.9826
# Epoch 261 | Loss: 0.0686 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 262 | Loss: 0.0694 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 263 | Loss: 0.0681 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 264 | Loss: 0.0681 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 265 | Loss: 0.0684 | Val Acc: 0.9670 | Val F1: 0.8262 | F1 Illicit: 0.9826
# Epoch 266 | Loss: 0.0679 | Val Acc: 0.9671 | Val F1: 0.8266 | F1 Illicit: 0.9827
# Epoch 267 | Loss: 0.0670 | Val Acc: 0.9671 | Val F1: 0.8264 | F1 Illicit: 0.9827
# Epoch 268 | Loss: 0.0674 | Val Acc: 0.9670 | Val F1: 0.8260 | F1 Illicit: 0.9826
# Epoch 269 | Loss: 0.0675 | Val Acc: 0.9670 | Val F1: 0.8260 | F1 Illicit: 0.9826
# Epoch 270 | Loss: 0.0669 | Val Acc: 0.9669 | Val F1: 0.8257 | F1 Illicit: 0.9826
# Epoch 271 | Loss: 0.0671 | Val Acc: 0.9669 | Val F1: 0.8253 | F1 Illicit: 0.9826
# Epoch 272 | Loss: 0.0676 | Val Acc: 0.9669 | Val F1: 0.8253 | F1 Illicit: 0.9826
# Epoch 273 | Loss: 0.0668 | Val Acc: 0.9669 | Val F1: 0.8255 | F1 Illicit: 0.9826
# Epoch 274 | Loss: 0.0674 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 275 | Loss: 0.0667 | Val Acc: 0.9671 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 276 | Loss: 0.0668 | Val Acc: 0.9673 | Val F1: 0.8269 | F1 Illicit: 0.9828
# Epoch 277 | Loss: 0.0663 | Val Acc: 0.9674 | Val F1: 0.8274 | F1 Illicit: 0.9828
# Epoch 278 | Loss: 0.0663 | Val Acc: 0.9673 | Val F1: 0.8267 | F1 Illicit: 0.9828
# Epoch 279 | Loss: 0.0666 | Val Acc: 0.9673 | Val F1: 0.8269 | F1 Illicit: 0.9828
# Epoch 280 | Loss: 0.0662 | Val Acc: 0.9674 | Val F1: 0.8274 | F1 Illicit: 0.9828
# Epoch 281 | Loss: 0.0659 | Val Acc: 0.9675 | Val F1: 0.8281 | F1 Illicit: 0.9829
# Epoch 282 | Loss: 0.0652 | Val Acc: 0.9676 | Val F1: 0.8283 | F1 Illicit: 0.9829
# Epoch 283 | Loss: 0.0662 | Val Acc: 0.9676 | Val F1: 0.8283 | F1 Illicit: 0.9829
# Epoch 284 | Loss: 0.0652 | Val Acc: 0.9673 | Val F1: 0.8267 | F1 Illicit: 0.9828
# Epoch 285 | Loss: 0.0655 | Val Acc: 0.9673 | Val F1: 0.8265 | F1 Illicit: 0.9828
# Epoch 286 | Loss: 0.0654 | Val Acc: 0.9673 | Val F1: 0.8267 | F1 Illicit: 0.9828
# Epoch 287 | Loss: 0.0652 | Val Acc: 0.9673 | Val F1: 0.8265 | F1 Illicit: 0.9828
# Epoch 288 | Loss: 0.0656 | Val Acc: 0.9673 | Val F1: 0.8265 | F1 Illicit: 0.9828
# Epoch 289 | Loss: 0.0649 | Val Acc: 0.9673 | Val F1: 0.8265 | F1 Illicit: 0.9828
# Epoch 290 | Loss: 0.0644 | Val Acc: 0.9672 | Val F1: 0.8262 | F1 Illicit: 0.9827
# Epoch 291 | Loss: 0.0647 | Val Acc: 0.9672 | Val F1: 0.8262 | F1 Illicit: 0.9827
# ...
# Epoch 104 | Loss: 0.1058 | Val Acc: 0.9496 | Val F1: 0.7757 | F1 Illicit: 0.9732
# Epoch 105 | Loss: 0.1059 | Val Acc: 0.9498 | Val F1: 0.7760 | F1 Illicit: 0.9733
# Epoch 106 | Loss: 0.1048 | Val Acc: 0.9500 | Val F1: 0.7772 | F1 Illicit: 0.9734
# Epoch 107 | Loss: 0.1037 | Val Acc: 0.9505 | Val F1: 0.7782 | F1 Illicit: 0.9737
# Epoch 108 | Loss: 0.1029 | Val Acc: 0.9510 | Val F1: 0.7792 | F1 Illicit: 0.9740
# Epoch 109 | Loss: 0.1026 | Val Acc: 0.9512 | Val F1: 0.7799 | F1 Illicit: 0.9741
# Epoch 110 | Loss: 0.1020 | Val Acc: 0.9517 | Val F1: 0.7814 | F1 Illicit: 0.9743
# Epoch 111 | Loss: 0.1013 | Val Acc: 0.9522 | Val F1: 0.7834 | F1 Illicit: 0.9746
# Epoch 112 | Loss: 0.1014 | Val Acc: 0.9525 | Val F1: 0.7840 | F1 Illicit: 0.9748
# Epoch 113 | Loss: 0.1003 | Val Acc: 0.9530 | Val F1: 0.7855 | F1 Illicit: 0.9751
# Epoch 114 | Loss: 0.0997 | Val Acc: 0.9532 | Val F1: 0.7861 | F1 Illicit: 0.9752
# Epoch 115 | Loss: 0.0997 | Val Acc: 0.9535 | Val F1: 0.7873 | F1 Illicit: 0.9753
# Epoch 116 | Loss: 0.0986 | Val Acc: 0.9535 | Val F1: 0.7877 | F1 Illicit: 0.9753
# Epoch 117 | Loss: 0.0975 | Val Acc: 0.9533 | Val F1: 0.7872 | F1 Illicit: 0.9752
# Epoch 118 | Loss: 0.0979 | Val Acc: 0.9538 | Val F1: 0.7891 | F1 Illicit: 0.9755
# Epoch 119 | Loss: 0.0972 | Val Acc: 0.9542 | Val F1: 0.7898 | F1 Illicit: 0.9757
# Epoch 120 | Loss: 0.0961 | Val Acc: 0.9543 | Val F1: 0.7897 | F1 Illicit: 0.9757
# Epoch 121 | Loss: 0.0959 | Val Acc: 0.9547 | Val F1: 0.7911 | F1 Illicit: 0.9760
# Epoch 122 | Loss: 0.0956 | Val Acc: 0.9552 | Val F1: 0.7926 | F1 Illicit: 0.9762
# Epoch 123 | Loss: 0.0954 | Val Acc: 0.9554 | Val F1: 0.7936 | F1 Illicit: 0.9764
# Epoch 124 | Loss: 0.0943 | Val Acc: 0.9558 | Val F1: 0.7948 | F1 Illicit: 0.9766
# Epoch 125 | Loss: 0.0933 | Val Acc: 0.9560 | Val F1: 0.7954 | F1 Illicit: 0.9767
# Epoch 126 | Loss: 0.0923 | Val Acc: 0.9560 | Val F1: 0.7951 | F1 Illicit: 0.9767
# Epoch 127 | Loss: 0.0935 | Val Acc: 0.9565 | Val F1: 0.7963 | F1 Illicit: 0.9769
# Epoch 128 | Loss: 0.0917 | Val Acc: 0.9566 | Val F1: 0.7964 | F1 Illicit: 0.9770
# Epoch 129 | Loss: 0.0915 | Val Acc: 0.9569 | Val F1: 0.7976 | F1 Illicit: 0.9771
# Epoch 130 | Loss: 0.0912 | Val Acc: 0.9567 | Val F1: 0.7977 | F1 Illicit: 0.9770
# Epoch 131 | Loss: 0.0905 | Val Acc: 0.9566 | Val F1: 0.7975 | F1 Illicit: 0.9770
# Epoch 132 | Loss: 0.0900 | Val Acc: 0.9564 | Val F1: 0.7969 | F1 Illicit: 0.9769
# Epoch 133 | Loss: 0.0890 | Val Acc: 0.9566 | Val F1: 0.7973 | F1 Illicit: 0.9770
# Epoch 134 | Loss: 0.0898 | Val Acc: 0.9567 | Val F1: 0.7966 | F1 Illicit: 0.9770
# Epoch 135 | Loss: 0.0880 | Val Acc: 0.9573 | Val F1: 0.7986 | F1 Illicit: 0.9774
# Epoch 136 | Loss: 0.0888 | Val Acc: 0.9576 | Val F1: 0.7994 | F1 Illicit: 0.9775
# Epoch 137 | Loss: 0.0878 | Val Acc: 0.9582 | Val F1: 0.8007 | F1 Illicit: 0.9779
# Epoch 138 | Loss: 0.0870 | Val Acc: 0.9584 | Val F1: 0.8011 | F1 Illicit: 0.9780
# Epoch 139 | Loss: 0.0874 | Val Acc: 0.9584 | Val F1: 0.8015 | F1 Illicit: 0.9780
# Epoch 140 | Loss: 0.0863 | Val Acc: 0.9583 | Val F1: 0.8005 | F1 Illicit: 0.9779
# Epoch 141 | Loss: 0.0858 | Val Acc: 0.9585 | Val F1: 0.8011 | F1 Illicit: 0.9780
# Epoch 142 | Loss: 0.0852 | Val Acc: 0.9585 | Val F1: 0.8009 | F1 Illicit: 0.9780
# Epoch 143 | Loss: 0.0855 | Val Acc: 0.9584 | Val F1: 0.8007 | F1 Illicit: 0.9780
# Epoch 144 | Loss: 0.0841 | Val Acc: 0.9587 | Val F1: 0.8015 | F1 Illicit: 0.9782
# Epoch 145 | Loss: 0.0853 | Val Acc: 0.9586 | Val F1: 0.8013 | F1 Illicit: 0.9781
# Epoch 146 | Loss: 0.0837 | Val Acc: 0.9587 | Val F1: 0.8019 | F1 Illicit: 0.9781
# Epoch 147 | Loss: 0.0838 | Val Acc: 0.9588 | Val F1: 0.8028 | F1 Illicit: 0.9782
# Epoch 148 | Loss: 0.0838 | Val Acc: 0.9590 | Val F1: 0.8034 | F1 Illicit: 0.9783
# Epoch 149 | Loss: 0.0838 | Val Acc: 0.9594 | Val F1: 0.8042 | F1 Illicit: 0.9785
# Epoch 150 | Loss: 0.0821 | Val Acc: 0.9592 | Val F1: 0.8035 | F1 Illicit: 0.9784
# Epoch 151 | Loss: 0.0824 | Val Acc: 0.9591 | Val F1: 0.8038 | F1 Illicit: 0.9784
# Epoch 152 | Loss: 0.0817 | Val Acc: 0.9589 | Val F1: 0.8034 | F1 Illicit: 0.9782
# Epoch 153 | Loss: 0.0808 | Val Acc: 0.9590 | Val F1: 0.8025 | F1 Illicit: 0.9783
# Epoch 154 | Loss: 0.0814 | Val Acc: 0.9590 | Val F1: 0.8023 | F1 Illicit: 0.9783
# Epoch 155 | Loss: 0.0812 | Val Acc: 0.9589 | Val F1: 0.8023 | F1 Illicit: 0.9783
# Epoch 156 | Loss: 0.0806 | Val Acc: 0.9597 | Val F1: 0.8058 | F1 Illicit: 0.9787
# Epoch 157 | Loss: 0.0793 | Val Acc: 0.9601 | Val F1: 0.8073 | F1 Illicit: 0.9789
# Epoch 158 | Loss: 0.0796 | Val Acc: 0.9596 | Val F1: 0.8061 | F1 Illicit: 0.9786
# Epoch 159 | Loss: 0.0798 | Val Acc: 0.9596 | Val F1: 0.8063 | F1 Illicit: 0.9786
# Epoch 160 | Loss: 0.0795 | Val Acc: 0.9599 | Val F1: 0.8069 | F1 Illicit: 0.9788
# Epoch 161 | Loss: 0.0782 | Val Acc: 0.9603 | Val F1: 0.8075 | F1 Illicit: 0.9790
# Epoch 162 | Loss: 0.0779 | Val Acc: 0.9603 | Val F1: 0.8075 | F1 Illicit: 0.9790
# Epoch 163 | Loss: 0.0781 | Val Acc: 0.9597 | Val F1: 0.8065 | F1 Illicit: 0.9787
# Epoch 164 | Loss: 0.0768 | Val Acc: 0.9596 | Val F1: 0.8056 | F1 Illicit: 0.9786
# Epoch 165 | Loss: 0.0780 | Val Acc: 0.9598 | Val F1: 0.8058 | F1 Illicit: 0.9787
# Epoch 166 | Loss: 0.0767 | Val Acc: 0.9602 | Val F1: 0.8066 | F1 Illicit: 0.9790
# Epoch 167 | Loss: 0.0765 | Val Acc: 0.9607 | Val F1: 0.8083 | F1 Illicit: 0.9792
# Epoch 168 | Loss: 0.0758 | Val Acc: 0.9604 | Val F1: 0.8075 | F1 Illicit: 0.9791
# Epoch 169 | Loss: 0.0753 | Val Acc: 0.9605 | Val F1: 0.8079 | F1 Illicit: 0.9791
# Epoch 170 | Loss: 0.0763 | Val Acc: 0.9607 | Val F1: 0.8087 | F1 Illicit: 0.9792
# Epoch 171 | Loss: 0.0753 | Val Acc: 0.9605 | Val F1: 0.8081 | F1 Illicit: 0.9791
# Epoch 172 | Loss: 0.0746 | Val Acc: 0.9605 | Val F1: 0.8081 | F1 Illicit: 0.9791
# Epoch 173 | Loss: 0.0740 | Val Acc: 0.9606 | Val F1: 0.8085 | F1 Illicit: 0.9792
# Epoch 174 | Loss: 0.0753 | Val Acc: 0.9609 | Val F1: 0.8098 | F1 Illicit: 0.9793
# Epoch 175 | Loss: 0.0744 | Val Acc: 0.9610 | Val F1: 0.8100 | F1 Illicit: 0.9794
# Epoch 176 | Loss: 0.0734 | Val Acc: 0.9612 | Val F1: 0.8106 | F1 Illicit: 0.9795
# Epoch 177 | Loss: 0.0732 | Val Acc: 0.9615 | Val F1: 0.8113 | F1 Illicit: 0.9797
# Epoch 178 | Loss: 0.0732 | Val Acc: 0.9616 | Val F1: 0.8119 | F1 Illicit: 0.9797
# Epoch 179 | Loss: 0.0729 | Val Acc: 0.9618 | Val F1: 0.8128 | F1 Illicit: 0.9798
# Epoch 180 | Loss: 0.0723 | Val Acc: 0.9620 | Val F1: 0.8134 | F1 Illicit: 0.9799
# Epoch 181 | Loss: 0.0726 | Val Acc: 0.9620 | Val F1: 0.8134 | F1 Illicit: 0.9799
# Epoch 182 | Loss: 0.0721 | Val Acc: 0.9618 | Val F1: 0.8130 | F1 Illicit: 0.9798
# Epoch 183 | Loss: 0.0724 | Val Acc: 0.9614 | Val F1: 0.8117 | F1 Illicit: 0.9796
# Epoch 184 | Loss: 0.0722 | Val Acc: 0.9614 | Val F1: 0.8117 | F1 Illicit: 0.9796
# Epoch 185 | Loss: 0.0722 | Val Acc: 0.9620 | Val F1: 0.8132 | F1 Illicit: 0.9799
# Epoch 186 | Loss: 0.0709 | Val Acc: 0.9624 | Val F1: 0.8145 | F1 Illicit: 0.9802
# Epoch 187 | Loss: 0.0708 | Val Acc: 0.9622 | Val F1: 0.8136 | F1 Illicit: 0.9800
# Epoch 188 | Loss: 0.0700 | Val Acc: 0.9619 | Val F1: 0.8130 | F1 Illicit: 0.9799
# Epoch 189 | Loss: 0.0702 | Val Acc: 0.9619 | Val F1: 0.8130 | F1 Illicit: 0.9799
# Epoch 190 | Loss: 0.0699 | Val Acc: 0.9624 | Val F1: 0.8145 | F1 Illicit: 0.9801
# Epoch 191 | Loss: 0.0695 | Val Acc: 0.9624 | Val F1: 0.8145 | F1 Illicit: 0.9801
# Epoch 192 | Loss: 0.0695 | Val Acc: 0.9621 | Val F1: 0.8138 | F1 Illicit: 0.9800
# Epoch 193 | Loss: 0.0692 | Val Acc: 0.9620 | Val F1: 0.8136 | F1 Illicit: 0.9799
# Epoch 194 | Loss: 0.0687 | Val Acc: 0.9623 | Val F1: 0.8145 | F1 Illicit: 0.9801
# Epoch 195 | Loss: 0.0690 | Val Acc: 0.9625 | Val F1: 0.8145 | F1 Illicit: 0.9802
# Epoch 196 | Loss: 0.0683 | Val Acc: 0.9626 | Val F1: 0.8147 | F1 Illicit: 0.9802
# Epoch 197 | Loss: 0.0680 | Val Acc: 0.9626 | Val F1: 0.8155 | F1 Illicit: 0.9803
# Epoch 198 | Loss: 0.0682 | Val Acc: 0.9628 | Val F1: 0.8160 | F1 Illicit: 0.9803
# Epoch 199 | Loss: 0.0681 | Val Acc: 0.9626 | Val F1: 0.8153 | F1 Illicit: 0.9803
# Epoch 200 | Loss: 0.0674 | Val Acc: 0.9628 | Val F1: 0.8153 | F1 Illicit: 0.9803
# Epoch 201 | Loss: 0.0670 | Val Acc: 0.9626 | Val F1: 0.8147 | F1 Illicit: 0.9802
# Epoch 202 | Loss: 0.0676 | Val Acc: 0.9626 | Val F1: 0.8151 | F1 Illicit: 0.9802
# Epoch 203 | Loss: 0.0661 | Val Acc: 0.9628 | Val F1: 0.8158 | F1 Illicit: 0.9804
# Epoch 204 | Loss: 0.0671 | Val Acc: 0.9632 | Val F1: 0.8169 | F1 Illicit: 0.9806
# Epoch 205 | Loss: 0.0654 | Val Acc: 0.9635 | Val F1: 0.8173 | F1 Illicit: 0.9807
# Epoch 206 | Loss: 0.0657 | Val Acc: 0.9637 | Val F1: 0.8184 | F1 Illicit: 0.9808
# Epoch 207 | Loss: 0.0660 | Val Acc: 0.9634 | Val F1: 0.8179 | F1 Illicit: 0.9807
# Epoch 208 | Loss: 0.0662 | Val Acc: 0.9633 | Val F1: 0.8179 | F1 Illicit: 0.9806
# Epoch 209 | Loss: 0.0651 | Val Acc: 0.9636 | Val F1: 0.8188 | F1 Illicit: 0.9808
# Epoch 210 | Loss: 0.0657 | Val Acc: 0.9636 | Val F1: 0.8182 | F1 Illicit: 0.9808
# Epoch 211 | Loss: 0.0654 | Val Acc: 0.9631 | Val F1: 0.8168 | F1 Illicit: 0.9805
# Epoch 212 | Loss: 0.0650 | Val Acc: 0.9630 | Val F1: 0.8175 | F1 Illicit: 0.9805
# Epoch 213 | Loss: 0.0650 | Val Acc: 0.9630 | Val F1: 0.8175 | F1 Illicit: 0.9805
# Epoch 214 | Loss: 0.0646 | Val Acc: 0.9635 | Val F1: 0.8184 | F1 Illicit: 0.9807
# Epoch 215 | Loss: 0.0646 | Val Acc: 0.9641 | Val F1: 0.8203 | F1 Illicit: 0.9810
# Epoch 216 | Loss: 0.0646 | Val Acc: 0.9642 | Val F1: 0.8210 | F1 Illicit: 0.9811
# Epoch 217 | Loss: 0.0637 | Val Acc: 0.9643 | Val F1: 0.8223 | F1 Illicit: 0.9811
# Epoch 218 | Loss: 0.0639 | Val Acc: 0.9639 | Val F1: 0.8212 | F1 Illicit: 0.9809
# Epoch 219 | Loss: 0.0638 | Val Acc: 0.9644 | Val F1: 0.8227 | F1 Illicit: 0.9812
# Epoch 220 | Loss: 0.0635 | Val Acc: 0.9644 | Val F1: 0.8217 | F1 Illicit: 0.9812
# Epoch 221 | Loss: 0.0626 | Val Acc: 0.9641 | Val F1: 0.8197 | F1 Illicit: 0.9811
# Epoch 222 | Loss: 0.0630 | Val Acc: 0.9643 | Val F1: 0.8219 | F1 Illicit: 0.9812
# Epoch 223 | Loss: 0.0629 | Val Acc: 0.9638 | Val F1: 0.8205 | F1 Illicit: 0.9809
# Epoch 224 | Loss: 0.0625 | Val Acc: 0.9644 | Val F1: 0.8219 | F1 Illicit: 0.9812
# Epoch 225 | Loss: 0.0631 | Val Acc: 0.9646 | Val F1: 0.8221 | F1 Illicit: 0.9813
# Epoch 226 | Loss: 0.0619 | Val Acc: 0.9648 | Val F1: 0.8228 | F1 Illicit: 0.9814
# Epoch 227 | Loss: 0.0626 | Val Acc: 0.9649 | Val F1: 0.8239 | F1 Illicit: 0.9815
# Epoch 228 | Loss: 0.0614 | Val Acc: 0.9646 | Val F1: 0.8227 | F1 Illicit: 0.9813
# Epoch 229 | Loss: 0.0626 | Val Acc: 0.9648 | Val F1: 0.8230 | F1 Illicit: 0.9814
# Epoch 230 | Loss: 0.0609 | Val Acc: 0.9648 | Val F1: 0.8228 | F1 Illicit: 0.9814
# Epoch 231 | Loss: 0.0619 | Val Acc: 0.9646 | Val F1: 0.8226 | F1 Illicit: 0.9813
# Epoch 232 | Loss: 0.0616 | Val Acc: 0.9648 | Val F1: 0.8228 | F1 Illicit: 0.9814
# Epoch 233 | Loss: 0.0615 | Val Acc: 0.9648 | Val F1: 0.8228 | F1 Illicit: 0.9814
# Epoch 234 | Loss: 0.0613 | Val Acc: 0.9650 | Val F1: 0.8233 | F1 Illicit: 0.9815
# Epoch 235 | Loss: 0.0614 | Val Acc: 0.9650 | Val F1: 0.8239 | F1 Illicit: 0.9815
# Epoch 236 | Loss: 0.0598 | Val Acc: 0.9650 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 237 | Loss: 0.0605 | Val Acc: 0.9653 | Val F1: 0.8248 | F1 Illicit: 0.9817
# Epoch 238 | Loss: 0.0609 | Val Acc: 0.9652 | Val F1: 0.8244 | F1 Illicit: 0.9816
# Epoch 239 | Loss: 0.0612 | Val Acc: 0.9649 | Val F1: 0.8235 | F1 Illicit: 0.9815
# Epoch 240 | Loss: 0.0606 | Val Acc: 0.9649 | Val F1: 0.8235 | F1 Illicit: 0.9815
# Epoch 241 | Loss: 0.0601 | Val Acc: 0.9650 | Val F1: 0.8235 | F1 Illicit: 0.9816
# Epoch 242 | Loss: 0.0592 | Val Acc: 0.9651 | Val F1: 0.8243 | F1 Illicit: 0.9816
# Epoch 243 | Loss: 0.0589 | Val Acc: 0.9650 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 244 | Loss: 0.0597 | Val Acc: 0.9648 | Val F1: 0.8232 | F1 Illicit: 0.9814
# Epoch 245 | Loss: 0.0600 | Val Acc: 0.9648 | Val F1: 0.8230 | F1 Illicit: 0.9814
# Epoch 246 | Loss: 0.0590 | Val Acc: 0.9648 | Val F1: 0.8228 | F1 Illicit: 0.9814
# Epoch 247 | Loss: 0.0594 | Val Acc: 0.9650 | Val F1: 0.8231 | F1 Illicit: 0.9815
# Epoch 248 | Loss: 0.0593 | Val Acc: 0.9647 | Val F1: 0.8222 | F1 Illicit: 0.9814
# Epoch 249 | Loss: 0.0595 | Val Acc: 0.9648 | Val F1: 0.8234 | F1 Illicit: 0.9814
# Epoch 250 | Loss: 0.0590 | Val Acc: 0.9648 | Val F1: 0.8234 | F1 Illicit: 0.9814
# Epoch 251 | Loss: 0.0590 | Val Acc: 0.9650 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 252 | Loss: 0.0591 | Val Acc: 0.9652 | Val F1: 0.8250 | F1 Illicit: 0.9817
# Epoch 253 | Loss: 0.0580 | Val Acc: 0.9650 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 254 | Loss: 0.0582 | Val Acc: 0.9653 | Val F1: 0.8258 | F1 Illicit: 0.9817
# Epoch 255 | Loss: 0.0574 | Val Acc: 0.9652 | Val F1: 0.8248 | F1 Illicit: 0.9817
# Epoch 256 | Loss: 0.0576 | Val Acc: 0.9650 | Val F1: 0.8239 | F1 Illicit: 0.9816
# Epoch 257 | Loss: 0.0574 | Val Acc: 0.9648 | Val F1: 0.8234 | F1 Illicit: 0.9814
# Epoch 258 | Loss: 0.0585 | Val Acc: 0.9648 | Val F1: 0.8230 | F1 Illicit: 0.9814
# Epoch 259 | Loss: 0.0568 | Val Acc: 0.9646 | Val F1: 0.8223 | F1 Illicit: 0.9813
# Epoch 260 | Loss: 0.0565 | Val Acc: 0.9645 | Val F1: 0.8219 | F1 Illicit: 0.9813
# Epoch 261 | Loss: 0.0573 | Val Acc: 0.9644 | Val F1: 0.8215 | F1 Illicit: 0.9812
# Epoch 262 | Loss: 0.0571 | Val Acc: 0.9644 | Val F1: 0.8210 | F1 Illicit: 0.9812
# Epoch 263 | Loss: 0.0573 | Val Acc: 0.9644 | Val F1: 0.8215 | F1 Illicit: 0.9812
# Epoch 264 | Loss: 0.0570 | Val Acc: 0.9646 | Val F1: 0.8234 | F1 Illicit: 0.9813
# Epoch 265 | Loss: 0.0576 | Val Acc: 0.9648 | Val F1: 0.8249 | F1 Illicit: 0.9814
# Epoch 266 | Loss: 0.0573 | Val Acc: 0.9652 | Val F1: 0.8260 | F1 Illicit: 0.9816
# Epoch 267 | Loss: 0.0565 | Val Acc: 0.9655 | Val F1: 0.8261 | F1 Illicit: 0.9818
# Epoch 268 | Loss: 0.0564 | Val Acc: 0.9653 | Val F1: 0.8252 | F1 Illicit: 0.9817
# Epoch 269 | Loss: 0.0559 | Val Acc: 0.9651 | Val F1: 0.8250 | F1 Illicit: 0.9816
# Epoch 270 | Loss: 0.0564 | Val Acc: 0.9650 | Val F1: 0.8247 | F1 Illicit: 0.9815
# Epoch 271 | Loss: 0.0563 | Val Acc: 0.9648 | Val F1: 0.8234 | F1 Illicit: 0.9814
# Epoch 272 | Loss: 0.0571 | Val Acc: 0.9648 | Val F1: 0.8230 | F1 Illicit: 0.9814
# Epoch 273 | Loss: 0.0563 | Val Acc: 0.9649 | Val F1: 0.8232 | F1 Illicit: 0.9815
# Epoch 274 | Loss: 0.0565 | Val Acc: 0.9649 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 275 | Loss: 0.0553 | Val Acc: 0.9645 | Val F1: 0.8227 | F1 Illicit: 0.9813
# Epoch 276 | Loss: 0.0562 | Val Acc: 0.9644 | Val F1: 0.8221 | F1 Illicit: 0.9812
# Epoch 277 | Loss: 0.0554 | Val Acc: 0.9644 | Val F1: 0.8221 | F1 Illicit: 0.9812
# Epoch 278 | Loss: 0.0565 | Val Acc: 0.9641 | Val F1: 0.8212 | F1 Illicit: 0.9810
# Epoch 279 | Loss: 0.0551 | Val Acc: 0.9644 | Val F1: 0.8223 | F1 Illicit: 0.9812
# Epoch 280 | Loss: 0.0562 | Val Acc: 0.9650 | Val F1: 0.8243 | F1 Illicit: 0.9815
# Epoch 281 | Loss: 0.0550 | Val Acc: 0.9649 | Val F1: 0.8239 | F1 Illicit: 0.9815
# Epoch 282 | Loss: 0.0556 | Val Acc: 0.9648 | Val F1: 0.8234 | F1 Illicit: 0.9814
# Epoch 283 | Loss: 0.0544 | Val Acc: 0.9648 | Val F1: 0.8236 | F1 Illicit: 0.9814
# Epoch 284 | Loss: 0.0550 | Val Acc: 0.9648 | Val F1: 0.8232 | F1 Illicit: 0.9814
# Epoch 285 | Loss: 0.0540 | Val Acc: 0.9648 | Val F1: 0.8232 | F1 Illicit: 0.9814
# Epoch 286 | Loss: 0.0543 | Val Acc: 0.9644 | Val F1: 0.8227 | F1 Illicit: 0.9812
# Epoch 287 | Loss: 0.0544 | Val Acc: 0.9644 | Val F1: 0.8229 | F1 Illicit: 0.9812
# Epoch 288 | Loss: 0.0547 | Val Acc: 0.9646 | Val F1: 0.8232 | F1 Illicit: 0.9813
# Epoch 289 | Loss: 0.0554 | Val Acc: 0.9649 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 290 | Loss: 0.0540 | Val Acc: 0.9650 | Val F1: 0.8241 | F1 Illicit: 0.9815
# Epoch 291 | Loss: 0.0537 | Val Acc: 0.9652 | Val F1: 0.8248 | F1 Illicit: 0.9817
# Epoch 292 | Loss: 0.0547 | Val Acc: 0.9654 | Val F1: 0.8259 | F1 Illicit: 0.9818
# Epoch 293 | Loss: 0.0536 | Val Acc: 0.9656 | Val F1: 0.8263 | F1 Illicit: 0.9818
# Epoch 294 | Loss: 0.0535 | Val Acc: 0.9652 | Val F1: 0.8252 | F1 Illicit: 0.9817
# Epoch 295 | Loss: 0.0543 | Val Acc: 0.9652 | Val F1: 0.8254 | F1 Illicit: 0.9817
# Epoch 296 | Loss: 0.0537 | Val Acc: 0.9649 | Val F1: 0.8253 | F1 Illicit: 0.9815
# Epoch 297 | Loss: 0.0532 | Val Acc: 0.9649 | Val F1: 0.8253 | F1 Illicit: 0.9815
# Epoch 298 | Loss: 0.0534 | Val Acc: 0.9651 | Val F1: 0.8256 | F1 Illicit: 0.9816
# Epoch 299 | Loss: 0.0532 | Val Acc: 0.9652 | Val F1: 0.8260 | F1 Illicit: 0.9816
# Epoch 300 | Loss: 0.0527 | Val Acc: 0.9651 | Val F1: 0.8258 | F1 Illicit: 0.9816

# %% [markdown]
# ## 4. Evaluation

# %%
import torch, os

base_dir = "../model_features/temporal/SAGE_ablation"  # adjust as needed

for ablation in sorted(os.listdir(base_dir)):
    for seed in [42, 123, 777, 2023, 31415]:
        path = os.path.join(base_dir, ablation, f"seed_{seed}", "model.pth")
        if not os.path.exists(path): continue
        state_dict = torch.load(path, map_location="cpu")
        in_dim = state_dict["conv1.lin_l.weight"].shape[1]
        print(f"{ablation}/seed_{seed} → expects in_channels: {in_dim}")
# Out:
# all/seed_42 → expects in_channels: 174
# all/seed_123 → expects in_channels: 174
# all/seed_777 → expects in_channels: 174
# all/seed_2023 → expects in_channels: 174
# all/seed_31415 → expects in_channels: 174
# base/seed_42 → expects in_channels: 166
# base/seed_123 → expects in_channels: 166
# base/seed_777 → expects in_channels: 166
# base/seed_2023 → expects in_channels: 166
# base/seed_31415 → expects in_channels: 166
# base+basic_temporal/seed_42 → expects in_channels: 168
# base+basic_temporal/seed_123 → expects in_channels: 168
# base+basic_temporal/seed_777 → expects in_channels: 168
# base+basic_temporal/seed_2023 → expects in_channels: 168
# base+basic_temporal/seed_31415 → expects in_channels: 168
# base+basic_temporal+typology/seed_42 → expects in_channels: 170
# base+basic_temporal+typology/seed_123 → expects in_channels: 170
# base+basic_temporal+typology/seed_777 → expects in_channels: 170
# base+basic_temporal+typology/seed_2023 → expects in_channels: 170
# base+basic_temporal+typology/seed_31415 → expects in_channels: 170
# base+structural/seed_42 → expects in_channels: 170
# base+structural/seed_123 → expects in_channels: 170
# base+structural/seed_777 → expects in_channels: 170
# base+structural/seed_2023 → expects in_channels: 170
# base+structural/seed_31415 → expects in_channels: 170
# base+structural+typology/seed_42 → expects in_channels: 172
# base+structural+typology/seed_123 → expects in_channels: 172
# base+structural+typology/seed_777 → expects in_channels: 172
# base+structural+typology/seed_2023 → expects in_channels: 172
# base+structural+typology/seed_31415 → expects in_channels: 172
# base+typology/seed_42 → expects in_channels: 168
# base+typology/seed_123 → expects in_channels: 168
# base+typology/seed_777 → expects in_channels: 168
# base+typology/seed_2023 → expects in_channels: 168
# base+typology/seed_31415 → expects in_channels: 168

# %%
import os
import json
import torch

base_dir = "../model_features/temporal/SAGE_ablation"
data_dir = "../data/SAGE_temporal"
seeds = [42, 123, 777, 2023, 31415]

for ablation in sorted(os.listdir(base_dir)):
    ablation_model_path = os.path.join(base_dir, ablation)
    ablation_data_path = os.path.join(data_dir, ablation)

    if not os.path.isdir(ablation_model_path):
        continue

    print(f"\n→ Processing ablation: {ablation}")

    for seed in seeds:
        seed_dir = f"seed_{seed}"
        config_path = os.path.join(ablation_model_path, seed_dir, "config.json")
        model_path = os.path.join(ablation_model_path, seed_dir, "model.pth")
        data_path = os.path.join(ablation_data_path, seed_dir, "data_exp.pt")

        if not all(os.path.exists(p) for p in [config_path, model_path, data_path]):
            continue

        with open(config_path, "r") as f:
            config = json.load(f)

        updated = False
        data = torch.load(data_path, map_location="cpu", weights_only=False)
        feature_dim = data.x.shape[1]

        if config.get("feature_dim") != feature_dim:
            config["feature_dim"] = feature_dim
            updated = True

        # Patch SAGE-specific fields
        if config.get("model") == "SAGE":
            if config.get("hidden_channels") != 64:
                config["hidden_channels"] = 64
                updated = True
            if config.get("out_channels") != 2:
                config["out_channels"] = 2
                updated = True
            if config.get("dropout") != 0.1:
                config["dropout"] = 0.1
                updated = True

        if updated:
            with open(config_path, "w") as f:
                json.dump(config, f, indent=4)
            print(f"✓ Patched config for {ablation} / seed {seed}")
        else:
            print(f"✓ Already complete: {ablation} / seed {seed}")
# Out:
# → Processing ablation: all
# ✓ Patched config for all / seed 42
# ✓ Patched config for all / seed 123
# ✓ Patched config for all / seed 777
# ✓ Patched config for all / seed 2023
# ✓ Patched config for all / seed 31415
#
# → Processing ablation: base
# ✓ Patched config for base / seed 42
# ✓ Patched config for base / seed 123
# ✓ Patched config for base / seed 777
# ✓ Patched config for base / seed 2023
# ✓ Patched config for base / seed 31415
#
# → Processing ablation: base+basic_temporal
# ✓ Patched config for base+basic_temporal / seed 42
# ✓ Patched config for base+basic_temporal / seed 123
# ✓ Patched config for base+basic_temporal / seed 777
# ✓ Patched config for base+basic_temporal / seed 2023
# ✓ Patched config for base+basic_temporal / seed 31415
#
# → Processing ablation: base+basic_temporal+typology
# ✓ Patched config for base+basic_temporal+typology / seed 42
# ✓ Patched config for base+basic_temporal+typology / seed 123
# ✓ Patched config for base+basic_temporal+typology / seed 777
# ✓ Patched config for base+basic_temporal+typology / seed 2023
# ✓ Patched config for base+basic_temporal+typology / seed 31415
#
# → Processing ablation: base+structural
# ✓ Patched config for base+structural / seed 42
# ✓ Patched config for base+structural / seed 123
# ✓ Patched config for base+structural / seed 777
# ✓ Patched config for base+structural / seed 2023
# ✓ Patched config for base+structural / seed 31415
#
# → Processing ablation: base+structural+typology
# ✓ Patched config for base+structural+typology / seed 42
# ✓ Patched config for base+structural+typology / seed 123
# ✓ Patched config for base+structural+typology / seed 777
# ✓ Patched config for base+structural+typology / seed 2023
# ✓ Patched config for base+structural+typology / seed 31415
#
# → Processing ablation: base+typology
# ✓ Patched config for base+typology / seed 42
# ✓ Patched config for base+typology / seed 123
# ✓ Patched config for base+typology / seed 777
# ✓ Patched config for base+typology / seed 2023
# ✓ Patched config for base+typology / seed 31415

# %%
import os
from features.evaluate_ablation_model import evaluate_ablation_model
from evaluation_pipeline import run_inference_all_seeds
from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
from features.feature_utils import make_model_class_from_config

# === Config ===
seeds = [42, 123, 777, 2023, 31415]
base_dir = "../model_features/temporal/SAGE_ablation"
data_exp_root = "../data/SAGE_temporal"
node_id_csv_path = "../elliptic_bitcoin_dataset/elliptic_txs_features.csv"

model_tag = "SAGE-Temporal"
split = "temporal"

# === Evaluate all ablations ===
for ablation in sorted(os.listdir(base_dir)):
    model_dir = os.path.join(base_dir, ablation)
    if not os.path.isdir(model_dir):
        continue

    print(f"\n→ Evaluating ablation: {ablation}")
    model_name = f"{model_tag}: {ablation}"
    ablation_data_dir = os.path.join(data_exp_root, ablation)
    config_path = os.path.join(model_dir, "seed_42", "config.json")
    model_class = make_model_class_from_config(config_path)

    # Run full evaluation
    evaluate_ablation_model(
        model_dir=model_dir,
        model_class=model_class,
        model_name=model_name,
        seeds=seeds,
        node_id_csv_path=node_id_csv_path,
        data_dir=ablation_data_dir
    )

    # Run inference (for logging CSV)
    y_true_all, y_pred_all, y_proba_all, seed_metrics = run_inference_all_seeds(
        model_dir=model_dir,
        model_class=model_class,
        data_dir=ablation_data_dir,
        seeds=seeds
    )
    val_acc_list = load_metrics_across_seeds(model_dir, ["val_acc"])["val_acc"]

    # Save to CSV
    log_metrics_to_csv(
        model_name=model_tag,
        split_name=split,
        ablation=ablation,
        seeds=seeds,
        val_acc_list=val_acc_list,
        seed_metrics=seed_metrics,
        is_feature=True  # append _feature to filename
    )
