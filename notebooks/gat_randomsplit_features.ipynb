# %% [markdown]
# ## 1. Environment Setup and Imports
# Ensure we're using the correct kernel and loading utils from the `src/` directory. Now we also load features.

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# Torch & GNN
import torch
from torch_geometric.nn import GATConv

# Custom modules
from load_elliptic_data import load_and_preprocess_elliptic_data
from data_utils_randomsplit import random_split
from model_gat import GATNet
from train_utils import set_seed, train_full, save_feature_experiment
from config import SEEDS

# Feature pipeline
from features.feature_config import FEATURE_CONFIGS
from features.feature_runner import apply_engineered_features
from features.feature_utils import prepare_graph_and_timestamps
from normalization import normalize_base_features_only

print("✓ All modules imported successfully.")
# Out:
# ✓ All modules imported successfully.

# %% [markdown]
# ## 2. Load and Preprocess the Elliptic Dataset + Graph for Features + Time Stamps
# This loads the PyG-formatted graph and base features. We also construct a NetworkX transaction graph for topology-based features. Per-node timestamp sequences is extracted for temporal burst analysis

# %%
from normalization import normalize_base_features_only
from features.feature_pipeline import generate_all_features
import os
import torch

# 1. Load graph
data = load_and_preprocess_elliptic_data("../elliptic_bitcoin_dataset", normalize=False)
print(f"✓ PyG Data object loaded: {data}")

# 2. Prepare NetworkX and timestamps
G_nx, node_timestamps = prepare_graph_and_timestamps(
    edgelist_path="../elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv",
    features_path="../elliptic_bitcoin_dataset/elliptic_txs_features.csv",
    num_nodes=data.num_nodes
)

# 3. Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ABLATORS = {
    k: v for k, v in FEATURE_CONFIGS.items()
}
FEATURED_DATA = {}

# 4. Loop through ablations and seeds
for ablation_name, feature_flags in ABLATORS.items():
    print(f"\n== Config: {ablation_name} ==")
    for seed in SEEDS:
        print(f"→ Seed {seed}")
        set_seed(seed)
        train_idx, val_idx = random_split(data, random_state=seed)

        # Clone and extract features
        data_exp = data.clone()
        X, feature_names = generate_all_features(data_exp, G_nx, node_timestamps, **feature_flags)
        data_exp.x = torch.tensor(X, dtype=torch.float)

        # Optional monitoring of temporal features
        temporal_names = {"temporal_lag", "component_size"}
        temporal_indices = [i for i, name in enumerate(feature_names) if name in temporal_names]

        if temporal_indices:
            print("→ Temporal features (raw)")
            print("  Means:", data_exp.x[:, temporal_indices].mean(0))
            print("  Stds :", data_exp.x[:, temporal_indices].std(0))

        # Normalize base features only
        data_exp.x = normalize_base_features_only(data_exp.x, feature_names)

        # Move to device
        data_exp = data_exp.to(device)

        # Store in memory
        FEATURED_DATA[(ablation_name, seed)] = {
            "data": data_exp,
            "train_idx": train_idx,
            "val_idx": val_idx,
            "feature_flags": feature_flags,
        }

        # Save to disk
        save_dir = f"../data/GAT_randomsplit/{ablation_name}/seed_{seed}"
        os.makedirs(save_dir, exist_ok=True)
        torch.save(data_exp, os.path.join(save_dir, "data_exp.pt"))
        torch.save(train_idx, os.path.join(save_dir, "train_idx.pt"))
        torch.save(val_idx, os.path.join(save_dir, "val_idx.pt"))
        print(f"✓ Saved: {save_dir}")
        print(f"✓ Final shape: {data_exp.x.shape}")
# Out:
# ✓ PyG Data object loaded: Data(x=[203769, 166], edge_index=[2, 234355], y=[203769])
# Loaded directed graph with 203769 nodes and 234355 edges.
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Features DataFrame shape: (203769, 167)
# Number of features (excluding txId and time_step): 165
# Timestamps found for 203769 out of 203769 nodes.
# ✓ Time step range: 1.0 to 49.0
#
# == Config: base ==
# → Seed 42
# ✓ Saved: ../data/GAT_randomsplit/base/seed_42
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 123
# ✓ Saved: ../data/GAT_randomsplit/base/seed_123
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 777
# ✓ Saved: ../data/GAT_randomsplit/base/seed_777
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 2023
# ✓ Saved: ../data/GAT_randomsplit/base/seed_2023
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 31415
# ✓ Saved: ../data/GAT_randomsplit/base/seed_31415
# ✓ Final shape: torch.Size([203769, 166])
#
# == Config: base+structural ==
# → Seed 42
# ✓ Saved: ../data/GAT_randomsplit/base+structural/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# ✓ Saved: ../data/GAT_randomsplit/base+structural/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# ✓ Saved: ../data/GAT_randomsplit/base+structural/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# ✓ Saved: ../data/GAT_randomsplit/base+structural/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# ✓ Saved: ../data/GAT_randomsplit/base+structural/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: base+typology ==
# → Seed 42
# ✓ Saved: ../data/GAT_randomsplit/base+typology/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# ✓ Saved: ../data/GAT_randomsplit/base+typology/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# ✓ Saved: ../data/GAT_randomsplit/base+typology/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# ✓ Saved: ../data/GAT_randomsplit/base+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# ✓ Saved: ../data/GAT_randomsplit/base+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+structural+typology ==
# → Seed 42
# ✓ Saved: ../data/GAT_randomsplit/base+structural+typology/seed_42
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 123
# ✓ Saved: ../data/GAT_randomsplit/base+structural+typology/seed_123
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 777
# ✓ Saved: ../data/GAT_randomsplit/base+structural+typology/seed_777
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 2023
# ✓ Saved: ../data/GAT_randomsplit/base+structural+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 31415
# ✓ Saved: ../data/GAT_randomsplit/base+structural+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 172])
#
# == Config: base+basic_temporal ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 406551.65it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 504853.87it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 532219.95it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 517017.76it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 460482.14it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+basic_temporal+typology ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 536434.64it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal+typology/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 532304.14it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal+typology/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 534371.94it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal+typology/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 563913.59it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 546734.91it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/base+basic_temporal+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: all ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 557969.08it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/all/seed_42
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 547144.42it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/all/seed_123
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 554280.99it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/all/seed_777
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 564875.92it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/all/seed_2023
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 566555.72it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GAT_randomsplit/all/seed_31415
# ✓ Final shape: torch.Size([203769, 174])

# %%
import torch
import os

ROOT_DIR = "../data/GAT_randomsplit"
BASE_DIM = 166
SEEDS = [42, 123, 777, 2023, 31415]

print("\n📊 ENGINEERED FEATURE INSPECTION (from disk)")

# Loop over ablation folders
for ablation_name in sorted(os.listdir(ROOT_DIR)):
    ablation_path = os.path.join(ROOT_DIR, ablation_name)
    if not os.path.isdir(ablation_path):
        continue

    for seed in SEEDS:
        seed_dir = f"seed_{seed}"
        data_path = os.path.join(ablation_path, seed_dir, "data_exp.pt")
        if not os.path.exists(data_path):
            print(f"⛔ Missing file: {data_path}")
            continue

        data = torch.load(data_path, map_location="cpu", weights_only=False)
        x = data.x

        if x.shape[1] <= BASE_DIM:
            print(f"\n {ablation_name} | Seed: {seed}")
            print(" No engineered features found.")
            continue

        engineered = x[:, BASE_DIM:]
        print(f"\n {ablation_name} | Seed: {seed}")
        print(f" Engineered feature count: {engineered.shape[1]}")

        means = engineered.mean(dim=0)
        stds = engineered.std(dim=0)

        for i in range(engineered.shape[1]):
            m = means[i].item()
            s = stds[i].item()
            sample_vals = engineered[:5, i].numpy()
            print(f"Feature {BASE_DIM + i:>3} | Mean: {m:8.4f} | Std: {s:8.4f} | Sample: {sample_vals}")
# Out:
# 📊 ENGINEERED FEATURE INSPECTION (from disk)
#
#  all | Seed: 42
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 123
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 777
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 2023
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 31415
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+structural | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural+typology | Seed: 42
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 123
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 777
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 2023
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 31415
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]

# %% [markdown]
# ## 3. Initialize the GAT Model and Training
# Set hyperparameters and move model/data to GPU/CPU if available.

# %%
from model_gat import GATNet
from train_utils import train_full, save_feature_experiment
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SKIP_GAT_TEMPORAL = {"base+structural", "base+typology", "base+structural+typology", "all", "base+basic_temporal", "base+basic_temporal+typology"}

for (ablation_name, seed), bundle in FEATURED_DATA.items():
    if ablation_name in SKIP_GAT_TEMPORAL:
        print(f"Skipping already trained config: {ablation_name}, seed: {seed}")
        continue

    print(f"\n=== Training GAT (Temporal): {ablation_name} | Seed: {seed} ===")

    data_exp = bundle["data"]
    train_idx = bundle["train_idx"]
    val_idx = bundle["val_idx"]
    feature_flags = bundle["feature_flags"]

    # Initialize model
    model = GATNet(
        in_channels=data_exp.x.shape[1],
        hidden_channels=8,
        out_channels=2,
        heads=8,
        dropout=0.1
    ).to(device)

    # Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # Train model
    model, *results = train_full(
        model=model,
        data=data_exp,
        train_idx=train_idx,
        val_idx=val_idx,
        optimizer=optimizer,
        num_epochs=300,
        patience=30
    )

    # Save logs and model
    output_dir = f"../model_features/randomsplit/GAT_ablation/{ablation_name}/seed_{seed}"
    os.makedirs(output_dir, exist_ok=True)

    save_feature_experiment(
        output_dir=output_dir,
        model=model,
        results=results,
        seed=seed,
        config={
            "model": "GAT",
            "ablation_name": ablation_name,
            "feature_flags": feature_flags,
            "feature_dim": data_exp.x.shape[1],
            "dropout": 0.1,
            "num_epochs": 300,
            "patience": 30,
            "lr": 0.001,
            "weight_decay": 5e-4
        },
        val_idx=val_idx
    )
# Out:
# === Training GAT (Temporal): base | Seed: 42 ===
# Epoch 001 | Loss: 0.9464 | Val Acc: 0.6367 | Val F1: 0.4907 | F1 Illicit: 0.7634
# Epoch 002 | Loss: 0.8481 | Val Acc: 0.6947 | Val F1: 0.5340 | F1 Illicit: 0.8076
# Epoch 003 | Loss: 0.7000 | Val Acc: 0.7294 | Val F1: 0.5633 | F1 Illicit: 0.8326
# Epoch 004 | Loss: 0.6189 | Val Acc: 0.7585 | Val F1: 0.5887 | F1 Illicit: 0.8530
# Epoch 005 | Loss: 0.5792 | Val Acc: 0.7786 | Val F1: 0.6050 | F1 Illicit: 0.8669
# Epoch 006 | Loss: 0.5319 | Val Acc: 0.7931 | Val F1: 0.6154 | F1 Illicit: 0.8768
# Epoch 007 | Loss: 0.5092 | Val Acc: 0.8039 | Val F1: 0.6229 | F1 Illicit: 0.8842
# Epoch 008 | Loss: 0.4734 | Val Acc: 0.8157 | Val F1: 0.6296 | F1 Illicit: 0.8922
# Epoch 009 | Loss: 0.4759 | Val Acc: 0.8296 | Val F1: 0.6392 | F1 Illicit: 0.9013
# Epoch 010 | Loss: 0.4294 | Val Acc: 0.8410 | Val F1: 0.6463 | F1 Illicit: 0.9087
# Epoch 011 | Loss: 0.4096 | Val Acc: 0.8530 | Val F1: 0.6534 | F1 Illicit: 0.9165
# Epoch 012 | Loss: 0.3933 | Val Acc: 0.8626 | Val F1: 0.6572 | F1 Illicit: 0.9226
# Epoch 013 | Loss: 0.3766 | Val Acc: 0.8737 | Val F1: 0.6631 | F1 Illicit: 0.9295
# Epoch 014 | Loss: 0.3650 | Val Acc: 0.8818 | Val F1: 0.6632 | F1 Illicit: 0.9345
# Epoch 015 | Loss: 0.3566 | Val Acc: 0.8898 | Val F1: 0.6644 | F1 Illicit: 0.9394
# Epoch 016 | Loss: 0.3421 | Val Acc: 0.8971 | Val F1: 0.6616 | F1 Illicit: 0.9439
# Epoch 017 | Loss: 0.3312 | Val Acc: 0.9018 | Val F1: 0.6526 | F1 Illicit: 0.9468
# Epoch 018 | Loss: 0.3245 | Val Acc: 0.9061 | Val F1: 0.6431 | F1 Illicit: 0.9495
# Epoch 019 | Loss: 0.3158 | Val Acc: 0.9076 | Val F1: 0.6310 | F1 Illicit: 0.9505
# Epoch 020 | Loss: 0.3124 | Val Acc: 0.9072 | Val F1: 0.6159 | F1 Illicit: 0.9504
# Epoch 021 | Loss: 0.3071 | Val Acc: 0.9074 | Val F1: 0.6044 | F1 Illicit: 0.9506
# Epoch 022 | Loss: 0.3009 | Val Acc: 0.9071 | Val F1: 0.5957 | F1 Illicit: 0.9505
# Epoch 023 | Loss: 0.3008 | Val Acc: 0.9067 | Val F1: 0.5885 | F1 Illicit: 0.9504
# Epoch 024 | Loss: 0.2953 | Val Acc: 0.9068 | Val F1: 0.5826 | F1 Illicit: 0.9505
# Epoch 025 | Loss: 0.2943 | Val Acc: 0.9075 | Val F1: 0.5811 | F1 Illicit: 0.9509
# Epoch 026 | Loss: 0.2906 | Val Acc: 0.9074 | Val F1: 0.5770 | F1 Illicit: 0.9508
# Epoch 027 | Loss: 0.2878 | Val Acc: 0.9076 | Val F1: 0.5763 | F1 Illicit: 0.9510
# Epoch 028 | Loss: 0.2862 | Val Acc: 0.9082 | Val F1: 0.5764 | F1 Illicit: 0.9513
# Epoch 029 | Loss: 0.2845 | Val Acc: 0.9087 | Val F1: 0.5785 | F1 Illicit: 0.9515
# Epoch 030 | Loss: 0.2815 | Val Acc: 0.9092 | Val F1: 0.5821 | F1 Illicit: 0.9518
# Epoch 031 | Loss: 0.2793 | Val Acc: 0.9097 | Val F1: 0.5846 | F1 Illicit: 0.9521
# Epoch 032 | Loss: 0.2785 | Val Acc: 0.9104 | Val F1: 0.5884 | F1 Illicit: 0.9524
# Epoch 033 | Loss: 0.2754 | Val Acc: 0.9107 | Val F1: 0.5902 | F1 Illicit: 0.9526
# Epoch 034 | Loss: 0.2711 | Val Acc: 0.9112 | Val F1: 0.5933 | F1 Illicit: 0.9529
# Epoch 035 | Loss: 0.2694 | Val Acc: 0.9119 | Val F1: 0.5983 | F1 Illicit: 0.9532
# Epoch 036 | Loss: 0.2688 | Val Acc: 0.9124 | Val F1: 0.6022 | F1 Illicit: 0.9535
# Epoch 037 | Loss: 0.2679 | Val Acc: 0.9129 | Val F1: 0.6056 | F1 Illicit: 0.9537
# Epoch 038 | Loss: 0.2667 | Val Acc: 0.9131 | Val F1: 0.6081 | F1 Illicit: 0.9538
# Epoch 039 | Loss: 0.2646 | Val Acc: 0.9135 | Val F1: 0.6113 | F1 Illicit: 0.9540
# Epoch 040 | Loss: 0.2614 | Val Acc: 0.9137 | Val F1: 0.6116 | F1 Illicit: 0.9541
# Epoch 041 | Loss: 0.2639 | Val Acc: 0.9141 | Val F1: 0.6144 | F1 Illicit: 0.9543
# Epoch 042 | Loss: 0.2621 | Val Acc: 0.9147 | Val F1: 0.6174 | F1 Illicit: 0.9546
# Epoch 043 | Loss: 0.2616 | Val Acc: 0.9149 | Val F1: 0.6199 | F1 Illicit: 0.9548
# Epoch 044 | Loss: 0.2619 | Val Acc: 0.9159 | Val F1: 0.6252 | F1 Illicit: 0.9553
# Epoch 045 | Loss: 0.2587 | Val Acc: 0.9161 | Val F1: 0.6260 | F1 Illicit: 0.9554
# Epoch 046 | Loss: 0.2591 | Val Acc: 0.9163 | Val F1: 0.6280 | F1 Illicit: 0.9555
# Epoch 047 | Loss: 0.2578 | Val Acc: 0.9169 | Val F1: 0.6322 | F1 Illicit: 0.9558
# Epoch 048 | Loss: 0.2510 | Val Acc: 0.9170 | Val F1: 0.6327 | F1 Illicit: 0.9558
# Epoch 049 | Loss: 0.2548 | Val Acc: 0.9170 | Val F1: 0.6327 | F1 Illicit: 0.9558
# Epoch 050 | Loss: 0.2515 | Val Acc: 0.9171 | Val F1: 0.6345 | F1 Illicit: 0.9559
# Epoch 051 | Loss: 0.2535 | Val Acc: 0.9174 | Val F1: 0.6362 | F1 Illicit: 0.9560
# Epoch 052 | Loss: 0.2519 | Val Acc: 0.9180 | Val F1: 0.6391 | F1 Illicit: 0.9563
# Epoch 053 | Loss: 0.2517 | Val Acc: 0.9181 | Val F1: 0.6405 | F1 Illicit: 0.9564
# Epoch 054 | Loss: 0.2513 | Val Acc: 0.9185 | Val F1: 0.6427 | F1 Illicit: 0.9566
# Epoch 055 | Loss: 0.2499 | Val Acc: 0.9188 | Val F1: 0.6447 | F1 Illicit: 0.9567
# Epoch 056 | Loss: 0.2505 | Val Acc: 0.9189 | Val F1: 0.6469 | F1 Illicit: 0.9568
# Epoch 057 | Loss: 0.2475 | Val Acc: 0.9191 | Val F1: 0.6488 | F1 Illicit: 0.9569
# Epoch 058 | Loss: 0.2438 | Val Acc: 0.9193 | Val F1: 0.6498 | F1 Illicit: 0.9570
# Epoch 059 | Loss: 0.2462 | Val Acc: 0.9197 | Val F1: 0.6524 | F1 Illicit: 0.9572
# Epoch 060 | Loss: 0.2411 | Val Acc: 0.9200 | Val F1: 0.6552 | F1 Illicit: 0.9573
# Epoch 061 | Loss: 0.2412 | Val Acc: 0.9203 | Val F1: 0.6576 | F1 Illicit: 0.9575
# Epoch 062 | Loss: 0.2415 | Val Acc: 0.9208 | Val F1: 0.6606 | F1 Illicit: 0.9577
# Epoch 063 | Loss: 0.2411 | Val Acc: 0.9210 | Val F1: 0.6636 | F1 Illicit: 0.9579
# Epoch 064 | Loss: 0.2414 | Val Acc: 0.9215 | Val F1: 0.6670 | F1 Illicit: 0.9581
# Epoch 065 | Loss: 0.2386 | Val Acc: 0.9217 | Val F1: 0.6683 | F1 Illicit: 0.9582
# Epoch 066 | Loss: 0.2386 | Val Acc: 0.9220 | Val F1: 0.6707 | F1 Illicit: 0.9584
# Epoch 067 | Loss: 0.2373 | Val Acc: 0.9220 | Val F1: 0.6714 | F1 Illicit: 0.9584
# Epoch 068 | Loss: 0.2367 | Val Acc: 0.9224 | Val F1: 0.6738 | F1 Illicit: 0.9586
# Epoch 069 | Loss: 0.2365 | Val Acc: 0.9228 | Val F1: 0.6769 | F1 Illicit: 0.9588
# Epoch 070 | Loss: 0.2371 | Val Acc: 0.9232 | Val F1: 0.6796 | F1 Illicit: 0.9590
# Epoch 071 | Loss: 0.2324 | Val Acc: 0.9236 | Val F1: 0.6816 | F1 Illicit: 0.9592
# Epoch 072 | Loss: 0.2341 | Val Acc: 0.9237 | Val F1: 0.6828 | F1 Illicit: 0.9592
# Epoch 073 | Loss: 0.2354 | Val Acc: 0.9241 | Val F1: 0.6856 | F1 Illicit: 0.9594
# Epoch 074 | Loss: 0.2338 | Val Acc: 0.9243 | Val F1: 0.6868 | F1 Illicit: 0.9595
# Epoch 075 | Loss: 0.2321 | Val Acc: 0.9246 | Val F1: 0.6898 | F1 Illicit: 0.9597
# Epoch 076 | Loss: 0.2333 | Val Acc: 0.9250 | Val F1: 0.6923 | F1 Illicit: 0.9599
# Epoch 077 | Loss: 0.2307 | Val Acc: 0.9252 | Val F1: 0.6943 | F1 Illicit: 0.9600
# Epoch 078 | Loss: 0.2301 | Val Acc: 0.9257 | Val F1: 0.6977 | F1 Illicit: 0.9602
# Epoch 079 | Loss: 0.2299 | Val Acc: 0.9257 | Val F1: 0.6980 | F1 Illicit: 0.9602
# Epoch 080 | Loss: 0.2292 | Val Acc: 0.9260 | Val F1: 0.7001 | F1 Illicit: 0.9604
# Epoch 081 | Loss: 0.2307 | Val Acc: 0.9263 | Val F1: 0.7025 | F1 Illicit: 0.9605
# Epoch 082 | Loss: 0.2292 | Val Acc: 0.9268 | Val F1: 0.7055 | F1 Illicit: 0.9608
# Epoch 083 | Loss: 0.2279 | Val Acc: 0.9271 | Val F1: 0.7076 | F1 Illicit: 0.9609
# Epoch 084 | Loss: 0.2274 | Val Acc: 0.9275 | Val F1: 0.7101 | F1 Illicit: 0.9611
# Epoch 085 | Loss: 0.2260 | Val Acc: 0.9279 | Val F1: 0.7127 | F1 Illicit: 0.9614
# Epoch 086 | Loss: 0.2245 | Val Acc: 0.9283 | Val F1: 0.7153 | F1 Illicit: 0.9616
# Epoch 087 | Loss: 0.2242 | Val Acc: 0.9287 | Val F1: 0.7171 | F1 Illicit: 0.9618
# Epoch 088 | Loss: 0.2231 | Val Acc: 0.9287 | Val F1: 0.7174 | F1 Illicit: 0.9618
# Epoch 089 | Loss: 0.2213 | Val Acc: 0.9291 | Val F1: 0.7198 | F1 Illicit: 0.9619
# Epoch 090 | Loss: 0.2241 | Val Acc: 0.9293 | Val F1: 0.7208 | F1 Illicit: 0.9621
# Epoch 091 | Loss: 0.2201 | Val Acc: 0.9297 | Val F1: 0.7233 | F1 Illicit: 0.9623
# Epoch 092 | Loss: 0.2205 | Val Acc: 0.9300 | Val F1: 0.7247 | F1 Illicit: 0.9624
# Epoch 093 | Loss: 0.2212 | Val Acc: 0.9304 | Val F1: 0.7273 | F1 Illicit: 0.9626
# Epoch 094 | Loss: 0.2224 | Val Acc: 0.9306 | Val F1: 0.7285 | F1 Illicit: 0.9627
# Epoch 095 | Loss: 0.2197 | Val Acc: 0.9308 | Val F1: 0.7300 | F1 Illicit: 0.9628
# Epoch 096 | Loss: 0.2193 | Val Acc: 0.9309 | Val F1: 0.7307 | F1 Illicit: 0.9629
# Epoch 097 | Loss: 0.2194 | Val Acc: 0.9311 | Val F1: 0.7323 | F1 Illicit: 0.9630
# Epoch 098 | Loss: 0.2188 | Val Acc: 0.9314 | Val F1: 0.7342 | F1 Illicit: 0.9632
# Epoch 099 | Loss: 0.2179 | Val Acc: 0.9315 | Val F1: 0.7346 | F1 Illicit: 0.9632
# Epoch 100 | Loss: 0.2169 | Val Acc: 0.9319 | Val F1: 0.7370 | F1 Illicit: 0.9634
# Epoch 101 | Loss: 0.2149 | Val Acc: 0.9324 | Val F1: 0.7396 | F1 Illicit: 0.9636
# Epoch 102 | Loss: 0.2161 | Val Acc: 0.9326 | Val F1: 0.7412 | F1 Illicit: 0.9638
# Epoch 103 | Loss: 0.2149 | Val Acc: 0.9331 | Val F1: 0.7438 | F1 Illicit: 0.9640
# Epoch 104 | Loss: 0.2146 | Val Acc: 0.9333 | Val F1: 0.7450 | F1 Illicit: 0.9641
# Epoch 105 | Loss: 0.2126 | Val Acc: 0.9336 | Val F1: 0.7475 | F1 Illicit: 0.9643
# Epoch 106 | Loss: 0.2131 | Val Acc: 0.9338 | Val F1: 0.7485 | F1 Illicit: 0.9644
# Epoch 107 | Loss: 0.2128 | Val Acc: 0.9341 | Val F1: 0.7504 | F1 Illicit: 0.9646
# Epoch 108 | Loss: 0.2138 | Val Acc: 0.9343 | Val F1: 0.7517 | F1 Illicit: 0.9646
# Epoch 109 | Loss: 0.2145 | Val Acc: 0.9346 | Val F1: 0.7534 | F1 Illicit: 0.9648
# Epoch 110 | Loss: 0.2112 | Val Acc: 0.9349 | Val F1: 0.7552 | F1 Illicit: 0.9649
# Epoch 111 | Loss: 0.2106 | Val Acc: 0.9355 | Val F1: 0.7590 | F1 Illicit: 0.9652
# Epoch 112 | Loss: 0.2124 | Val Acc: 0.9358 | Val F1: 0.7608 | F1 Illicit: 0.9654
# Epoch 113 | Loss: 0.2114 | Val Acc: 0.9362 | Val F1: 0.7628 | F1 Illicit: 0.9656
# Epoch 114 | Loss: 0.2106 | Val Acc: 0.9365 | Val F1: 0.7643 | F1 Illicit: 0.9658
# Epoch 115 | Loss: 0.2084 | Val Acc: 0.9368 | Val F1: 0.7656 | F1 Illicit: 0.9659
# Epoch 116 | Loss: 0.2076 | Val Acc: 0.9370 | Val F1: 0.7665 | F1 Illicit: 0.9660
# Epoch 117 | Loss: 0.2083 | Val Acc: 0.9371 | Val F1: 0.7669 | F1 Illicit: 0.9661
# Epoch 118 | Loss: 0.2089 | Val Acc: 0.9371 | Val F1: 0.7669 | F1 Illicit: 0.9661
# Epoch 119 | Loss: 0.2080 | Val Acc: 0.9374 | Val F1: 0.7687 | F1 Illicit: 0.9663
# Epoch 120 | Loss: 0.2083 | Val Acc: 0.9376 | Val F1: 0.7696 | F1 Illicit: 0.9663
# Epoch 121 | Loss: 0.2089 | Val Acc: 0.9379 | Val F1: 0.7709 | F1 Illicit: 0.9665
# Epoch 122 | Loss: 0.2068 | Val Acc: 0.9385 | Val F1: 0.7742 | F1 Illicit: 0.9668
# Epoch 123 | Loss: 0.2045 | Val Acc: 0.9392 | Val F1: 0.7775 | F1 Illicit: 0.9672
# Epoch 124 | Loss: 0.2055 | Val Acc: 0.9397 | Val F1: 0.7798 | F1 Illicit: 0.9674
# Epoch 125 | Loss: 0.2066 | Val Acc: 0.9399 | Val F1: 0.7809 | F1 Illicit: 0.9675
# Epoch 126 | Loss: 0.2047 | Val Acc: 0.9399 | Val F1: 0.7814 | F1 Illicit: 0.9676
# Epoch 127 | Loss: 0.2039 | Val Acc: 0.9402 | Val F1: 0.7825 | F1 Illicit: 0.9677
# Epoch 128 | Loss: 0.2039 | Val Acc: 0.9402 | Val F1: 0.7832 | F1 Illicit: 0.9677
# Epoch 129 | Loss: 0.2006 | Val Acc: 0.9407 | Val F1: 0.7855 | F1 Illicit: 0.9679
# Epoch 130 | Loss: 0.2016 | Val Acc: 0.9409 | Val F1: 0.7866 | F1 Illicit: 0.9680
# Epoch 131 | Loss: 0.2037 | Val Acc: 0.9412 | Val F1: 0.7884 | F1 Illicit: 0.9682
# Epoch 132 | Loss: 0.2018 | Val Acc: 0.9417 | Val F1: 0.7901 | F1 Illicit: 0.9685
# Epoch 133 | Loss: 0.2000 | Val Acc: 0.9419 | Val F1: 0.7917 | F1 Illicit: 0.9686
# Epoch 134 | Loss: 0.2005 | Val Acc: 0.9422 | Val F1: 0.7932 | F1 Illicit: 0.9687
# Epoch 135 | Loss: 0.2023 | Val Acc: 0.9424 | Val F1: 0.7943 | F1 Illicit: 0.9688
# Epoch 136 | Loss: 0.1972 | Val Acc: 0.9424 | Val F1: 0.7948 | F1 Illicit: 0.9689
# Epoch 137 | Loss: 0.1988 | Val Acc: 0.9429 | Val F1: 0.7967 | F1 Illicit: 0.9691
# Epoch 138 | Loss: 0.1988 | Val Acc: 0.9431 | Val F1: 0.7979 | F1 Illicit: 0.9692
# Epoch 139 | Loss: 0.2012 | Val Acc: 0.9432 | Val F1: 0.7982 | F1 Illicit: 0.9692
# Epoch 140 | Loss: 0.1976 | Val Acc: 0.9435 | Val F1: 0.7994 | F1 Illicit: 0.9694
# Epoch 141 | Loss: 0.1967 | Val Acc: 0.9439 | Val F1: 0.8013 | F1 Illicit: 0.9696
# Epoch 142 | Loss: 0.1973 | Val Acc: 0.9442 | Val F1: 0.8026 | F1 Illicit: 0.9698
# Epoch 143 | Loss: 0.1981 | Val Acc: 0.9445 | Val F1: 0.8035 | F1 Illicit: 0.9699
# Epoch 144 | Loss: 0.1987 | Val Acc: 0.9446 | Val F1: 0.8043 | F1 Illicit: 0.9700
# Epoch 145 | Loss: 0.1960 | Val Acc: 0.9450 | Val F1: 0.8063 | F1 Illicit: 0.9702
# Epoch 146 | Loss: 0.1957 | Val Acc: 0.9452 | Val F1: 0.8077 | F1 Illicit: 0.9703
# Epoch 147 | Loss: 0.1951 | Val Acc: 0.9452 | Val F1: 0.8075 | F1 Illicit: 0.9703
# Epoch 148 | Loss: 0.1964 | Val Acc: 0.9455 | Val F1: 0.8088 | F1 Illicit: 0.9704
# Epoch 149 | Loss: 0.1928 | Val Acc: 0.9460 | Val F1: 0.8113 | F1 Illicit: 0.9707
# Epoch 150 | Loss: 0.1963 | Val Acc: 0.9462 | Val F1: 0.8123 | F1 Illicit: 0.9708
# Epoch 151 | Loss: 0.1923 | Val Acc: 0.9465 | Val F1: 0.8139 | F1 Illicit: 0.9710
# Epoch 152 | Loss: 0.1945 | Val Acc: 0.9467 | Val F1: 0.8147 | F1 Illicit: 0.9711
# Epoch 153 | Loss: 0.1919 | Val Acc: 0.9468 | Val F1: 0.8156 | F1 Illicit: 0.9712
# Epoch 154 | Loss: 0.1925 | Val Acc: 0.9472 | Val F1: 0.8172 | F1 Illicit: 0.9714
# Epoch 155 | Loss: 0.1919 | Val Acc: 0.9473 | Val F1: 0.8174 | F1 Illicit: 0.9714
# Epoch 156 | Loss: 0.1922 | Val Acc: 0.9474 | Val F1: 0.8178 | F1 Illicit: 0.9715
# Epoch 157 | Loss: 0.1924 | Val Acc: 0.9479 | Val F1: 0.8197 | F1 Illicit: 0.9717
# Epoch 158 | Loss: 0.1907 | Val Acc: 0.9482 | Val F1: 0.8209 | F1 Illicit: 0.9719
# Epoch 159 | Loss: 0.1901 | Val Acc: 0.9484 | Val F1: 0.8219 | F1 Illicit: 0.9720
# Epoch 160 | Loss: 0.1924 | Val Acc: 0.9487 | Val F1: 0.8234 | F1 Illicit: 0.9722
# Epoch 161 | Loss: 0.1892 | Val Acc: 0.9489 | Val F1: 0.8243 | F1 Illicit: 0.9723
# Epoch 162 | Loss: 0.1882 | Val Acc: 0.9489 | Val F1: 0.8247 | F1 Illicit: 0.9722
# Epoch 163 | Loss: 0.1891 | Val Acc: 0.9494 | Val F1: 0.8271 | F1 Illicit: 0.9725
# Epoch 164 | Loss: 0.1898 | Val Acc: 0.9495 | Val F1: 0.8277 | F1 Illicit: 0.9726
# Epoch 165 | Loss: 0.1881 | Val Acc: 0.9495 | Val F1: 0.8280 | F1 Illicit: 0.9726
# Epoch 166 | Loss: 0.1890 | Val Acc: 0.9497 | Val F1: 0.8291 | F1 Illicit: 0.9727
# Epoch 167 | Loss: 0.1872 | Val Acc: 0.9501 | Val F1: 0.8307 | F1 Illicit: 0.9729
# Epoch 168 | Loss: 0.1869 | Val Acc: 0.9503 | Val F1: 0.8316 | F1 Illicit: 0.9730
# Epoch 169 | Loss: 0.1882 | Val Acc: 0.9505 | Val F1: 0.8321 | F1 Illicit: 0.9731
# Epoch 170 | Loss: 0.1867 | Val Acc: 0.9505 | Val F1: 0.8321 | F1 Illicit: 0.9731
# Epoch 171 | Loss: 0.1882 | Val Acc: 0.9507 | Val F1: 0.8330 | F1 Illicit: 0.9732
# Epoch 172 | Loss: 0.1867 | Val Acc: 0.9506 | Val F1: 0.8328 | F1 Illicit: 0.9731
# Epoch 173 | Loss: 0.1857 | Val Acc: 0.9509 | Val F1: 0.8338 | F1 Illicit: 0.9733
# Epoch 174 | Loss: 0.1854 | Val Acc: 0.9513 | Val F1: 0.8349 | F1 Illicit: 0.9735
# Epoch 175 | Loss: 0.1839 | Val Acc: 0.9513 | Val F1: 0.8351 | F1 Illicit: 0.9735
# Epoch 176 | Loss: 0.1851 | Val Acc: 0.9516 | Val F1: 0.8364 | F1 Illicit: 0.9737
# Epoch 177 | Loss: 0.1856 | Val Acc: 0.9519 | Val F1: 0.8373 | F1 Illicit: 0.9738
# Epoch 178 | Loss: 0.1823 | Val Acc: 0.9519 | Val F1: 0.8373 | F1 Illicit: 0.9738
# Epoch 179 | Loss: 0.1838 | Val Acc: 0.9520 | Val F1: 0.8379 | F1 Illicit: 0.9739
# Epoch 180 | Loss: 0.1845 | Val Acc: 0.9520 | Val F1: 0.8379 | F1 Illicit: 0.9739
# Epoch 181 | Loss: 0.1844 | Val Acc: 0.9521 | Val F1: 0.8385 | F1 Illicit: 0.9740
# Epoch 182 | Loss: 0.1852 | Val Acc: 0.9524 | Val F1: 0.8401 | F1 Illicit: 0.9741
# Epoch 183 | Loss: 0.1828 | Val Acc: 0.9524 | Val F1: 0.8403 | F1 Illicit: 0.9741
# Epoch 184 | Loss: 0.1805 | Val Acc: 0.9525 | Val F1: 0.8409 | F1 Illicit: 0.9742
# Epoch 185 | Loss: 0.1799 | Val Acc: 0.9526 | Val F1: 0.8412 | F1 Illicit: 0.9742
# Epoch 186 | Loss: 0.1803 | Val Acc: 0.9528 | Val F1: 0.8418 | F1 Illicit: 0.9743
# Epoch 187 | Loss: 0.1821 | Val Acc: 0.9528 | Val F1: 0.8419 | F1 Illicit: 0.9743
# Epoch 188 | Loss: 0.1821 | Val Acc: 0.9530 | Val F1: 0.8430 | F1 Illicit: 0.9744
# Epoch 189 | Loss: 0.1798 | Val Acc: 0.9530 | Val F1: 0.8430 | F1 Illicit: 0.9744
# Epoch 190 | Loss: 0.1777 | Val Acc: 0.9533 | Val F1: 0.8440 | F1 Illicit: 0.9746
# Epoch 191 | Loss: 0.1796 | Val Acc: 0.9532 | Val F1: 0.8437 | F1 Illicit: 0.9745
# Epoch 192 | Loss: 0.1783 | Val Acc: 0.9533 | Val F1: 0.8442 | F1 Illicit: 0.9746
# Epoch 193 | Loss: 0.1806 | Val Acc: 0.9535 | Val F1: 0.8448 | F1 Illicit: 0.9747
# Epoch 194 | Loss: 0.1788 | Val Acc: 0.9535 | Val F1: 0.8451 | F1 Illicit: 0.9747
# Epoch 195 | Loss: 0.1774 | Val Acc: 0.9536 | Val F1: 0.8454 | F1 Illicit: 0.9747
# Epoch 196 | Loss: 0.1784 | Val Acc: 0.9536 | Val F1: 0.8456 | F1 Illicit: 0.9747
# Epoch 197 | Loss: 0.1757 | Val Acc: 0.9536 | Val F1: 0.8458 | F1 Illicit: 0.9747
# Epoch 198 | Loss: 0.1767 | Val Acc: 0.9539 | Val F1: 0.8470 | F1 Illicit: 0.9749
# Epoch 199 | Loss: 0.1759 | Val Acc: 0.9543 | Val F1: 0.8486 | F1 Illicit: 0.9751
# Epoch 200 | Loss: 0.1767 | Val Acc: 0.9545 | Val F1: 0.8498 | F1 Illicit: 0.9752
# Epoch 201 | Loss: 0.1765 | Val Acc: 0.9545 | Val F1: 0.8496 | F1 Illicit: 0.9752
# Epoch 202 | Loss: 0.1750 | Val Acc: 0.9546 | Val F1: 0.8502 | F1 Illicit: 0.9753
# Epoch 203 | Loss: 0.1763 | Val Acc: 0.9547 | Val F1: 0.8506 | F1 Illicit: 0.9753
# Epoch 204 | Loss: 0.1752 | Val Acc: 0.9548 | Val F1: 0.8512 | F1 Illicit: 0.9754
# Epoch 205 | Loss: 0.1747 | Val Acc: 0.9548 | Val F1: 0.8512 | F1 Illicit: 0.9754
# Epoch 206 | Loss: 0.1726 | Val Acc: 0.9549 | Val F1: 0.8516 | F1 Illicit: 0.9754
# Epoch 207 | Loss: 0.1751 | Val Acc: 0.9548 | Val F1: 0.8516 | F1 Illicit: 0.9754
# Epoch 208 | Loss: 0.1755 | Val Acc: 0.9550 | Val F1: 0.8523 | F1 Illicit: 0.9754
# Epoch 209 | Loss: 0.1739 | Val Acc: 0.9550 | Val F1: 0.8526 | F1 Illicit: 0.9755
# Epoch 210 | Loss: 0.1740 | Val Acc: 0.9551 | Val F1: 0.8529 | F1 Illicit: 0.9755
# Epoch 211 | Loss: 0.1748 | Val Acc: 0.9552 | Val F1: 0.8531 | F1 Illicit: 0.9756
# Epoch 212 | Loss: 0.1735 | Val Acc: 0.9553 | Val F1: 0.8534 | F1 Illicit: 0.9756
# Epoch 213 | Loss: 0.1748 | Val Acc: 0.9553 | Val F1: 0.8537 | F1 Illicit: 0.9756
# Epoch 214 | Loss: 0.1763 | Val Acc: 0.9553 | Val F1: 0.8537 | F1 Illicit: 0.9756
# Epoch 215 | Loss: 0.1727 | Val Acc: 0.9555 | Val F1: 0.8540 | F1 Illicit: 0.9757
# Epoch 216 | Loss: 0.1718 | Val Acc: 0.9556 | Val F1: 0.8546 | F1 Illicit: 0.9758
# Epoch 217 | Loss: 0.1744 | Val Acc: 0.9558 | Val F1: 0.8555 | F1 Illicit: 0.9759
# Epoch 218 | Loss: 0.1720 | Val Acc: 0.9559 | Val F1: 0.8558 | F1 Illicit: 0.9759
# Epoch 219 | Loss: 0.1707 | Val Acc: 0.9560 | Val F1: 0.8563 | F1 Illicit: 0.9760
# Epoch 220 | Loss: 0.1732 | Val Acc: 0.9562 | Val F1: 0.8568 | F1 Illicit: 0.9761
# Epoch 221 | Loss: 0.1689 | Val Acc: 0.9563 | Val F1: 0.8572 | F1 Illicit: 0.9761
# Epoch 222 | Loss: 0.1697 | Val Acc: 0.9563 | Val F1: 0.8575 | F1 Illicit: 0.9761
# Epoch 223 | Loss: 0.1699 | Val Acc: 0.9563 | Val F1: 0.8576 | F1 Illicit: 0.9761
# Epoch 224 | Loss: 0.1717 | Val Acc: 0.9562 | Val F1: 0.8574 | F1 Illicit: 0.9761
# Epoch 225 | Loss: 0.1686 | Val Acc: 0.9564 | Val F1: 0.8581 | F1 Illicit: 0.9762
# Epoch 226 | Loss: 0.1706 | Val Acc: 0.9565 | Val F1: 0.8587 | F1 Illicit: 0.9763
# Epoch 227 | Loss: 0.1705 | Val Acc: 0.9567 | Val F1: 0.8592 | F1 Illicit: 0.9764
# Epoch 228 | Loss: 0.1692 | Val Acc: 0.9568 | Val F1: 0.8594 | F1 Illicit: 0.9764
# Epoch 229 | Loss: 0.1697 | Val Acc: 0.9570 | Val F1: 0.8602 | F1 Illicit: 0.9765
# Epoch 230 | Loss: 0.1693 | Val Acc: 0.9572 | Val F1: 0.8611 | F1 Illicit: 0.9766
# Epoch 231 | Loss: 0.1690 | Val Acc: 0.9576 | Val F1: 0.8627 | F1 Illicit: 0.9769
# Epoch 232 | Loss: 0.1687 | Val Acc: 0.9575 | Val F1: 0.8624 | F1 Illicit: 0.9768
# Epoch 233 | Loss: 0.1666 | Val Acc: 0.9577 | Val F1: 0.8634 | F1 Illicit: 0.9769
# Epoch 234 | Loss: 0.1670 | Val Acc: 0.9578 | Val F1: 0.8638 | F1 Illicit: 0.9769
# Epoch 235 | Loss: 0.1681 | Val Acc: 0.9578 | Val F1: 0.8641 | F1 Illicit: 0.9769
# Epoch 236 | Loss: 0.1667 | Val Acc: 0.9578 | Val F1: 0.8645 | F1 Illicit: 0.9770
# Epoch 237 | Loss: 0.1673 | Val Acc: 0.9580 | Val F1: 0.8654 | F1 Illicit: 0.9770
# Epoch 238 | Loss: 0.1676 | Val Acc: 0.9581 | Val F1: 0.8655 | F1 Illicit: 0.9771
# Epoch 239 | Loss: 0.1670 | Val Acc: 0.9581 | Val F1: 0.8655 | F1 Illicit: 0.9771
# Epoch 240 | Loss: 0.1664 | Val Acc: 0.9581 | Val F1: 0.8655 | F1 Illicit: 0.9771
# Epoch 241 | Loss: 0.1657 | Val Acc: 0.9579 | Val F1: 0.8651 | F1 Illicit: 0.9770
# Epoch 242 | Loss: 0.1639 | Val Acc: 0.9581 | Val F1: 0.8653 | F1 Illicit: 0.9771
# Epoch 243 | Loss: 0.1638 | Val Acc: 0.9582 | Val F1: 0.8657 | F1 Illicit: 0.9772
# Epoch 244 | Loss: 0.1643 | Val Acc: 0.9583 | Val F1: 0.8661 | F1 Illicit: 0.9772
# Epoch 245 | Loss: 0.1671 | Val Acc: 0.9585 | Val F1: 0.8667 | F1 Illicit: 0.9773
# Epoch 246 | Loss: 0.1663 | Val Acc: 0.9588 | Val F1: 0.8679 | F1 Illicit: 0.9775
# Epoch 247 | Loss: 0.1656 | Val Acc: 0.9589 | Val F1: 0.8683 | F1 Illicit: 0.9775
# Epoch 248 | Loss: 0.1637 | Val Acc: 0.9590 | Val F1: 0.8686 | F1 Illicit: 0.9776
# Epoch 249 | Loss: 0.1657 | Val Acc: 0.9591 | Val F1: 0.8688 | F1 Illicit: 0.9776
# Epoch 250 | Loss: 0.1652 | Val Acc: 0.9593 | Val F1: 0.8698 | F1 Illicit: 0.9778
# Epoch 251 | Loss: 0.1647 | Val Acc: 0.9594 | Val F1: 0.8701 | F1 Illicit: 0.9778
# Epoch 252 | Loss: 0.1648 | Val Acc: 0.9594 | Val F1: 0.8702 | F1 Illicit: 0.9778
# Epoch 253 | Loss: 0.1641 | Val Acc: 0.9596 | Val F1: 0.8710 | F1 Illicit: 0.9779
# Epoch 254 | Loss: 0.1642 | Val Acc: 0.9596 | Val F1: 0.8710 | F1 Illicit: 0.9779
# Epoch 255 | Loss: 0.1632 | Val Acc: 0.9598 | Val F1: 0.8716 | F1 Illicit: 0.9780
# Epoch 256 | Loss: 0.1620 | Val Acc: 0.9598 | Val F1: 0.8718 | F1 Illicit: 0.9780
# Epoch 257 | Loss: 0.1635 | Val Acc: 0.9600 | Val F1: 0.8724 | F1 Illicit: 0.9781
# Epoch 258 | Loss: 0.1591 | Val Acc: 0.9599 | Val F1: 0.8721 | F1 Illicit: 0.9781
# Epoch 259 | Loss: 0.1626 | Val Acc: 0.9599 | Val F1: 0.8723 | F1 Illicit: 0.9781
# Epoch 260 | Loss: 0.1616 | Val Acc: 0.9599 | Val F1: 0.8723 | F1 Illicit: 0.9781
# Epoch 261 | Loss: 0.1615 | Val Acc: 0.9599 | Val F1: 0.8725 | F1 Illicit: 0.9781
# Epoch 262 | Loss: 0.1619 | Val Acc: 0.9599 | Val F1: 0.8726 | F1 Illicit: 0.9781
# Epoch 263 | Loss: 0.1581 | Val Acc: 0.9600 | Val F1: 0.8728 | F1 Illicit: 0.9781
# Epoch 264 | Loss: 0.1609 | Val Acc: 0.9600 | Val F1: 0.8727 | F1 Illicit: 0.9781
# Epoch 265 | Loss: 0.1612 | Val Acc: 0.9601 | Val F1: 0.8731 | F1 Illicit: 0.9782
# Epoch 266 | Loss: 0.1603 | Val Acc: 0.9601 | Val F1: 0.8730 | F1 Illicit: 0.9781
# Epoch 267 | Loss: 0.1623 | Val Acc: 0.9601 | Val F1: 0.8730 | F1 Illicit: 0.9781
# Epoch 268 | Loss: 0.1582 | Val Acc: 0.9603 | Val F1: 0.8738 | F1 Illicit: 0.9783
# Epoch 269 | Loss: 0.1605 | Val Acc: 0.9604 | Val F1: 0.8744 | F1 Illicit: 0.9783
# Epoch 270 | Loss: 0.1598 | Val Acc: 0.9607 | Val F1: 0.8754 | F1 Illicit: 0.9785
# Epoch 271 | Loss: 0.1612 | Val Acc: 0.9609 | Val F1: 0.8760 | F1 Illicit: 0.9786
# Epoch 272 | Loss: 0.1627 | Val Acc: 0.9610 | Val F1: 0.8764 | F1 Illicit: 0.9787
# Epoch 273 | Loss: 0.1577 | Val Acc: 0.9611 | Val F1: 0.8767 | F1 Illicit: 0.9787
# Epoch 274 | Loss: 0.1606 | Val Acc: 0.9612 | Val F1: 0.8771 | F1 Illicit: 0.9788
# Epoch 275 | Loss: 0.1587 | Val Acc: 0.9614 | Val F1: 0.8778 | F1 Illicit: 0.9789
# Epoch 276 | Loss: 0.1616 | Val Acc: 0.9615 | Val F1: 0.8779 | F1 Illicit: 0.9789
# Epoch 277 | Loss: 0.1595 | Val Acc: 0.9616 | Val F1: 0.8781 | F1 Illicit: 0.9790
# Epoch 278 | Loss: 0.1606 | Val Acc: 0.9616 | Val F1: 0.8781 | F1 Illicit: 0.9790
# Epoch 279 | Loss: 0.1620 | Val Acc: 0.9615 | Val F1: 0.8779 | F1 Illicit: 0.9789
# Epoch 280 | Loss: 0.1581 | Val Acc: 0.9617 | Val F1: 0.8788 | F1 Illicit: 0.9790
# Epoch 281 | Loss: 0.1575 | Val Acc: 0.9617 | Val F1: 0.8788 | F1 Illicit: 0.9790
# Epoch 282 | Loss: 0.1574 | Val Acc: 0.9617 | Val F1: 0.8788 | F1 Illicit: 0.9790
# Epoch 283 | Loss: 0.1588 | Val Acc: 0.9618 | Val F1: 0.8794 | F1 Illicit: 0.9791
# Epoch 284 | Loss: 0.1571 | Val Acc: 0.9618 | Val F1: 0.8795 | F1 Illicit: 0.9791
# Epoch 285 | Loss: 0.1573 | Val Acc: 0.9618 | Val F1: 0.8793 | F1 Illicit: 0.9791
# Epoch 286 | Loss: 0.1581 | Val Acc: 0.9620 | Val F1: 0.8800 | F1 Illicit: 0.9792
# Epoch 287 | Loss: 0.1564 | Val Acc: 0.9620 | Val F1: 0.8800 | F1 Illicit: 0.9792
# Epoch 288 | Loss: 0.1582 | Val Acc: 0.9619 | Val F1: 0.8797 | F1 Illicit: 0.9792
# Epoch 289 | Loss: 0.1576 | Val Acc: 0.9620 | Val F1: 0.8800 | F1 Illicit: 0.9792
# Epoch 290 | Loss: 0.1574 | Val Acc: 0.9621 | Val F1: 0.8806 | F1 Illicit: 0.9793
# Epoch 291 | Loss: 0.1561 | Val Acc: 0.9621 | Val F1: 0.8806 | F1 Illicit: 0.9793
# Epoch 292 | Loss: 0.1575 | Val Acc: 0.9622 | Val F1: 0.8807 | F1 Illicit: 0.9793
# Epoch 293 | Loss: 0.1563 | Val Acc: 0.9623 | Val F1: 0.8810 | F1 Illicit: 0.9793
# Epoch 294 | Loss: 0.1579 | Val Acc: 0.9623 | Val F1: 0.8809 | F1 Illicit: 0.9793
# Epoch 295 | Loss: 0.1552 | Val Acc: 0.9625 | Val F1: 0.8816 | F1 Illicit: 0.9795
# Epoch 296 | Loss: 0.1548 | Val Acc: 0.9625 | Val F1: 0.8816 | F1 Illicit: 0.9795
# Epoch 297 | Loss: 0.1543 | Val Acc: 0.9624 | Val F1: 0.8814 | F1 Illicit: 0.9794
# Epoch 298 | Loss: 0.1567 | Val Acc: 0.9623 | Val F1: 0.8809 | F1 Illicit: 0.9793
# Epoch 299 | Loss: 0.1577 | Val Acc: 0.9626 | Val F1: 0.8820 | F1 Illicit: 0.9795
# Epoch 300 | Loss: 0.1571 | Val Acc: 0.9625 | Val F1: 0.8817 | F1 Illicit: 0.9795
#
# === Training GAT (Temporal): base | Seed: 123 ===
# Epoch 001 | Loss: 0.9402 | Val Acc: 0.6224 | Val F1: 0.4517 | F1 Illicit: 0.7576
# Epoch 002 | Loss: 0.8012 | Val Acc: 0.6583 | Val F1: 0.4815 | F1 Illicit: 0.7843
# Epoch 003 | Loss: 0.7088 | Val Acc: 0.6989 | Val F1: 0.5195 | F1 Illicit: 0.8131
# Epoch 004 | Loss: 0.6163 | Val Acc: 0.7382 | Val F1: 0.5552 | F1 Illicit: 0.8405
# Epoch 005 | Loss: 0.5621 | Val Acc: 0.7678 | Val F1: 0.5850 | F1 Illicit: 0.8604
# Epoch 006 | Loss: 0.5092 | Val Acc: 0.7883 | Val F1: 0.6075 | F1 Illicit: 0.8739
# Epoch 007 | Loss: 0.4694 | Val Acc: 0.8095 | Val F1: 0.6301 | F1 Illicit: 0.8877
# Epoch 008 | Loss: 0.4452 | Val Acc: 0.8264 | Val F1: 0.6469 | F1 Illicit: 0.8987
# Epoch 009 | Loss: 0.4205 | Val Acc: 0.8384 | Val F1: 0.6578 | F1 Illicit: 0.9064
# Epoch 010 | Loss: 0.3973 | Val Acc: 0.8490 | Val F1: 0.6659 | F1 Illicit: 0.9133
# Epoch 011 | Loss: 0.3820 | Val Acc: 0.8566 | Val F1: 0.6689 | F1 Illicit: 0.9182
# Epoch 012 | Loss: 0.3710 | Val Acc: 0.8621 | Val F1: 0.6681 | F1 Illicit: 0.9219
# Epoch 013 | Loss: 0.3576 | Val Acc: 0.8666 | Val F1: 0.6645 | F1 Illicit: 0.9249
# Epoch 014 | Loss: 0.3443 | Val Acc: 0.8732 | Val F1: 0.6669 | F1 Illicit: 0.9291
# Epoch 015 | Loss: 0.3384 | Val Acc: 0.8785 | Val F1: 0.6661 | F1 Illicit: 0.9324
# Epoch 016 | Loss: 0.3294 | Val Acc: 0.8827 | Val F1: 0.6662 | F1 Illicit: 0.9351
# Epoch 017 | Loss: 0.3210 | Val Acc: 0.8861 | Val F1: 0.6621 | F1 Illicit: 0.9372
# Epoch 018 | Loss: 0.3154 | Val Acc: 0.8889 | Val F1: 0.6581 | F1 Illicit: 0.9390
# Epoch 019 | Loss: 0.3053 | Val Acc: 0.8910 | Val F1: 0.6548 | F1 Illicit: 0.9403
# Epoch 020 | Loss: 0.3017 | Val Acc: 0.8931 | Val F1: 0.6500 | F1 Illicit: 0.9417
# Epoch 021 | Loss: 0.2977 | Val Acc: 0.8955 | Val F1: 0.6488 | F1 Illicit: 0.9431
# Epoch 022 | Loss: 0.2950 | Val Acc: 0.8972 | Val F1: 0.6469 | F1 Illicit: 0.9442
# Epoch 023 | Loss: 0.2876 | Val Acc: 0.8996 | Val F1: 0.6449 | F1 Illicit: 0.9456
# Epoch 024 | Loss: 0.2880 | Val Acc: 0.9005 | Val F1: 0.6409 | F1 Illicit: 0.9462
# Epoch 025 | Loss: 0.2849 | Val Acc: 0.9028 | Val F1: 0.6419 | F1 Illicit: 0.9476
# Epoch 026 | Loss: 0.2801 | Val Acc: 0.9054 | Val F1: 0.6424 | F1 Illicit: 0.9491
# Epoch 027 | Loss: 0.2776 | Val Acc: 0.9071 | Val F1: 0.6429 | F1 Illicit: 0.9501
# Epoch 028 | Loss: 0.2733 | Val Acc: 0.9087 | Val F1: 0.6439 | F1 Illicit: 0.9510
# Epoch 029 | Loss: 0.2753 | Val Acc: 0.9103 | Val F1: 0.6467 | F1 Illicit: 0.9519
# Epoch 030 | Loss: 0.2724 | Val Acc: 0.9122 | Val F1: 0.6520 | F1 Illicit: 0.9529
# Epoch 031 | Loss: 0.2688 | Val Acc: 0.9138 | Val F1: 0.6570 | F1 Illicit: 0.9538
# Epoch 032 | Loss: 0.2659 | Val Acc: 0.9147 | Val F1: 0.6588 | F1 Illicit: 0.9543
# Epoch 033 | Loss: 0.2635 | Val Acc: 0.9159 | Val F1: 0.6635 | F1 Illicit: 0.9549
# Epoch 034 | Loss: 0.2618 | Val Acc: 0.9171 | Val F1: 0.6692 | F1 Illicit: 0.9556
# Epoch 035 | Loss: 0.2560 | Val Acc: 0.9177 | Val F1: 0.6721 | F1 Illicit: 0.9559
# Epoch 036 | Loss: 0.2595 | Val Acc: 0.9184 | Val F1: 0.6756 | F1 Illicit: 0.9562
# Epoch 037 | Loss: 0.2605 | Val Acc: 0.9185 | Val F1: 0.6780 | F1 Illicit: 0.9563
# Epoch 038 | Loss: 0.2561 | Val Acc: 0.9184 | Val F1: 0.6800 | F1 Illicit: 0.9562
# Epoch 039 | Loss: 0.2542 | Val Acc: 0.9185 | Val F1: 0.6809 | F1 Illicit: 0.9563
# Epoch 040 | Loss: 0.2554 | Val Acc: 0.9192 | Val F1: 0.6854 | F1 Illicit: 0.9566
# Epoch 041 | Loss: 0.2524 | Val Acc: 0.9200 | Val F1: 0.6889 | F1 Illicit: 0.9570
# Epoch 042 | Loss: 0.2506 | Val Acc: 0.9205 | Val F1: 0.6921 | F1 Illicit: 0.9573
# Epoch 043 | Loss: 0.2502 | Val Acc: 0.9212 | Val F1: 0.6958 | F1 Illicit: 0.9576
# Epoch 044 | Loss: 0.2493 | Val Acc: 0.9215 | Val F1: 0.6990 | F1 Illicit: 0.9578
# Epoch 045 | Loss: 0.2452 | Val Acc: 0.9220 | Val F1: 0.7024 | F1 Illicit: 0.9580
# Epoch 046 | Loss: 0.2430 | Val Acc: 0.9225 | Val F1: 0.7067 | F1 Illicit: 0.9583
# Epoch 047 | Loss: 0.2433 | Val Acc: 0.9228 | Val F1: 0.7089 | F1 Illicit: 0.9585
# Epoch 048 | Loss: 0.2417 | Val Acc: 0.9232 | Val F1: 0.7112 | F1 Illicit: 0.9586
# Epoch 049 | Loss: 0.2399 | Val Acc: 0.9238 | Val F1: 0.7147 | F1 Illicit: 0.9589
# Epoch 050 | Loss: 0.2385 | Val Acc: 0.9245 | Val F1: 0.7181 | F1 Illicit: 0.9593
# Epoch 051 | Loss: 0.2381 | Val Acc: 0.9253 | Val F1: 0.7217 | F1 Illicit: 0.9597
# Epoch 052 | Loss: 0.2372 | Val Acc: 0.9254 | Val F1: 0.7230 | F1 Illicit: 0.9598
# Epoch 053 | Loss: 0.2411 | Val Acc: 0.9264 | Val F1: 0.7284 | F1 Illicit: 0.9603
# Epoch 054 | Loss: 0.2328 | Val Acc: 0.9266 | Val F1: 0.7292 | F1 Illicit: 0.9604
# Epoch 055 | Loss: 0.2350 | Val Acc: 0.9267 | Val F1: 0.7305 | F1 Illicit: 0.9604
# Epoch 056 | Loss: 0.2341 | Val Acc: 0.9271 | Val F1: 0.7319 | F1 Illicit: 0.9606
# Epoch 057 | Loss: 0.2299 | Val Acc: 0.9281 | Val F1: 0.7365 | F1 Illicit: 0.9612
# Epoch 058 | Loss: 0.2361 | Val Acc: 0.9284 | Val F1: 0.7384 | F1 Illicit: 0.9614
# Epoch 059 | Loss: 0.2303 | Val Acc: 0.9288 | Val F1: 0.7405 | F1 Illicit: 0.9615
# Epoch 060 | Loss: 0.2267 | Val Acc: 0.9296 | Val F1: 0.7449 | F1 Illicit: 0.9619
# Epoch 061 | Loss: 0.2282 | Val Acc: 0.9301 | Val F1: 0.7476 | F1 Illicit: 0.9622
# Epoch 062 | Loss: 0.2271 | Val Acc: 0.9307 | Val F1: 0.7508 | F1 Illicit: 0.9625
# Epoch 063 | Loss: 0.2258 | Val Acc: 0.9309 | Val F1: 0.7517 | F1 Illicit: 0.9627
# Epoch 064 | Loss: 0.2272 | Val Acc: 0.9312 | Val F1: 0.7531 | F1 Illicit: 0.9628
# Epoch 065 | Loss: 0.2287 | Val Acc: 0.9314 | Val F1: 0.7545 | F1 Illicit: 0.9629
# Epoch 066 | Loss: 0.2240 | Val Acc: 0.9316 | Val F1: 0.7568 | F1 Illicit: 0.9630
# Epoch 067 | Loss: 0.2227 | Val Acc: 0.9324 | Val F1: 0.7609 | F1 Illicit: 0.9634
# Epoch 068 | Loss: 0.2248 | Val Acc: 0.9329 | Val F1: 0.7629 | F1 Illicit: 0.9636
# Epoch 069 | Loss: 0.2216 | Val Acc: 0.9336 | Val F1: 0.7661 | F1 Illicit: 0.9641
# Epoch 070 | Loss: 0.2200 | Val Acc: 0.9341 | Val F1: 0.7681 | F1 Illicit: 0.9643
# Epoch 071 | Loss: 0.2186 | Val Acc: 0.9346 | Val F1: 0.7703 | F1 Illicit: 0.9646
# Epoch 072 | Loss: 0.2214 | Val Acc: 0.9350 | Val F1: 0.7724 | F1 Illicit: 0.9648
# Epoch 073 | Loss: 0.2187 | Val Acc: 0.9352 | Val F1: 0.7734 | F1 Illicit: 0.9649
# Epoch 074 | Loss: 0.2190 | Val Acc: 0.9357 | Val F1: 0.7755 | F1 Illicit: 0.9652
# Epoch 075 | Loss: 0.2157 | Val Acc: 0.9359 | Val F1: 0.7763 | F1 Illicit: 0.9653
# Epoch 076 | Loss: 0.2164 | Val Acc: 0.9363 | Val F1: 0.7779 | F1 Illicit: 0.9655
# Epoch 077 | Loss: 0.2173 | Val Acc: 0.9364 | Val F1: 0.7787 | F1 Illicit: 0.9655
# Epoch 078 | Loss: 0.2162 | Val Acc: 0.9369 | Val F1: 0.7810 | F1 Illicit: 0.9658
# Epoch 079 | Loss: 0.2155 | Val Acc: 0.9374 | Val F1: 0.7829 | F1 Illicit: 0.9661
# Epoch 080 | Loss: 0.2144 | Val Acc: 0.9378 | Val F1: 0.7848 | F1 Illicit: 0.9663
# Epoch 081 | Loss: 0.2140 | Val Acc: 0.9377 | Val F1: 0.7847 | F1 Illicit: 0.9662
# Epoch 082 | Loss: 0.2121 | Val Acc: 0.9382 | Val F1: 0.7865 | F1 Illicit: 0.9664
# Epoch 083 | Loss: 0.2134 | Val Acc: 0.9384 | Val F1: 0.7877 | F1 Illicit: 0.9665
# Epoch 084 | Loss: 0.2128 | Val Acc: 0.9383 | Val F1: 0.7879 | F1 Illicit: 0.9665
# Epoch 085 | Loss: 0.2100 | Val Acc: 0.9385 | Val F1: 0.7889 | F1 Illicit: 0.9666
# Epoch 086 | Loss: 0.2092 | Val Acc: 0.9388 | Val F1: 0.7902 | F1 Illicit: 0.9668
# Epoch 087 | Loss: 0.2086 | Val Acc: 0.9392 | Val F1: 0.7919 | F1 Illicit: 0.9670
# Epoch 088 | Loss: 0.2095 | Val Acc: 0.9392 | Val F1: 0.7924 | F1 Illicit: 0.9670
# Epoch 089 | Loss: 0.2091 | Val Acc: 0.9395 | Val F1: 0.7937 | F1 Illicit: 0.9671
# Epoch 090 | Loss: 0.2088 | Val Acc: 0.9398 | Val F1: 0.7952 | F1 Illicit: 0.9673
# Epoch 091 | Loss: 0.2067 | Val Acc: 0.9400 | Val F1: 0.7956 | F1 Illicit: 0.9674
# Epoch 092 | Loss: 0.2056 | Val Acc: 0.9402 | Val F1: 0.7961 | F1 Illicit: 0.9675
# Epoch 093 | Loss: 0.2072 | Val Acc: 0.9404 | Val F1: 0.7974 | F1 Illicit: 0.9676
# Epoch 094 | Loss: 0.2074 | Val Acc: 0.9407 | Val F1: 0.7987 | F1 Illicit: 0.9678
# Epoch 095 | Loss: 0.2052 | Val Acc: 0.9409 | Val F1: 0.7994 | F1 Illicit: 0.9679
# Epoch 096 | Loss: 0.2054 | Val Acc: 0.9409 | Val F1: 0.7996 | F1 Illicit: 0.9679
# Epoch 097 | Loss: 0.2056 | Val Acc: 0.9412 | Val F1: 0.8005 | F1 Illicit: 0.9680
# Epoch 098 | Loss: 0.2079 | Val Acc: 0.9418 | Val F1: 0.8031 | F1 Illicit: 0.9684
# Epoch 099 | Loss: 0.2060 | Val Acc: 0.9421 | Val F1: 0.8042 | F1 Illicit: 0.9685
# Epoch 100 | Loss: 0.2069 | Val Acc: 0.9425 | Val F1: 0.8058 | F1 Illicit: 0.9687
# Epoch 101 | Loss: 0.2011 | Val Acc: 0.9427 | Val F1: 0.8065 | F1 Illicit: 0.9688
# Epoch 102 | Loss: 0.2011 | Val Acc: 0.9430 | Val F1: 0.8081 | F1 Illicit: 0.9690
# Epoch 103 | Loss: 0.2021 | Val Acc: 0.9433 | Val F1: 0.8092 | F1 Illicit: 0.9692
# Epoch 104 | Loss: 0.2011 | Val Acc: 0.9435 | Val F1: 0.8100 | F1 Illicit: 0.9692
# Epoch 105 | Loss: 0.2012 | Val Acc: 0.9437 | Val F1: 0.8109 | F1 Illicit: 0.9693
# Epoch 106 | Loss: 0.1989 | Val Acc: 0.9440 | Val F1: 0.8122 | F1 Illicit: 0.9695
# Epoch 107 | Loss: 0.1978 | Val Acc: 0.9444 | Val F1: 0.8142 | F1 Illicit: 0.9697
# Epoch 108 | Loss: 0.2006 | Val Acc: 0.9445 | Val F1: 0.8149 | F1 Illicit: 0.9698
# Epoch 109 | Loss: 0.1970 | Val Acc: 0.9450 | Val F1: 0.8169 | F1 Illicit: 0.9700
# Epoch 110 | Loss: 0.1982 | Val Acc: 0.9452 | Val F1: 0.8181 | F1 Illicit: 0.9702
# Epoch 111 | Loss: 0.1958 | Val Acc: 0.9452 | Val F1: 0.8183 | F1 Illicit: 0.9702
# Epoch 112 | Loss: 0.1963 | Val Acc: 0.9454 | Val F1: 0.8189 | F1 Illicit: 0.9702
# Epoch 113 | Loss: 0.1991 | Val Acc: 0.9455 | Val F1: 0.8195 | F1 Illicit: 0.9703
# Epoch 114 | Loss: 0.1964 | Val Acc: 0.9456 | Val F1: 0.8198 | F1 Illicit: 0.9704
# Epoch 115 | Loss: 0.1941 | Val Acc: 0.9457 | Val F1: 0.8204 | F1 Illicit: 0.9704
# Epoch 116 | Loss: 0.1970 | Val Acc: 0.9460 | Val F1: 0.8212 | F1 Illicit: 0.9706
# Epoch 117 | Loss: 0.1955 | Val Acc: 0.9460 | Val F1: 0.8217 | F1 Illicit: 0.9706
# Epoch 118 | Loss: 0.1937 | Val Acc: 0.9462 | Val F1: 0.8221 | F1 Illicit: 0.9707
# Epoch 119 | Loss: 0.1943 | Val Acc: 0.9462 | Val F1: 0.8221 | F1 Illicit: 0.9707
# Epoch 120 | Loss: 0.1946 | Val Acc: 0.9464 | Val F1: 0.8231 | F1 Illicit: 0.9708
# Epoch 121 | Loss: 0.1921 | Val Acc: 0.9465 | Val F1: 0.8237 | F1 Illicit: 0.9709
# Epoch 122 | Loss: 0.1916 | Val Acc: 0.9466 | Val F1: 0.8240 | F1 Illicit: 0.9709
# Epoch 123 | Loss: 0.1912 | Val Acc: 0.9465 | Val F1: 0.8239 | F1 Illicit: 0.9709
# Epoch 124 | Loss: 0.1945 | Val Acc: 0.9472 | Val F1: 0.8263 | F1 Illicit: 0.9712
# Epoch 125 | Loss: 0.1915 | Val Acc: 0.9478 | Val F1: 0.8289 | F1 Illicit: 0.9715
# Epoch 126 | Loss: 0.1914 | Val Acc: 0.9481 | Val F1: 0.8299 | F1 Illicit: 0.9717
# Epoch 127 | Loss: 0.1881 | Val Acc: 0.9482 | Val F1: 0.8305 | F1 Illicit: 0.9718
# Epoch 128 | Loss: 0.1880 | Val Acc: 0.9483 | Val F1: 0.8310 | F1 Illicit: 0.9718
# Epoch 129 | Loss: 0.1885 | Val Acc: 0.9486 | Val F1: 0.8323 | F1 Illicit: 0.9720
# Epoch 130 | Loss: 0.1903 | Val Acc: 0.9490 | Val F1: 0.8337 | F1 Illicit: 0.9722
# Epoch 131 | Loss: 0.1866 | Val Acc: 0.9492 | Val F1: 0.8346 | F1 Illicit: 0.9723
# Epoch 132 | Loss: 0.1898 | Val Acc: 0.9495 | Val F1: 0.8354 | F1 Illicit: 0.9724
# Epoch 133 | Loss: 0.1885 | Val Acc: 0.9497 | Val F1: 0.8365 | F1 Illicit: 0.9726
# Epoch 134 | Loss: 0.1880 | Val Acc: 0.9501 | Val F1: 0.8379 | F1 Illicit: 0.9728
# Epoch 135 | Loss: 0.1878 | Val Acc: 0.9504 | Val F1: 0.8390 | F1 Illicit: 0.9729
# Epoch 136 | Loss: 0.1865 | Val Acc: 0.9510 | Val F1: 0.8411 | F1 Illicit: 0.9732
# Epoch 137 | Loss: 0.1848 | Val Acc: 0.9510 | Val F1: 0.8413 | F1 Illicit: 0.9733
# Epoch 138 | Loss: 0.1833 | Val Acc: 0.9513 | Val F1: 0.8423 | F1 Illicit: 0.9734
# Epoch 139 | Loss: 0.1856 | Val Acc: 0.9513 | Val F1: 0.8423 | F1 Illicit: 0.9734
# Epoch 140 | Loss: 0.1833 | Val Acc: 0.9515 | Val F1: 0.8427 | F1 Illicit: 0.9735
# Epoch 141 | Loss: 0.1817 | Val Acc: 0.9516 | Val F1: 0.8432 | F1 Illicit: 0.9736
# Epoch 142 | Loss: 0.1832 | Val Acc: 0.9517 | Val F1: 0.8436 | F1 Illicit: 0.9736
# Epoch 143 | Loss: 0.1838 | Val Acc: 0.9519 | Val F1: 0.8445 | F1 Illicit: 0.9737
# Epoch 144 | Loss: 0.1823 | Val Acc: 0.9518 | Val F1: 0.8444 | F1 Illicit: 0.9737
# Epoch 145 | Loss: 0.1829 | Val Acc: 0.9520 | Val F1: 0.8450 | F1 Illicit: 0.9738
# Epoch 146 | Loss: 0.1817 | Val Acc: 0.9521 | Val F1: 0.8456 | F1 Illicit: 0.9738
# Epoch 147 | Loss: 0.1830 | Val Acc: 0.9523 | Val F1: 0.8465 | F1 Illicit: 0.9740
# Epoch 148 | Loss: 0.1823 | Val Acc: 0.9523 | Val F1: 0.8464 | F1 Illicit: 0.9739
# Epoch 149 | Loss: 0.1814 | Val Acc: 0.9523 | Val F1: 0.8469 | F1 Illicit: 0.9739
# Epoch 150 | Loss: 0.1810 | Val Acc: 0.9524 | Val F1: 0.8475 | F1 Illicit: 0.9740
# Epoch 151 | Loss: 0.1801 | Val Acc: 0.9523 | Val F1: 0.8471 | F1 Illicit: 0.9739
# Epoch 152 | Loss: 0.1800 | Val Acc: 0.9525 | Val F1: 0.8485 | F1 Illicit: 0.9740
# Epoch 153 | Loss: 0.1813 | Val Acc: 0.9527 | Val F1: 0.8491 | F1 Illicit: 0.9741
# Epoch 154 | Loss: 0.1795 | Val Acc: 0.9530 | Val F1: 0.8503 | F1 Illicit: 0.9743
# Epoch 155 | Loss: 0.1779 | Val Acc: 0.9529 | Val F1: 0.8503 | F1 Illicit: 0.9742
# Epoch 156 | Loss: 0.1786 | Val Acc: 0.9530 | Val F1: 0.8507 | F1 Illicit: 0.9743
# Epoch 157 | Loss: 0.1782 | Val Acc: 0.9533 | Val F1: 0.8517 | F1 Illicit: 0.9744
# Epoch 158 | Loss: 0.1804 | Val Acc: 0.9534 | Val F1: 0.8520 | F1 Illicit: 0.9745
# Epoch 159 | Loss: 0.1765 | Val Acc: 0.9535 | Val F1: 0.8522 | F1 Illicit: 0.9745
# Epoch 160 | Loss: 0.1763 | Val Acc: 0.9535 | Val F1: 0.8525 | F1 Illicit: 0.9746
# Epoch 161 | Loss: 0.1785 | Val Acc: 0.9538 | Val F1: 0.8532 | F1 Illicit: 0.9747
# Epoch 162 | Loss: 0.1765 | Val Acc: 0.9538 | Val F1: 0.8532 | F1 Illicit: 0.9747
# Epoch 163 | Loss: 0.1772 | Val Acc: 0.9539 | Val F1: 0.8538 | F1 Illicit: 0.9748
# Epoch 164 | Loss: 0.1780 | Val Acc: 0.9543 | Val F1: 0.8551 | F1 Illicit: 0.9750
# Epoch 165 | Loss: 0.1765 | Val Acc: 0.9545 | Val F1: 0.8563 | F1 Illicit: 0.9751
# Epoch 166 | Loss: 0.1764 | Val Acc: 0.9547 | Val F1: 0.8569 | F1 Illicit: 0.9752
# Epoch 167 | Loss: 0.1753 | Val Acc: 0.9549 | Val F1: 0.8576 | F1 Illicit: 0.9753
# Epoch 168 | Loss: 0.1740 | Val Acc: 0.9552 | Val F1: 0.8586 | F1 Illicit: 0.9755
# Epoch 169 | Loss: 0.1728 | Val Acc: 0.9552 | Val F1: 0.8587 | F1 Illicit: 0.9755
# Epoch 170 | Loss: 0.1743 | Val Acc: 0.9552 | Val F1: 0.8588 | F1 Illicit: 0.9755
# Epoch 171 | Loss: 0.1736 | Val Acc: 0.9555 | Val F1: 0.8598 | F1 Illicit: 0.9756
# Epoch 172 | Loss: 0.1745 | Val Acc: 0.9558 | Val F1: 0.8609 | F1 Illicit: 0.9758
# Epoch 173 | Loss: 0.1740 | Val Acc: 0.9559 | Val F1: 0.8616 | F1 Illicit: 0.9758
# Epoch 174 | Loss: 0.1715 | Val Acc: 0.9565 | Val F1: 0.8638 | F1 Illicit: 0.9762
# Epoch 175 | Loss: 0.1711 | Val Acc: 0.9568 | Val F1: 0.8649 | F1 Illicit: 0.9763
# Epoch 176 | Loss: 0.1735 | Val Acc: 0.9570 | Val F1: 0.8656 | F1 Illicit: 0.9764
# Epoch 177 | Loss: 0.1721 | Val Acc: 0.9571 | Val F1: 0.8662 | F1 Illicit: 0.9765
# Epoch 178 | Loss: 0.1717 | Val Acc: 0.9573 | Val F1: 0.8667 | F1 Illicit: 0.9766
# Epoch 179 | Loss: 0.1728 | Val Acc: 0.9573 | Val F1: 0.8666 | F1 Illicit: 0.9766
# Epoch 180 | Loss: 0.1726 | Val Acc: 0.9573 | Val F1: 0.8665 | F1 Illicit: 0.9766
# Epoch 181 | Loss: 0.1718 | Val Acc: 0.9573 | Val F1: 0.8665 | F1 Illicit: 0.9766
# Epoch 182 | Loss: 0.1701 | Val Acc: 0.9574 | Val F1: 0.8669 | F1 Illicit: 0.9767
# Epoch 183 | Loss: 0.1704 | Val Acc: 0.9574 | Val F1: 0.8669 | F1 Illicit: 0.9767
# Epoch 184 | Loss: 0.1690 | Val Acc: 0.9575 | Val F1: 0.8672 | F1 Illicit: 0.9767
# Epoch 185 | Loss: 0.1695 | Val Acc: 0.9578 | Val F1: 0.8681 | F1 Illicit: 0.9769
# Epoch 186 | Loss: 0.1696 | Val Acc: 0.9578 | Val F1: 0.8681 | F1 Illicit: 0.9769
# Epoch 187 | Loss: 0.1686 | Val Acc: 0.9577 | Val F1: 0.8678 | F1 Illicit: 0.9768
# Epoch 188 | Loss: 0.1690 | Val Acc: 0.9577 | Val F1: 0.8678 | F1 Illicit: 0.9768
# Epoch 189 | Loss: 0.1694 | Val Acc: 0.9577 | Val F1: 0.8678 | F1 Illicit: 0.9768
# Epoch 190 | Loss: 0.1682 | Val Acc: 0.9579 | Val F1: 0.8687 | F1 Illicit: 0.9769
# Epoch 191 | Loss: 0.1707 | Val Acc: 0.9579 | Val F1: 0.8686 | F1 Illicit: 0.9769
# Epoch 192 | Loss: 0.1681 | Val Acc: 0.9578 | Val F1: 0.8683 | F1 Illicit: 0.9769
# Epoch 193 | Loss: 0.1670 | Val Acc: 0.9578 | Val F1: 0.8685 | F1 Illicit: 0.9769
# Epoch 194 | Loss: 0.1679 | Val Acc: 0.9579 | Val F1: 0.8688 | F1 Illicit: 0.9769
# Epoch 195 | Loss: 0.1694 | Val Acc: 0.9579 | Val F1: 0.8688 | F1 Illicit: 0.9769
# Epoch 196 | Loss: 0.1687 | Val Acc: 0.9578 | Val F1: 0.8686 | F1 Illicit: 0.9769
# Epoch 197 | Loss: 0.1678 | Val Acc: 0.9580 | Val F1: 0.8692 | F1 Illicit: 0.9770
# Epoch 198 | Loss: 0.1669 | Val Acc: 0.9581 | Val F1: 0.8698 | F1 Illicit: 0.9770
# Epoch 199 | Loss: 0.1683 | Val Acc: 0.9583 | Val F1: 0.8705 | F1 Illicit: 0.9772
# Epoch 200 | Loss: 0.1686 | Val Acc: 0.9583 | Val F1: 0.8707 | F1 Illicit: 0.9772
# Epoch 201 | Loss: 0.1675 | Val Acc: 0.9584 | Val F1: 0.8709 | F1 Illicit: 0.9772
# Epoch 202 | Loss: 0.1649 | Val Acc: 0.9587 | Val F1: 0.8721 | F1 Illicit: 0.9773
# Epoch 203 | Loss: 0.1649 | Val Acc: 0.9588 | Val F1: 0.8725 | F1 Illicit: 0.9774
# Epoch 204 | Loss: 0.1655 | Val Acc: 0.9588 | Val F1: 0.8725 | F1 Illicit: 0.9774
# Epoch 205 | Loss: 0.1657 | Val Acc: 0.9592 | Val F1: 0.8736 | F1 Illicit: 0.9776
# Epoch 206 | Loss: 0.1655 | Val Acc: 0.9592 | Val F1: 0.8736 | F1 Illicit: 0.9776
# Epoch 207 | Loss: 0.1662 | Val Acc: 0.9592 | Val F1: 0.8737 | F1 Illicit: 0.9776
# Epoch 208 | Loss: 0.1639 | Val Acc: 0.9593 | Val F1: 0.8742 | F1 Illicit: 0.9777
# Epoch 209 | Loss: 0.1647 | Val Acc: 0.9593 | Val F1: 0.8742 | F1 Illicit: 0.9777
# Epoch 210 | Loss: 0.1621 | Val Acc: 0.9596 | Val F1: 0.8749 | F1 Illicit: 0.9778
# Epoch 211 | Loss: 0.1623 | Val Acc: 0.9596 | Val F1: 0.8751 | F1 Illicit: 0.9778
# Epoch 212 | Loss: 0.1646 | Val Acc: 0.9598 | Val F1: 0.8755 | F1 Illicit: 0.9779
# Epoch 213 | Loss: 0.1625 | Val Acc: 0.9597 | Val F1: 0.8752 | F1 Illicit: 0.9779
# Epoch 214 | Loss: 0.1627 | Val Acc: 0.9597 | Val F1: 0.8751 | F1 Illicit: 0.9779
# Epoch 215 | Loss: 0.1629 | Val Acc: 0.9597 | Val F1: 0.8751 | F1 Illicit: 0.9779
# Epoch 216 | Loss: 0.1608 | Val Acc: 0.9597 | Val F1: 0.8752 | F1 Illicit: 0.9779
# Epoch 217 | Loss: 0.1621 | Val Acc: 0.9597 | Val F1: 0.8754 | F1 Illicit: 0.9779
# Epoch 218 | Loss: 0.1612 | Val Acc: 0.9596 | Val F1: 0.8753 | F1 Illicit: 0.9778
# Epoch 219 | Loss: 0.1618 | Val Acc: 0.9598 | Val F1: 0.8757 | F1 Illicit: 0.9779
# Epoch 220 | Loss: 0.1622 | Val Acc: 0.9598 | Val F1: 0.8757 | F1 Illicit: 0.9779
# Epoch 221 | Loss: 0.1623 | Val Acc: 0.9598 | Val F1: 0.8756 | F1 Illicit: 0.9779
# Epoch 222 | Loss: 0.1610 | Val Acc: 0.9596 | Val F1: 0.8751 | F1 Illicit: 0.9778
# Epoch 223 | Loss: 0.1614 | Val Acc: 0.9596 | Val F1: 0.8749 | F1 Illicit: 0.9778
# Epoch 224 | Loss: 0.1598 | Val Acc: 0.9596 | Val F1: 0.8749 | F1 Illicit: 0.9778
# Epoch 225 | Loss: 0.1578 | Val Acc: 0.9596 | Val F1: 0.8750 | F1 Illicit: 0.9779
# Epoch 226 | Loss: 0.1570 | Val Acc: 0.9596 | Val F1: 0.8750 | F1 Illicit: 0.9779
# Epoch 227 | Loss: 0.1602 | Val Acc: 0.9597 | Val F1: 0.8752 | F1 Illicit: 0.9779
# Epoch 228 | Loss: 0.1583 | Val Acc: 0.9598 | Val F1: 0.8757 | F1 Illicit: 0.9780
# Epoch 229 | Loss: 0.1596 | Val Acc: 0.9599 | Val F1: 0.8759 | F1 Illicit: 0.9780
# Epoch 230 | Loss: 0.1592 | Val Acc: 0.9598 | Val F1: 0.8756 | F1 Illicit: 0.9779
# Epoch 231 | Loss: 0.1602 | Val Acc: 0.9599 | Val F1: 0.8760 | F1 Illicit: 0.9780
# Epoch 232 | Loss: 0.1583 | Val Acc: 0.9600 | Val F1: 0.8764 | F1 Illicit: 0.9780
# Epoch 233 | Loss: 0.1576 | Val Acc: 0.9601 | Val F1: 0.8769 | F1 Illicit: 0.9781
# Epoch 234 | Loss: 0.1585 | Val Acc: 0.9601 | Val F1: 0.8769 | F1 Illicit: 0.9781
# Epoch 235 | Loss: 0.1576 | Val Acc: 0.9601 | Val F1: 0.8766 | F1 Illicit: 0.9781
# Epoch 236 | Loss: 0.1579 | Val Acc: 0.9601 | Val F1: 0.8769 | F1 Illicit: 0.9781
# Epoch 237 | Loss: 0.1575 | Val Acc: 0.9601 | Val F1: 0.8767 | F1 Illicit: 0.9781
# Epoch 238 | Loss: 0.1596 | Val Acc: 0.9602 | Val F1: 0.8773 | F1 Illicit: 0.9782
# Epoch 239 | Loss: 0.1567 | Val Acc: 0.9603 | Val F1: 0.8776 | F1 Illicit: 0.9782
# Epoch 240 | Loss: 0.1576 | Val Acc: 0.9603 | Val F1: 0.8779 | F1 Illicit: 0.9782
# Epoch 241 | Loss: 0.1589 | Val Acc: 0.9603 | Val F1: 0.8779 | F1 Illicit: 0.9782
# Epoch 242 | Loss: 0.1568 | Val Acc: 0.9603 | Val F1: 0.8779 | F1 Illicit: 0.9782
# Epoch 243 | Loss: 0.1564 | Val Acc: 0.9604 | Val F1: 0.8781 | F1 Illicit: 0.9783
# Epoch 244 | Loss: 0.1550 | Val Acc: 0.9604 | Val F1: 0.8781 | F1 Illicit: 0.9783
# Epoch 245 | Loss: 0.1570 | Val Acc: 0.9604 | Val F1: 0.8780 | F1 Illicit: 0.9783
# Epoch 246 | Loss: 0.1547 | Val Acc: 0.9605 | Val F1: 0.8782 | F1 Illicit: 0.9783
# Epoch 247 | Loss: 0.1570 | Val Acc: 0.9606 | Val F1: 0.8787 | F1 Illicit: 0.9784
# Epoch 248 | Loss: 0.1566 | Val Acc: 0.9608 | Val F1: 0.8795 | F1 Illicit: 0.9785
# Epoch 249 | Loss: 0.1571 | Val Acc: 0.9611 | Val F1: 0.8804 | F1 Illicit: 0.9787
# Epoch 250 | Loss: 0.1547 | Val Acc: 0.9611 | Val F1: 0.8803 | F1 Illicit: 0.9786
# Epoch 251 | Loss: 0.1548 | Val Acc: 0.9611 | Val F1: 0.8803 | F1 Illicit: 0.9786
# Epoch 252 | Loss: 0.1562 | Val Acc: 0.9610 | Val F1: 0.8802 | F1 Illicit: 0.9786
# Epoch 253 | Loss: 0.1546 | Val Acc: 0.9610 | Val F1: 0.8803 | F1 Illicit: 0.9786
# Epoch 254 | Loss: 0.1554 | Val Acc: 0.9611 | Val F1: 0.8807 | F1 Illicit: 0.9786
# Epoch 255 | Loss: 0.1571 | Val Acc: 0.9611 | Val F1: 0.8807 | F1 Illicit: 0.9786
# Epoch 256 | Loss: 0.1537 | Val Acc: 0.9612 | Val F1: 0.8810 | F1 Illicit: 0.9787
# Epoch 257 | Loss: 0.1548 | Val Acc: 0.9613 | Val F1: 0.8813 | F1 Illicit: 0.9788
# Epoch 258 | Loss: 0.1509 | Val Acc: 0.9613 | Val F1: 0.8814 | F1 Illicit: 0.9788
# Epoch 259 | Loss: 0.1550 | Val Acc: 0.9616 | Val F1: 0.8820 | F1 Illicit: 0.9789
# Epoch 260 | Loss: 0.1543 | Val Acc: 0.9618 | Val F1: 0.8826 | F1 Illicit: 0.9790
# Epoch 261 | Loss: 0.1531 | Val Acc: 0.9617 | Val F1: 0.8823 | F1 Illicit: 0.9790
# Epoch 262 | Loss: 0.1522 | Val Acc: 0.9618 | Val F1: 0.8827 | F1 Illicit: 0.9791
# Epoch 263 | Loss: 0.1531 | Val Acc: 0.9619 | Val F1: 0.8829 | F1 Illicit: 0.9791
# Epoch 264 | Loss: 0.1528 | Val Acc: 0.9618 | Val F1: 0.8825 | F1 Illicit: 0.9790
# Epoch 265 | Loss: 0.1532 | Val Acc: 0.9618 | Val F1: 0.8825 | F1 Illicit: 0.9790
# Epoch 266 | Loss: 0.1517 | Val Acc: 0.9618 | Val F1: 0.8826 | F1 Illicit: 0.9790
# Epoch 267 | Loss: 0.1560 | Val Acc: 0.9619 | Val F1: 0.8832 | F1 Illicit: 0.9791
# Epoch 268 | Loss: 0.1533 | Val Acc: 0.9618 | Val F1: 0.8833 | F1 Illicit: 0.9790
# Epoch 269 | Loss: 0.1526 | Val Acc: 0.9618 | Val F1: 0.8832 | F1 Illicit: 0.9790
# Epoch 270 | Loss: 0.1508 | Val Acc: 0.9620 | Val F1: 0.8840 | F1 Illicit: 0.9791
# Epoch 271 | Loss: 0.1536 | Val Acc: 0.9621 | Val F1: 0.8843 | F1 Illicit: 0.9792
# Epoch 272 | Loss: 0.1480 | Val Acc: 0.9621 | Val F1: 0.8843 | F1 Illicit: 0.9792
# Epoch 273 | Loss: 0.1535 | Val Acc: 0.9621 | Val F1: 0.8843 | F1 Illicit: 0.9792
# Epoch 274 | Loss: 0.1501 | Val Acc: 0.9623 | Val F1: 0.8852 | F1 Illicit: 0.9793
# Epoch 275 | Loss: 0.1527 | Val Acc: 0.9624 | Val F1: 0.8854 | F1 Illicit: 0.9793
# Epoch 276 | Loss: 0.1499 | Val Acc: 0.9626 | Val F1: 0.8861 | F1 Illicit: 0.9795
# Epoch 277 | Loss: 0.1515 | Val Acc: 0.9626 | Val F1: 0.8861 | F1 Illicit: 0.9795
# Epoch 278 | Loss: 0.1495 | Val Acc: 0.9626 | Val F1: 0.8861 | F1 Illicit: 0.9795
# Epoch 279 | Loss: 0.1483 | Val Acc: 0.9626 | Val F1: 0.8862 | F1 Illicit: 0.9795
# Epoch 280 | Loss: 0.1496 | Val Acc: 0.9626 | Val F1: 0.8862 | F1 Illicit: 0.9795
# Epoch 281 | Loss: 0.1501 | Val Acc: 0.9626 | Val F1: 0.8859 | F1 Illicit: 0.9794
# Epoch 282 | Loss: 0.1489 | Val Acc: 0.9626 | Val F1: 0.8859 | F1 Illicit: 0.9794
# Epoch 283 | Loss: 0.1522 | Val Acc: 0.9625 | Val F1: 0.8856 | F1 Illicit: 0.9794
# Epoch 284 | Loss: 0.1469 | Val Acc: 0.9625 | Val F1: 0.8857 | F1 Illicit: 0.9794
# Epoch 285 | Loss: 0.1493 | Val Acc: 0.9623 | Val F1: 0.8852 | F1 Illicit: 0.9793
# Epoch 286 | Loss: 0.1488 | Val Acc: 0.9625 | Val F1: 0.8856 | F1 Illicit: 0.9794
# Epoch 287 | Loss: 0.1491 | Val Acc: 0.9626 | Val F1: 0.8857 | F1 Illicit: 0.9794
# Epoch 288 | Loss: 0.1502 | Val Acc: 0.9626 | Val F1: 0.8857 | F1 Illicit: 0.9794
# Epoch 289 | Loss: 0.1479 | Val Acc: 0.9627 | Val F1: 0.8859 | F1 Illicit: 0.9795
# Epoch 290 | Loss: 0.1491 | Val Acc: 0.9628 | Val F1: 0.8862 | F1 Illicit: 0.9796
# Epoch 291 | Loss: 0.1489 | Val Acc: 0.9628 | Val F1: 0.8864 | F1 Illicit: 0.9796
# ...
# Epoch 127 | Loss: 0.2081 | Val Acc: 0.9462 | Val F1: 0.8209 | F1 Illicit: 0.9707
# Epoch 128 | Loss: 0.2063 | Val Acc: 0.9462 | Val F1: 0.8210 | F1 Illicit: 0.9707
# Epoch 129 | Loss: 0.2046 | Val Acc: 0.9463 | Val F1: 0.8215 | F1 Illicit: 0.9708
# Epoch 130 | Loss: 0.2064 | Val Acc: 0.9462 | Val F1: 0.8211 | F1 Illicit: 0.9707
# Epoch 131 | Loss: 0.2064 | Val Acc: 0.9465 | Val F1: 0.8224 | F1 Illicit: 0.9709
# Epoch 132 | Loss: 0.2047 | Val Acc: 0.9466 | Val F1: 0.8227 | F1 Illicit: 0.9709
# Epoch 133 | Loss: 0.2055 | Val Acc: 0.9467 | Val F1: 0.8236 | F1 Illicit: 0.9710
# Epoch 134 | Loss: 0.2052 | Val Acc: 0.9469 | Val F1: 0.8245 | F1 Illicit: 0.9711
# Epoch 135 | Loss: 0.2096 | Val Acc: 0.9472 | Val F1: 0.8256 | F1 Illicit: 0.9712
# Epoch 136 | Loss: 0.2053 | Val Acc: 0.9473 | Val F1: 0.8263 | F1 Illicit: 0.9713
# Epoch 137 | Loss: 0.2034 | Val Acc: 0.9475 | Val F1: 0.8275 | F1 Illicit: 0.9714
# Epoch 138 | Loss: 0.2076 | Val Acc: 0.9475 | Val F1: 0.8276 | F1 Illicit: 0.9713
# Epoch 139 | Loss: 0.2044 | Val Acc: 0.9475 | Val F1: 0.8275 | F1 Illicit: 0.9714
# Epoch 140 | Loss: 0.2041 | Val Acc: 0.9477 | Val F1: 0.8283 | F1 Illicit: 0.9715
# Epoch 141 | Loss: 0.2031 | Val Acc: 0.9478 | Val F1: 0.8283 | F1 Illicit: 0.9716
# Epoch 142 | Loss: 0.2031 | Val Acc: 0.9478 | Val F1: 0.8281 | F1 Illicit: 0.9716
# Epoch 143 | Loss: 0.2023 | Val Acc: 0.9477 | Val F1: 0.8276 | F1 Illicit: 0.9715
# Epoch 144 | Loss: 0.2018 | Val Acc: 0.9479 | Val F1: 0.8278 | F1 Illicit: 0.9716
# Epoch 145 | Loss: 0.2027 | Val Acc: 0.9480 | Val F1: 0.8282 | F1 Illicit: 0.9717
# Epoch 146 | Loss: 0.2025 | Val Acc: 0.9481 | Val F1: 0.8285 | F1 Illicit: 0.9717
# Epoch 147 | Loss: 0.2015 | Val Acc: 0.9480 | Val F1: 0.8286 | F1 Illicit: 0.9717
# Epoch 148 | Loss: 0.2059 | Val Acc: 0.9482 | Val F1: 0.8292 | F1 Illicit: 0.9718
# Epoch 149 | Loss: 0.2019 | Val Acc: 0.9483 | Val F1: 0.8296 | F1 Illicit: 0.9718
# Epoch 150 | Loss: 0.2033 | Val Acc: 0.9484 | Val F1: 0.8299 | F1 Illicit: 0.9719
# Epoch 151 | Loss: 0.2003 | Val Acc: 0.9484 | Val F1: 0.8299 | F1 Illicit: 0.9719
# Epoch 152 | Loss: 0.2019 | Val Acc: 0.9485 | Val F1: 0.8304 | F1 Illicit: 0.9719
# Epoch 153 | Loss: 0.2013 | Val Acc: 0.9488 | Val F1: 0.8314 | F1 Illicit: 0.9721
# Epoch 154 | Loss: 0.2010 | Val Acc: 0.9488 | Val F1: 0.8315 | F1 Illicit: 0.9721
# Epoch 155 | Loss: 0.2002 | Val Acc: 0.9487 | Val F1: 0.8312 | F1 Illicit: 0.9721
# Epoch 156 | Loss: 0.1979 | Val Acc: 0.9488 | Val F1: 0.8316 | F1 Illicit: 0.9721
# Epoch 157 | Loss: 0.1994 | Val Acc: 0.9489 | Val F1: 0.8323 | F1 Illicit: 0.9721
# Epoch 158 | Loss: 0.1967 | Val Acc: 0.9488 | Val F1: 0.8323 | F1 Illicit: 0.9721
# Epoch 159 | Loss: 0.2016 | Val Acc: 0.9490 | Val F1: 0.8330 | F1 Illicit: 0.9722
# Epoch 160 | Loss: 0.1982 | Val Acc: 0.9490 | Val F1: 0.8333 | F1 Illicit: 0.9722
# Epoch 161 | Loss: 0.1950 | Val Acc: 0.9491 | Val F1: 0.8336 | F1 Illicit: 0.9722
# Epoch 162 | Loss: 0.1974 | Val Acc: 0.9491 | Val F1: 0.8336 | F1 Illicit: 0.9722
# Epoch 163 | Loss: 0.1976 | Val Acc: 0.9490 | Val F1: 0.8333 | F1 Illicit: 0.9722
# Epoch 164 | Loss: 0.1987 | Val Acc: 0.9487 | Val F1: 0.8326 | F1 Illicit: 0.9720
# Epoch 165 | Loss: 0.1954 | Val Acc: 0.9488 | Val F1: 0.8329 | F1 Illicit: 0.9721
# Epoch 166 | Loss: 0.1971 | Val Acc: 0.9490 | Val F1: 0.8334 | F1 Illicit: 0.9722
# Epoch 167 | Loss: 0.1968 | Val Acc: 0.9492 | Val F1: 0.8342 | F1 Illicit: 0.9723
# Epoch 168 | Loss: 0.1976 | Val Acc: 0.9495 | Val F1: 0.8350 | F1 Illicit: 0.9725
# Epoch 169 | Loss: 0.1965 | Val Acc: 0.9496 | Val F1: 0.8353 | F1 Illicit: 0.9725
# Epoch 170 | Loss: 0.1949 | Val Acc: 0.9497 | Val F1: 0.8352 | F1 Illicit: 0.9726
# Epoch 171 | Loss: 0.1959 | Val Acc: 0.9496 | Val F1: 0.8349 | F1 Illicit: 0.9725
# Epoch 172 | Loss: 0.1963 | Val Acc: 0.9495 | Val F1: 0.8348 | F1 Illicit: 0.9725
# Epoch 173 | Loss: 0.1943 | Val Acc: 0.9496 | Val F1: 0.8351 | F1 Illicit: 0.9725
# Epoch 174 | Loss: 0.1938 | Val Acc: 0.9497 | Val F1: 0.8352 | F1 Illicit: 0.9726
# Epoch 175 | Loss: 0.1956 | Val Acc: 0.9497 | Val F1: 0.8355 | F1 Illicit: 0.9726
# Epoch 176 | Loss: 0.1947 | Val Acc: 0.9499 | Val F1: 0.8360 | F1 Illicit: 0.9727
# Epoch 177 | Loss: 0.1931 | Val Acc: 0.9503 | Val F1: 0.8375 | F1 Illicit: 0.9729
# Epoch 178 | Loss: 0.1945 | Val Acc: 0.9499 | Val F1: 0.8365 | F1 Illicit: 0.9727
# Epoch 179 | Loss: 0.1922 | Val Acc: 0.9501 | Val F1: 0.8375 | F1 Illicit: 0.9728
# Epoch 180 | Loss: 0.1930 | Val Acc: 0.9503 | Val F1: 0.8382 | F1 Illicit: 0.9728
# Epoch 181 | Loss: 0.1928 | Val Acc: 0.9501 | Val F1: 0.8379 | F1 Illicit: 0.9728
# Epoch 182 | Loss: 0.1919 | Val Acc: 0.9505 | Val F1: 0.8391 | F1 Illicit: 0.9730
# Epoch 183 | Loss: 0.1908 | Val Acc: 0.9505 | Val F1: 0.8392 | F1 Illicit: 0.9730
# Epoch 184 | Loss: 0.1929 | Val Acc: 0.9505 | Val F1: 0.8391 | F1 Illicit: 0.9730
# Epoch 185 | Loss: 0.1902 | Val Acc: 0.9501 | Val F1: 0.8378 | F1 Illicit: 0.9728
# Epoch 186 | Loss: 0.1944 | Val Acc: 0.9505 | Val F1: 0.8387 | F1 Illicit: 0.9730
# Epoch 187 | Loss: 0.1903 | Val Acc: 0.9505 | Val F1: 0.8385 | F1 Illicit: 0.9730
# Epoch 188 | Loss: 0.1930 | Val Acc: 0.9504 | Val F1: 0.8379 | F1 Illicit: 0.9729
# Epoch 189 | Loss: 0.1918 | Val Acc: 0.9503 | Val F1: 0.8374 | F1 Illicit: 0.9729
# Epoch 190 | Loss: 0.1922 | Val Acc: 0.9504 | Val F1: 0.8378 | F1 Illicit: 0.9729
# Epoch 191 | Loss: 0.1878 | Val Acc: 0.9508 | Val F1: 0.8392 | F1 Illicit: 0.9731
# Epoch 192 | Loss: 0.1913 | Val Acc: 0.9507 | Val F1: 0.8393 | F1 Illicit: 0.9731
# Epoch 193 | Loss: 0.1909 | Val Acc: 0.9510 | Val F1: 0.8406 | F1 Illicit: 0.9732
# Epoch 194 | Loss: 0.1916 | Val Acc: 0.9511 | Val F1: 0.8414 | F1 Illicit: 0.9733
# Epoch 195 | Loss: 0.1897 | Val Acc: 0.9512 | Val F1: 0.8421 | F1 Illicit: 0.9733
# Epoch 196 | Loss: 0.1901 | Val Acc: 0.9508 | Val F1: 0.8408 | F1 Illicit: 0.9731
# Epoch 197 | Loss: 0.1883 | Val Acc: 0.9507 | Val F1: 0.8406 | F1 Illicit: 0.9731
# Epoch 198 | Loss: 0.1891 | Val Acc: 0.9505 | Val F1: 0.8402 | F1 Illicit: 0.9730
# Epoch 199 | Loss: 0.1906 | Val Acc: 0.9509 | Val F1: 0.8416 | F1 Illicit: 0.9732
# Epoch 200 | Loss: 0.1888 | Val Acc: 0.9508 | Val F1: 0.8412 | F1 Illicit: 0.9731
# Epoch 201 | Loss: 0.1878 | Val Acc: 0.9510 | Val F1: 0.8420 | F1 Illicit: 0.9732
# Epoch 202 | Loss: 0.1891 | Val Acc: 0.9514 | Val F1: 0.8431 | F1 Illicit: 0.9735
# Epoch 203 | Loss: 0.1863 | Val Acc: 0.9513 | Val F1: 0.8424 | F1 Illicit: 0.9734
# Epoch 204 | Loss: 0.1885 | Val Acc: 0.9515 | Val F1: 0.8425 | F1 Illicit: 0.9735
# Epoch 205 | Loss: 0.1866 | Val Acc: 0.9514 | Val F1: 0.8418 | F1 Illicit: 0.9735
# Epoch 206 | Loss: 0.1865 | Val Acc: 0.9513 | Val F1: 0.8415 | F1 Illicit: 0.9734
# Epoch 207 | Loss: 0.1897 | Val Acc: 0.9515 | Val F1: 0.8422 | F1 Illicit: 0.9736
# Epoch 208 | Loss: 0.1885 | Val Acc: 0.9515 | Val F1: 0.8420 | F1 Illicit: 0.9735
# Epoch 209 | Loss: 0.1851 | Val Acc: 0.9514 | Val F1: 0.8420 | F1 Illicit: 0.9735
# Epoch 210 | Loss: 0.1871 | Val Acc: 0.9515 | Val F1: 0.8425 | F1 Illicit: 0.9735
# Epoch 211 | Loss: 0.1869 | Val Acc: 0.9514 | Val F1: 0.8424 | F1 Illicit: 0.9735
# Epoch 212 | Loss: 0.1872 | Val Acc: 0.9517 | Val F1: 0.8439 | F1 Illicit: 0.9736
# Epoch 213 | Loss: 0.1866 | Val Acc: 0.9518 | Val F1: 0.8443 | F1 Illicit: 0.9736
# Epoch 214 | Loss: 0.1856 | Val Acc: 0.9516 | Val F1: 0.8438 | F1 Illicit: 0.9736
# Epoch 215 | Loss: 0.1841 | Val Acc: 0.9518 | Val F1: 0.8446 | F1 Illicit: 0.9737
# Epoch 216 | Loss: 0.1846 | Val Acc: 0.9518 | Val F1: 0.8443 | F1 Illicit: 0.9736
# Epoch 217 | Loss: 0.1810 | Val Acc: 0.9517 | Val F1: 0.8439 | F1 Illicit: 0.9736
# Epoch 218 | Loss: 0.1819 | Val Acc: 0.9516 | Val F1: 0.8436 | F1 Illicit: 0.9736
# Epoch 219 | Loss: 0.1840 | Val Acc: 0.9518 | Val F1: 0.8444 | F1 Illicit: 0.9737
# Epoch 220 | Loss: 0.1850 | Val Acc: 0.9518 | Val F1: 0.8442 | F1 Illicit: 0.9737
# Epoch 221 | Loss: 0.1845 | Val Acc: 0.9520 | Val F1: 0.8447 | F1 Illicit: 0.9738
# Epoch 222 | Loss: 0.1836 | Val Acc: 0.9519 | Val F1: 0.8445 | F1 Illicit: 0.9737
# Epoch 223 | Loss: 0.1839 | Val Acc: 0.9519 | Val F1: 0.8448 | F1 Illicit: 0.9737
# Epoch 224 | Loss: 0.1823 | Val Acc: 0.9521 | Val F1: 0.8458 | F1 Illicit: 0.9738
# Epoch 225 | Loss: 0.1814 | Val Acc: 0.9523 | Val F1: 0.8466 | F1 Illicit: 0.9740
# Epoch 226 | Loss: 0.1826 | Val Acc: 0.9523 | Val F1: 0.8468 | F1 Illicit: 0.9739
# Epoch 227 | Loss: 0.1859 | Val Acc: 0.9523 | Val F1: 0.8471 | F1 Illicit: 0.9739
# Epoch 228 | Loss: 0.1816 | Val Acc: 0.9526 | Val F1: 0.8481 | F1 Illicit: 0.9741
# Epoch 229 | Loss: 0.1809 | Val Acc: 0.9523 | Val F1: 0.8474 | F1 Illicit: 0.9739
# Epoch 230 | Loss: 0.1826 | Val Acc: 0.9525 | Val F1: 0.8481 | F1 Illicit: 0.9741
# Epoch 231 | Loss: 0.1818 | Val Acc: 0.9524 | Val F1: 0.8476 | F1 Illicit: 0.9740
# Epoch 232 | Loss: 0.1840 | Val Acc: 0.9525 | Val F1: 0.8476 | F1 Illicit: 0.9741
# Epoch 233 | Loss: 0.1827 | Val Acc: 0.9525 | Val F1: 0.8473 | F1 Illicit: 0.9740
# Epoch 234 | Loss: 0.1817 | Val Acc: 0.9528 | Val F1: 0.8482 | F1 Illicit: 0.9742
# Epoch 235 | Loss: 0.1832 | Val Acc: 0.9528 | Val F1: 0.8482 | F1 Illicit: 0.9742
# Epoch 236 | Loss: 0.1810 | Val Acc: 0.9525 | Val F1: 0.8475 | F1 Illicit: 0.9741
# Epoch 237 | Loss: 0.1812 | Val Acc: 0.9525 | Val F1: 0.8475 | F1 Illicit: 0.9741
# Epoch 238 | Loss: 0.1807 | Val Acc: 0.9525 | Val F1: 0.8474 | F1 Illicit: 0.9740
# Epoch 239 | Loss: 0.1813 | Val Acc: 0.9528 | Val F1: 0.8483 | F1 Illicit: 0.9742
# Epoch 240 | Loss: 0.1779 | Val Acc: 0.9528 | Val F1: 0.8485 | F1 Illicit: 0.9742
# Epoch 241 | Loss: 0.1808 | Val Acc: 0.9529 | Val F1: 0.8487 | F1 Illicit: 0.9743
# Epoch 242 | Loss: 0.1794 | Val Acc: 0.9535 | Val F1: 0.8509 | F1 Illicit: 0.9746
# Epoch 243 | Loss: 0.1798 | Val Acc: 0.9535 | Val F1: 0.8505 | F1 Illicit: 0.9746
# Epoch 244 | Loss: 0.1812 | Val Acc: 0.9536 | Val F1: 0.8506 | F1 Illicit: 0.9747
# Epoch 245 | Loss: 0.1793 | Val Acc: 0.9535 | Val F1: 0.8503 | F1 Illicit: 0.9746
# Epoch 246 | Loss: 0.1794 | Val Acc: 0.9536 | Val F1: 0.8504 | F1 Illicit: 0.9747
# Epoch 247 | Loss: 0.1765 | Val Acc: 0.9535 | Val F1: 0.8498 | F1 Illicit: 0.9746
# Epoch 248 | Loss: 0.1779 | Val Acc: 0.9532 | Val F1: 0.8494 | F1 Illicit: 0.9744
# Epoch 249 | Loss: 0.1787 | Val Acc: 0.9533 | Val F1: 0.8499 | F1 Illicit: 0.9745
# Epoch 250 | Loss: 0.1782 | Val Acc: 0.9531 | Val F1: 0.8498 | F1 Illicit: 0.9744
# Epoch 251 | Loss: 0.1806 | Val Acc: 0.9530 | Val F1: 0.8499 | F1 Illicit: 0.9743
# Epoch 252 | Loss: 0.1779 | Val Acc: 0.9529 | Val F1: 0.8494 | F1 Illicit: 0.9742
# Epoch 253 | Loss: 0.1781 | Val Acc: 0.9527 | Val F1: 0.8486 | F1 Illicit: 0.9741
# Epoch 254 | Loss: 0.1787 | Val Acc: 0.9524 | Val F1: 0.8476 | F1 Illicit: 0.9740
# Epoch 255 | Loss: 0.1784 | Val Acc: 0.9525 | Val F1: 0.8479 | F1 Illicit: 0.9741
# Epoch 256 | Loss: 0.1757 | Val Acc: 0.9527 | Val F1: 0.8483 | F1 Illicit: 0.9741
# Epoch 257 | Loss: 0.1777 | Val Acc: 0.9526 | Val F1: 0.8477 | F1 Illicit: 0.9741
# Epoch 258 | Loss: 0.1755 | Val Acc: 0.9526 | Val F1: 0.8477 | F1 Illicit: 0.9741
# Epoch 259 | Loss: 0.1769 | Val Acc: 0.9527 | Val F1: 0.8479 | F1 Illicit: 0.9741
# Epoch 260 | Loss: 0.1765 | Val Acc: 0.9525 | Val F1: 0.8476 | F1 Illicit: 0.9741
# Epoch 261 | Loss: 0.1766 | Val Acc: 0.9526 | Val F1: 0.8480 | F1 Illicit: 0.9741
# Epoch 262 | Loss: 0.1777 | Val Acc: 0.9527 | Val F1: 0.8484 | F1 Illicit: 0.9741
# Epoch 263 | Loss: 0.1787 | Val Acc: 0.9530 | Val F1: 0.8495 | F1 Illicit: 0.9743
# Epoch 264 | Loss: 0.1759 | Val Acc: 0.9532 | Val F1: 0.8503 | F1 Illicit: 0.9744
# Epoch 265 | Loss: 0.1762 | Val Acc: 0.9535 | Val F1: 0.8513 | F1 Illicit: 0.9746
# Epoch 266 | Loss: 0.1760 | Val Acc: 0.9536 | Val F1: 0.8519 | F1 Illicit: 0.9746
# Epoch 267 | Loss: 0.1754 | Val Acc: 0.9537 | Val F1: 0.8520 | F1 Illicit: 0.9747
# Epoch 268 | Loss: 0.1763 | Val Acc: 0.9538 | Val F1: 0.8524 | F1 Illicit: 0.9748
# Epoch 269 | Loss: 0.1759 | Val Acc: 0.9538 | Val F1: 0.8519 | F1 Illicit: 0.9747
# Epoch 270 | Loss: 0.1764 | Val Acc: 0.9537 | Val F1: 0.8518 | F1 Illicit: 0.9747
# Epoch 271 | Loss: 0.1738 | Val Acc: 0.9536 | Val F1: 0.8516 | F1 Illicit: 0.9746
# Epoch 272 | Loss: 0.1748 | Val Acc: 0.9535 | Val F1: 0.8515 | F1 Illicit: 0.9746
# Epoch 273 | Loss: 0.1728 | Val Acc: 0.9535 | Val F1: 0.8515 | F1 Illicit: 0.9746
# Epoch 274 | Loss: 0.1729 | Val Acc: 0.9536 | Val F1: 0.8519 | F1 Illicit: 0.9746
# Epoch 275 | Loss: 0.1738 | Val Acc: 0.9535 | Val F1: 0.8516 | F1 Illicit: 0.9746
# Epoch 276 | Loss: 0.1728 | Val Acc: 0.9538 | Val F1: 0.8524 | F1 Illicit: 0.9748
# Epoch 277 | Loss: 0.1732 | Val Acc: 0.9539 | Val F1: 0.8528 | F1 Illicit: 0.9748
# Epoch 278 | Loss: 0.1749 | Val Acc: 0.9539 | Val F1: 0.8528 | F1 Illicit: 0.9748
# Epoch 279 | Loss: 0.1706 | Val Acc: 0.9540 | Val F1: 0.8531 | F1 Illicit: 0.9748
# Epoch 280 | Loss: 0.1752 | Val Acc: 0.9540 | Val F1: 0.8533 | F1 Illicit: 0.9749
# Epoch 281 | Loss: 0.1706 | Val Acc: 0.9540 | Val F1: 0.8535 | F1 Illicit: 0.9749
# Epoch 282 | Loss: 0.1731 | Val Acc: 0.9541 | Val F1: 0.8535 | F1 Illicit: 0.9749
# Epoch 283 | Loss: 0.1737 | Val Acc: 0.9541 | Val F1: 0.8536 | F1 Illicit: 0.9749
# Epoch 284 | Loss: 0.1701 | Val Acc: 0.9544 | Val F1: 0.8545 | F1 Illicit: 0.9751
# Epoch 285 | Loss: 0.1732 | Val Acc: 0.9545 | Val F1: 0.8548 | F1 Illicit: 0.9751
# Epoch 286 | Loss: 0.1751 | Val Acc: 0.9545 | Val F1: 0.8554 | F1 Illicit: 0.9751
# Epoch 287 | Loss: 0.1713 | Val Acc: 0.9547 | Val F1: 0.8564 | F1 Illicit: 0.9752
# Epoch 288 | Loss: 0.1732 | Val Acc: 0.9546 | Val F1: 0.8563 | F1 Illicit: 0.9752
# Epoch 289 | Loss: 0.1728 | Val Acc: 0.9545 | Val F1: 0.8559 | F1 Illicit: 0.9751
# Epoch 290 | Loss: 0.1722 | Val Acc: 0.9545 | Val F1: 0.8559 | F1 Illicit: 0.9751
# Epoch 291 | Loss: 0.1705 | Val Acc: 0.9545 | Val F1: 0.8554 | F1 Illicit: 0.9751
# Epoch 292 | Loss: 0.1727 | Val Acc: 0.9545 | Val F1: 0.8554 | F1 Illicit: 0.9751
# Epoch 293 | Loss: 0.1715 | Val Acc: 0.9548 | Val F1: 0.8559 | F1 Illicit: 0.9753
# Epoch 294 | Loss: 0.1732 | Val Acc: 0.9548 | Val F1: 0.8561 | F1 Illicit: 0.9753
# Epoch 295 | Loss: 0.1724 | Val Acc: 0.9548 | Val F1: 0.8557 | F1 Illicit: 0.9753
# Epoch 296 | Loss: 0.1727 | Val Acc: 0.9546 | Val F1: 0.8554 | F1 Illicit: 0.9752
# Epoch 297 | Loss: 0.1723 | Val Acc: 0.9545 | Val F1: 0.8549 | F1 Illicit: 0.9751
# Epoch 298 | Loss: 0.1720 | Val Acc: 0.9543 | Val F1: 0.8544 | F1 Illicit: 0.9750
# Epoch 299 | Loss: 0.1704 | Val Acc: 0.9547 | Val F1: 0.8559 | F1 Illicit: 0.9752
# Epoch 300 | Loss: 0.1712 | Val Acc: 0.9548 | Val F1: 0.8564 | F1 Illicit: 0.9752
# Skipping already trained config: base+structural, seed: 42
# Skipping already trained config: base+structural, seed: 123
# Skipping already trained config: base+structural, seed: 777
# Skipping already trained config: base+structural, seed: 2023
# Skipping already trained config: base+structural, seed: 31415
# Skipping already trained config: base+typology, seed: 42
# Skipping already trained config: base+typology, seed: 123
# Skipping already trained config: base+typology, seed: 777
# Skipping already trained config: base+typology, seed: 2023
# Skipping already trained config: base+typology, seed: 31415
# Skipping already trained config: base+structural+typology, seed: 42
# Skipping already trained config: base+structural+typology, seed: 123
# Skipping already trained config: base+structural+typology, seed: 777
# Skipping already trained config: base+structural+typology, seed: 2023
# Skipping already trained config: base+structural+typology, seed: 31415
# Skipping already trained config: base+basic_temporal, seed: 42
# Skipping already trained config: base+basic_temporal, seed: 123
# Skipping already trained config: base+basic_temporal, seed: 777
# Skipping already trained config: base+basic_temporal, seed: 2023
# Skipping already trained config: base+basic_temporal, seed: 31415
# Skipping already trained config: base+basic_temporal+typology, seed: 42
# Skipping already trained config: base+basic_temporal+typology, seed: 123
# Skipping already trained config: base+basic_temporal+typology, seed: 777
# Skipping already trained config: base+basic_temporal+typology, seed: 2023
# Skipping already trained config: base+basic_temporal+typology, seed: 31415
# Skipping already trained config: all, seed: 42
# Skipping already trained config: all, seed: 123
# Skipping already trained config: all, seed: 777
# Skipping already trained config: all, seed: 2023
# Skipping already trained config: all, seed: 31415

# %% [markdown]
# ## 4. Evaluation

# %% [markdown]
# Patch, errors with config

# %%
import os
import json
import torch

base_dir = "../model_features/randomsplit/GAT_ablation"
data_dir = "../data/GAT_randomsplit"
seeds = [42, 123, 777, 2023, 31415]

for ablation in sorted(os.listdir(base_dir)):
    ablation_model_path = os.path.join(base_dir, ablation)
    ablation_data_path = os.path.join(data_dir, ablation)

    if not os.path.isdir(ablation_model_path):
        continue

    print(f"\n→ Processing ablation: {ablation}")

    for seed in seeds:
        seed_dir = f"seed_{seed}"
        config_path = os.path.join(ablation_model_path, seed_dir, "config.json")
        model_path = os.path.join(ablation_model_path, seed_dir, "model.pth")
        data_path = os.path.join(ablation_data_path, seed_dir, "data_exp.pt")

        if not all(os.path.exists(p) for p in [config_path, model_path, data_path]):
            continue

        # Load existing config
        with open(config_path, "r") as f:
            config = json.load(f)

        updated = False

        # Load data to recover feature_dim
        data = torch.load(data_path, map_location="cpu", weights_only=False)
        feature_dim = data.x.shape[1]
        if config.get("feature_dim") != feature_dim:
            config["feature_dim"] = feature_dim
            updated = True

        # Patch GAT-only fields
        if config.get("model") == "GAT":
            state_dict = torch.load(model_path, map_location="cpu")

            if "gat1.lin.weight" in state_dict:
                total_hidden_dim = state_dict["gat1.lin.weight"].shape[0]  # = heads * hidden_channels
                heads = config.get("heads", 8)
                hidden_channels = total_hidden_dim // heads

                if config.get("hidden_channels") != hidden_channels:
                    config["hidden_channels"] = hidden_channels
                    updated = True
                if config.get("heads") != heads:
                    config["heads"] = heads
                    updated = True
                if config.get("out_channels") != 2:
                    config["out_channels"] = 2
                    updated = True
            else:
                print(f"[!] Warning: gat1.lin.weight not found in {model_path}")
                continue

        if updated:
            with open(config_path, "w") as f:
                json.dump(config, f, indent=4)
            print(f"✓ Patched config for {ablation} / seed {seed}")
        else:
            print(f"✓ Already complete: {ablation} / seed {seed}")
# Out:
# → Processing ablation: all
# ✓ Already complete: all / seed 42
# ✓ Already complete: all / seed 123
# ✓ Already complete: all / seed 777
# ✓ Already complete: all / seed 2023
# ✓ Already complete: all / seed 31415
#
# → Processing ablation: base
# ✓ Already complete: base / seed 42
# ✓ Already complete: base / seed 123
# ✓ Already complete: base / seed 777
# ✓ Already complete: base / seed 2023
# ✓ Already complete: base / seed 31415
#
# → Processing ablation: base+basic_temporal
# ✓ Already complete: base+basic_temporal / seed 42
# ✓ Already complete: base+basic_temporal / seed 123
# ✓ Already complete: base+basic_temporal / seed 777
# ✓ Already complete: base+basic_temporal / seed 2023
# ✓ Already complete: base+basic_temporal / seed 31415
#
# → Processing ablation: base+basic_temporal+typology
# ✓ Already complete: base+basic_temporal+typology / seed 42
# ✓ Already complete: base+basic_temporal+typology / seed 123
# ✓ Already complete: base+basic_temporal+typology / seed 777
# ✓ Already complete: base+basic_temporal+typology / seed 2023
# ✓ Already complete: base+basic_temporal+typology / seed 31415
#
# → Processing ablation: base+structural
# ✓ Already complete: base+structural / seed 42
# ✓ Already complete: base+structural / seed 123
# ✓ Already complete: base+structural / seed 777
# ✓ Already complete: base+structural / seed 2023
# ✓ Already complete: base+structural / seed 31415
#
# → Processing ablation: base+structural+typology
# ✓ Already complete: base+structural+typology / seed 42
# ✓ Already complete: base+structural+typology / seed 123
# ✓ Already complete: base+structural+typology / seed 777
# ✓ Already complete: base+structural+typology / seed 2023
# ✓ Already complete: base+structural+typology / seed 31415
#
# → Processing ablation: base+typology
# ✓ Already complete: base+typology / seed 42
# ✓ Already complete: base+typology / seed 123
# ✓ Already complete: base+typology / seed 777
# ✓ Already complete: base+typology / seed 2023
# ✓ Already complete: base+typology / seed 31415

# %%
import os
from features.evaluate_ablation_model import evaluate_ablation_model
from evaluation_pipeline import run_inference_all_seeds
from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
from features.feature_utils import make_model_class_from_config

# === Config ===
seeds = [42, 123, 777, 2023, 31415]
base_dir = "../model_features/randomsplit/GAT_ablation"
data_exp_root = "../data/GAT_randomsplit"
node_id_csv_path = "../elliptic_bitcoin_dataset/elliptic_txs_features.csv"

model_tag = "GAT-Random"
split = "randomsplit"

# === Evaluate all ablations ===
for ablation in sorted(os.listdir(base_dir)):
    model_dir = os.path.join(base_dir, ablation)
    if not os.path.isdir(model_dir):
        continue

    print(f"\n→ Evaluating ablation: {ablation}")
    model_name = f"{model_tag}: {ablation}"
    ablation_data_dir = os.path.join(data_exp_root, ablation)
    config_path = os.path.join(model_dir, "seed_42", "config.json")
    model_class = make_model_class_from_config(config_path)

    # Run full evaluation
    evaluate_ablation_model(
        model_dir=model_dir,
        model_class=model_class,
        model_name=model_name,
        seeds=seeds,
        node_id_csv_path=node_id_csv_path,
        data_dir=ablation_data_dir
    )

    # Run inference (to extract structured metrics for CSV logging)
    y_true_all, y_pred_all, y_proba_all, seed_metrics = run_inference_all_seeds(
        model_dir=model_dir,
        model_class=model_class,
        data_dir=ablation_data_dir,
        seeds=seeds
    )
    val_acc_list = load_metrics_across_seeds(model_dir, ["val_acc"])["val_acc"]

    # Save to CSV
    log_metrics_to_csv(
        model_name=model_tag,
        split_name=split,
        ablation=ablation,
        seeds=seeds,
        val_acc_list=val_acc_list,
        seed_metrics=seed_metrics,
        is_feature=True  # ← optional flag to append _feature to filename
    )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 from features.evaluate_ablation_model import evaluate_ablation_model
#       3 from evaluation_pipeline import run_inference_all_seeds
#       4 from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
#
# File c:\Users\ruoho\Documents\BSP\src\features\evaluate_ablation_model.py:16
#      13 from model_gcn import GCNNet
#      14 from model_sage import GraphSAGENet
# ---> 16 from .feature_utils import evaluate_model_from_checkpoint
#      17 from analysis_utils import (
#      18     load_metrics_across_seeds,
#      19     aggregate_metrics_table,
#      20     plot_loss_curve,
#      21     compute_prediction_metrics
#      22 )
#      23 from evaluation_pipeline import (
#      24     save_fp_fn_indices,
#      25     attach_node_times,
#    (...)     30     plot_conf_matrices
#      31 )
#
# ImportError: cannot import name 'evaluate_model_from_checkpoint' from 'features.feature_utils' (c:\Users\ruoho\Documents\BSP\src\features\feature_utils.py)
