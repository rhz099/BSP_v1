# %% [markdown]
# ## 1. Import and Setup

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# Torch & GNN
import torch
from torch_geometric.nn import GCNConv

# Custom modules
from data_utils_temporal import load_and_preprocess_elliptic_temporal
from train_temporal import temporal_split
from model_gcn import GCNNet
from train_utils import set_seed, train_full, save_feature_experiment
from config import SEEDS

# Feature engineering control
from features.feature_config import FEATURE_CONFIGS
from features.feature_runner import apply_engineered_features

print("✓ All modules imported successfully.")
# Out:
# ✓ All modules imported successfully.

# %% [markdown]
# ## 2. Load and Preprocess the Elliptic Dataset
# This loads the data, maps transaction IDs to node indices, filters isolated nodes, and normalizes node features. Uses temporal splitting.

# %%
from normalization import normalize_base_features_only
from features.feature_pipeline import generate_all_features
from features.feature_utils import prepare_graph_and_timestamps
from data_utils_temporal import load_and_preprocess_elliptic_temporal
from train_temporal import temporal_split
from features.feature_config import FEATURE_CONFIGS
from train_utils import set_seed
from config import SEEDS
import torch
import os

# 1. Load PyG temporal data (with node_times)
data, node_times = load_and_preprocess_elliptic_temporal("../elliptic_bitcoin_dataset", normalize=False)
print(f"✓ Temporal PyG Data object loaded: {data}")

# 2. Prepare NetworkX graph + timestamps
G_nx, node_timestamps = prepare_graph_and_timestamps(
    edgelist_path="../elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv",
    features_path="../elliptic_bitcoin_dataset/elliptic_txs_features.csv",
    num_nodes=data.num_nodes
)

print(f"✓ NetworkX Graph: {G_nx.number_of_nodes()} nodes, {G_nx.number_of_edges()} edges")
print(f"✓ Timestamps found for {sum(len(ts) > 0 for ts in node_timestamps)} nodes")

# 3. Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ABLATORS = {
    k: v for k, v in FEATURE_CONFIGS.items()
}
FEATURED_DATA = {}

# 4. Loop through ablations + seeds
for ablation_name, feature_flags in ABLATORS.items():
    print(f"\n== Config: {ablation_name} ==")
    for seed in SEEDS:
        print(f"→ Seed {seed}")
        set_seed(seed)

        # 4.1 Temporal split (train up to time step 35)
        train_idx, val_idx = temporal_split(data, node_times=node_times, train_until=35)

        # 4.2 Feature engineering
        data_exp = data.clone()
        X, feature_names = generate_all_features(data_exp, G_nx, node_timestamps, **feature_flags)
        data_exp.x = torch.tensor(X, dtype=torch.float)

        # Optional: monitor temporal feature stats
        temporal_names = {"temporal_lag", "component_size"}
        temporal_indices = [i for i, name in enumerate(feature_names) if name in temporal_names]
        if temporal_indices:
            print("→ Temporal features (raw)")
            print("  Means:", data_exp.x[:, temporal_indices].mean(0))
            print("  Stds :", data_exp.x[:, temporal_indices].std(0))

        # 4.3 Normalize base features only
        data_exp.x = normalize_base_features_only(data_exp.x, feature_names)

        # 4.4 Finalize
        data_exp = data_exp.to(device)
        FEATURED_DATA[(ablation_name, seed)] = {
            "data": data_exp,
            "train_idx": train_idx,
            "val_idx": val_idx,
            "feature_flags": feature_flags,
        }

        # 4.5 Save to disk
        save_dir = f"../data/GCN_temporal/{ablation_name}/seed_{seed}"
        os.makedirs(save_dir, exist_ok=True)
        torch.save(data_exp, os.path.join(save_dir, "data_exp.pt"))
        torch.save(train_idx, os.path.join(save_dir, "train_idx.pt"))
        torch.save(val_idx, os.path.join(save_dir, "val_idx.pt"))
        print(f"✓ Saved to {save_dir}")
        print(f"✓ Final shape: {data_exp.x.shape}")
# Out:
# ✓ Temporal PyG Data object loaded: Data(x=[203769, 166], edge_index=[2, 234355], y=[203769])
# Loaded directed graph with 203769 nodes and 234355 edges.
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Features DataFrame shape: (203769, 167)
# Number of features (excluding txId and time_step): 165
# Timestamps found for 203769 out of 203769 nodes.
# ✓ Time step range: 1.0 to 49.0
# ✓ NetworkX Graph: 203769 nodes, 234355 edges
# ✓ Timestamps found for 203769 nodes
#
# == Config: base ==
# → Seed 42
# ✓ Saved to ../data/GCN_temporal/base/seed_42
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 123
# ✓ Saved to ../data/GCN_temporal/base/seed_123
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 777
# ✓ Saved to ../data/GCN_temporal/base/seed_777
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 2023
# ✓ Saved to ../data/GCN_temporal/base/seed_2023
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 31415
# ✓ Saved to ../data/GCN_temporal/base/seed_31415
# ✓ Final shape: torch.Size([203769, 166])
#
# == Config: base+structural ==
# → Seed 42
# ✓ Saved to ../data/GCN_temporal/base+structural/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# ✓ Saved to ../data/GCN_temporal/base+structural/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# ✓ Saved to ../data/GCN_temporal/base+structural/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# ✓ Saved to ../data/GCN_temporal/base+structural/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# ✓ Saved to ../data/GCN_temporal/base+structural/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: base+typology ==
# → Seed 42
# ✓ Saved to ../data/GCN_temporal/base+typology/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# ✓ Saved to ../data/GCN_temporal/base+typology/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# ✓ Saved to ../data/GCN_temporal/base+typology/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# ✓ Saved to ../data/GCN_temporal/base+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# ✓ Saved to ../data/GCN_temporal/base+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+structural+typology ==
# → Seed 42
# ✓ Saved to ../data/GCN_temporal/base+structural+typology/seed_42
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 123
# ✓ Saved to ../data/GCN_temporal/base+structural+typology/seed_123
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 777
# ✓ Saved to ../data/GCN_temporal/base+structural+typology/seed_777
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 2023
# ✓ Saved to ../data/GCN_temporal/base+structural+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 31415
# ✓ Saved to ../data/GCN_temporal/base+structural+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 172])
#
# == Config: base+basic_temporal ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 241937.22it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 296458.00it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 192331.39it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 164233.34it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 213539.53it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+basic_temporal+typology ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 184728.90it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal+typology/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 297128.12it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal+typology/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 196587.20it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal+typology/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 211420.26it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 167146.91it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/base+basic_temporal+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: all ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 162988.09it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/all/seed_42
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 359049.31it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/all/seed_123
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 175704.70it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/all/seed_777
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:01<00:00, 175689.24it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/all/seed_2023
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 215898.98it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved to ../data/GCN_temporal/all/seed_31415
# ✓ Final shape: torch.Size([203769, 174])

# %%
import torch
import os

ROOT_DIR = "../data/GCN_temporal"
BASE_DIM = 166
SEEDS = [42, 123, 777, 2023, 31415]

print("\n📊 ENGINEERED FEATURE INSPECTION (from disk)")

# Loop over ablation folders
for ablation_name in sorted(os.listdir(ROOT_DIR)):
    ablation_path = os.path.join(ROOT_DIR, ablation_name)
    if not os.path.isdir(ablation_path):
        continue

    for seed in SEEDS:
        seed_dir = f"seed_{seed}"
        data_path = os.path.join(ablation_path, seed_dir, "data_exp.pt")
        if not os.path.exists(data_path):
            print(f"⛔ Missing file: {data_path}")
            continue

        data = torch.load(data_path, map_location="cpu", weights_only=False)
        x = data.x

        if x.shape[1] <= BASE_DIM:
            print(f"\n {ablation_name} | Seed: {seed}")
            print(" No engineered features found.")
            continue

        engineered = x[:, BASE_DIM:]
        print(f"\n {ablation_name} | Seed: {seed}")
        print(f" Engineered feature count: {engineered.shape[1]}")

        means = engineered.mean(dim=0)
        stds = engineered.std(dim=0)

        for i in range(engineered.shape[1]):
            m = means[i].item()
            s = stds[i].item()
            sample_vals = engineered[:5, i].numpy()
            print(f"Feature {BASE_DIM + i:>3} | Mean: {m:8.4f} | Std: {s:8.4f} | Sample: {sample_vals}")
# Out:
# 📊 ENGINEERED FEATURE INSPECTION (from disk)
#
#  all | Seed: 42
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 123
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 777
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 2023
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 31415
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base | Seed: 42
#  No engineered features found.
#
#  base | Seed: 123
#  No engineered features found.
#
#  base | Seed: 777
#  No engineered features found.
#
#  base | Seed: 2023
#  No engineered features found.
#
#  base | Seed: 31415
#  No engineered features found.
#
#  base+basic_temporal | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+structural | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural+typology | Seed: 42
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 123
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 777
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 2023
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 31415
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]

# %% [markdown]
# ## 3. Training Multiseed Models and Ablation

# %%
from model_gcn import GCNNet
from train_utils import train_full, save_feature_experiment
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


for (ablation_name, seed), bundle in FEATURED_DATA.items():
    print(f"\n=== Training GCN (Temporal Split): {ablation_name} | Seed: {seed} ===")

    data_exp = bundle["data"]
    train_idx = bundle["train_idx"]
    val_idx = bundle["val_idx"]
    feature_flags = bundle["feature_flags"]

    # 1. Initialize model
    model = GCNNet(
        in_channels=data_exp.x.shape[1],
        hidden_channels=64,
        out_channels=2,
        dropout=0.1
    ).to(device)

    # 2. Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # 3. Train the model (use default CrossEntropyLoss)
    model, *results = train_full(
        model=model,
        data=data_exp,
        train_idx=train_idx,
        val_idx=val_idx,
        optimizer=optimizer,
        num_epochs=300,
        patience=30
    )

    # 4. Save model + logs
    output_dir = f"../model_features/temporal/GCN_ablation/{ablation_name}/seed_{seed}"
    os.makedirs(output_dir, exist_ok=True)

    save_feature_experiment(
        output_dir=output_dir,
        model=model,
        results=results,
        seed=seed,
        config={
            "model": "GCN",
            "ablation_name": ablation_name,
            "feature_flags": feature_flags,
            "feature_dim": data_exp.x.shape[1],
            "dropout": 0.1,
            "num_epochs": 300,
            "patience": 30,
            "lr": 0.001,
            "weight_decay": 5e-4,
            "class_weights": None  # explicitly noting unweighted
        },
        val_idx=val_idx
    )
# Out:
# === Training GCN (Temporal Split): base | Seed: 42 ===
# Epoch 001 | Loss: 0.3891 | Val Acc: 0.8023 | Val F1: 0.5096 | F1 Illicit: 0.8885
# Epoch 002 | Loss: 0.3479 | Val Acc: 0.8126 | Val F1: 0.5235 | F1 Illicit: 0.8947
# Epoch 003 | Loss: 0.3180 | Val Acc: 0.8206 | Val F1: 0.5385 | F1 Illicit: 0.8993
# Epoch 004 | Loss: 0.3016 | Val Acc: 0.8241 | Val F1: 0.5480 | F1 Illicit: 0.9013
# Epoch 005 | Loss: 0.2871 | Val Acc: 0.8251 | Val F1: 0.5521 | F1 Illicit: 0.9018
# Epoch 006 | Loss: 0.2788 | Val Acc: 0.8252 | Val F1: 0.5531 | F1 Illicit: 0.9018
# Epoch 007 | Loss: 0.2715 | Val Acc: 0.8278 | Val F1: 0.5569 | F1 Illicit: 0.9033
# Epoch 008 | Loss: 0.2663 | Val Acc: 0.8290 | Val F1: 0.5593 | F1 Illicit: 0.9041
# Epoch 009 | Loss: 0.2612 | Val Acc: 0.8311 | Val F1: 0.5626 | F1 Illicit: 0.9053
# Epoch 010 | Loss: 0.2572 | Val Acc: 0.8312 | Val F1: 0.5618 | F1 Illicit: 0.9054
# Epoch 011 | Loss: 0.2543 | Val Acc: 0.8325 | Val F1: 0.5626 | F1 Illicit: 0.9062
# Epoch 012 | Loss: 0.2505 | Val Acc: 0.8335 | Val F1: 0.5641 | F1 Illicit: 0.9068
# Epoch 013 | Loss: 0.2470 | Val Acc: 0.8348 | Val F1: 0.5647 | F1 Illicit: 0.9076
# Epoch 014 | Loss: 0.2436 | Val Acc: 0.8368 | Val F1: 0.5657 | F1 Illicit: 0.9088
# Epoch 015 | Loss: 0.2409 | Val Acc: 0.8396 | Val F1: 0.5673 | F1 Illicit: 0.9105
# Epoch 016 | Loss: 0.2379 | Val Acc: 0.8419 | Val F1: 0.5688 | F1 Illicit: 0.9119
# Epoch 017 | Loss: 0.2369 | Val Acc: 0.8449 | Val F1: 0.5719 | F1 Illicit: 0.9138
# Epoch 018 | Loss: 0.2345 | Val Acc: 0.8480 | Val F1: 0.5748 | F1 Illicit: 0.9156
# Epoch 019 | Loss: 0.2315 | Val Acc: 0.8505 | Val F1: 0.5766 | F1 Illicit: 0.9172
# Epoch 020 | Loss: 0.2300 | Val Acc: 0.8537 | Val F1: 0.5787 | F1 Illicit: 0.9191
# Epoch 021 | Loss: 0.2274 | Val Acc: 0.8565 | Val F1: 0.5801 | F1 Illicit: 0.9208
# Epoch 022 | Loss: 0.2254 | Val Acc: 0.8597 | Val F1: 0.5815 | F1 Illicit: 0.9227
# Epoch 023 | Loss: 0.2239 | Val Acc: 0.8641 | Val F1: 0.5852 | F1 Illicit: 0.9253
# Epoch 024 | Loss: 0.2217 | Val Acc: 0.8661 | Val F1: 0.5863 | F1 Illicit: 0.9265
# Epoch 025 | Loss: 0.2196 | Val Acc: 0.8691 | Val F1: 0.5885 | F1 Illicit: 0.9283
# Epoch 026 | Loss: 0.2194 | Val Acc: 0.8722 | Val F1: 0.5905 | F1 Illicit: 0.9301
# Epoch 027 | Loss: 0.2177 | Val Acc: 0.8746 | Val F1: 0.5927 | F1 Illicit: 0.9315
# Epoch 028 | Loss: 0.2163 | Val Acc: 0.8770 | Val F1: 0.5953 | F1 Illicit: 0.9330
# Epoch 029 | Loss: 0.2143 | Val Acc: 0.8800 | Val F1: 0.5985 | F1 Illicit: 0.9347
# Epoch 030 | Loss: 0.2130 | Val Acc: 0.8832 | Val F1: 0.6021 | F1 Illicit: 0.9366
# Epoch 031 | Loss: 0.2110 | Val Acc: 0.8853 | Val F1: 0.6042 | F1 Illicit: 0.9378
# Epoch 032 | Loss: 0.2105 | Val Acc: 0.8880 | Val F1: 0.6063 | F1 Illicit: 0.9393
# Epoch 033 | Loss: 0.2076 | Val Acc: 0.8896 | Val F1: 0.6074 | F1 Illicit: 0.9403
# Epoch 034 | Loss: 0.2071 | Val Acc: 0.8916 | Val F1: 0.6106 | F1 Illicit: 0.9414
# Epoch 035 | Loss: 0.2063 | Val Acc: 0.8937 | Val F1: 0.6135 | F1 Illicit: 0.9426
# Epoch 036 | Loss: 0.2054 | Val Acc: 0.8953 | Val F1: 0.6152 | F1 Illicit: 0.9435
# Epoch 037 | Loss: 0.2028 | Val Acc: 0.8965 | Val F1: 0.6171 | F1 Illicit: 0.9442
# Epoch 038 | Loss: 0.2017 | Val Acc: 0.8980 | Val F1: 0.6184 | F1 Illicit: 0.9451
# Epoch 039 | Loss: 0.2017 | Val Acc: 0.8995 | Val F1: 0.6223 | F1 Illicit: 0.9459
# Epoch 040 | Loss: 0.2017 | Val Acc: 0.9013 | Val F1: 0.6253 | F1 Illicit: 0.9469
# Epoch 041 | Loss: 0.2001 | Val Acc: 0.9020 | Val F1: 0.6268 | F1 Illicit: 0.9472
# Epoch 042 | Loss: 0.1992 | Val Acc: 0.9034 | Val F1: 0.6288 | F1 Illicit: 0.9481
# Epoch 043 | Loss: 0.1979 | Val Acc: 0.9041 | Val F1: 0.6292 | F1 Illicit: 0.9485
# Epoch 044 | Loss: 0.1967 | Val Acc: 0.9052 | Val F1: 0.6304 | F1 Illicit: 0.9491
# Epoch 045 | Loss: 0.1959 | Val Acc: 0.9065 | Val F1: 0.6335 | F1 Illicit: 0.9498
# Epoch 046 | Loss: 0.1954 | Val Acc: 0.9076 | Val F1: 0.6341 | F1 Illicit: 0.9504
# Epoch 047 | Loss: 0.1942 | Val Acc: 0.9089 | Val F1: 0.6350 | F1 Illicit: 0.9512
# Epoch 048 | Loss: 0.1927 | Val Acc: 0.9100 | Val F1: 0.6360 | F1 Illicit: 0.9518
# Epoch 049 | Loss: 0.1934 | Val Acc: 0.9108 | Val F1: 0.6363 | F1 Illicit: 0.9523
# Epoch 050 | Loss: 0.1910 | Val Acc: 0.9115 | Val F1: 0.6367 | F1 Illicit: 0.9527
# Epoch 051 | Loss: 0.1904 | Val Acc: 0.9124 | Val F1: 0.6369 | F1 Illicit: 0.9532
# Epoch 052 | Loss: 0.1902 | Val Acc: 0.9132 | Val F1: 0.6371 | F1 Illicit: 0.9536
# Epoch 053 | Loss: 0.1889 | Val Acc: 0.9147 | Val F1: 0.6391 | F1 Illicit: 0.9545
# Epoch 054 | Loss: 0.1890 | Val Acc: 0.9158 | Val F1: 0.6416 | F1 Illicit: 0.9551
# Epoch 055 | Loss: 0.1873 | Val Acc: 0.9176 | Val F1: 0.6441 | F1 Illicit: 0.9561
# Epoch 056 | Loss: 0.1869 | Val Acc: 0.9188 | Val F1: 0.6467 | F1 Illicit: 0.9567
# Epoch 057 | Loss: 0.1861 | Val Acc: 0.9191 | Val F1: 0.6462 | F1 Illicit: 0.9569
# Epoch 058 | Loss: 0.1850 | Val Acc: 0.9200 | Val F1: 0.6477 | F1 Illicit: 0.9574
# Epoch 059 | Loss: 0.1842 | Val Acc: 0.9207 | Val F1: 0.6474 | F1 Illicit: 0.9578
# Epoch 060 | Loss: 0.1831 | Val Acc: 0.9217 | Val F1: 0.6488 | F1 Illicit: 0.9584
# Epoch 061 | Loss: 0.1828 | Val Acc: 0.9230 | Val F1: 0.6529 | F1 Illicit: 0.9591
# Epoch 062 | Loss: 0.1819 | Val Acc: 0.9243 | Val F1: 0.6562 | F1 Illicit: 0.9598
# Epoch 063 | Loss: 0.1821 | Val Acc: 0.9254 | Val F1: 0.6588 | F1 Illicit: 0.9604
# Epoch 064 | Loss: 0.1818 | Val Acc: 0.9263 | Val F1: 0.6609 | F1 Illicit: 0.9609
# Epoch 065 | Loss: 0.1810 | Val Acc: 0.9269 | Val F1: 0.6612 | F1 Illicit: 0.9612
# Epoch 066 | Loss: 0.1796 | Val Acc: 0.9279 | Val F1: 0.6635 | F1 Illicit: 0.9618
# Epoch 067 | Loss: 0.1791 | Val Acc: 0.9289 | Val F1: 0.6654 | F1 Illicit: 0.9623
# Epoch 068 | Loss: 0.1788 | Val Acc: 0.9301 | Val F1: 0.6678 | F1 Illicit: 0.9630
# Epoch 069 | Loss: 0.1780 | Val Acc: 0.9308 | Val F1: 0.6680 | F1 Illicit: 0.9634
# Epoch 070 | Loss: 0.1776 | Val Acc: 0.9312 | Val F1: 0.6687 | F1 Illicit: 0.9636
# Epoch 071 | Loss: 0.1775 | Val Acc: 0.9324 | Val F1: 0.6718 | F1 Illicit: 0.9642
# Epoch 072 | Loss: 0.1762 | Val Acc: 0.9331 | Val F1: 0.6736 | F1 Illicit: 0.9646
# Epoch 073 | Loss: 0.1750 | Val Acc: 0.9333 | Val F1: 0.6738 | F1 Illicit: 0.9648
# Epoch 074 | Loss: 0.1754 | Val Acc: 0.9338 | Val F1: 0.6744 | F1 Illicit: 0.9650
# Epoch 075 | Loss: 0.1744 | Val Acc: 0.9344 | Val F1: 0.6768 | F1 Illicit: 0.9654
# Epoch 076 | Loss: 0.1738 | Val Acc: 0.9353 | Val F1: 0.6779 | F1 Illicit: 0.9658
# Epoch 077 | Loss: 0.1729 | Val Acc: 0.9355 | Val F1: 0.6768 | F1 Illicit: 0.9659
# Epoch 078 | Loss: 0.1723 | Val Acc: 0.9361 | Val F1: 0.6766 | F1 Illicit: 0.9663
# Epoch 079 | Loss: 0.1718 | Val Acc: 0.9367 | Val F1: 0.6762 | F1 Illicit: 0.9666
# Epoch 080 | Loss: 0.1720 | Val Acc: 0.9374 | Val F1: 0.6770 | F1 Illicit: 0.9670
# Epoch 081 | Loss: 0.1715 | Val Acc: 0.9382 | Val F1: 0.6787 | F1 Illicit: 0.9674
# Epoch 082 | Loss: 0.1711 | Val Acc: 0.9388 | Val F1: 0.6797 | F1 Illicit: 0.9678
# Epoch 083 | Loss: 0.1709 | Val Acc: 0.9391 | Val F1: 0.6803 | F1 Illicit: 0.9679
# Epoch 084 | Loss: 0.1691 | Val Acc: 0.9397 | Val F1: 0.6812 | F1 Illicit: 0.9682
# Epoch 085 | Loss: 0.1706 | Val Acc: 0.9400 | Val F1: 0.6816 | F1 Illicit: 0.9684
# Epoch 086 | Loss: 0.1686 | Val Acc: 0.9404 | Val F1: 0.6826 | F1 Illicit: 0.9687
# Epoch 087 | Loss: 0.1680 | Val Acc: 0.9407 | Val F1: 0.6828 | F1 Illicit: 0.9688
# Epoch 088 | Loss: 0.1681 | Val Acc: 0.9412 | Val F1: 0.6835 | F1 Illicit: 0.9691
# Epoch 089 | Loss: 0.1680 | Val Acc: 0.9412 | Val F1: 0.6836 | F1 Illicit: 0.9691
# Epoch 090 | Loss: 0.1671 | Val Acc: 0.9418 | Val F1: 0.6854 | F1 Illicit: 0.9694
# Epoch 091 | Loss: 0.1674 | Val Acc: 0.9421 | Val F1: 0.6861 | F1 Illicit: 0.9696
# Epoch 092 | Loss: 0.1675 | Val Acc: 0.9423 | Val F1: 0.6870 | F1 Illicit: 0.9697
# Epoch 093 | Loss: 0.1662 | Val Acc: 0.9428 | Val F1: 0.6881 | F1 Illicit: 0.9699
# Epoch 094 | Loss: 0.1656 | Val Acc: 0.9428 | Val F1: 0.6869 | F1 Illicit: 0.9700
# Epoch 095 | Loss: 0.1659 | Val Acc: 0.9430 | Val F1: 0.6879 | F1 Illicit: 0.9701
# Epoch 096 | Loss: 0.1648 | Val Acc: 0.9431 | Val F1: 0.6873 | F1 Illicit: 0.9701
# Epoch 097 | Loss: 0.1643 | Val Acc: 0.9431 | Val F1: 0.6873 | F1 Illicit: 0.9701
# Epoch 098 | Loss: 0.1641 | Val Acc: 0.9430 | Val F1: 0.6863 | F1 Illicit: 0.9701
# Epoch 099 | Loss: 0.1639 | Val Acc: 0.9434 | Val F1: 0.6868 | F1 Illicit: 0.9703
# Epoch 100 | Loss: 0.1637 | Val Acc: 0.9438 | Val F1: 0.6880 | F1 Illicit: 0.9705
# Epoch 101 | Loss: 0.1631 | Val Acc: 0.9440 | Val F1: 0.6886 | F1 Illicit: 0.9706
# Epoch 102 | Loss: 0.1622 | Val Acc: 0.9442 | Val F1: 0.6887 | F1 Illicit: 0.9707
# Epoch 103 | Loss: 0.1621 | Val Acc: 0.9447 | Val F1: 0.6908 | F1 Illicit: 0.9710
# Epoch 104 | Loss: 0.1606 | Val Acc: 0.9449 | Val F1: 0.6911 | F1 Illicit: 0.9711
# Epoch 105 | Loss: 0.1607 | Val Acc: 0.9449 | Val F1: 0.6917 | F1 Illicit: 0.9711
# Epoch 106 | Loss: 0.1609 | Val Acc: 0.9454 | Val F1: 0.6924 | F1 Illicit: 0.9714
# Epoch 107 | Loss: 0.1606 | Val Acc: 0.9457 | Val F1: 0.6931 | F1 Illicit: 0.9715
# Epoch 108 | Loss: 0.1596 | Val Acc: 0.9458 | Val F1: 0.6930 | F1 Illicit: 0.9716
# Epoch 109 | Loss: 0.1592 | Val Acc: 0.9459 | Val F1: 0.6933 | F1 Illicit: 0.9716
# Epoch 110 | Loss: 0.1586 | Val Acc: 0.9462 | Val F1: 0.6940 | F1 Illicit: 0.9718
# Epoch 111 | Loss: 0.1594 | Val Acc: 0.9465 | Val F1: 0.6948 | F1 Illicit: 0.9720
# Epoch 112 | Loss: 0.1592 | Val Acc: 0.9467 | Val F1: 0.6953 | F1 Illicit: 0.9721
# Epoch 113 | Loss: 0.1571 | Val Acc: 0.9467 | Val F1: 0.6945 | F1 Illicit: 0.9721
# Epoch 114 | Loss: 0.1576 | Val Acc: 0.9469 | Val F1: 0.6950 | F1 Illicit: 0.9722
# Epoch 115 | Loss: 0.1580 | Val Acc: 0.9470 | Val F1: 0.6945 | F1 Illicit: 0.9723
# Epoch 116 | Loss: 0.1573 | Val Acc: 0.9470 | Val F1: 0.6936 | F1 Illicit: 0.9723
# Epoch 117 | Loss: 0.1572 | Val Acc: 0.9471 | Val F1: 0.6938 | F1 Illicit: 0.9723
# Epoch 118 | Loss: 0.1568 | Val Acc: 0.9470 | Val F1: 0.6936 | F1 Illicit: 0.9723
# Epoch 119 | Loss: 0.1558 | Val Acc: 0.9474 | Val F1: 0.6946 | F1 Illicit: 0.9725
# Epoch 120 | Loss: 0.1559 | Val Acc: 0.9476 | Val F1: 0.6951 | F1 Illicit: 0.9726
# Epoch 121 | Loss: 0.1555 | Val Acc: 0.9477 | Val F1: 0.6946 | F1 Illicit: 0.9726
# Epoch 122 | Loss: 0.1550 | Val Acc: 0.9478 | Val F1: 0.6948 | F1 Illicit: 0.9727
# Epoch 123 | Loss: 0.1548 | Val Acc: 0.9479 | Val F1: 0.6947 | F1 Illicit: 0.9728
# Epoch 124 | Loss: 0.1547 | Val Acc: 0.9478 | Val F1: 0.6935 | F1 Illicit: 0.9727
# Epoch 125 | Loss: 0.1535 | Val Acc: 0.9481 | Val F1: 0.6944 | F1 Illicit: 0.9729
# Epoch 126 | Loss: 0.1529 | Val Acc: 0.9485 | Val F1: 0.6956 | F1 Illicit: 0.9730
# Epoch 127 | Loss: 0.1527 | Val Acc: 0.9485 | Val F1: 0.6958 | F1 Illicit: 0.9731
# Epoch 128 | Loss: 0.1527 | Val Acc: 0.9487 | Val F1: 0.6957 | F1 Illicit: 0.9731
# Epoch 129 | Loss: 0.1520 | Val Acc: 0.9488 | Val F1: 0.6957 | F1 Illicit: 0.9732
# Epoch 130 | Loss: 0.1519 | Val Acc: 0.9488 | Val F1: 0.6957 | F1 Illicit: 0.9732
# Epoch 131 | Loss: 0.1523 | Val Acc: 0.9491 | Val F1: 0.6961 | F1 Illicit: 0.9734
# Epoch 132 | Loss: 0.1523 | Val Acc: 0.9491 | Val F1: 0.6961 | F1 Illicit: 0.9734
# Epoch 133 | Loss: 0.1518 | Val Acc: 0.9492 | Val F1: 0.6963 | F1 Illicit: 0.9734
# Epoch 134 | Loss: 0.1509 | Val Acc: 0.9492 | Val F1: 0.6964 | F1 Illicit: 0.9735
# Epoch 135 | Loss: 0.1510 | Val Acc: 0.9495 | Val F1: 0.6971 | F1 Illicit: 0.9736
# Epoch 136 | Loss: 0.1511 | Val Acc: 0.9496 | Val F1: 0.6970 | F1 Illicit: 0.9737
# Epoch 137 | Loss: 0.1506 | Val Acc: 0.9500 | Val F1: 0.6979 | F1 Illicit: 0.9739
# Epoch 138 | Loss: 0.1488 | Val Acc: 0.9500 | Val F1: 0.6979 | F1 Illicit: 0.9739
# Epoch 139 | Loss: 0.1499 | Val Acc: 0.9500 | Val F1: 0.6977 | F1 Illicit: 0.9739
# Epoch 140 | Loss: 0.1500 | Val Acc: 0.9501 | Val F1: 0.6978 | F1 Illicit: 0.9739
# Epoch 141 | Loss: 0.1499 | Val Acc: 0.9499 | Val F1: 0.6960 | F1 Illicit: 0.9738
# Epoch 142 | Loss: 0.1490 | Val Acc: 0.9500 | Val F1: 0.6962 | F1 Illicit: 0.9739
# Epoch 143 | Loss: 0.1481 | Val Acc: 0.9503 | Val F1: 0.6975 | F1 Illicit: 0.9740
# Epoch 144 | Loss: 0.1485 | Val Acc: 0.9503 | Val F1: 0.6975 | F1 Illicit: 0.9740
# Epoch 145 | Loss: 0.1488 | Val Acc: 0.9502 | Val F1: 0.6969 | F1 Illicit: 0.9740
# Epoch 146 | Loss: 0.1471 | Val Acc: 0.9502 | Val F1: 0.6969 | F1 Illicit: 0.9740
# Epoch 147 | Loss: 0.1475 | Val Acc: 0.9502 | Val F1: 0.6960 | F1 Illicit: 0.9740
# Epoch 148 | Loss: 0.1472 | Val Acc: 0.9502 | Val F1: 0.6956 | F1 Illicit: 0.9740
# Epoch 149 | Loss: 0.1464 | Val Acc: 0.9502 | Val F1: 0.6956 | F1 Illicit: 0.9740
# Epoch 150 | Loss: 0.1463 | Val Acc: 0.9503 | Val F1: 0.6957 | F1 Illicit: 0.9740
# Epoch 151 | Loss: 0.1461 | Val Acc: 0.9503 | Val F1: 0.6957 | F1 Illicit: 0.9740
# Epoch 152 | Loss: 0.1457 | Val Acc: 0.9504 | Val F1: 0.6964 | F1 Illicit: 0.9741
# Epoch 153 | Loss: 0.1458 | Val Acc: 0.9504 | Val F1: 0.6965 | F1 Illicit: 0.9741
# Epoch 154 | Loss: 0.1455 | Val Acc: 0.9505 | Val F1: 0.6972 | F1 Illicit: 0.9741
# Epoch 155 | Loss: 0.1459 | Val Acc: 0.9504 | Val F1: 0.6970 | F1 Illicit: 0.9741
# Epoch 156 | Loss: 0.1441 | Val Acc: 0.9504 | Val F1: 0.6968 | F1 Illicit: 0.9741
# Epoch 157 | Loss: 0.1444 | Val Acc: 0.9504 | Val F1: 0.6968 | F1 Illicit: 0.9741
# Epoch 158 | Loss: 0.1436 | Val Acc: 0.9504 | Val F1: 0.6970 | F1 Illicit: 0.9741
# Epoch 159 | Loss: 0.1445 | Val Acc: 0.9506 | Val F1: 0.6969 | F1 Illicit: 0.9742
# Epoch 160 | Loss: 0.1426 | Val Acc: 0.9506 | Val F1: 0.6969 | F1 Illicit: 0.9742
# Epoch 161 | Loss: 0.1442 | Val Acc: 0.9505 | Val F1: 0.6958 | F1 Illicit: 0.9741
# Epoch 162 | Loss: 0.1432 | Val Acc: 0.9506 | Val F1: 0.6957 | F1 Illicit: 0.9742
# Epoch 163 | Loss: 0.1433 | Val Acc: 0.9505 | Val F1: 0.6940 | F1 Illicit: 0.9742
# Epoch 164 | Loss: 0.1429 | Val Acc: 0.9504 | Val F1: 0.6929 | F1 Illicit: 0.9741
# Epoch 165 | Loss: 0.1423 | Val Acc: 0.9503 | Val F1: 0.6917 | F1 Illicit: 0.9741
# Epoch 166 | Loss: 0.1427 | Val Acc: 0.9503 | Val F1: 0.6917 | F1 Illicit: 0.9741
# Epoch 167 | Loss: 0.1419 | Val Acc: 0.9504 | Val F1: 0.6919 | F1 Illicit: 0.9741
# Epoch 168 | Loss: 0.1419 | Val Acc: 0.9504 | Val F1: 0.6920 | F1 Illicit: 0.9741
# Epoch 169 | Loss: 0.1414 | Val Acc: 0.9505 | Val F1: 0.6922 | F1 Illicit: 0.9742
# Epoch 170 | Loss: 0.1411 | Val Acc: 0.9504 | Val F1: 0.6920 | F1 Illicit: 0.9741
# Epoch 171 | Loss: 0.1413 | Val Acc: 0.9506 | Val F1: 0.6935 | F1 Illicit: 0.9742
# Epoch 172 | Loss: 0.1407 | Val Acc: 0.9507 | Val F1: 0.6943 | F1 Illicit: 0.9743
# Epoch 173 | Loss: 0.1399 | Val Acc: 0.9507 | Val F1: 0.6937 | F1 Illicit: 0.9743
# Epoch 174 | Loss: 0.1405 | Val Acc: 0.9506 | Val F1: 0.6928 | F1 Illicit: 0.9742
# Epoch 175 | Loss: 0.1401 | Val Acc: 0.9506 | Val F1: 0.6928 | F1 Illicit: 0.9742
# Epoch 176 | Loss: 0.1399 | Val Acc: 0.9505 | Val F1: 0.6927 | F1 Illicit: 0.9742
# Epoch 177 | Loss: 0.1405 | Val Acc: 0.9506 | Val F1: 0.6938 | F1 Illicit: 0.9742
# Epoch 178 | Loss: 0.1395 | Val Acc: 0.9506 | Val F1: 0.6935 | F1 Illicit: 0.9742
# Epoch 179 | Loss: 0.1386 | Val Acc: 0.9506 | Val F1: 0.6924 | F1 Illicit: 0.9742
# Epoch 180 | Loss: 0.1397 | Val Acc: 0.9507 | Val F1: 0.6932 | F1 Illicit: 0.9743
# Epoch 181 | Loss: 0.1391 | Val Acc: 0.9507 | Val F1: 0.6938 | F1 Illicit: 0.9743
# Epoch 182 | Loss: 0.1379 | Val Acc: 0.9508 | Val F1: 0.6940 | F1 Illicit: 0.9743
# Epoch 183 | Loss: 0.1396 | Val Acc: 0.9509 | Val F1: 0.6939 | F1 Illicit: 0.9744
# Epoch 184 | Loss: 0.1384 | Val Acc: 0.9509 | Val F1: 0.6935 | F1 Illicit: 0.9744
# Epoch 185 | Loss: 0.1385 | Val Acc: 0.9510 | Val F1: 0.6941 | F1 Illicit: 0.9744
# Epoch 186 | Loss: 0.1373 | Val Acc: 0.9510 | Val F1: 0.6945 | F1 Illicit: 0.9744
# Epoch 187 | Loss: 0.1372 | Val Acc: 0.9511 | Val F1: 0.6947 | F1 Illicit: 0.9745
# Epoch 188 | Loss: 0.1383 | Val Acc: 0.9511 | Val F1: 0.6947 | F1 Illicit: 0.9745
# Epoch 189 | Loss: 0.1367 | Val Acc: 0.9509 | Val F1: 0.6939 | F1 Illicit: 0.9744
# Epoch 190 | Loss: 0.1369 | Val Acc: 0.9511 | Val F1: 0.6943 | F1 Illicit: 0.9745
# Epoch 191 | Loss: 0.1361 | Val Acc: 0.9511 | Val F1: 0.6938 | F1 Illicit: 0.9745
# Epoch 192 | Loss: 0.1366 | Val Acc: 0.9512 | Val F1: 0.6942 | F1 Illicit: 0.9745
# Epoch 193 | Loss: 0.1370 | Val Acc: 0.9513 | Val F1: 0.6943 | F1 Illicit: 0.9746
# Epoch 194 | Loss: 0.1371 | Val Acc: 0.9513 | Val F1: 0.6943 | F1 Illicit: 0.9746
# Epoch 195 | Loss: 0.1358 | Val Acc: 0.9513 | Val F1: 0.6953 | F1 Illicit: 0.9746
# Epoch 196 | Loss: 0.1350 | Val Acc: 0.9512 | Val F1: 0.6951 | F1 Illicit: 0.9745
# Epoch 197 | Loss: 0.1352 | Val Acc: 0.9511 | Val F1: 0.6952 | F1 Illicit: 0.9745
# Epoch 198 | Loss: 0.1347 | Val Acc: 0.9511 | Val F1: 0.6963 | F1 Illicit: 0.9745
# Epoch 199 | Loss: 0.1351 | Val Acc: 0.9513 | Val F1: 0.6966 | F1 Illicit: 0.9746
# Epoch 200 | Loss: 0.1339 | Val Acc: 0.9513 | Val F1: 0.6968 | F1 Illicit: 0.9746
# Epoch 201 | Loss: 0.1357 | Val Acc: 0.9514 | Val F1: 0.6970 | F1 Illicit: 0.9746
# Epoch 202 | Loss: 0.1345 | Val Acc: 0.9515 | Val F1: 0.6972 | F1 Illicit: 0.9747
# Epoch 203 | Loss: 0.1351 | Val Acc: 0.9515 | Val F1: 0.6978 | F1 Illicit: 0.9747
# Epoch 204 | Loss: 0.1341 | Val Acc: 0.9515 | Val F1: 0.6978 | F1 Illicit: 0.9747
# Epoch 205 | Loss: 0.1338 | Val Acc: 0.9515 | Val F1: 0.6978 | F1 Illicit: 0.9747
# Epoch 206 | Loss: 0.1336 | Val Acc: 0.9515 | Val F1: 0.6978 | F1 Illicit: 0.9747
# Epoch 207 | Loss: 0.1348 | Val Acc: 0.9515 | Val F1: 0.6978 | F1 Illicit: 0.9747
# Epoch 208 | Loss: 0.1331 | Val Acc: 0.9515 | Val F1: 0.6982 | F1 Illicit: 0.9747
# Epoch 209 | Loss: 0.1335 | Val Acc: 0.9516 | Val F1: 0.6980 | F1 Illicit: 0.9747
# Epoch 210 | Loss: 0.1334 | Val Acc: 0.9517 | Val F1: 0.6986 | F1 Illicit: 0.9748
# Epoch 211 | Loss: 0.1331 | Val Acc: 0.9517 | Val F1: 0.6997 | F1 Illicit: 0.9748
# Epoch 212 | Loss: 0.1319 | Val Acc: 0.9517 | Val F1: 0.6997 | F1 Illicit: 0.9748
# Epoch 213 | Loss: 0.1320 | Val Acc: 0.9517 | Val F1: 0.7001 | F1 Illicit: 0.9748
# Epoch 214 | Loss: 0.1324 | Val Acc: 0.9518 | Val F1: 0.7003 | F1 Illicit: 0.9748
# Epoch 215 | Loss: 0.1324 | Val Acc: 0.9518 | Val F1: 0.7003 | F1 Illicit: 0.9748
# Epoch 216 | Loss: 0.1321 | Val Acc: 0.9517 | Val F1: 0.7001 | F1 Illicit: 0.9748
# Epoch 217 | Loss: 0.1319 | Val Acc: 0.9515 | Val F1: 0.6991 | F1 Illicit: 0.9747
# Epoch 218 | Loss: 0.1313 | Val Acc: 0.9513 | Val F1: 0.6977 | F1 Illicit: 0.9746
# Epoch 219 | Loss: 0.1313 | Val Acc: 0.9512 | Val F1: 0.6973 | F1 Illicit: 0.9745
# Epoch 220 | Loss: 0.1319 | Val Acc: 0.9515 | Val F1: 0.6999 | F1 Illicit: 0.9747
# Epoch 221 | Loss: 0.1309 | Val Acc: 0.9515 | Val F1: 0.7012 | F1 Illicit: 0.9747
# Epoch 222 | Loss: 0.1301 | Val Acc: 0.9515 | Val F1: 0.7018 | F1 Illicit: 0.9747
# Epoch 223 | Loss: 0.1308 | Val Acc: 0.9515 | Val F1: 0.7018 | F1 Illicit: 0.9747
# Epoch 224 | Loss: 0.1310 | Val Acc: 0.9515 | Val F1: 0.7016 | F1 Illicit: 0.9747
# Epoch 225 | Loss: 0.1305 | Val Acc: 0.9515 | Val F1: 0.7022 | F1 Illicit: 0.9747
# Epoch 226 | Loss: 0.1304 | Val Acc: 0.9515 | Val F1: 0.7018 | F1 Illicit: 0.9747
# Epoch 227 | Loss: 0.1296 | Val Acc: 0.9516 | Val F1: 0.7020 | F1 Illicit: 0.9747
# Epoch 228 | Loss: 0.1294 | Val Acc: 0.9515 | Val F1: 0.7014 | F1 Illicit: 0.9747
# Epoch 229 | Loss: 0.1296 | Val Acc: 0.9515 | Val F1: 0.7014 | F1 Illicit: 0.9747
# Epoch 230 | Loss: 0.1294 | Val Acc: 0.9516 | Val F1: 0.7015 | F1 Illicit: 0.9747
# Epoch 231 | Loss: 0.1302 | Val Acc: 0.9517 | Val F1: 0.7023 | F1 Illicit: 0.9748
# Epoch 232 | Loss: 0.1291 | Val Acc: 0.9519 | Val F1: 0.7040 | F1 Illicit: 0.9749
# Epoch 233 | Loss: 0.1291 | Val Acc: 0.9519 | Val F1: 0.7040 | F1 Illicit: 0.9749
# Epoch 234 | Loss: 0.1284 | Val Acc: 0.9519 | Val F1: 0.7040 | F1 Illicit: 0.9749
# Epoch 235 | Loss: 0.1283 | Val Acc: 0.9519 | Val F1: 0.7040 | F1 Illicit: 0.9749
# Epoch 236 | Loss: 0.1284 | Val Acc: 0.9519 | Val F1: 0.7046 | F1 Illicit: 0.9749
# Epoch 237 | Loss: 0.1273 | Val Acc: 0.9519 | Val F1: 0.7045 | F1 Illicit: 0.9749
# Epoch 238 | Loss: 0.1278 | Val Acc: 0.9517 | Val F1: 0.7043 | F1 Illicit: 0.9748
# Epoch 239 | Loss: 0.1272 | Val Acc: 0.9517 | Val F1: 0.7049 | F1 Illicit: 0.9748
# Epoch 240 | Loss: 0.1286 | Val Acc: 0.9517 | Val F1: 0.7048 | F1 Illicit: 0.9748
# Epoch 241 | Loss: 0.1277 | Val Acc: 0.9515 | Val F1: 0.7042 | F1 Illicit: 0.9746
# Epoch 242 | Loss: 0.1278 | Val Acc: 0.9515 | Val F1: 0.7055 | F1 Illicit: 0.9746
# Epoch 243 | Loss: 0.1272 | Val Acc: 0.9515 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 244 | Loss: 0.1268 | Val Acc: 0.9515 | Val F1: 0.7059 | F1 Illicit: 0.9746
# Epoch 245 | Loss: 0.1268 | Val Acc: 0.9515 | Val F1: 0.7070 | F1 Illicit: 0.9747
# Epoch 246 | Loss: 0.1264 | Val Acc: 0.9515 | Val F1: 0.7068 | F1 Illicit: 0.9746
# Epoch 247 | Loss: 0.1263 | Val Acc: 0.9517 | Val F1: 0.7077 | F1 Illicit: 0.9747
# Epoch 248 | Loss: 0.1261 | Val Acc: 0.9516 | Val F1: 0.7063 | F1 Illicit: 0.9747
# Epoch 249 | Loss: 0.1262 | Val Acc: 0.9517 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 250 | Loss: 0.1259 | Val Acc: 0.9516 | Val F1: 0.7059 | F1 Illicit: 0.9747
# Epoch 251 | Loss: 0.1264 | Val Acc: 0.9516 | Val F1: 0.7059 | F1 Illicit: 0.9747
# Epoch 252 | Loss: 0.1255 | Val Acc: 0.9516 | Val F1: 0.7054 | F1 Illicit: 0.9747
# Epoch 253 | Loss: 0.1265 | Val Acc: 0.9517 | Val F1: 0.7056 | F1 Illicit: 0.9747
# Epoch 254 | Loss: 0.1247 | Val Acc: 0.9516 | Val F1: 0.7050 | F1 Illicit: 0.9747
# Epoch 255 | Loss: 0.1252 | Val Acc: 0.9515 | Val F1: 0.7048 | F1 Illicit: 0.9747
# Epoch 256 | Loss: 0.1259 | Val Acc: 0.9513 | Val F1: 0.7026 | F1 Illicit: 0.9746
# Epoch 257 | Loss: 0.1247 | Val Acc: 0.9510 | Val F1: 0.6999 | F1 Illicit: 0.9744
# Epoch 258 | Loss: 0.1248 | Val Acc: 0.9511 | Val F1: 0.7005 | F1 Illicit: 0.9744
# Epoch 259 | Loss: 0.1243 | Val Acc: 0.9511 | Val F1: 0.7010 | F1 Illicit: 0.9744
# Epoch 260 | Loss: 0.1237 | Val Acc: 0.9512 | Val F1: 0.7022 | F1 Illicit: 0.9745
# Epoch 261 | Loss: 0.1252 | Val Acc: 0.9512 | Val F1: 0.7026 | F1 Illicit: 0.9745
# Epoch 262 | Loss: 0.1239 | Val Acc: 0.9513 | Val F1: 0.7047 | F1 Illicit: 0.9746
# Epoch 263 | Loss: 0.1232 | Val Acc: 0.9515 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 264 | Loss: 0.1240 | Val Acc: 0.9515 | Val F1: 0.7065 | F1 Illicit: 0.9747
# Epoch 265 | Loss: 0.1248 | Val Acc: 0.9516 | Val F1: 0.7071 | F1 Illicit: 0.9747
# Epoch 266 | Loss: 0.1240 | Val Acc: 0.9515 | Val F1: 0.7065 | F1 Illicit: 0.9747
# Epoch 267 | Loss: 0.1245 | Val Acc: 0.9514 | Val F1: 0.7053 | F1 Illicit: 0.9746
# Epoch 268 | Loss: 0.1234 | Val Acc: 0.9513 | Val F1: 0.7043 | F1 Illicit: 0.9746
# Epoch 269 | Loss: 0.1237 | Val Acc: 0.9512 | Val F1: 0.7039 | F1 Illicit: 0.9745
# Epoch 270 | Loss: 0.1238 | Val Acc: 0.9511 | Val F1: 0.7037 | F1 Illicit: 0.9745
# Epoch 271 | Loss: 0.1227 | Val Acc: 0.9511 | Val F1: 0.7036 | F1 Illicit: 0.9744
# Epoch 272 | Loss: 0.1235 | Val Acc: 0.9511 | Val F1: 0.7036 | F1 Illicit: 0.9744
# Epoch 273 | Loss: 0.1224 | Val Acc: 0.9510 | Val F1: 0.7034 | F1 Illicit: 0.9744
# Epoch 274 | Loss: 0.1224 | Val Acc: 0.9510 | Val F1: 0.7034 | F1 Illicit: 0.9744
# Epoch 275 | Loss: 0.1231 | Val Acc: 0.9511 | Val F1: 0.7040 | F1 Illicit: 0.9744
# Epoch 276 | Loss: 0.1224 | Val Acc: 0.9511 | Val F1: 0.7046 | F1 Illicit: 0.9745
# Epoch 277 | Loss: 0.1209 | Val Acc: 0.9511 | Val F1: 0.7054 | F1 Illicit: 0.9745
# Early stopping triggered at epoch 277.
#
# === Training GCN (Temporal Split): base | Seed: 123 ===
# Epoch 001 | Loss: 0.8248 | Val Acc: 0.7278 | Val F1: 0.4882 | F1 Illicit: 0.8384
# Epoch 002 | Loss: 0.7013 | Val Acc: 0.7443 | Val F1: 0.5007 | F1 Illicit: 0.8494
# Epoch 003 | Loss: 0.6072 | Val Acc: 0.7631 | Val F1: 0.5122 | F1 Illicit: 0.8621
# Epoch 004 | Loss: 0.5242 | Val Acc: 0.7783 | Val F1: 0.5226 | F1 Illicit: 0.8720
# Epoch 005 | Loss: 0.4682 | Val Acc: 0.7895 | Val F1: 0.5292 | F1 Illicit: 0.8793
# Epoch 006 | Loss: 0.4143 | Val Acc: 0.7988 | Val F1: 0.5357 | F1 Illicit: 0.8852
# Epoch 007 | Loss: 0.3783 | Val Acc: 0.8070 | Val F1: 0.5418 | F1 Illicit: 0.8904
# Epoch 008 | Loss: 0.3474 | Val Acc: 0.8129 | Val F1: 0.5447 | F1 Illicit: 0.8941
# Epoch 009 | Loss: 0.3245 | Val Acc: 0.8189 | Val F1: 0.5492 | F1 Illicit: 0.8979
# Epoch 010 | Loss: 0.3063 | Val Acc: 0.8242 | Val F1: 0.5520 | F1 Illicit: 0.9012
# Epoch 011 | Loss: 0.2930 | Val Acc: 0.8299 | Val F1: 0.5565 | F1 Illicit: 0.9047
# Epoch 012 | Loss: 0.2810 | Val Acc: 0.8345 | Val F1: 0.5592 | F1 Illicit: 0.9076
# Epoch 013 | Loss: 0.2723 | Val Acc: 0.8394 | Val F1: 0.5647 | F1 Illicit: 0.9105
# Epoch 014 | Loss: 0.2643 | Val Acc: 0.8436 | Val F1: 0.5677 | F1 Illicit: 0.9130
# Epoch 015 | Loss: 0.2602 | Val Acc: 0.8468 | Val F1: 0.5700 | F1 Illicit: 0.9150
# Epoch 016 | Loss: 0.2548 | Val Acc: 0.8498 | Val F1: 0.5717 | F1 Illicit: 0.9168
# Epoch 017 | Loss: 0.2523 | Val Acc: 0.8517 | Val F1: 0.5728 | F1 Illicit: 0.9179
# Epoch 018 | Loss: 0.2496 | Val Acc: 0.8541 | Val F1: 0.5750 | F1 Illicit: 0.9194
# Epoch 019 | Loss: 0.2474 | Val Acc: 0.8554 | Val F1: 0.5764 | F1 Illicit: 0.9202
# Epoch 020 | Loss: 0.2449 | Val Acc: 0.8575 | Val F1: 0.5786 | F1 Illicit: 0.9214
# Epoch 021 | Loss: 0.2423 | Val Acc: 0.8600 | Val F1: 0.5836 | F1 Illicit: 0.9229
# Epoch 022 | Loss: 0.2421 | Val Acc: 0.8617 | Val F1: 0.5860 | F1 Illicit: 0.9238
# Epoch 023 | Loss: 0.2395 | Val Acc: 0.8626 | Val F1: 0.5885 | F1 Illicit: 0.9244
# Epoch 024 | Loss: 0.2375 | Val Acc: 0.8641 | Val F1: 0.5916 | F1 Illicit: 0.9252
# Epoch 025 | Loss: 0.2370 | Val Acc: 0.8651 | Val F1: 0.5931 | F1 Illicit: 0.9258
# Epoch 026 | Loss: 0.2350 | Val Acc: 0.8654 | Val F1: 0.5939 | F1 Illicit: 0.9260
# Epoch 027 | Loss: 0.2334 | Val Acc: 0.8661 | Val F1: 0.5962 | F1 Illicit: 0.9263
# Epoch 028 | Loss: 0.2308 | Val Acc: 0.8662 | Val F1: 0.5971 | F1 Illicit: 0.9264
# Epoch 029 | Loss: 0.2291 | Val Acc: 0.8661 | Val F1: 0.5977 | F1 Illicit: 0.9263
# Epoch 030 | Loss: 0.2275 | Val Acc: 0.8659 | Val F1: 0.5985 | F1 Illicit: 0.9261
# Epoch 031 | Loss: 0.2257 | Val Acc: 0.8667 | Val F1: 0.6002 | F1 Illicit: 0.9266
# Epoch 032 | Loss: 0.2243 | Val Acc: 0.8669 | Val F1: 0.6011 | F1 Illicit: 0.9267
# Epoch 033 | Loss: 0.2236 | Val Acc: 0.8672 | Val F1: 0.6019 | F1 Illicit: 0.9269
# Epoch 034 | Loss: 0.2215 | Val Acc: 0.8671 | Val F1: 0.6031 | F1 Illicit: 0.9268
# Epoch 035 | Loss: 0.2202 | Val Acc: 0.8671 | Val F1: 0.6026 | F1 Illicit: 0.9268
# Epoch 036 | Loss: 0.2204 | Val Acc: 0.8681 | Val F1: 0.6039 | F1 Illicit: 0.9274
# Epoch 037 | Loss: 0.2182 | Val Acc: 0.8696 | Val F1: 0.6068 | F1 Illicit: 0.9283
# Epoch 038 | Loss: 0.2167 | Val Acc: 0.8708 | Val F1: 0.6080 | F1 Illicit: 0.9289
# Epoch 039 | Loss: 0.2154 | Val Acc: 0.8717 | Val F1: 0.6091 | F1 Illicit: 0.9295
# Epoch 040 | Loss: 0.2142 | Val Acc: 0.8728 | Val F1: 0.6105 | F1 Illicit: 0.9301
# Epoch 041 | Loss: 0.2138 | Val Acc: 0.8738 | Val F1: 0.6132 | F1 Illicit: 0.9307
# Epoch 042 | Loss: 0.2131 | Val Acc: 0.8755 | Val F1: 0.6151 | F1 Illicit: 0.9317
# Epoch 043 | Loss: 0.2116 | Val Acc: 0.8771 | Val F1: 0.6169 | F1 Illicit: 0.9326
# Epoch 044 | Loss: 0.2108 | Val Acc: 0.8790 | Val F1: 0.6183 | F1 Illicit: 0.9337
# Epoch 045 | Loss: 0.2092 | Val Acc: 0.8805 | Val F1: 0.6201 | F1 Illicit: 0.9346
# Epoch 046 | Loss: 0.2087 | Val Acc: 0.8827 | Val F1: 0.6227 | F1 Illicit: 0.9359
# Epoch 047 | Loss: 0.2072 | Val Acc: 0.8846 | Val F1: 0.6250 | F1 Illicit: 0.9370
# Epoch 048 | Loss: 0.2063 | Val Acc: 0.8863 | Val F1: 0.6274 | F1 Illicit: 0.9380
# Epoch 049 | Loss: 0.2064 | Val Acc: 0.8883 | Val F1: 0.6299 | F1 Illicit: 0.9392
# Epoch 050 | Loss: 0.2047 | Val Acc: 0.8898 | Val F1: 0.6315 | F1 Illicit: 0.9400
# Epoch 051 | Loss: 0.2041 | Val Acc: 0.8917 | Val F1: 0.6326 | F1 Illicit: 0.9411
# Epoch 052 | Loss: 0.2032 | Val Acc: 0.8934 | Val F1: 0.6348 | F1 Illicit: 0.9421
# Epoch 053 | Loss: 0.2032 | Val Acc: 0.8965 | Val F1: 0.6410 | F1 Illicit: 0.9439
# Epoch 054 | Loss: 0.2019 | Val Acc: 0.8988 | Val F1: 0.6443 | F1 Illicit: 0.9451
# Epoch 055 | Loss: 0.2016 | Val Acc: 0.9010 | Val F1: 0.6467 | F1 Illicit: 0.9465
# Epoch 056 | Loss: 0.2005 | Val Acc: 0.9031 | Val F1: 0.6485 | F1 Illicit: 0.9476
# Epoch 057 | Loss: 0.1993 | Val Acc: 0.9055 | Val F1: 0.6516 | F1 Illicit: 0.9490
# Epoch 058 | Loss: 0.1993 | Val Acc: 0.9070 | Val F1: 0.6530 | F1 Illicit: 0.9499
# Epoch 059 | Loss: 0.1962 | Val Acc: 0.9081 | Val F1: 0.6538 | F1 Illicit: 0.9505
# Epoch 060 | Loss: 0.1972 | Val Acc: 0.9096 | Val F1: 0.6546 | F1 Illicit: 0.9514
# Epoch 061 | Loss: 0.1964 | Val Acc: 0.9116 | Val F1: 0.6568 | F1 Illicit: 0.9525
# Epoch 062 | Loss: 0.1955 | Val Acc: 0.9123 | Val F1: 0.6576 | F1 Illicit: 0.9529
# Epoch 063 | Loss: 0.1952 | Val Acc: 0.9132 | Val F1: 0.6582 | F1 Illicit: 0.9534
# Epoch 064 | Loss: 0.1941 | Val Acc: 0.9147 | Val F1: 0.6600 | F1 Illicit: 0.9543
# Epoch 065 | Loss: 0.1940 | Val Acc: 0.9157 | Val F1: 0.6600 | F1 Illicit: 0.9548
# Epoch 066 | Loss: 0.1930 | Val Acc: 0.9168 | Val F1: 0.6617 | F1 Illicit: 0.9555
# Epoch 067 | Loss: 0.1918 | Val Acc: 0.9184 | Val F1: 0.6646 | F1 Illicit: 0.9564
# Epoch 068 | Loss: 0.1912 | Val Acc: 0.9194 | Val F1: 0.6652 | F1 Illicit: 0.9569
# Epoch 069 | Loss: 0.1903 | Val Acc: 0.9203 | Val F1: 0.6657 | F1 Illicit: 0.9574
# Epoch 070 | Loss: 0.1906 | Val Acc: 0.9208 | Val F1: 0.6660 | F1 Illicit: 0.9577
# Epoch 071 | Loss: 0.1895 | Val Acc: 0.9216 | Val F1: 0.6670 | F1 Illicit: 0.9582
# Epoch 072 | Loss: 0.1892 | Val Acc: 0.9230 | Val F1: 0.6699 | F1 Illicit: 0.9590
# Epoch 073 | Loss: 0.1887 | Val Acc: 0.9233 | Val F1: 0.6701 | F1 Illicit: 0.9591
# Epoch 074 | Loss: 0.1879 | Val Acc: 0.9241 | Val F1: 0.6713 | F1 Illicit: 0.9596
# Epoch 075 | Loss: 0.1877 | Val Acc: 0.9248 | Val F1: 0.6732 | F1 Illicit: 0.9599
# Epoch 076 | Loss: 0.1877 | Val Acc: 0.9252 | Val F1: 0.6740 | F1 Illicit: 0.9602
# Epoch 077 | Loss: 0.1856 | Val Acc: 0.9254 | Val F1: 0.6733 | F1 Illicit: 0.9603
# Epoch 078 | Loss: 0.1855 | Val Acc: 0.9265 | Val F1: 0.6758 | F1 Illicit: 0.9609
# Epoch 079 | Loss: 0.1845 | Val Acc: 0.9267 | Val F1: 0.6762 | F1 Illicit: 0.9610
# Epoch 080 | Loss: 0.1844 | Val Acc: 0.9275 | Val F1: 0.6782 | F1 Illicit: 0.9614
# Epoch 081 | Loss: 0.1843 | Val Acc: 0.9279 | Val F1: 0.6791 | F1 Illicit: 0.9617
# Epoch 082 | Loss: 0.1833 | Val Acc: 0.9286 | Val F1: 0.6808 | F1 Illicit: 0.9621
# Epoch 083 | Loss: 0.1830 | Val Acc: 0.9292 | Val F1: 0.6815 | F1 Illicit: 0.9624
# Epoch 084 | Loss: 0.1827 | Val Acc: 0.9294 | Val F1: 0.6817 | F1 Illicit: 0.9625
# Epoch 085 | Loss: 0.1816 | Val Acc: 0.9301 | Val F1: 0.6827 | F1 Illicit: 0.9629
# Epoch 086 | Loss: 0.1810 | Val Acc: 0.9303 | Val F1: 0.6835 | F1 Illicit: 0.9630
# Epoch 087 | Loss: 0.1811 | Val Acc: 0.9307 | Val F1: 0.6840 | F1 Illicit: 0.9632
# Epoch 088 | Loss: 0.1804 | Val Acc: 0.9312 | Val F1: 0.6850 | F1 Illicit: 0.9635
# Epoch 089 | Loss: 0.1802 | Val Acc: 0.9318 | Val F1: 0.6854 | F1 Illicit: 0.9638
# Epoch 090 | Loss: 0.1796 | Val Acc: 0.9321 | Val F1: 0.6857 | F1 Illicit: 0.9640
# Epoch 091 | Loss: 0.1791 | Val Acc: 0.9325 | Val F1: 0.6864 | F1 Illicit: 0.9642
# Epoch 092 | Loss: 0.1785 | Val Acc: 0.9327 | Val F1: 0.6868 | F1 Illicit: 0.9643
# Epoch 093 | Loss: 0.1769 | Val Acc: 0.9333 | Val F1: 0.6878 | F1 Illicit: 0.9646
# Epoch 094 | Loss: 0.1776 | Val Acc: 0.9339 | Val F1: 0.6892 | F1 Illicit: 0.9650
# Epoch 095 | Loss: 0.1780 | Val Acc: 0.9341 | Val F1: 0.6886 | F1 Illicit: 0.9651
# Epoch 096 | Loss: 0.1773 | Val Acc: 0.9346 | Val F1: 0.6896 | F1 Illicit: 0.9654
# Epoch 097 | Loss: 0.1772 | Val Acc: 0.9352 | Val F1: 0.6898 | F1 Illicit: 0.9657
# Epoch 098 | Loss: 0.1758 | Val Acc: 0.9355 | Val F1: 0.6896 | F1 Illicit: 0.9659
# Epoch 099 | Loss: 0.1748 | Val Acc: 0.9357 | Val F1: 0.6897 | F1 Illicit: 0.9660
# Epoch 100 | Loss: 0.1754 | Val Acc: 0.9362 | Val F1: 0.6907 | F1 Illicit: 0.9663
# Epoch 101 | Loss: 0.1749 | Val Acc: 0.9365 | Val F1: 0.6910 | F1 Illicit: 0.9664
# Epoch 102 | Loss: 0.1743 | Val Acc: 0.9368 | Val F1: 0.6912 | F1 Illicit: 0.9666
# Epoch 103 | Loss: 0.1727 | Val Acc: 0.9373 | Val F1: 0.6924 | F1 Illicit: 0.9669
# Epoch 104 | Loss: 0.1734 | Val Acc: 0.9376 | Val F1: 0.6931 | F1 Illicit: 0.9670
# Epoch 105 | Loss: 0.1729 | Val Acc: 0.9378 | Val F1: 0.6936 | F1 Illicit: 0.9672
# Epoch 106 | Loss: 0.1724 | Val Acc: 0.9380 | Val F1: 0.6936 | F1 Illicit: 0.9673
# Epoch 107 | Loss: 0.1715 | Val Acc: 0.9383 | Val F1: 0.6942 | F1 Illicit: 0.9674
# Epoch 108 | Loss: 0.1721 | Val Acc: 0.9384 | Val F1: 0.6940 | F1 Illicit: 0.9674
# Epoch 109 | Loss: 0.1711 | Val Acc: 0.9385 | Val F1: 0.6943 | F1 Illicit: 0.9675
# Epoch 110 | Loss: 0.1706 | Val Acc: 0.9389 | Val F1: 0.6953 | F1 Illicit: 0.9678
# Epoch 111 | Loss: 0.1709 | Val Acc: 0.9391 | Val F1: 0.6958 | F1 Illicit: 0.9679
# Epoch 112 | Loss: 0.1698 | Val Acc: 0.9394 | Val F1: 0.6957 | F1 Illicit: 0.9680
# Epoch 113 | Loss: 0.1694 | Val Acc: 0.9399 | Val F1: 0.6965 | F1 Illicit: 0.9683
# Epoch 114 | Loss: 0.1696 | Val Acc: 0.9402 | Val F1: 0.6968 | F1 Illicit: 0.9684
# Epoch 115 | Loss: 0.1689 | Val Acc: 0.9402 | Val F1: 0.6969 | F1 Illicit: 0.9685
# Epoch 116 | Loss: 0.1687 | Val Acc: 0.9407 | Val F1: 0.6980 | F1 Illicit: 0.9687
# Epoch 117 | Loss: 0.1685 | Val Acc: 0.9411 | Val F1: 0.6985 | F1 Illicit: 0.9689
# Epoch 118 | Loss: 0.1670 | Val Acc: 0.9415 | Val F1: 0.6991 | F1 Illicit: 0.9692
# Epoch 119 | Loss: 0.1677 | Val Acc: 0.9417 | Val F1: 0.6988 | F1 Illicit: 0.9693
# Epoch 120 | Loss: 0.1674 | Val Acc: 0.9419 | Val F1: 0.6993 | F1 Illicit: 0.9694
# Epoch 121 | Loss: 0.1675 | Val Acc: 0.9421 | Val F1: 0.6996 | F1 Illicit: 0.9695
# Epoch 122 | Loss: 0.1669 | Val Acc: 0.9423 | Val F1: 0.6995 | F1 Illicit: 0.9696
# Epoch 123 | Loss: 0.1661 | Val Acc: 0.9424 | Val F1: 0.6998 | F1 Illicit: 0.9697
# Epoch 124 | Loss: 0.1651 | Val Acc: 0.9427 | Val F1: 0.7004 | F1 Illicit: 0.9698
# Epoch 125 | Loss: 0.1650 | Val Acc: 0.9428 | Val F1: 0.7004 | F1 Illicit: 0.9699
# Epoch 126 | Loss: 0.1650 | Val Acc: 0.9430 | Val F1: 0.7010 | F1 Illicit: 0.9700
# Epoch 127 | Loss: 0.1644 | Val Acc: 0.9432 | Val F1: 0.7011 | F1 Illicit: 0.9701
# Epoch 128 | Loss: 0.1647 | Val Acc: 0.9434 | Val F1: 0.7016 | F1 Illicit: 0.9702
# Epoch 129 | Loss: 0.1637 | Val Acc: 0.9436 | Val F1: 0.7021 | F1 Illicit: 0.9703
# Epoch 130 | Loss: 0.1635 | Val Acc: 0.9436 | Val F1: 0.7012 | F1 Illicit: 0.9703
# Epoch 131 | Loss: 0.1639 | Val Acc: 0.9438 | Val F1: 0.7013 | F1 Illicit: 0.9704
# Epoch 132 | Loss: 0.1633 | Val Acc: 0.9440 | Val F1: 0.7019 | F1 Illicit: 0.9706
# Epoch 133 | Loss: 0.1620 | Val Acc: 0.9440 | Val F1: 0.7016 | F1 Illicit: 0.9706
# Epoch 134 | Loss: 0.1616 | Val Acc: 0.9441 | Val F1: 0.7013 | F1 Illicit: 0.9706
# Epoch 135 | Loss: 0.1620 | Val Acc: 0.9442 | Val F1: 0.7013 | F1 Illicit: 0.9707
# Epoch 136 | Loss: 0.1625 | Val Acc: 0.9442 | Val F1: 0.7013 | F1 Illicit: 0.9707
# Epoch 137 | Loss: 0.1618 | Val Acc: 0.9442 | Val F1: 0.7009 | F1 Illicit: 0.9707
# Epoch 138 | Loss: 0.1605 | Val Acc: 0.9444 | Val F1: 0.7009 | F1 Illicit: 0.9707
# Epoch 139 | Loss: 0.1611 | Val Acc: 0.9444 | Val F1: 0.7006 | F1 Illicit: 0.9708
# Epoch 140 | Loss: 0.1606 | Val Acc: 0.9446 | Val F1: 0.7007 | F1 Illicit: 0.9709
# Epoch 141 | Loss: 0.1597 | Val Acc: 0.9449 | Val F1: 0.7014 | F1 Illicit: 0.9710
# Epoch 142 | Loss: 0.1597 | Val Acc: 0.9449 | Val F1: 0.7016 | F1 Illicit: 0.9711
# Epoch 143 | Loss: 0.1592 | Val Acc: 0.9450 | Val F1: 0.7006 | F1 Illicit: 0.9711
# Epoch 144 | Loss: 0.1587 | Val Acc: 0.9451 | Val F1: 0.7007 | F1 Illicit: 0.9711
# Epoch 145 | Loss: 0.1597 | Val Acc: 0.9453 | Val F1: 0.7008 | F1 Illicit: 0.9713
# Epoch 146 | Loss: 0.1584 | Val Acc: 0.9453 | Val F1: 0.7004 | F1 Illicit: 0.9713
# Epoch 147 | Loss: 0.1587 | Val Acc: 0.9454 | Val F1: 0.7008 | F1 Illicit: 0.9713
# Epoch 148 | Loss: 0.1582 | Val Acc: 0.9456 | Val F1: 0.7009 | F1 Illicit: 0.9714
# Epoch 149 | Loss: 0.1573 | Val Acc: 0.9457 | Val F1: 0.7010 | F1 Illicit: 0.9715
# Epoch 150 | Loss: 0.1570 | Val Acc: 0.9460 | Val F1: 0.7024 | F1 Illicit: 0.9717
# Epoch 151 | Loss: 0.1570 | Val Acc: 0.9460 | Val F1: 0.7020 | F1 Illicit: 0.9717
# Epoch 152 | Loss: 0.1572 | Val Acc: 0.9462 | Val F1: 0.7024 | F1 Illicit: 0.9717
# Epoch 153 | Loss: 0.1563 | Val Acc: 0.9463 | Val F1: 0.7027 | F1 Illicit: 0.9718
# Epoch 154 | Loss: 0.1560 | Val Acc: 0.9464 | Val F1: 0.7025 | F1 Illicit: 0.9719
# Epoch 155 | Loss: 0.1550 | Val Acc: 0.9467 | Val F1: 0.7033 | F1 Illicit: 0.9720
# Epoch 156 | Loss: 0.1560 | Val Acc: 0.9472 | Val F1: 0.7045 | F1 Illicit: 0.9723
# Epoch 157 | Loss: 0.1555 | Val Acc: 0.9473 | Val F1: 0.7044 | F1 Illicit: 0.9724
# Epoch 158 | Loss: 0.1554 | Val Acc: 0.9474 | Val F1: 0.7044 | F1 Illicit: 0.9724
# Epoch 159 | Loss: 0.1546 | Val Acc: 0.9476 | Val F1: 0.7047 | F1 Illicit: 0.9725
# Epoch 160 | Loss: 0.1552 | Val Acc: 0.9477 | Val F1: 0.7055 | F1 Illicit: 0.9726
# Epoch 161 | Loss: 0.1544 | Val Acc: 0.9478 | Val F1: 0.7058 | F1 Illicit: 0.9726
# Epoch 162 | Loss: 0.1547 | Val Acc: 0.9479 | Val F1: 0.7056 | F1 Illicit: 0.9727
# Epoch 163 | Loss: 0.1538 | Val Acc: 0.9481 | Val F1: 0.7055 | F1 Illicit: 0.9728
# Epoch 164 | Loss: 0.1534 | Val Acc: 0.9481 | Val F1: 0.7049 | F1 Illicit: 0.9728
# Epoch 165 | Loss: 0.1531 | Val Acc: 0.9482 | Val F1: 0.7053 | F1 Illicit: 0.9729
# Epoch 166 | Loss: 0.1525 | Val Acc: 0.9481 | Val F1: 0.7041 | F1 Illicit: 0.9728
# Epoch 167 | Loss: 0.1518 | Val Acc: 0.9481 | Val F1: 0.7035 | F1 Illicit: 0.9728
# Epoch 168 | Loss: 0.1519 | Val Acc: 0.9483 | Val F1: 0.7042 | F1 Illicit: 0.9729
# Epoch 169 | Loss: 0.1522 | Val Acc: 0.9485 | Val F1: 0.7056 | F1 Illicit: 0.9730
# Epoch 170 | Loss: 0.1520 | Val Acc: 0.9487 | Val F1: 0.7061 | F1 Illicit: 0.9731
# Epoch 171 | Loss: 0.1520 | Val Acc: 0.9487 | Val F1: 0.7061 | F1 Illicit: 0.9731
# Epoch 172 | Loss: 0.1519 | Val Acc: 0.9488 | Val F1: 0.7060 | F1 Illicit: 0.9732
# Epoch 173 | Loss: 0.1516 | Val Acc: 0.9489 | Val F1: 0.7062 | F1 Illicit: 0.9732
# Epoch 174 | Loss: 0.1511 | Val Acc: 0.9489 | Val F1: 0.7062 | F1 Illicit: 0.9732
# Epoch 175 | Loss: 0.1497 | Val Acc: 0.9491 | Val F1: 0.7067 | F1 Illicit: 0.9733
# Epoch 176 | Loss: 0.1508 | Val Acc: 0.9492 | Val F1: 0.7071 | F1 Illicit: 0.9734
# Epoch 177 | Loss: 0.1491 | Val Acc: 0.9491 | Val F1: 0.7065 | F1 Illicit: 0.9733
# Epoch 178 | Loss: 0.1500 | Val Acc: 0.9494 | Val F1: 0.7074 | F1 Illicit: 0.9735
# Epoch 179 | Loss: 0.1497 | Val Acc: 0.9494 | Val F1: 0.7074 | F1 Illicit: 0.9735
# Epoch 180 | Loss: 0.1491 | Val Acc: 0.9494 | Val F1: 0.7074 | F1 Illicit: 0.9735
# Epoch 181 | Loss: 0.1493 | Val Acc: 0.9496 | Val F1: 0.7079 | F1 Illicit: 0.9736
# Epoch 182 | Loss: 0.1483 | Val Acc: 0.9498 | Val F1: 0.7084 | F1 Illicit: 0.9737
# Epoch 183 | Loss: 0.1487 | Val Acc: 0.9500 | Val F1: 0.7090 | F1 Illicit: 0.9738
# Epoch 184 | Loss: 0.1483 | Val Acc: 0.9501 | Val F1: 0.7092 | F1 Illicit: 0.9739
# Epoch 185 | Loss: 0.1484 | Val Acc: 0.9500 | Val F1: 0.7086 | F1 Illicit: 0.9738
# Epoch 186 | Loss: 0.1478 | Val Acc: 0.9500 | Val F1: 0.7086 | F1 Illicit: 0.9738
# Epoch 187 | Loss: 0.1480 | Val Acc: 0.9498 | Val F1: 0.7076 | F1 Illicit: 0.9737
# Epoch 188 | Loss: 0.1471 | Val Acc: 0.9501 | Val F1: 0.7092 | F1 Illicit: 0.9739
# Epoch 189 | Loss: 0.1477 | Val Acc: 0.9502 | Val F1: 0.7087 | F1 Illicit: 0.9739
# Epoch 190 | Loss: 0.1468 | Val Acc: 0.9503 | Val F1: 0.7085 | F1 Illicit: 0.9740
# Epoch 191 | Loss: 0.1466 | Val Acc: 0.9504 | Val F1: 0.7088 | F1 Illicit: 0.9741
# Epoch 192 | Loss: 0.1465 | Val Acc: 0.9504 | Val F1: 0.7088 | F1 Illicit: 0.9741
# Epoch 193 | Loss: 0.1461 | Val Acc: 0.9505 | Val F1: 0.7090 | F1 Illicit: 0.9741
# Epoch 194 | Loss: 0.1473 | Val Acc: 0.9506 | Val F1: 0.7092 | F1 Illicit: 0.9741
# Epoch 195 | Loss: 0.1462 | Val Acc: 0.9507 | Val F1: 0.7097 | F1 Illicit: 0.9742
# Epoch 196 | Loss: 0.1460 | Val Acc: 0.9507 | Val F1: 0.7087 | F1 Illicit: 0.9742
# Epoch 197 | Loss: 0.1459 | Val Acc: 0.9507 | Val F1: 0.7089 | F1 Illicit: 0.9742
# Epoch 198 | Loss: 0.1453 | Val Acc: 0.9507 | Val F1: 0.7085 | F1 Illicit: 0.9742
# Epoch 199 | Loss: 0.1448 | Val Acc: 0.9507 | Val F1: 0.7085 | F1 Illicit: 0.9742
# Epoch 200 | Loss: 0.1445 | Val Acc: 0.9508 | Val F1: 0.7087 | F1 Illicit: 0.9743
# Epoch 201 | Loss: 0.1444 | Val Acc: 0.9509 | Val F1: 0.7089 | F1 Illicit: 0.9743
# Epoch 202 | Loss: 0.1448 | Val Acc: 0.9507 | Val F1: 0.7077 | F1 Illicit: 0.9742
# Epoch 203 | Loss: 0.1441 | Val Acc: 0.9507 | Val F1: 0.7073 | F1 Illicit: 0.9742
# Epoch 204 | Loss: 0.1440 | Val Acc: 0.9508 | Val F1: 0.7070 | F1 Illicit: 0.9743
# Epoch 205 | Loss: 0.1440 | Val Acc: 0.9508 | Val F1: 0.7075 | F1 Illicit: 0.9743
# Epoch 206 | Loss: 0.1443 | Val Acc: 0.9508 | Val F1: 0.7075 | F1 Illicit: 0.9743
# Epoch 207 | Loss: 0.1425 | Val Acc: 0.9508 | Val F1: 0.7066 | F1 Illicit: 0.9743
# Epoch 208 | Loss: 0.1431 | Val Acc: 0.9508 | Val F1: 0.7066 | F1 Illicit: 0.9743
# Epoch 209 | Loss: 0.1428 | Val Acc: 0.9508 | Val F1: 0.7066 | F1 Illicit: 0.9743
# Epoch 210 | Loss: 0.1428 | Val Acc: 0.9509 | Val F1: 0.7076 | F1 Illicit: 0.9743
# Epoch 211 | Loss: 0.1414 | Val Acc: 0.9509 | Val F1: 0.7078 | F1 Illicit: 0.9743
# Epoch 212 | Loss: 0.1430 | Val Acc: 0.9509 | Val F1: 0.7078 | F1 Illicit: 0.9743
# Epoch 213 | Loss: 0.1423 | Val Acc: 0.9509 | Val F1: 0.7078 | F1 Illicit: 0.9743
# Epoch 214 | Loss: 0.1424 | Val Acc: 0.9511 | Val F1: 0.7082 | F1 Illicit: 0.9744
# Epoch 215 | Loss: 0.1417 | Val Acc: 0.9511 | Val F1: 0.7082 | F1 Illicit: 0.9744
# Epoch 216 | Loss: 0.1406 | Val Acc: 0.9510 | Val F1: 0.7080 | F1 Illicit: 0.9744
# Epoch 217 | Loss: 0.1423 | Val Acc: 0.9512 | Val F1: 0.7086 | F1 Illicit: 0.9745
# Epoch 218 | Loss: 0.1410 | Val Acc: 0.9513 | Val F1: 0.7085 | F1 Illicit: 0.9746
# Epoch 219 | Loss: 0.1408 | Val Acc: 0.9515 | Val F1: 0.7091 | F1 Illicit: 0.9747
# Epoch 220 | Loss: 0.1404 | Val Acc: 0.9516 | Val F1: 0.7092 | F1 Illicit: 0.9747
# Epoch 221 | Loss: 0.1402 | Val Acc: 0.9516 | Val F1: 0.7092 | F1 Illicit: 0.9747
# Epoch 222 | Loss: 0.1413 | Val Acc: 0.9516 | Val F1: 0.7092 | F1 Illicit: 0.9747
# Epoch 223 | Loss: 0.1403 | Val Acc: 0.9515 | Val F1: 0.7086 | F1 Illicit: 0.9747
# Epoch 224 | Loss: 0.1400 | Val Acc: 0.9516 | Val F1: 0.7092 | F1 Illicit: 0.9747
# Epoch 225 | Loss: 0.1405 | Val Acc: 0.9516 | Val F1: 0.7092 | F1 Illicit: 0.9747
# Epoch 226 | Loss: 0.1390 | Val Acc: 0.9517 | Val F1: 0.7098 | F1 Illicit: 0.9747
# Epoch 227 | Loss: 0.1399 | Val Acc: 0.9519 | Val F1: 0.7106 | F1 Illicit: 0.9749
# Epoch 228 | Loss: 0.1396 | Val Acc: 0.9519 | Val F1: 0.7102 | F1 Illicit: 0.9749
# Epoch 229 | Loss: 0.1397 | Val Acc: 0.9519 | Val F1: 0.7102 | F1 Illicit: 0.9749
# Epoch 230 | Loss: 0.1388 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 231 | Loss: 0.1375 | Val Acc: 0.9521 | Val F1: 0.7101 | F1 Illicit: 0.9749
# Epoch 232 | Loss: 0.1383 | Val Acc: 0.9519 | Val F1: 0.7093 | F1 Illicit: 0.9749
# Epoch 233 | Loss: 0.1390 | Val Acc: 0.9520 | Val F1: 0.7099 | F1 Illicit: 0.9749
# Epoch 234 | Loss: 0.1386 | Val Acc: 0.9520 | Val F1: 0.7099 | F1 Illicit: 0.9749
# Epoch 235 | Loss: 0.1373 | Val Acc: 0.9521 | Val F1: 0.7101 | F1 Illicit: 0.9749
# Epoch 236 | Loss: 0.1381 | Val Acc: 0.9519 | Val F1: 0.7091 | F1 Illicit: 0.9748
# Epoch 237 | Loss: 0.1370 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 238 | Loss: 0.1372 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 239 | Loss: 0.1377 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 240 | Loss: 0.1375 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 241 | Loss: 0.1373 | Val Acc: 0.9521 | Val F1: 0.7107 | F1 Illicit: 0.9750
# Epoch 242 | Loss: 0.1374 | Val Acc: 0.9521 | Val F1: 0.7105 | F1 Illicit: 0.9749
# Epoch 243 | Loss: 0.1365 | Val Acc: 0.9521 | Val F1: 0.7107 | F1 Illicit: 0.9750
# Epoch 244 | Loss: 0.1359 | Val Acc: 0.9522 | Val F1: 0.7109 | F1 Illicit: 0.9750
# Epoch 245 | Loss: 0.1365 | Val Acc: 0.9521 | Val F1: 0.7103 | F1 Illicit: 0.9750
# Epoch 246 | Loss: 0.1359 | Val Acc: 0.9520 | Val F1: 0.7091 | F1 Illicit: 0.9749
# Epoch 247 | Loss: 0.1357 | Val Acc: 0.9519 | Val F1: 0.7085 | F1 Illicit: 0.9749
# Epoch 248 | Loss: 0.1353 | Val Acc: 0.9519 | Val F1: 0.7085 | F1 Illicit: 0.9749
# Epoch 249 | Loss: 0.1362 | Val Acc: 0.9519 | Val F1: 0.7089 | F1 Illicit: 0.9749
# Epoch 250 | Loss: 0.1357 | Val Acc: 0.9519 | Val F1: 0.7089 | F1 Illicit: 0.9749
# Epoch 251 | Loss: 0.1361 | Val Acc: 0.9520 | Val F1: 0.7095 | F1 Illicit: 0.9749
# Epoch 252 | Loss: 0.1349 | Val Acc: 0.9519 | Val F1: 0.7093 | F1 Illicit: 0.9749
# Epoch 253 | Loss: 0.1353 | Val Acc: 0.9519 | Val F1: 0.7091 | F1 Illicit: 0.9748
# Epoch 254 | Loss: 0.1344 | Val Acc: 0.9520 | Val F1: 0.7095 | F1 Illicit: 0.9749
# Epoch 255 | Loss: 0.1355 | Val Acc: 0.9521 | Val F1: 0.7097 | F1 Illicit: 0.9749
# Epoch 256 | Loss: 0.1344 | Val Acc: 0.9519 | Val F1: 0.7085 | F1 Illicit: 0.9749
# Epoch 257 | Loss: 0.1340 | Val Acc: 0.9519 | Val F1: 0.7081 | F1 Illicit: 0.9749
# Epoch 258 | Loss: 0.1347 | Val Acc: 0.9519 | Val F1: 0.7075 | F1 Illicit: 0.9748
# Epoch 259 | Loss: 0.1337 | Val Acc: 0.9519 | Val F1: 0.7070 | F1 Illicit: 0.9748
# Epoch 260 | Loss: 0.1345 | Val Acc: 0.9518 | Val F1: 0.7064 | F1 Illicit: 0.9748
# Epoch 261 | Loss: 0.1345 | Val Acc: 0.9517 | Val F1: 0.7062 | F1 Illicit: 0.9748
# Epoch 262 | Loss: 0.1339 | Val Acc: 0.9517 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 263 | Loss: 0.1326 | Val Acc: 0.9517 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 264 | Loss: 0.1330 | Val Acc: 0.9517 | Val F1: 0.7061 | F1 Illicit: 0.9747
# Epoch 265 | Loss: 0.1330 | Val Acc: 0.9517 | Val F1: 0.7065 | F1 Illicit: 0.9747
# Epoch 266 | Loss: 0.1325 | Val Acc: 0.9518 | Val F1: 0.7077 | F1 Illicit: 0.9748
# Epoch 267 | Loss: 0.1333 | Val Acc: 0.9519 | Val F1: 0.7083 | F1 Illicit: 0.9748
# Epoch 268 | Loss: 0.1324 | Val Acc: 0.9519 | Val F1: 0.7089 | F1 Illicit: 0.9749
# Epoch 269 | Loss: 0.1329 | Val Acc: 0.9519 | Val F1: 0.7087 | F1 Illicit: 0.9748
# Epoch 270 | Loss: 0.1326 | Val Acc: 0.9518 | Val F1: 0.7077 | F1 Illicit: 0.9748
# Epoch 271 | Loss: 0.1319 | Val Acc: 0.9517 | Val F1: 0.7065 | F1 Illicit: 0.9747
# Epoch 272 | Loss: 0.1322 | Val Acc: 0.9515 | Val F1: 0.7046 | F1 Illicit: 0.9746
# Epoch 273 | Loss: 0.1313 | Val Acc: 0.9515 | Val F1: 0.7046 | F1 Illicit: 0.9746
# Epoch 274 | Loss: 0.1317 | Val Acc: 0.9514 | Val F1: 0.7045 | F1 Illicit: 0.9746
# Early stopping triggered at epoch 274.
#
# === Training GCN (Temporal Split): base | Seed: 777 ===
# Epoch 001 | Loss: 1.0051 | Val Acc: 0.5079 | Val F1: 0.3837 | F1 Illicit: 0.6604
# Epoch 002 | Loss: 0.8168 | Val Acc: 0.5173 | Val F1: 0.3917 | F1 Illicit: 0.6681
# Epoch 003 | Loss: 0.7013 | Val Acc: 0.5299 | Val F1: 0.4020 | F1 Illicit: 0.6786
# Epoch 004 | Loss: 0.5814 | Val Acc: 0.5474 | Val F1: 0.4156 | F1 Illicit: 0.6931
# Epoch 005 | Loss: 0.4999 | Val Acc: 0.5736 | Val F1: 0.4315 | F1 Illicit: 0.7157
# Epoch 006 | Loss: 0.4299 | Val Acc: 0.6097 | Val F1: 0.4531 | F1 Illicit: 0.7457
# Epoch 007 | Loss: 0.3837 | Val Acc: 0.6410 | Val F1: 0.4716 | F1 Illicit: 0.7708
# Epoch 008 | Loss: 0.3485 | Val Acc: 0.6619 | Val F1: 0.4836 | F1 Illicit: 0.7871
# Epoch 009 | Loss: 0.3200 | Val Acc: 0.6798 | Val F1: 0.4935 | F1 Illicit: 0.8007
# Epoch 010 | Loss: 0.3022 | Val Acc: 0.6946 | Val F1: 0.5003 | F1 Illicit: 0.8119
# Epoch 011 | Loss: 0.2868 | Val Acc: 0.7089 | Val F1: 0.5086 | F1 Illicit: 0.8223
# Epoch 012 | Loss: 0.2786 | Val Acc: 0.7233 | Val F1: 0.5156 | F1 Illicit: 0.8328
# Epoch 013 | Loss: 0.2703 | Val Acc: 0.7360 | Val F1: 0.5214 | F1 Illicit: 0.8419
# Epoch 014 | Loss: 0.2643 | Val Acc: 0.7457 | Val F1: 0.5261 | F1 Illicit: 0.8487
# Epoch 015 | Loss: 0.2597 | Val Acc: 0.7552 | Val F1: 0.5310 | F1 Illicit: 0.8553
# Epoch 016 | Loss: 0.2566 | Val Acc: 0.7630 | Val F1: 0.5346 | F1 Illicit: 0.8606
# Epoch 017 | Loss: 0.2546 | Val Acc: 0.7695 | Val F1: 0.5377 | F1 Illicit: 0.8650
# Epoch 018 | Loss: 0.2524 | Val Acc: 0.7765 | Val F1: 0.5425 | F1 Illicit: 0.8697
# Epoch 019 | Loss: 0.2501 | Val Acc: 0.7815 | Val F1: 0.5443 | F1 Illicit: 0.8730
# Epoch 020 | Loss: 0.2480 | Val Acc: 0.7860 | Val F1: 0.5471 | F1 Illicit: 0.8760
# Epoch 021 | Loss: 0.2462 | Val Acc: 0.7884 | Val F1: 0.5476 | F1 Illicit: 0.8777
# Epoch 022 | Loss: 0.2454 | Val Acc: 0.7912 | Val F1: 0.5495 | F1 Illicit: 0.8795
# Epoch 023 | Loss: 0.2431 | Val Acc: 0.7939 | Val F1: 0.5505 | F1 Illicit: 0.8813
# Epoch 024 | Loss: 0.2400 | Val Acc: 0.7961 | Val F1: 0.5525 | F1 Illicit: 0.8826
# Epoch 025 | Loss: 0.2395 | Val Acc: 0.7981 | Val F1: 0.5523 | F1 Illicit: 0.8840
# Epoch 026 | Loss: 0.2361 | Val Acc: 0.7995 | Val F1: 0.5538 | F1 Illicit: 0.8849
# Epoch 027 | Loss: 0.2352 | Val Acc: 0.8001 | Val F1: 0.5542 | F1 Illicit: 0.8853
# Epoch 028 | Loss: 0.2336 | Val Acc: 0.8014 | Val F1: 0.5553 | F1 Illicit: 0.8861
# Epoch 029 | Loss: 0.2316 | Val Acc: 0.8035 | Val F1: 0.5593 | F1 Illicit: 0.8874
# Epoch 030 | Loss: 0.2302 | Val Acc: 0.8047 | Val F1: 0.5612 | F1 Illicit: 0.8881
# Epoch 031 | Loss: 0.2281 | Val Acc: 0.8057 | Val F1: 0.5625 | F1 Illicit: 0.8887
# Epoch 032 | Loss: 0.2270 | Val Acc: 0.8074 | Val F1: 0.5646 | F1 Illicit: 0.8897
# Epoch 033 | Loss: 0.2239 | Val Acc: 0.8074 | Val F1: 0.5647 | F1 Illicit: 0.8898
# Epoch 034 | Loss: 0.2230 | Val Acc: 0.8091 | Val F1: 0.5666 | F1 Illicit: 0.8908
# Epoch 035 | Loss: 0.2225 | Val Acc: 0.8098 | Val F1: 0.5673 | F1 Illicit: 0.8913
# Epoch 036 | Loss: 0.2207 | Val Acc: 0.8117 | Val F1: 0.5694 | F1 Illicit: 0.8924
# Epoch 037 | Loss: 0.2190 | Val Acc: 0.8124 | Val F1: 0.5704 | F1 Illicit: 0.8928
# Epoch 038 | Loss: 0.2171 | Val Acc: 0.8139 | Val F1: 0.5718 | F1 Illicit: 0.8938
# ...
# Epoch 104 | Loss: 0.1850 | Val Acc: 0.9277 | Val F1: 0.6692 | F1 Illicit: 0.9616
# Epoch 105 | Loss: 0.1877 | Val Acc: 0.9293 | Val F1: 0.6705 | F1 Illicit: 0.9625
# Epoch 106 | Loss: 0.1855 | Val Acc: 0.9299 | Val F1: 0.6692 | F1 Illicit: 0.9629
# Epoch 107 | Loss: 0.1832 | Val Acc: 0.9307 | Val F1: 0.6706 | F1 Illicit: 0.9633
# Epoch 108 | Loss: 0.1845 | Val Acc: 0.9313 | Val F1: 0.6719 | F1 Illicit: 0.9636
# Epoch 109 | Loss: 0.1842 | Val Acc: 0.9314 | Val F1: 0.6733 | F1 Illicit: 0.9637
# Epoch 110 | Loss: 0.1840 | Val Acc: 0.9319 | Val F1: 0.6749 | F1 Illicit: 0.9639
# Epoch 111 | Loss: 0.1810 | Val Acc: 0.9322 | Val F1: 0.6751 | F1 Illicit: 0.9641
# Epoch 112 | Loss: 0.1803 | Val Acc: 0.9329 | Val F1: 0.6756 | F1 Illicit: 0.9645
# Epoch 113 | Loss: 0.1805 | Val Acc: 0.9341 | Val F1: 0.6769 | F1 Illicit: 0.9652
# Epoch 114 | Loss: 0.1804 | Val Acc: 0.9350 | Val F1: 0.6772 | F1 Illicit: 0.9657
# Epoch 115 | Loss: 0.1780 | Val Acc: 0.9357 | Val F1: 0.6783 | F1 Illicit: 0.9660
# Epoch 116 | Loss: 0.1784 | Val Acc: 0.9357 | Val F1: 0.6783 | F1 Illicit: 0.9660
# Epoch 117 | Loss: 0.1791 | Val Acc: 0.9360 | Val F1: 0.6783 | F1 Illicit: 0.9662
# Epoch 118 | Loss: 0.1786 | Val Acc: 0.9367 | Val F1: 0.6808 | F1 Illicit: 0.9666
# Epoch 119 | Loss: 0.1752 | Val Acc: 0.9372 | Val F1: 0.6819 | F1 Illicit: 0.9669
# Epoch 120 | Loss: 0.1766 | Val Acc: 0.9374 | Val F1: 0.6829 | F1 Illicit: 0.9670
# Epoch 121 | Loss: 0.1789 | Val Acc: 0.9378 | Val F1: 0.6828 | F1 Illicit: 0.9672
# Epoch 122 | Loss: 0.1764 | Val Acc: 0.9384 | Val F1: 0.6826 | F1 Illicit: 0.9675
# Epoch 123 | Loss: 0.1782 | Val Acc: 0.9396 | Val F1: 0.6842 | F1 Illicit: 0.9682
# Epoch 124 | Loss: 0.1757 | Val Acc: 0.9396 | Val F1: 0.6838 | F1 Illicit: 0.9682
# Epoch 125 | Loss: 0.1720 | Val Acc: 0.9397 | Val F1: 0.6828 | F1 Illicit: 0.9682
# Epoch 126 | Loss: 0.1716 | Val Acc: 0.9391 | Val F1: 0.6828 | F1 Illicit: 0.9679
# Epoch 127 | Loss: 0.1716 | Val Acc: 0.9391 | Val F1: 0.6846 | F1 Illicit: 0.9679
# Epoch 128 | Loss: 0.1716 | Val Acc: 0.9392 | Val F1: 0.6849 | F1 Illicit: 0.9680
# Epoch 129 | Loss: 0.1699 | Val Acc: 0.9399 | Val F1: 0.6856 | F1 Illicit: 0.9683
# Epoch 130 | Loss: 0.1711 | Val Acc: 0.9405 | Val F1: 0.6863 | F1 Illicit: 0.9687
# Epoch 131 | Loss: 0.1703 | Val Acc: 0.9411 | Val F1: 0.6873 | F1 Illicit: 0.9690
# Epoch 132 | Loss: 0.1712 | Val Acc: 0.9414 | Val F1: 0.6872 | F1 Illicit: 0.9692
# Epoch 133 | Loss: 0.1689 | Val Acc: 0.9419 | Val F1: 0.6883 | F1 Illicit: 0.9694
# Epoch 134 | Loss: 0.1672 | Val Acc: 0.9424 | Val F1: 0.6899 | F1 Illicit: 0.9697
# Epoch 135 | Loss: 0.1690 | Val Acc: 0.9426 | Val F1: 0.6900 | F1 Illicit: 0.9698
# Epoch 136 | Loss: 0.1675 | Val Acc: 0.9427 | Val F1: 0.6891 | F1 Illicit: 0.9699
# Epoch 137 | Loss: 0.1653 | Val Acc: 0.9432 | Val F1: 0.6888 | F1 Illicit: 0.9702
# Epoch 138 | Loss: 0.1658 | Val Acc: 0.9433 | Val F1: 0.6885 | F1 Illicit: 0.9702
# Epoch 139 | Loss: 0.1663 | Val Acc: 0.9436 | Val F1: 0.6897 | F1 Illicit: 0.9704
# Epoch 140 | Loss: 0.1656 | Val Acc: 0.9434 | Val F1: 0.6880 | F1 Illicit: 0.9703
# Epoch 141 | Loss: 0.1642 | Val Acc: 0.9438 | Val F1: 0.6886 | F1 Illicit: 0.9705
# Epoch 142 | Loss: 0.1655 | Val Acc: 0.9442 | Val F1: 0.6890 | F1 Illicit: 0.9707
# Epoch 143 | Loss: 0.1633 | Val Acc: 0.9447 | Val F1: 0.6900 | F1 Illicit: 0.9710
# Epoch 144 | Loss: 0.1666 | Val Acc: 0.9449 | Val F1: 0.6895 | F1 Illicit: 0.9711
# Epoch 145 | Loss: 0.1617 | Val Acc: 0.9452 | Val F1: 0.6899 | F1 Illicit: 0.9713
# Epoch 146 | Loss: 0.1626 | Val Acc: 0.9453 | Val F1: 0.6902 | F1 Illicit: 0.9713
# Epoch 147 | Loss: 0.1618 | Val Acc: 0.9453 | Val F1: 0.6893 | F1 Illicit: 0.9713
# Epoch 148 | Loss: 0.1644 | Val Acc: 0.9457 | Val F1: 0.6906 | F1 Illicit: 0.9715
# Epoch 149 | Loss: 0.1603 | Val Acc: 0.9458 | Val F1: 0.6901 | F1 Illicit: 0.9716
# Epoch 150 | Loss: 0.1601 | Val Acc: 0.9460 | Val F1: 0.6897 | F1 Illicit: 0.9717
# Epoch 151 | Loss: 0.1602 | Val Acc: 0.9460 | Val F1: 0.6882 | F1 Illicit: 0.9717
# Epoch 152 | Loss: 0.1602 | Val Acc: 0.9466 | Val F1: 0.6891 | F1 Illicit: 0.9720
# Epoch 153 | Loss: 0.1596 | Val Acc: 0.9467 | Val F1: 0.6894 | F1 Illicit: 0.9721
# Epoch 154 | Loss: 0.1594 | Val Acc: 0.9468 | Val F1: 0.6900 | F1 Illicit: 0.9721
# Epoch 155 | Loss: 0.1588 | Val Acc: 0.9468 | Val F1: 0.6919 | F1 Illicit: 0.9722
# Epoch 156 | Loss: 0.1579 | Val Acc: 0.9463 | Val F1: 0.6922 | F1 Illicit: 0.9719
# Epoch 157 | Loss: 0.1587 | Val Acc: 0.9463 | Val F1: 0.6918 | F1 Illicit: 0.9719
# Epoch 158 | Loss: 0.1589 | Val Acc: 0.9469 | Val F1: 0.6924 | F1 Illicit: 0.9722
# Epoch 159 | Loss: 0.1569 | Val Acc: 0.9471 | Val F1: 0.6912 | F1 Illicit: 0.9723
# Epoch 160 | Loss: 0.1572 | Val Acc: 0.9470 | Val F1: 0.6894 | F1 Illicit: 0.9723
# Epoch 161 | Loss: 0.1574 | Val Acc: 0.9474 | Val F1: 0.6902 | F1 Illicit: 0.9725
# Epoch 162 | Loss: 0.1547 | Val Acc: 0.9472 | Val F1: 0.6890 | F1 Illicit: 0.9724
# Epoch 163 | Loss: 0.1528 | Val Acc: 0.9472 | Val F1: 0.6879 | F1 Illicit: 0.9724
# Epoch 164 | Loss: 0.1554 | Val Acc: 0.9470 | Val F1: 0.6870 | F1 Illicit: 0.9723
# Epoch 165 | Loss: 0.1544 | Val Acc: 0.9472 | Val F1: 0.6868 | F1 Illicit: 0.9724
# Epoch 166 | Loss: 0.1546 | Val Acc: 0.9471 | Val F1: 0.6851 | F1 Illicit: 0.9723
# Epoch 167 | Loss: 0.1519 | Val Acc: 0.9472 | Val F1: 0.6846 | F1 Illicit: 0.9724
# Epoch 168 | Loss: 0.1530 | Val Acc: 0.9477 | Val F1: 0.6853 | F1 Illicit: 0.9727
# Epoch 169 | Loss: 0.1541 | Val Acc: 0.9476 | Val F1: 0.6869 | F1 Illicit: 0.9726
# Epoch 170 | Loss: 0.1524 | Val Acc: 0.9477 | Val F1: 0.6899 | F1 Illicit: 0.9727
# Epoch 171 | Loss: 0.1537 | Val Acc: 0.9476 | Val F1: 0.6900 | F1 Illicit: 0.9726
# Epoch 172 | Loss: 0.1508 | Val Acc: 0.9477 | Val F1: 0.6902 | F1 Illicit: 0.9726
# Epoch 173 | Loss: 0.1532 | Val Acc: 0.9479 | Val F1: 0.6885 | F1 Illicit: 0.9727
# Epoch 174 | Loss: 0.1516 | Val Acc: 0.9481 | Val F1: 0.6867 | F1 Illicit: 0.9729
# Epoch 175 | Loss: 0.1510 | Val Acc: 0.9483 | Val F1: 0.6863 | F1 Illicit: 0.9730
# Epoch 176 | Loss: 0.1508 | Val Acc: 0.9481 | Val F1: 0.6849 | F1 Illicit: 0.9729
# Epoch 177 | Loss: 0.1508 | Val Acc: 0.9481 | Val F1: 0.6858 | F1 Illicit: 0.9729
# Epoch 178 | Loss: 0.1497 | Val Acc: 0.9482 | Val F1: 0.6866 | F1 Illicit: 0.9729
# Epoch 179 | Loss: 0.1503 | Val Acc: 0.9481 | Val F1: 0.6869 | F1 Illicit: 0.9729
# Epoch 180 | Loss: 0.1511 | Val Acc: 0.9482 | Val F1: 0.6875 | F1 Illicit: 0.9729
# Epoch 181 | Loss: 0.1487 | Val Acc: 0.9483 | Val F1: 0.6865 | F1 Illicit: 0.9730
# Epoch 182 | Loss: 0.1479 | Val Acc: 0.9484 | Val F1: 0.6871 | F1 Illicit: 0.9730
# Epoch 183 | Loss: 0.1480 | Val Acc: 0.9485 | Val F1: 0.6884 | F1 Illicit: 0.9731
# Epoch 184 | Loss: 0.1496 | Val Acc: 0.9485 | Val F1: 0.6886 | F1 Illicit: 0.9731
# Epoch 185 | Loss: 0.1477 | Val Acc: 0.9485 | Val F1: 0.6888 | F1 Illicit: 0.9731
# Epoch 186 | Loss: 0.1466 | Val Acc: 0.9489 | Val F1: 0.6883 | F1 Illicit: 0.9733
# Epoch 187 | Loss: 0.1470 | Val Acc: 0.9490 | Val F1: 0.6873 | F1 Illicit: 0.9734
# Epoch 188 | Loss: 0.1450 | Val Acc: 0.9493 | Val F1: 0.6877 | F1 Illicit: 0.9735
# Epoch 189 | Loss: 0.1451 | Val Acc: 0.9493 | Val F1: 0.6886 | F1 Illicit: 0.9735
# Epoch 190 | Loss: 0.1454 | Val Acc: 0.9492 | Val F1: 0.6898 | F1 Illicit: 0.9735
# Epoch 191 | Loss: 0.1464 | Val Acc: 0.9493 | Val F1: 0.6918 | F1 Illicit: 0.9735
# Epoch 192 | Loss: 0.1458 | Val Acc: 0.9494 | Val F1: 0.6919 | F1 Illicit: 0.9736
# Epoch 193 | Loss: 0.1451 | Val Acc: 0.9492 | Val F1: 0.6916 | F1 Illicit: 0.9735
# Epoch 194 | Loss: 0.1464 | Val Acc: 0.9494 | Val F1: 0.6930 | F1 Illicit: 0.9736
# Epoch 195 | Loss: 0.1459 | Val Acc: 0.9493 | Val F1: 0.6927 | F1 Illicit: 0.9735
# Epoch 196 | Loss: 0.1433 | Val Acc: 0.9492 | Val F1: 0.6941 | F1 Illicit: 0.9734
# Epoch 197 | Loss: 0.1435 | Val Acc: 0.9492 | Val F1: 0.6956 | F1 Illicit: 0.9735
# Epoch 198 | Loss: 0.1441 | Val Acc: 0.9493 | Val F1: 0.6949 | F1 Illicit: 0.9735
# Epoch 199 | Loss: 0.1436 | Val Acc: 0.9495 | Val F1: 0.6936 | F1 Illicit: 0.9736
# Epoch 200 | Loss: 0.1439 | Val Acc: 0.9491 | Val F1: 0.6884 | F1 Illicit: 0.9734
# Epoch 201 | Loss: 0.1426 | Val Acc: 0.9488 | Val F1: 0.6863 | F1 Illicit: 0.9733
# Epoch 202 | Loss: 0.1422 | Val Acc: 0.9489 | Val F1: 0.6871 | F1 Illicit: 0.9733
# Epoch 203 | Loss: 0.1428 | Val Acc: 0.9489 | Val F1: 0.6867 | F1 Illicit: 0.9733
# Epoch 204 | Loss: 0.1424 | Val Acc: 0.9487 | Val F1: 0.6866 | F1 Illicit: 0.9732
# Epoch 205 | Loss: 0.1420 | Val Acc: 0.9487 | Val F1: 0.6874 | F1 Illicit: 0.9732
# Epoch 206 | Loss: 0.1420 | Val Acc: 0.9489 | Val F1: 0.6903 | F1 Illicit: 0.9733
# Epoch 207 | Loss: 0.1427 | Val Acc: 0.9492 | Val F1: 0.6923 | F1 Illicit: 0.9734
# Epoch 208 | Loss: 0.1411 | Val Acc: 0.9491 | Val F1: 0.6904 | F1 Illicit: 0.9734
# Epoch 209 | Loss: 0.1405 | Val Acc: 0.9492 | Val F1: 0.6887 | F1 Illicit: 0.9735
# Epoch 210 | Loss: 0.1409 | Val Acc: 0.9492 | Val F1: 0.6880 | F1 Illicit: 0.9735
# Epoch 211 | Loss: 0.1408 | Val Acc: 0.9494 | Val F1: 0.6883 | F1 Illicit: 0.9736
# Epoch 212 | Loss: 0.1397 | Val Acc: 0.9496 | Val F1: 0.6888 | F1 Illicit: 0.9737
# Epoch 213 | Loss: 0.1400 | Val Acc: 0.9495 | Val F1: 0.6887 | F1 Illicit: 0.9736
# Epoch 214 | Loss: 0.1394 | Val Acc: 0.9495 | Val F1: 0.6882 | F1 Illicit: 0.9736
# Epoch 215 | Loss: 0.1389 | Val Acc: 0.9496 | Val F1: 0.6888 | F1 Illicit: 0.9737
# Epoch 216 | Loss: 0.1403 | Val Acc: 0.9496 | Val F1: 0.6926 | F1 Illicit: 0.9737
# Epoch 217 | Loss: 0.1386 | Val Acc: 0.9494 | Val F1: 0.6928 | F1 Illicit: 0.9735
# Epoch 218 | Loss: 0.1391 | Val Acc: 0.9491 | Val F1: 0.6926 | F1 Illicit: 0.9734
# Epoch 219 | Loss: 0.1378 | Val Acc: 0.9491 | Val F1: 0.6933 | F1 Illicit: 0.9734
# Epoch 220 | Loss: 0.1387 | Val Acc: 0.9492 | Val F1: 0.6943 | F1 Illicit: 0.9735
# Epoch 221 | Loss: 0.1374 | Val Acc: 0.9494 | Val F1: 0.6942 | F1 Illicit: 0.9735
# Epoch 222 | Loss: 0.1379 | Val Acc: 0.9494 | Val F1: 0.6933 | F1 Illicit: 0.9735
# Epoch 223 | Loss: 0.1378 | Val Acc: 0.9495 | Val F1: 0.6923 | F1 Illicit: 0.9736
# Epoch 224 | Loss: 0.1370 | Val Acc: 0.9491 | Val F1: 0.6876 | F1 Illicit: 0.9734
# Epoch 225 | Loss: 0.1366 | Val Acc: 0.9494 | Val F1: 0.6879 | F1 Illicit: 0.9736
# Epoch 226 | Loss: 0.1372 | Val Acc: 0.9497 | Val F1: 0.6906 | F1 Illicit: 0.9737
# Epoch 227 | Loss: 0.1364 | Val Acc: 0.9499 | Val F1: 0.6938 | F1 Illicit: 0.9738
# Epoch 228 | Loss: 0.1355 | Val Acc: 0.9500 | Val F1: 0.6949 | F1 Illicit: 0.9739
# Epoch 229 | Loss: 0.1366 | Val Acc: 0.9502 | Val F1: 0.6954 | F1 Illicit: 0.9740
# Epoch 230 | Loss: 0.1353 | Val Acc: 0.9498 | Val F1: 0.6912 | F1 Illicit: 0.9738
# Epoch 231 | Loss: 0.1351 | Val Acc: 0.9497 | Val F1: 0.6901 | F1 Illicit: 0.9737
# Epoch 232 | Loss: 0.1352 | Val Acc: 0.9496 | Val F1: 0.6907 | F1 Illicit: 0.9737
# Epoch 233 | Loss: 0.1354 | Val Acc: 0.9494 | Val F1: 0.6919 | F1 Illicit: 0.9736
# Epoch 234 | Loss: 0.1348 | Val Acc: 0.9494 | Val F1: 0.6933 | F1 Illicit: 0.9735
# Epoch 235 | Loss: 0.1342 | Val Acc: 0.9492 | Val F1: 0.6929 | F1 Illicit: 0.9735
# Epoch 236 | Loss: 0.1348 | Val Acc: 0.9492 | Val F1: 0.6943 | F1 Illicit: 0.9735
# Epoch 237 | Loss: 0.1324 | Val Acc: 0.9492 | Val F1: 0.6947 | F1 Illicit: 0.9735
# Epoch 238 | Loss: 0.1337 | Val Acc: 0.9492 | Val F1: 0.6941 | F1 Illicit: 0.9734
# Epoch 239 | Loss: 0.1342 | Val Acc: 0.9489 | Val F1: 0.6928 | F1 Illicit: 0.9733
# Epoch 240 | Loss: 0.1329 | Val Acc: 0.9489 | Val F1: 0.6950 | F1 Illicit: 0.9733
# Epoch 241 | Loss: 0.1339 | Val Acc: 0.9491 | Val F1: 0.6974 | F1 Illicit: 0.9734
# Epoch 242 | Loss: 0.1335 | Val Acc: 0.9491 | Val F1: 0.6963 | F1 Illicit: 0.9734
# Epoch 243 | Loss: 0.1332 | Val Acc: 0.9492 | Val F1: 0.6945 | F1 Illicit: 0.9734
# Epoch 244 | Loss: 0.1329 | Val Acc: 0.9492 | Val F1: 0.6923 | F1 Illicit: 0.9734
# Epoch 245 | Loss: 0.1315 | Val Acc: 0.9493 | Val F1: 0.6922 | F1 Illicit: 0.9735
# Epoch 246 | Loss: 0.1303 | Val Acc: 0.9494 | Val F1: 0.6930 | F1 Illicit: 0.9736
# Epoch 247 | Loss: 0.1322 | Val Acc: 0.9496 | Val F1: 0.6956 | F1 Illicit: 0.9736
# Epoch 248 | Loss: 0.1305 | Val Acc: 0.9495 | Val F1: 0.6967 | F1 Illicit: 0.9736
# Epoch 249 | Loss: 0.1317 | Val Acc: 0.9497 | Val F1: 0.6972 | F1 Illicit: 0.9737
# Epoch 250 | Loss: 0.1321 | Val Acc: 0.9504 | Val F1: 0.6986 | F1 Illicit: 0.9741
# Epoch 251 | Loss: 0.1298 | Val Acc: 0.9500 | Val F1: 0.6977 | F1 Illicit: 0.9739
# Epoch 252 | Loss: 0.1312 | Val Acc: 0.9501 | Val F1: 0.6987 | F1 Illicit: 0.9739
# Epoch 253 | Loss: 0.1301 | Val Acc: 0.9499 | Val F1: 0.6986 | F1 Illicit: 0.9738
# Epoch 254 | Loss: 0.1288 | Val Acc: 0.9497 | Val F1: 0.6981 | F1 Illicit: 0.9737
# Epoch 255 | Loss: 0.1299 | Val Acc: 0.9498 | Val F1: 0.6984 | F1 Illicit: 0.9738
# Epoch 256 | Loss: 0.1297 | Val Acc: 0.9495 | Val F1: 0.6941 | F1 Illicit: 0.9736
# Epoch 257 | Loss: 0.1297 | Val Acc: 0.9498 | Val F1: 0.6945 | F1 Illicit: 0.9738
# Epoch 258 | Loss: 0.1297 | Val Acc: 0.9496 | Val F1: 0.6957 | F1 Illicit: 0.9737
# Epoch 259 | Loss: 0.1300 | Val Acc: 0.9494 | Val F1: 0.6968 | F1 Illicit: 0.9735
# Epoch 260 | Loss: 0.1297 | Val Acc: 0.9498 | Val F1: 0.6993 | F1 Illicit: 0.9738
# Epoch 261 | Loss: 0.1293 | Val Acc: 0.9500 | Val F1: 0.7003 | F1 Illicit: 0.9739
# Epoch 262 | Loss: 0.1290 | Val Acc: 0.9501 | Val F1: 0.6996 | F1 Illicit: 0.9739
# Epoch 263 | Loss: 0.1282 | Val Acc: 0.9502 | Val F1: 0.7002 | F1 Illicit: 0.9739
# Epoch 264 | Loss: 0.1295 | Val Acc: 0.9505 | Val F1: 0.7015 | F1 Illicit: 0.9741
# Epoch 265 | Loss: 0.1278 | Val Acc: 0.9504 | Val F1: 0.7007 | F1 Illicit: 0.9741
# Epoch 266 | Loss: 0.1282 | Val Acc: 0.9504 | Val F1: 0.7013 | F1 Illicit: 0.9741
# Epoch 267 | Loss: 0.1271 | Val Acc: 0.9502 | Val F1: 0.7012 | F1 Illicit: 0.9740
# Epoch 268 | Loss: 0.1278 | Val Acc: 0.9502 | Val F1: 0.7010 | F1 Illicit: 0.9739
# Epoch 269 | Loss: 0.1283 | Val Acc: 0.9499 | Val F1: 0.7012 | F1 Illicit: 0.9738
# Epoch 270 | Loss: 0.1265 | Val Acc: 0.9494 | Val F1: 0.6995 | F1 Illicit: 0.9736
# Epoch 271 | Loss: 0.1262 | Val Acc: 0.9494 | Val F1: 0.7008 | F1 Illicit: 0.9736
# Epoch 272 | Loss: 0.1277 | Val Acc: 0.9491 | Val F1: 0.7003 | F1 Illicit: 0.9734
# Epoch 273 | Loss: 0.1261 | Val Acc: 0.9492 | Val F1: 0.7011 | F1 Illicit: 0.9734
# Epoch 274 | Loss: 0.1253 | Val Acc: 0.9494 | Val F1: 0.7019 | F1 Illicit: 0.9735
# Epoch 275 | Loss: 0.1267 | Val Acc: 0.9496 | Val F1: 0.7038 | F1 Illicit: 0.9736
# Epoch 276 | Loss: 0.1247 | Val Acc: 0.9500 | Val F1: 0.7045 | F1 Illicit: 0.9739
# Epoch 277 | Loss: 0.1246 | Val Acc: 0.9499 | Val F1: 0.7041 | F1 Illicit: 0.9738
# Epoch 278 | Loss: 0.1261 | Val Acc: 0.9499 | Val F1: 0.7041 | F1 Illicit: 0.9738
# Epoch 279 | Loss: 0.1250 | Val Acc: 0.9502 | Val F1: 0.7053 | F1 Illicit: 0.9739
# Epoch 280 | Loss: 0.1252 | Val Acc: 0.9500 | Val F1: 0.7049 | F1 Illicit: 0.9739
# Epoch 281 | Loss: 0.1241 | Val Acc: 0.9501 | Val F1: 0.7059 | F1 Illicit: 0.9739
# Epoch 282 | Loss: 0.1256 | Val Acc: 0.9499 | Val F1: 0.7054 | F1 Illicit: 0.9738
# Epoch 283 | Loss: 0.1246 | Val Acc: 0.9506 | Val F1: 0.7061 | F1 Illicit: 0.9742
# Epoch 284 | Loss: 0.1250 | Val Acc: 0.9511 | Val F1: 0.7065 | F1 Illicit: 0.9744
# Epoch 285 | Loss: 0.1233 | Val Acc: 0.9504 | Val F1: 0.7051 | F1 Illicit: 0.9741
# Epoch 286 | Loss: 0.1238 | Val Acc: 0.9501 | Val F1: 0.7071 | F1 Illicit: 0.9739
# Epoch 287 | Loss: 0.1241 | Val Acc: 0.9500 | Val F1: 0.7065 | F1 Illicit: 0.9738
# Epoch 288 | Loss: 0.1238 | Val Acc: 0.9500 | Val F1: 0.7064 | F1 Illicit: 0.9738
# Epoch 289 | Loss: 0.1236 | Val Acc: 0.9498 | Val F1: 0.7044 | F1 Illicit: 0.9738
# Epoch 290 | Loss: 0.1238 | Val Acc: 0.9502 | Val F1: 0.7048 | F1 Illicit: 0.9739
# Epoch 291 | Loss: 0.1229 | Val Acc: 0.9496 | Val F1: 0.7034 | F1 Illicit: 0.9736
# Epoch 292 | Loss: 0.1222 | Val Acc: 0.9500 | Val F1: 0.7065 | F1 Illicit: 0.9738
# Epoch 293 | Loss: 0.1226 | Val Acc: 0.9501 | Val F1: 0.7047 | F1 Illicit: 0.9739
# Epoch 294 | Loss: 0.1221 | Val Acc: 0.9506 | Val F1: 0.7042 | F1 Illicit: 0.9741
# Epoch 295 | Loss: 0.1219 | Val Acc: 0.9506 | Val F1: 0.7053 | F1 Illicit: 0.9742
# Epoch 296 | Loss: 0.1214 | Val Acc: 0.9502 | Val F1: 0.7073 | F1 Illicit: 0.9739
# Epoch 297 | Loss: 0.1220 | Val Acc: 0.9498 | Val F1: 0.7075 | F1 Illicit: 0.9737
# Epoch 298 | Loss: 0.1216 | Val Acc: 0.9502 | Val F1: 0.7087 | F1 Illicit: 0.9739
# Epoch 299 | Loss: 0.1206 | Val Acc: 0.9506 | Val F1: 0.7072 | F1 Illicit: 0.9741
# Epoch 300 | Loss: 0.1226 | Val Acc: 0.9506 | Val F1: 0.7065 | F1 Illicit: 0.9742

# %% [markdown]
# ## 4. Evaluation

# %%
import os
import json
import torch

base_dir = "../model_features/temporal/GCN_ablation"
data_dir = "../data/GCN_temporal"
seeds = [42, 123, 777, 2023, 31415]

for ablation in sorted(os.listdir(base_dir)):
    ablation_model_path = os.path.join(base_dir, ablation)
    ablation_data_path = os.path.join(data_dir, ablation)

    if not os.path.isdir(ablation_model_path):
        continue

    print(f"\n→ Processing ablation: {ablation}")

    for seed in seeds:
        seed_dir = f"seed_{seed}"
        config_path = os.path.join(ablation_model_path, seed_dir, "config.json")
        model_path = os.path.join(ablation_model_path, seed_dir, "model.pth")
        data_path = os.path.join(ablation_data_path, seed_dir, "data_exp.pt")

        if not all(os.path.exists(p) for p in [config_path, model_path, data_path]):
            continue

        with open(config_path, "r") as f:
            config = json.load(f)

        updated = False
        data = torch.load(data_path, map_location="cpu", weights_only=False)
        feature_dim = data.x.shape[1]

        if config.get("feature_dim") != feature_dim:
            config["feature_dim"] = feature_dim
            updated = True

        if config.get("model") == "GCN":
            if config.get("hidden_channels") != 64:
                config["hidden_channels"] = 64
                updated = True
            if config.get("out_channels") != 2:
                config["out_channels"] = 2
                updated = True
            if config.get("dropout") != 0.1:
                config["dropout"] = 0.1
                updated = True

        if updated:
            with open(config_path, "w") as f:
                json.dump(config, f, indent=4)
            print(f"✓ Patched config for {ablation} / seed {seed}")
        else:
            print(f"✓ Already complete: {ablation} / seed {seed}")
# Out:
# → Processing ablation: all
# ✓ Patched config for all / seed 42
# ✓ Patched config for all / seed 123
# ✓ Patched config for all / seed 777
# ✓ Patched config for all / seed 2023
# ✓ Patched config for all / seed 31415
#
# → Processing ablation: base
# ✓ Patched config for base / seed 42
# ✓ Patched config for base / seed 123
# ✓ Patched config for base / seed 777
# ✓ Patched config for base / seed 2023
# ✓ Patched config for base / seed 31415
#
# → Processing ablation: base+basic_temporal
# ✓ Patched config for base+basic_temporal / seed 42
# ✓ Patched config for base+basic_temporal / seed 123
# ✓ Patched config for base+basic_temporal / seed 777
# ✓ Patched config for base+basic_temporal / seed 2023
# ✓ Patched config for base+basic_temporal / seed 31415
#
# → Processing ablation: base+basic_temporal+typology
# ✓ Patched config for base+basic_temporal+typology / seed 42
# ✓ Patched config for base+basic_temporal+typology / seed 123
# ✓ Patched config for base+basic_temporal+typology / seed 777
# ✓ Patched config for base+basic_temporal+typology / seed 2023
# ✓ Patched config for base+basic_temporal+typology / seed 31415
#
# → Processing ablation: base+structural
# ✓ Patched config for base+structural / seed 42
# ✓ Patched config for base+structural / seed 123
# ✓ Patched config for base+structural / seed 777
# ✓ Patched config for base+structural / seed 2023
# ✓ Patched config for base+structural / seed 31415
#
# → Processing ablation: base+structural+typology
# ✓ Patched config for base+structural+typology / seed 42
# ✓ Patched config for base+structural+typology / seed 123
# ✓ Patched config for base+structural+typology / seed 777
# ✓ Patched config for base+structural+typology / seed 2023
# ✓ Patched config for base+structural+typology / seed 31415
#
# → Processing ablation: base+typology
# ✓ Patched config for base+typology / seed 42
# ✓ Patched config for base+typology / seed 123
# ✓ Patched config for base+typology / seed 777
# ✓ Patched config for base+typology / seed 2023
# ✓ Patched config for base+typology / seed 31415

# %%
import os
from features.evaluate_ablation_model import evaluate_ablation_model
from evaluation_pipeline import run_inference_all_seeds
from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
from features.feature_utils import make_model_class_from_config

# === Config ===
seeds = [42, 123, 777, 2023, 31415]
base_dir = "../model_features/temporal/GCN_ablation"
data_exp_root = "../data/GCN_temporal"
node_id_csv_path = "../elliptic_bitcoin_dataset/elliptic_txs_features.csv"

model_tag = "GCN-Temporal"
split = "temporal"

# === Evaluate all ablations ===
for ablation in sorted(os.listdir(base_dir)):
    model_dir = os.path.join(base_dir, ablation)
    if not os.path.isdir(model_dir):
        continue

    print(f"\n→ Evaluating ablation: {ablation}")
    model_name = f"{model_tag}: {ablation}"
    ablation_data_dir = os.path.join(data_exp_root, ablation)
    config_path = os.path.join(model_dir, "seed_42", "config.json")
    model_class = make_model_class_from_config(config_path)

    # Run full evaluation
    evaluate_ablation_model(
        model_dir=model_dir,
        model_class=model_class,
        model_name=model_name,
        seeds=seeds,
        node_id_csv_path=node_id_csv_path,
        data_dir=ablation_data_dir
    )

    # Run inference (for logging CSV)
    y_true_all, y_pred_all, y_proba_all, seed_metrics = run_inference_all_seeds(
        model_dir=model_dir,
        model_class=model_class,
        data_dir=ablation_data_dir,
        seeds=seeds
    )
    val_acc_list = load_metrics_across_seeds(model_dir, ["val_acc"])["val_acc"]

    # Save to CSV
    log_metrics_to_csv(
        model_name=model_tag,
        split_name=split,
        ablation=ablation,
        seeds=seeds,
        val_acc_list=val_acc_list,
        seed_metrics=seed_metrics,
        is_feature=True  # append _feature to filename
    )
