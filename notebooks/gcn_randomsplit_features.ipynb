# %% [markdown]
# ## 1. Environment Setup and Imports
# Ensure we're using the correct kernel and loading utils from the `src/` directory. Now we also load features.

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# Torch & GNN
import torch
from torch_geometric.nn import GCNConv

# Custom modules
from load_elliptic_data import load_and_preprocess_elliptic_data
from data_utils_randomsplit import random_split
from model_gcn import GCNNet
from train_utils import set_seed, train_full, save_feature_experiment
from config import SEEDS

# Feature pipeline
from features.feature_config import FEATURE_CONFIGS
from features.feature_runner import apply_engineered_features
from features.feature_utils import prepare_graph_and_timestamps
from normalization import normalize_base_features_only

print("✓ All modules imported successfully.")
# Out:
# ✓ All modules imported successfully.

# %% [markdown]
# ## 2. Load and Preprocess the Elliptic Dataset + Graph for Features + Time Stamps
# This loads the PyG-formatted graph and base features. We also construct a NetworkX transaction graph for topology-based features. Per-node timestamp sequences is extracted for temporal burst analysis

# %%
from normalization import normalize_base_features_only
from features.feature_pipeline import generate_all_features
import os
import torch

# 1. Load graph
data = load_and_preprocess_elliptic_data("../elliptic_bitcoin_dataset", normalize=False)
print(f"✓ PyG Data object loaded: {data}")

# 2. Prepare NetworkX and timestamps
G_nx, node_timestamps = prepare_graph_and_timestamps(
    edgelist_path="../elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv",
    features_path="../elliptic_bitcoin_dataset/elliptic_txs_features.csv",
    num_nodes=data.num_nodes
)

# 3. Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ABLATORS = {k: v for k, v in FEATURE_CONFIGS.items()}
FEATURED_DATA = {}

# 4. Loop through ablations and seeds
for ablation_name, feature_flags in ABLATORS.items():
    print(f"\n== Config: {ablation_name} ==")
    for seed in SEEDS:
        print(f"→ Seed {seed}")
        set_seed(seed)
        train_idx, val_idx = random_split(data, random_state=seed)

        # Clone and extract features
        data_exp = data.clone()
        X, feature_names = generate_all_features(data_exp, G_nx, node_timestamps, **feature_flags)
        data_exp.x = torch.tensor(X, dtype=torch.float)

        # Optional monitoring of temporal features
        temporal_names = {"temporal_lag", "component_size"}
        temporal_indices = [i for i, name in enumerate(feature_names) if name in temporal_names]

        if temporal_indices:
            print("→ Temporal features (raw)")
            print("  Means:", data_exp.x[:, temporal_indices].mean(0))
            print("  Stds :", data_exp.x[:, temporal_indices].std(0))

        # Normalize base features only
        data_exp.x = normalize_base_features_only(data_exp.x, feature_names)

        # Move to device
        data_exp = data_exp.to(device)

        # Store in memory
        FEATURED_DATA[(ablation_name, seed)] = {
            "data": data_exp,
            "train_idx": train_idx,
            "val_idx": val_idx,
            "feature_flags": feature_flags,
        }

        # Save to disk
        save_dir = f"../data/GCN_randomsplit/{ablation_name}/seed_{seed}"
        os.makedirs(save_dir, exist_ok=True)
        torch.save(data_exp, os.path.join(save_dir, "data_exp.pt"))
        torch.save(train_idx, os.path.join(save_dir, "train_idx.pt"))
        torch.save(val_idx, os.path.join(save_dir, "val_idx.pt"))
        print(f"✓ Saved: {save_dir}")
        print(f"✓ Final shape: {data_exp.x.shape}")
# Out:
# ✓ PyG Data object loaded: Data(x=[203769, 166], edge_index=[2, 234355], y=[203769])
# Loaded directed graph with 203769 nodes and 234355 edges.
# Graph type: <class 'networkx.classes.digraph.DiGraph'>
# Features DataFrame shape: (203769, 167)
# Number of features (excluding txId and time_step): 165
# Timestamps found for 203769 out of 203769 nodes.
# ✓ Time step range: 1.0 to 49.0
#
# == Config: base ==
# → Seed 42
# ✓ Saved: ../data/GCN_randomsplit/base/seed_42
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 123
# ✓ Saved: ../data/GCN_randomsplit/base/seed_123
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 777
# ✓ Saved: ../data/GCN_randomsplit/base/seed_777
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 2023
# ✓ Saved: ../data/GCN_randomsplit/base/seed_2023
# ✓ Final shape: torch.Size([203769, 166])
# → Seed 31415
# ✓ Saved: ../data/GCN_randomsplit/base/seed_31415
# ✓ Final shape: torch.Size([203769, 166])
#
# == Config: base+structural ==
# → Seed 42
# ✓ Saved: ../data/GCN_randomsplit/base+structural/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# ✓ Saved: ../data/GCN_randomsplit/base+structural/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# ✓ Saved: ../data/GCN_randomsplit/base+structural/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# ✓ Saved: ../data/GCN_randomsplit/base+structural/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# ✓ Saved: ../data/GCN_randomsplit/base+structural/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: base+typology ==
# → Seed 42
# ✓ Saved: ../data/GCN_randomsplit/base+typology/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# ✓ Saved: ../data/GCN_randomsplit/base+typology/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# ✓ Saved: ../data/GCN_randomsplit/base+typology/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# ✓ Saved: ../data/GCN_randomsplit/base+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# ✓ Saved: ../data/GCN_randomsplit/base+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+structural+typology ==
# → Seed 42
# ✓ Saved: ../data/GCN_randomsplit/base+structural+typology/seed_42
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 123
# ✓ Saved: ../data/GCN_randomsplit/base+structural+typology/seed_123
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 777
# ✓ Saved: ../data/GCN_randomsplit/base+structural+typology/seed_777
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 2023
# ✓ Saved: ../data/GCN_randomsplit/base+structural+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 172])
# → Seed 31415
# ✓ Saved: ../data/GCN_randomsplit/base+structural+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 172])
#
# == Config: base+basic_temporal ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 559476.11it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal/seed_42
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 494074.38it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal/seed_123
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 533264.32it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal/seed_777
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 488059.68it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal/seed_2023
# ✓ Final shape: torch.Size([203769, 168])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 494281.83it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal/seed_31415
# ✓ Final shape: torch.Size([203769, 168])
#
# == Config: base+basic_temporal+typology ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 491594.86it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal+typology/seed_42
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 548529.74it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal+typology/seed_123
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 510696.59it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal+typology/seed_777
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 565579.80it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal+typology/seed_2023
# ✓ Final shape: torch.Size([203769, 170])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 539427.63it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/base+basic_temporal+typology/seed_31415
# ✓ Final shape: torch.Size([203769, 170])
#
# == Config: all ==
# → Seed 42
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 564008.49it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/all/seed_42
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 123
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 543380.55it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/all/seed_123
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 777
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 536657.63it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/all/seed_777
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 2023
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 563840.30it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/all/seed_2023
# ✓ Final shape: torch.Size([203769, 174])
# → Seed 31415
# Computing temporal features: 100%|██████████| 203769/203769 [00:00<00:00, 537219.28it/s]
# → Temporal features (raw)
#   Means: tensor([25.1560])
#   Stds : tensor([15.1722])
# ✓ Saved: ../data/GCN_randomsplit/all/seed_31415
# ✓ Final shape: torch.Size([203769, 174])

# %%
import torch
import os

ROOT_DIR = "../data/GCN_randomsplit"
BASE_DIM = 166
SEEDS = [42, 123, 777, 2023, 31415]

print("\n📊 ENGINEERED FEATURE INSPECTION (from disk)")

# Loop over ablation folders
for ablation_name in sorted(os.listdir(ROOT_DIR)):
    ablation_path = os.path.join(ROOT_DIR, ablation_name)
    if not os.path.isdir(ablation_path):
        continue

    for seed in SEEDS:
        seed_dir = f"seed_{seed}"
        data_path = os.path.join(ablation_path, seed_dir, "data_exp.pt")
        if not os.path.exists(data_path):
            print(f"⛔ Missing file: {data_path}")
            continue

        data = torch.load(data_path, map_location="cpu", weights_only=False)
        x = data.x

        if x.shape[1] <= BASE_DIM:
            print(f"\n {ablation_name} | Seed: {seed}")
            print(" No engineered features found.")
            continue

        engineered = x[:, BASE_DIM:]
        print(f"\n {ablation_name} | Seed: {seed}")
        print(f" Engineered feature count: {engineered.shape[1]}")

        means = engineered.mean(dim=0)
        stds = engineered.std(dim=0)

        for i in range(engineered.shape[1]):
            m = means[i].item()
            s = stds[i].item()
            sample_vals = engineered[:5, i].numpy()
            print(f"Feature {BASE_DIM + i:>3} | Mean: {m:8.4f} | Std: {s:8.4f} | Sample: {sample_vals}")
# Out:
# 📊 ENGINEERED FEATURE INSPECTION (from disk)
#
#  all | Seed: 42
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 123
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 777
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 2023
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  all | Seed: 31415
#  Engineered feature count: 8
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 172 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 173 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 167 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+basic_temporal+typology | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
# Feature 168 | Mean:  25.1560 | Std:  15.1722 | Sample: [ 1. 43. 15. 48.  1.]
# Feature 169 | Mean:   8.4067 | Std:   0.3653 | Sample: [7.991254  8.373092  7.8188324 8.97221   7.991254 ]
#
#  base+structural | Seed: 42
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 123
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 777
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 2023
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural | Seed: 31415
#  Engineered feature count: 4
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
#
#  base+structural+typology | Seed: 42
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 123
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 777
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 2023
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+structural+typology | Seed: 31415
#  Engineered feature count: 6
# Feature 166 | Mean:   1.1501 | Std:   3.9111 | Sample: [1. 0. 1. 1. 0.]
# Feature 167 | Mean:   1.1501 | Std:   1.8947 | Sample: [  1.   3. 112.   0.  50.]
# Feature 168 | Mean:   0.0000 | Std:   4.3634 | Sample: [   0.   -3. -111.    1.  -50.]
# Feature 169 | Mean:   0.0138 | Std:   0.0973 | Sample: [0.         0.         0.00063211 0.         0.        ]
# Feature 170 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 171 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 42
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 123
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 777
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 2023
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]
#
#  base+typology | Seed: 31415
#  Engineered feature count: 2
# Feature 166 | Mean:   4.2315 | Std:   6.0100 | Sample: [ 0.6931467 14.914124   4.727387   0.        17.727533 ]
# Feature 167 | Mean:   0.4457 | Std:   0.3437 | Sample: [0.49999976 0.         0.00884956 0.999999   0.        ]

# %% [markdown]
# ## 3. Initialize the GCN Model and Training
# Set hyperparameters and move model/data to GPU/CPU if available.

# %%
from model_gcn import GCNNet
from train_utils import train_full, save_feature_experiment
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SKIP_CONFIGS = {
    "base+structural",
    "base+typology",
    "base+structural+typology",
    "base"
}

for (ablation_name, seed), bundle in FEATURED_DATA.items():
    if ablation_name in SKIP_CONFIGS:
        print(f"Skipping config: {ablation_name}")
        continue
    print(f"\n=== Training GCN (Random, No Class Weights): {ablation_name} | Seed: {seed} ===")

    data_exp = bundle["data"]
    train_idx = bundle["train_idx"]
    val_idx = bundle["val_idx"]
    feature_flags = bundle["feature_flags"]

    # 1. Initialize model
    model = GCNNet(
        in_channels=data_exp.x.shape[1],
        hidden_channels=64,
        out_channels=2,
        dropout=0.1
    ).to(device)

    # 2. Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # 3. Train model (use default loss)
    model, *results = train_full(
        model=model,
        data=data_exp,
        train_idx=train_idx,
        val_idx=val_idx,
        optimizer=optimizer,
        num_epochs=300,
        patience=30
        # no loss_fn passed → default to CrossEntropyLoss()
    )

    # 4. Save model and results
    output_dir = f"../model_features/randomsplit/GCN_ablation/{ablation_name}/seed_{seed}"
    os.makedirs(output_dir, exist_ok=True)

    save_feature_experiment(
        output_dir=output_dir,
        model=model,
        results=results,
        seed=seed,
        config={
            "model": "GCN",
            "ablation_name": ablation_name,
            "feature_flags": feature_flags,
            "feature_dim": data_exp.x.shape[1],
            "dropout": 0.1,
            "num_epochs": 300,
            "patience": 30,
            "lr": 0.001,
            "weight_decay": 5e-4,
            "class_weights": None  # explicitly note: unweighted
        },
        val_idx=val_idx
    )
# Out:
# Skipping config: base
# Skipping config: base
# Skipping config: base
# Skipping config: base
# Skipping config: base
# Skipping config: base+structural
# Skipping config: base+structural
# Skipping config: base+structural
# Skipping config: base+structural
# Skipping config: base+structural
# Skipping config: base+typology
# Skipping config: base+typology
# Skipping config: base+typology
# Skipping config: base+typology
# Skipping config: base+typology
# Skipping config: base+structural+typology
# Skipping config: base+structural+typology
# Skipping config: base+structural+typology
# Skipping config: base+structural+typology
# Skipping config: base+structural+typology
#
# === Training GCN (Random, No Class Weights): base+basic_temporal | Seed: 42 ===
# Epoch 001 | Loss: 7.8363 | Val Acc: 0.1780 | Val F1: 0.1779 | F1 Illicit: 0.1730
# Epoch 002 | Loss: 7.1464 | Val Acc: 0.2052 | Val F1: 0.2047 | F1 Illicit: 0.2234
# Epoch 003 | Loss: 6.4894 | Val Acc: 0.2351 | Val F1: 0.2328 | F1 Illicit: 0.2752
# Epoch 004 | Loss: 5.7785 | Val Acc: 0.2692 | Val F1: 0.2630 | F1 Illicit: 0.3305
# Epoch 263 | Loss: 0.1346 | Val Acc: 0.9538 | Val F1: 0.8531 | F1 Illicit: 0.9747
# Epoch 264 | Loss: 0.1332 | Val Acc: 0.9539 | Val F1: 0.8536 | F1 Illicit: 0.9748
# Epoch 265 | Loss: 0.1334 | Val Acc: 0.9538 | Val F1: 0.8531 | F1 Illicit: 0.9747
# Epoch 266 | Loss: 0.1321 | Val Acc: 0.9537 | Val F1: 0.8522 | F1 Illicit: 0.9747
# Epoch 267 | Loss: 0.1319 | Val Acc: 0.9536 | Val F1: 0.8523 | F1 Illicit: 0.9746
# Epoch 268 | Loss: 0.1334 | Val Acc: 0.9538 | Val F1: 0.8532 | F1 Illicit: 0.9747
# Epoch 269 | Loss: 0.1330 | Val Acc: 0.9538 | Val F1: 0.8535 | F1 Illicit: 0.9747
# Epoch 270 | Loss: 0.1328 | Val Acc: 0.9536 | Val F1: 0.8526 | F1 Illicit: 0.9746
# Epoch 271 | Loss: 0.1318 | Val Acc: 0.9536 | Val F1: 0.8528 | F1 Illicit: 0.9746
# Epoch 272 | Loss: 0.1311 | Val Acc: 0.9538 | Val F1: 0.8532 | F1 Illicit: 0.9747
# Epoch 273 | Loss: 0.1315 | Val Acc: 0.9537 | Val F1: 0.8528 | F1 Illicit: 0.9747
# Epoch 274 | Loss: 0.1307 | Val Acc: 0.9537 | Val F1: 0.8527 | F1 Illicit: 0.9747
# Epoch 275 | Loss: 0.1311 | Val Acc: 0.9537 | Val F1: 0.8528 | F1 Illicit: 0.9747
# Epoch 276 | Loss: 0.1311 | Val Acc: 0.9538 | Val F1: 0.8533 | F1 Illicit: 0.9747
# Epoch 277 | Loss: 0.1307 | Val Acc: 0.9539 | Val F1: 0.8533 | F1 Illicit: 0.9748
# Epoch 278 | Loss: 0.1301 | Val Acc: 0.9537 | Val F1: 0.8525 | F1 Illicit: 0.9747
# Epoch 279 | Loss: 0.1305 | Val Acc: 0.9538 | Val F1: 0.8533 | F1 Illicit: 0.9747
# Epoch 280 | Loss: 0.1304 | Val Acc: 0.9541 | Val F1: 0.8543 | F1 Illicit: 0.9749
# Epoch 281 | Loss: 0.1297 | Val Acc: 0.9542 | Val F1: 0.8547 | F1 Illicit: 0.9749
# Epoch 282 | Loss: 0.1309 | Val Acc: 0.9541 | Val F1: 0.8545 | F1 Illicit: 0.9749
# Epoch 283 | Loss: 0.1301 | Val Acc: 0.9538 | Val F1: 0.8533 | F1 Illicit: 0.9747
# Epoch 284 | Loss: 0.1285 | Val Acc: 0.9542 | Val F1: 0.8542 | F1 Illicit: 0.9749
# Epoch 285 | Loss: 0.1294 | Val Acc: 0.9543 | Val F1: 0.8547 | F1 Illicit: 0.9750
# Epoch 286 | Loss: 0.1294 | Val Acc: 0.9543 | Val F1: 0.8552 | F1 Illicit: 0.9750
# Epoch 287 | Loss: 0.1290 | Val Acc: 0.9545 | Val F1: 0.8563 | F1 Illicit: 0.9751
# Epoch 288 | Loss: 0.1300 | Val Acc: 0.9541 | Val F1: 0.8547 | F1 Illicit: 0.9749
# Epoch 289 | Loss: 0.1294 | Val Acc: 0.9542 | Val F1: 0.8551 | F1 Illicit: 0.9749
# Epoch 290 | Loss: 0.1284 | Val Acc: 0.9541 | Val F1: 0.8542 | F1 Illicit: 0.9749
# Epoch 291 | Loss: 0.1277 | Val Acc: 0.9543 | Val F1: 0.8547 | F1 Illicit: 0.9750
# Epoch 292 | Loss: 0.1280 | Val Acc: 0.9540 | Val F1: 0.8545 | F1 Illicit: 0.9748
# Epoch 293 | Loss: 0.1277 | Val Acc: 0.9543 | Val F1: 0.8556 | F1 Illicit: 0.9750
# Epoch 294 | Loss: 0.1271 | Val Acc: 0.9545 | Val F1: 0.8564 | F1 Illicit: 0.9751
# Epoch 295 | Loss: 0.1279 | Val Acc: 0.9545 | Val F1: 0.8560 | F1 Illicit: 0.9751
# Epoch 296 | Loss: 0.1276 | Val Acc: 0.9549 | Val F1: 0.8566 | F1 Illicit: 0.9753
# Epoch 297 | Loss: 0.1262 | Val Acc: 0.9548 | Val F1: 0.8567 | F1 Illicit: 0.9752
# Epoch 298 | Loss: 0.1260 | Val Acc: 0.9550 | Val F1: 0.8581 | F1 Illicit: 0.9753
# Epoch 299 | Loss: 0.1267 | Val Acc: 0.9550 | Val F1: 0.8584 | F1 Illicit: 0.9754
# Epoch 300 | Loss: 0.1276 | Val Acc: 0.9548 | Val F1: 0.8571 | F1 Illicit: 0.9752

# %% [markdown]
# ## 4. Evaluation

# %%
import os
import json
import torch

base_dir = "../model_features/randomsplit/GCN_ablation"
data_dir = "../data/GCN_randomsplit"
seeds = [42, 123, 777, 2023, 31415]

for ablation in sorted(os.listdir(base_dir)):
    ablation_model_path = os.path.join(base_dir, ablation)
    ablation_data_path = os.path.join(data_dir, ablation)

    if not os.path.isdir(ablation_model_path):
        continue

    print(f"\n→ Processing ablation: {ablation}")

    for seed in seeds:
        seed_dir = f"seed_{seed}"
        config_path = os.path.join(ablation_model_path, seed_dir, "config.json")
        model_path = os.path.join(ablation_model_path, seed_dir, "model.pth")
        data_path = os.path.join(ablation_data_path, seed_dir, "data_exp.pt")

        if not all(os.path.exists(p) for p in [config_path, model_path, data_path]):
            continue

        with open(config_path, "r") as f:
            config = json.load(f)

        updated = False
        data = torch.load(data_path, map_location="cpu", weights_only=False)
        feature_dim = data.x.shape[1]

        if config.get("feature_dim") != feature_dim:
            config["feature_dim"] = feature_dim
            updated = True

        if config.get("model") == "GCN":
            if config.get("hidden_channels") != 64:
                config["hidden_channels"] = 64
                updated = True
            if config.get("out_channels") != 2:
                config["out_channels"] = 2
                updated = True
            if config.get("dropout") != 0.1:
                config["dropout"] = 0.1
                updated = True

        if updated:
            with open(config_path, "w") as f:
                json.dump(config, f, indent=4)
            print(f"✓ Patched config for {ablation} / seed {seed}")
        else:
            print(f"✓ Already complete: {ablation} / seed {seed}")
# Out:
# → Processing ablation: all
# ✓ Patched config for all / seed 42
# ✓ Patched config for all / seed 123
# ✓ Patched config for all / seed 777
# ✓ Patched config for all / seed 2023
# ✓ Patched config for all / seed 31415
#
# → Processing ablation: base
# ✓ Patched config for base / seed 42
# ✓ Patched config for base / seed 123
# ✓ Patched config for base / seed 777
# ✓ Patched config for base / seed 2023
# ✓ Patched config for base / seed 31415
#
# → Processing ablation: base+basic_temporal
# ✓ Patched config for base+basic_temporal / seed 42
# ✓ Patched config for base+basic_temporal / seed 123
# ✓ Patched config for base+basic_temporal / seed 777
# ✓ Patched config for base+basic_temporal / seed 2023
# ✓ Patched config for base+basic_temporal / seed 31415
#
# → Processing ablation: base+basic_temporal+typology
# ✓ Patched config for base+basic_temporal+typology / seed 42
# ✓ Patched config for base+basic_temporal+typology / seed 123
# ✓ Patched config for base+basic_temporal+typology / seed 777
# ✓ Patched config for base+basic_temporal+typology / seed 2023
# ✓ Patched config for base+basic_temporal+typology / seed 31415
#
# → Processing ablation: base+structural
# ✓ Patched config for base+structural / seed 42
# ✓ Patched config for base+structural / seed 123
# ✓ Patched config for base+structural / seed 777
# ✓ Patched config for base+structural / seed 2023
# ✓ Patched config for base+structural / seed 31415
#
# → Processing ablation: base+structural+typology
# ✓ Patched config for base+structural+typology / seed 42
# ✓ Patched config for base+structural+typology / seed 123
# ✓ Patched config for base+structural+typology / seed 777
# ✓ Patched config for base+structural+typology / seed 2023
# ✓ Patched config for base+structural+typology / seed 31415
#
# → Processing ablation: base+typology
# ✓ Patched config for base+typology / seed 42
# ✓ Patched config for base+typology / seed 123
# ✓ Patched config for base+typology / seed 777
# ✓ Patched config for base+typology / seed 2023
# ✓ Patched config for base+typology / seed 31415

# %%
import os
from features.evaluate_ablation_model import evaluate_ablation_model
from evaluation_pipeline import run_inference_all_seeds
from analysis_utils import load_metrics_across_seeds, log_metrics_to_csv
from features.feature_utils import make_model_class_from_config

# === Config ===
seeds = [42, 123, 777, 2023, 31415]
base_dir = "../model_features/randomsplit/GCN_ablation"
data_exp_root = "../data/GCN_randomsplit"
node_id_csv_path = "../elliptic_bitcoin_dataset/elliptic_txs_features.csv"

model_tag = "GCN-Random"
split = "randomsplit"

# === Evaluate all ablations ===
for ablation in sorted(os.listdir(base_dir)):
    model_dir = os.path.join(base_dir, ablation)
    if not os.path.isdir(model_dir):
        continue

    print(f"\n→ Evaluating ablation: {ablation}")
    model_name = f"{model_tag}: {ablation}"
    ablation_data_dir = os.path.join(data_exp_root, ablation)
    config_path = os.path.join(model_dir, "seed_42", "config.json")
    model_class = make_model_class_from_config(config_path)

    # Run full evaluation
    evaluate_ablation_model(
        model_dir=model_dir,
        model_class=model_class,
        model_name=model_name,
        seeds=seeds,
        node_id_csv_path=node_id_csv_path,
        data_dir=ablation_data_dir
    )

    # Run inference (to extract structured metrics for CSV logging)
    y_true_all, y_pred_all, y_proba_all, seed_metrics = run_inference_all_seeds(
        model_dir=model_dir,
        model_class=model_class,
        data_dir=ablation_data_dir,
        seeds=seeds
    )
    val_acc_list = load_metrics_across_seeds(model_dir, ["val_acc"])["val_acc"]

    # Save to CSV
    log_metrics_to_csv(
        model_name=model_tag,
        split_name=split,
        ablation=ablation,
        seeds=seeds,
        val_acc_list=val_acc_list,
        seed_metrics=seed_metrics,
        is_feature=True  # ← optional flag to append _feature to filename
    )
